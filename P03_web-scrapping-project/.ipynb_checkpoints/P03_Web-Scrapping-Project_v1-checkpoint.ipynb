# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import re
import math

# %% [markdown]
# # DATA VIA WEB SCRAPPING

# %% [markdown]
# ## SEGUROS DE SAÚDE

# %%
# Connecting to ANS: 

ans = requests.get('http://www.dados.gov.br/organization/agencia-nacional-de-saude-suplementar-ans?page=1')
ans_soup = BeautifulSoup(ans.content)
ans.status_code
# Out:
# 200

# %%
# finding number of results and pages to scrap: 

results_text = ans_soup.find_all('h3')[0].text.strip()
result = re.findall('\d+', results_text)[0]

# rounding up to get number of pages: 
page_number = math.ceil(int(result)/20)
page_number
# Out:
# 3

# %%
# getting the links to all files

url = 'http://www.dados.gov.br/organization/agencia-nacional-de-saude-suplementar-ans?page='
file_links = get_file_link (url, page_number)
print(len(file_links))
file_links
# Out:
# 47
# ['http://www.dados.gov.br/dataset/indice-de-reclamacoes',
#  'http://www.dados.gov.br/dataset/dados-de-beneficiarios-por-regiao-geografica',
#  'http://www.dados.gov.br/dataset/programa-de-qualificacao-institucional',
#  'http://www.dados.gov.br/dataset/procedimentos-ambulatoriais-por-uf',
#  'http://www.dados.gov.br/dataset/procedimentos-hospitalares-por-uf',
#  'http://www.dados.gov.br/dataset/caderno-de-informacao',
#  'http://www.dados.gov.br/dataset/http-www-ans-gov-br-perfil-do-setor-dados-abertos-dados-abertos-disponiveis-n3',
#  'http://www.dados.gov.br/dataset/operadoras-e-prestadores-nao-hospitalares',
#  'http://www.dados.gov.br/dataset/glossario-da-saude-suplementar',
#  'http://www.dados.gov.br/dataset/produtos-e-prestadores-hospitalares',
#  'http://www.dados.gov.br/dataset/caracteristicas-dos-produtos-da-saude-suplementar',
#  'http://www.dados.gov.br/dataset/dados-de-pagamento-do-ressarcimento-ao-sus-por-operadora',
#  'http://www.dados.gov.br/dataset/dados-de-cobranca-e-arrecadacao-do-ressarcimento-ao-sus',
#  'http://www.dados.gov.br/dataset/historico-do-idss',
#  'http://www.dados.gov.br/dataset/terminologia-unificada-da-saude-suplementar-tuss',
#  'http://www.dados.gov.br/dataset/dados-gov-br-dataset-dados-de-beneficiarios-por-operadora',
#  'http://www.dados.gov.br/dataset/operadoras-de-planos-privados-de-saude',
#  'http://www.dados.gov.br/dataset/operadoras-de-planos-de-saude-com-registro-cancelado',
#  'http://www.dados.gov.br/dataset/demandas-dos-consumidores-nip',
#  'http://www.dados.gov.br/dataset/peona-sus',
#  'http://www.dados.gov.br/dataset/percentual-historico-de-cobranca-hc-do-ressarcimento-ao-sus',
#  'http://www.dados.gov.br/dataset/reajuste-de-planos-coletivos',
#  'http://www.dados.gov.br/dataset/penalidades-aplicadas-a-operadoras',
#  'http://www.dados.gov.br/dataset/historico-de-planos-de-saude',
#  'http://www.dados.gov.br/dataset/plano-anual-de-atividades-da-auditoria-interna-paint',
#  'http://www.dados.gov.br/dataset/fator-de-qualidade-profissionais-100',
#  'http://www.dados.gov.br/dataset/operadoras-acreditadas',
#  'http://www.dados.gov.br/dataset/informacoes-consolidadas-de-beneficiarios',
#  'http://www.dados.gov.br/dataset/fator-de-qualidade-hospitais-100',
#  'http://www.dados.gov.br/dataset/fator-de-qualidade-sadt-100',
#  'http://www.dados.gov.br/dataset/fator-de-qualidade-hospitais-105',
#  'http://www.dados.gov.br/dataset/fator-de-qualidade-profissionais-105',
#  'http://www.dados.gov.br/dataset/fator-de-qualidade-hospitais-dia-100',
#  'http://www.dados.gov.br/dataset/fator-de-qualidade-sadt-105',
#  'http://www.dados.gov.br/dataset/fator-de-qualidade-hospitais-dia-105',
#  'http://www.dados.gov.br/dataset/beneficiarios-com-vinculos-ativos-por-tipo-de-contratacao-para-calculo-da-vda',
#  'http://www.dados.gov.br/dataset/dados-do-ressarcimento-ao-sus-por-operadora-de-planos-de-saude',
#  'http://www.dados.gov.br/dataset/beneficiarios-identificados-sus-abi',
#  'http://www.dados.gov.br/dataset/taxa-de-cobertura-de-planos-de-saude',
#  'http://www.dados.gov.br/dataset/abrangencia-geografica-de-comercializacao-dos-planos-de-saude-ntrp',
#  'http://www.dados.gov.br/dataset/planos-de-saude-e-operadoras-ntrp',
#  'http://www.dados.gov.br/dataset/abrangencia-geografica-dos-planos-de-saude',
#  'http://www.dados.gov.br/dataset/percentual-de-finalizacao-assistencial-pfa',
#  'http://www.dados.gov.br/dataset/indice-de-abertura-de-processo-administrativo-iap',
#  'http://www.dados.gov.br/dataset/prestadores-acreditados',
#  'http://www.dados.gov.br/dataset/demandas-dos-consumidores-reclamacoes-de-beneficiarios',
#  'http://www.dados.gov.br/dataset/saude-suplementar']

# %%
# function that get file links from all pages:

def get_file_link (url: str, page_number: int) -> list:
    '''
    This function receives:
        - a url without the page number
        - the total number of pages to go forward
    it connects to all pages available in the url
    and outputs a list of links to all files in each page.
    
    example:
    inputs: 
        url = 'http://www.dados.gov.br/organization/agencia-nacional-de-saude-suplementar-ans?page='
        page_number = 3
    output:
        list with all the complete links to access files from the pages.
        
    '''
    list_pages = []
    list_links = []
    root = 'http://' + url.split('/')[2]
    
    for i in range(1, page_number+1):
        ans = requests.get(url+str(i))
        list_pages.append (BeautifulSoup(ans.content))

    for j in range(len(list_pages)):
        soup = list_pages[j].find_all('h3', attrs={'class':'dataset-heading'})
        for k in range(len(soup)):
            link = soup[k].find_all('a')[0]['href']
            list_links.append (root + link)
   
    return list_links

# %%
# filter only files related to 'plano', 'plano de saúde', 'beneficiário' or 'operadora':
filtered_list = [] 
pattern = ".*[Pp]lano.*|.*[Pp]lano.+[Ss]aúde.*|.*[Bb]enefici[áa]ri[oa].*|.*[Oo]peradora.*"

for file in file_links:
    file = re.findall(pattern, file)
    if len(file)>0:
        filtered_list.append(file[0])
print(len(filtered_list))
filtered_list
# Out:
# 20
# ['http://www.dados.gov.br/dataset/dados-de-beneficiarios-por-regiao-geografica',
#  'http://www.dados.gov.br/dataset/operadoras-e-prestadores-nao-hospitalares',
#  'http://www.dados.gov.br/dataset/dados-de-pagamento-do-ressarcimento-ao-sus-por-operadora',
#  'http://www.dados.gov.br/dataset/dados-gov-br-dataset-dados-de-beneficiarios-por-operadora',
#  'http://www.dados.gov.br/dataset/operadoras-de-planos-privados-de-saude',
#  'http://www.dados.gov.br/dataset/operadoras-de-planos-de-saude-com-registro-cancelado',
#  'http://www.dados.gov.br/dataset/reajuste-de-planos-coletivos',
#  'http://www.dados.gov.br/dataset/penalidades-aplicadas-a-operadoras',
#  'http://www.dados.gov.br/dataset/historico-de-planos-de-saude',
#  'http://www.dados.gov.br/dataset/plano-anual-de-atividades-da-auditoria-interna-paint',
#  'http://www.dados.gov.br/dataset/operadoras-acreditadas',
#  'http://www.dados.gov.br/dataset/informacoes-consolidadas-de-beneficiarios',
#  'http://www.dados.gov.br/dataset/beneficiarios-com-vinculos-ativos-por-tipo-de-contratacao-para-calculo-da-vda',
#  'http://www.dados.gov.br/dataset/dados-do-ressarcimento-ao-sus-por-operadora-de-planos-de-saude',
#  'http://www.dados.gov.br/dataset/beneficiarios-identificados-sus-abi',
#  'http://www.dados.gov.br/dataset/taxa-de-cobertura-de-planos-de-saude',
#  'http://www.dados.gov.br/dataset/abrangencia-geografica-de-comercializacao-dos-planos-de-saude-ntrp',
#  'http://www.dados.gov.br/dataset/planos-de-saude-e-operadoras-ntrp',
#  'http://www.dados.gov.br/dataset/abrangencia-geografica-dos-planos-de-saude',
#  'http://www.dados.gov.br/dataset/demandas-dos-consumidores-reclamacoes-de-beneficiarios']

# %%
# requesting every filtered link to get url to access file:

list_files = []

for url in filtered_list:
    soup = BeautifulSoup(requests.get(url).content)
    
for j in range(len(list_pages)):
    soup = list_pages[j].find_all('h3', attrs={'class':'dataset-heading'})
    for k in range(len(soup)):
        link = soup[k].find_all('a')[0]['href']
        list_links.append (root + link)

return list_links

# %%
filtered_list[0]
# Out:
# 'http://www.dados.gov.br/dataset/dados-de-beneficiarios-por-regiao-geografica'

# %%
soup = BeautifulSoup(requests.get(filtered_list[0]).content)
soup
# Out:
# <!DOCTYPE html>
# <!--[if IE 7]> <html lang="pt_BR" class="ie ie7"> <![endif]--><!--[if IE 8]> <html lang="pt_BR" class="ie ie8"> <![endif]--><!--[if IE 9]> <html lang="pt_BR" class="ie9"> <![endif]--><!--[if gt IE 8]><!--><html lang="pt_BR"> <!--<![endif]-->
# <head>
# <!--[if lte ie 8]><script type="text/javascript" src="/fanstatic/vendor/:version:2018-07-05T22:13:16/html5.min.js"></script><![endif]-->
# <link href="/fanstatic/vendor/:version:2018-07-05T22:13:16/select2/select2.css" rel="stylesheet" type="text/css"/>
# <link href="/fanstatic/css/:version:2018-07-05T22:13:16/main.min.css" rel="stylesheet" type="text/css"/>
# <link href="/fanstatic/vendor/:version:2018-07-05T22:13:16/font-awesome/css/font-awesome.min.css" rel="stylesheet" type="text/css"/>
# <!--[if ie 7]><link rel="stylesheet" type="text/css" href="/fanstatic/vendor/:version:2018-07-05T22:13:16/font-awesome/css/font-awesome-ie7.min.css" /><![endif]-->
# <link href="/fanstatic/ckanext-harvest/:version:2018-07-05T22:15:46/styles/harvest.css" rel="stylesheet" type="text/css"/>
# <meta charset="utf-8"/>
# <meta content="ckan 2.6.3" name="generator"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta name="description" value="O Portal Brasileiro de Dados Abertos (dados.gov.br) é o sítio eletrônico de referência para a busca e o acesso aos dados públicos, seus metadados, informações, aplicativos e serviços relacionados."/>
# <title>Dados de Beneficiários por Região Geográfica - Conjuntos de dados - Portal Brasileiro de Dados Abertos</title>
# <link href="/images/icons/ckan.ico" rel="shortcut icon"/>
# <!-- CSS Basic UI - Governo Brasileiro -->
# <link href="/css/application.css" rel="stylesheet"/>
# <!-- CSS Bootstrap 3 - Grid and Responsive -->
# <link href="/css/bootstrap3-grid.min.css" rel="stylesheet"/>
# <link href="/css/bootstrap3-responsive.min.css" rel="stylesheet"/>
# <!-- JS jQuery 3 -->
# <script src="https://code.jquery.com/jquery-3.2.1.min.js"></script>
# <!-- Semantic UI -->
# <link href="https://cdnjs.cloudflare.com/ajax/libs/semantic-ui/2.2.10/semantic.min.css" rel="stylesheet"/>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/semantic-ui/2.2.10/semantic.min.js"></script>
# <!-- CSS Main CSS - dados.gov.br -->
# <link href="/css/extra.min.css" rel="stylesheet"/>
# <!-- CSS Font Awesome -->
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" integrity="sha384-wvfXpqpZZVQGK6TAh5PVlGOfQNHSoD2xbE+QkPxCAFlNEevoEH3Sl0sibVcOQVnN" rel="stylesheet"/>
# <!-- Favicon -->
# <link href="/img/favicon/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/img/favicon/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/img/favicon/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/img/favicon/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/img/favicon/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/img/favicon/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/img/favicon/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/img/favicon/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/img/favicon/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/img/favicon/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/img/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/img/favicon/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/img/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/img/favicon/manifest.json" rel="manifest"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="/ms-icon-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="Dados de Beneficiários por Região Geográfica - Portal Brasileiro de Dados Abertos" property="og:title"/>
# <meta content="Quantidade de beneficiários por UF, Região Metropolitana e capital." property="og:description"/>
# </head>
# <body data-locale-root="http://dados.gov.br/" data-site-root="http://dados.gov.br/">
# <div class="hide"><a href="#content">Pular para o conteúdo</a></div>
# <div id="barra-brasil">
# <a href="http://brasil.gov.br" style="background:#7F7F7F; height: 20px; padding:4px 0 4px 10px; display: block; font-family:sans,sans-serif; text-decoration:none; color:white; ">Portal do Governo Brasileiro</a>
# </div>
# <header class="masthead">
# <div class="container">
# <ul id="accessibility">
# <li>
# <a accesskey="1" href="#content" id="link-conteudo">
#           Ir para o conteúdo
#           <span>1</span>
# </a>
# </li>
# <li>
# <a accesskey="2" href="#menu-horizontal" id="link-navegacao">
#           Ir para o menu
#           <span>2</span>
# </a>
# </li>
# <li>
# <a accesskey="3" href="#search" id="link-buscar">
#           Ir para a busca
#           <span>3</span>
# </a>
# </li>
# <li>
# <a accesskey="4" href="#footer" id="link-rodape" onclick="window.scrollTo(0,document.body.scrollHeight)">
#           Ir para o rodapé
#           <span>4</span>
# </a>
# </li>
# </ul>
# <hgroup class="header-text-logo-tagline" id="site_logo">
# <h1>
# <a href="/" title="Portal Brasileiro de Dados Abertos"><span id="portal-title">dados.gov.br</span></a>
# </h1>
# <h2><span id="portal-description">Portal Brasileiro de Dados Abertos</span></h2>
# </hgroup>
# <form action="/dataset" class="search-form" data-module="select-switch" method="get">
# <div class="search-input control-group">
# <input autocomplete="off" class="search" name="q" placeholder="Pesquisar conjuntos de dados..." type="text" value=""/>
# <button type="submit" value="search">
# <i class="icon-search"></i>
# <span>Enviar</span>
# </button>
# </div>
# </form>
# <ul id="news">
# <li id="feed"><a href="/feed/" rel="feed" title="Inscrever-se no feed de notícias">feed</a></li>
# <li id="twitter"><a href="http://twitter.com/dadosgovbr" title="Microblog no Twitter">twitter</a></li>
# <li id="github"><a href="https://github.com/dadosgovbr" title="Códigos fonte de projetos do dados.gov.br no Github">Códigos fonte de projetos do dados.gov.br no Github</a></li>
# </ul>
# <div class="content hidden">
# <form action="/dataset" class="section site-search simple-input" method="get">
# <div class="field">
# <label for="field-sitewide-search">Buscar conjunto de dados</label>
# <input id="field-sitewide-search" name="q" placeholder="Pesquisar conjuntos de dados..." type="text"/>
# <button class="btn-search" type="submit"><i class="icon-search"></i></button>
# </div>
# </form>
# </div>
# </div>
# <div id="barra-menu">
# </div>
# <nav class="section navigation" id="menu-horizontal">
# <ul class="barra-apoio">
# <li class="first link-dados"><a href="/dataset/">Dados</a></li>
# <li class="link-organizacoes"><a href="/organization/">Organizações</a></li>
# <!--<li class="link-aplicativos"><a href="/pagina/aplicativos/">Aplicativos</a></li>-->
# <li class="link-aplicativos"><a href="/aplicativos/">Aplicativos</a></li>
# <li class="link-inventarios"><a href="/inventarios/">Inventários</a></li>
# <li class="link-concursos"><a href="/concursos/">Concursos</a></li>
# <li class="link-wiki"><a href="http://wiki.dados.gov.br/"><abbr style="border: none;" title="Infraestrutura Nacional de Dados Abertos">INDA</abbr></a></li>
# <li class="link-perguntas-frequentes"><a href="/pagina/faq/">Perguntas frequentes</a></li>
# <li class="link-contato"><a href="/pagina/contato/">Contato</a></li>
# <li class="link-sobre"><a href="/pagina/sobre/">Sobre o portal</a></li>
# </ul>
# </nav>
# </header>
# <div role="main">
# <div class="container" id="content">
# <div class="flash-messages">
# </div>
# <div class="toolbar">
# <ol class="breadcrumb">
# <li class="home"><a href="/"><i class="icon-home"></i><span> Início</span></a></li>
# <li><a href="/organization">Organizações</a></li>
# <li><a href="/organization/agencia-nacional-de-saude-suplementar-ans">Agência Nacional de Saúde ...</a></li>
# <li class="active"><a class="active" href="/dataset/dados-de-beneficiarios-por-regiao-geografica">Dados de Beneficiários por ...</a></li>
# </ol>
# </div>
# <div class="row wrapper">
# <div class="primary span9">
# <article class="module">
# <header class="module-content page-header">
# <ul class="nav nav-tabs">
# <li class="active"><a href="/dataset/dados-de-beneficiarios-por-regiao-geografica"><i class="icon-sitemap"></i> Conjunto de dados</a></li>
# <li><a href="/dataset/groups/dados-de-beneficiarios-por-regiao-geografica"><i class="icon-group"></i> Grupos</a></li>
# <li><a href="/dataset/activity/dados-de-beneficiarios-por-regiao-geografica"><i class="icon-time"></i> Fluxo de Atividades</a></li>
# </ul>
# </header>
# <div class="module-content">
# <h1>
#
#           Dados de Beneficiários por Região Geográfica
#
#
#
#       </h1>
# <hr/>
# <div class="notes embedded-content">
# <p>Quantidade de beneficiários por UF, Região Metropolitana e capital.</p>
# </div>
# <span class="insert-comment-thread"></span>
# <br/>
# <section class="tags">
# <ul class="tag-list well">
# <li>
# <a class="tag" href="/dataset?tags=ANS">ANS</a>
# </li>
# <li>
# <a class="tag" href="/dataset?tags=Ag%C3%AAncia+Nacional+de+Sa%C3%BAde+Suplementar">Agência Nacional de...</a>
# </li>
# <li>
# <a class="tag" href="/dataset?tags=Assist%C3%AAncia+%C3%A0+sa%C3%BAde">Assistência à saúde</a>
# </li>
# <li>
# <a class="tag" href="/dataset?tags=benefici%C3%A1rios+de+plano+de+sa%C3%BAde">beneficiários de pl...</a>
# </li>
# </ul>
# </section>
# <script>
#         // Set new URL for tags based on package type
#         (function() {
#         $('.tags .tag').each(function(){
#             var new_url = $(this).attr('href').replace('/dataset?', '/dataset?');
#             $(this).attr('href', new_url);
#             //console.log(new_url);
#         });
#         })();
#     </script>
# <span class="hidden" id="package_id">fbea8c97-bef5-4bda-b73a-9d4ffe441e92</span>
# <span class="hidden" id="package_name">dados-de-beneficiarios-por-regiao-geografica</span>
# <span class="hidden" id="package_siorg">45013</span>
# <div class="ui blurring segment" id="feedback-eouv">
# <!-- Botões principais -->
# <div class="ui basic center" style="text-align:center;">
# <h4 class="ui header msg-title">Estes dados estão disponíveis como o esperado?</h4>
# <div class="ui labeled buttons">
# <button class="ui labeled button sim" tabindex="0">
# <a class="ui basic green right pointing label" id="ouv_like_counter" style="min-height: 36px; border-radius: 5px 0 0 5px;">
#           11
#         </a>
# <div class="ui green button">
# <i class="thumbs up chevron icon"></i> Sim
#         </div>
# </button>
# <div class="or" data-text="ou"></div>
# <button class="ui labeled button nao" tabindex="0">
# <div class="ui orange button" style="border-radius: 0;">
# <i class="thumbs down chevron icon"></i> Não
#         </div>
# <a class="ui basic orange left pointing label" id="ouv_dislike_counter" style="min-height: 36px; border-radius: 0 5px 5px 0;">
#           15
#         </a>
# </button>
# </div>
# </div>
# <!-- Formulário / Ouvidoria -->
# <div class="dimmable form-problems" style="display:none;">
# <hr/>
# <h4 align="justify" class="ui header msg-error" style="display:none;">Desculpe-nos. Verifique se a solução para o seu problema está na relação de <a href="/pagina/faq-dataset" style="color:#769F29;">perguntas frequentes</a>. Diga-nos o motivo para que possamos buscar uma solução.</h4>
# <div style="padding: 10px; position: relative;">
# <form class="ui reply form" id="form_eouv">
# <div class="checkbox-group required">
# <div class="ui inline checkbox">
# <input name="eouv-motivo-1" tabindex="1" type="checkbox"/>
# <label name="eouv-motivo-1" style="z-index: 4;">Os dados estão desatualizados.</label>
# </div>
# <div class="ui inline checkbox">
# <input name="eouv-motivo-2" tabindex="2" type="checkbox"/>
# <label name="eouv-motivo-2" style="z-index: 4;">Não consegui acessar o conjunto de dados(especifique o recurso).</label>
# </div>
# <div class="ui inline checkbox">
# <input name="eouv-motivo-3" tabindex="3" type="checkbox"/>
# <label name="eouv-motivo-3" style="z-index: 4;">Documentação insuficiente para compreender o conjunto de dados.</label>
# </div>
# <div class="ui inline checkbox">
# <input name="eouv-motivo-4" tabindex="4" type="checkbox"/>
# <label name="eouv-motivo-4" style="z-index: 4;">Os dados contém erro ou inconsistência.</label>
# </div>
# <div class="ui attached field" style="padding-top: 12px;">
# <label for="eouv-text">Descreva a situação encontrada</label>
# <textarea id="situacao_encontrada" name="eouv-text" style="margin-bottom: 16px;" tabindex="5"></textarea>
# </div>
# </div>
# <!-- Campos opcionais -->
# <div class="botao_campos_opcionais">
# <div class="ui segment">
# <div class="field">
# <div class="ui checkbox mostrar_campos_opcionais">
# <input name="ser_identificado" tabindex="6" type="checkbox"/>
# <label align="justify" for="ser_identificado" style="z-index: 4;">Sua avaliação será enviada para o sistema de Ouvidoria e-Ouv como uma reclamação. Clique aqui caso queira acompanhar seu andamento.</label>
# </div>
# </div>
# </div>
# </div>
# <div class="campos_opcionais" style="display:none;">
# <hr/>
# <div class="field">
# <label>Nome</label>
# <input name="eouv-name" placeholder="" tabindex="7" type="text"/>
# </div>
# <div class="field">
# <label>Email</label>
# <input name="eouv-email" placeholder="" tabindex="8" type="email"/>
# </div>
# <!--<div class="field">
#               <div class="ui checkbox">
#                 <input type="checkbox" class="hidden" name="eouv-receber-email" tabindex="0">
#                 <label>Desejo receber email para acompanhar o relato.</label>
#               </div>
#             </div>-->
# </div>
# <hr/>
# <div id="submit">
# <button class="ui button enviar" tabindex="9" type="submit">Enviar manifestação para ouvidoria</button>
# <button class="ui loading button carregando" style="display:none">Carregando</button>
# </div>
# <div data-position="bottom left" data-tooltip="Por favor, selecione pelo menos um dos motivos e/ou descreva a situação encontrada" id="submit_block">
# <button class="ui disabled button">Enviar manifestação para ouvidoria</button>
# </div>
# </form>
# </div>
# </div>
# <!-- Mensagem / Enviado com sucesso -->
# <div class="ui inverted dimmer transition">
# <div class="content">
# <div class="center">
# <h2 class="ui icon header">
# <i class="checkmark icon" style="display:none;"></i>
# <span class="msg">Obrigado!</span>
# </h2>
# </div>
# </div>
# </div>
# </div>
# <script>
# $(document).ready(function(){
#   var eouv = $("#feedback-eouv");
#
#
#   // function Rebuild tabindex
#   // ==============================================
#   function rebuildTabindex () {
#     var tabindex = 1;
#     $('input,select').each(function() {
#         if (this.type != "hidden") {
#             var $input = $(this);
#             $input.attr("tabindex", tabindex);
#             tabindex++;
#         }
#     });
#   }
#
#   // function verifica se pelo menos um checkbox foi selecionado e/ou situacao encontrada foi preenchida
#   // caso esteja prenchida, o botão enviar manifestação é ativado. Caso contrario é exibido o botão desativado.
#   // ==============================================
#   function verifica_campos_nulos () {
#     var info_adicionais = form_eouv.situacao_encontrada.value;
#     if(($('div.checkbox-group.required :checkbox:checked').length > 0)||(info_adicionais != "")){
#       $("#submit_block").hide();
#       $("#submit").show();
#     }else{
#       $("#submit").hide();
#       $("#submit_block").show();
#     }
#   }
#   $('div.checkbox-group.required').get()[0].addEventListener('change', verifica_campos_nulos);
#   document.getElementById('situacao_encontrada').addEventListener("keyup", verifica_campos_nulos);
#   $('div.checkbox-group.required').click(function() {
#     setTimeout(verifica_campos_nulos, 80);
#   });
#
#   // function Mostrar campos opcionais
#   // ==============================================
#   function campos_opcionais_atualizar () {
#     if($('.mostrar_campos_opcionais input').is(":checked"))
#       $('.campos_opcionais').show();
#     else
#       $('.campos_opcionais').hide();
#   }
#   $('.mostrar_campos_opcionais input').get()[0].addEventListener('change', campos_opcionais_atualizar);
#   $('.mostrar_campos_opcionais').click(function() {
#     setTimeout(campos_opcionais_atualizar, 80);
#   });
#
#
#   // ==============================================
#   // Se avaliar como "Sim"
#   // ==============================================
#   eouv.find(".sim").on("click", function(){
#     eouv.find(".msg").html("Obrigado!<br>Sua avaliação foi contabilizada.");
#     eouv.find('.dimmer').addClass('active');
#
#
#     var data_eouv = {
#       package_id: $('#package_id').html(),
#       package_name: $('#package_name').html()
#     }
#
#     // Envia requisição
#     $.ajax({ url      : "/eouv/new_positive",
#              type     : 'POST',
#              data     : data_eouv,
#              dataType : 'xml'
#           })
#
#       // Sucesso na requisição
#       .done(function( data ) {
#         console.log(data);
#       });
#   });
#
#
#   // ==============================================
#   // Se avaliar como "Não"
#   // ==============================================
#   eouv.find(".nao").on("click", function(){
#     eouv.find(".form-problems").show();
#     eouv.find(".sim").removeClass("sim").addClass("disabled");
#     eouv.addClass("red").removeClass("green");
#     eouv.find(".msg-title").html('');
#     eouv.find(".msg-error").show();
#     $("#submit").hide();
#   });
#
#   // Enviar problema para ouvidoria
#   eouv.find('form').submit(function(event) {
#     event.preventDefault();
#     eouv.find('.enviar').hide();
#     eouv.find('.carregando').show();
#
#
#     // Msg Sucesso
#     // ==============================================
#     function msg_sucesso () {
#         eouv.find("i.checkmark").show(); // Exibe ícone
#         eouv.removeClass("red"); // Remove top border
#         eouv.find(".msg").html("Sua manifestação foi enviada para o Sistema de Ouvidoria <br>e-Ouv.<br>Protocolo: <span class='protocolo'></span>");
#         eouv.find('.dimmer').addClass('active');
#     }
#
#     // Msg Erro
#     // ==============================================
#     function msg_erro () {
#         eouv.find("i.checkmark").show().removeClass('checkmark').addClass('warning sign red'); // Exibe ícone
#         eouv.removeClass("red"); // Remove top border
#         eouv.find(".msg").html("Erro ao enviar sua mensagem para a ouvidoria.<br>Por favor, tente mais tarde.");
#         eouv.find('.dimmer').addClass('active');
#     }
#
#     // ==============================================
#     // Conteúdo a ser enviado para o server
#     // ==============================================
#     var data_eouv_text = "";
#     $('input[name^=eouv-motivo-]').each(function() {
#       if ($(this).is(":checked")) {
#         data_eouv_text += "- "+$(this).parent().find('label').html();
#         data_eouv_text += "\n";
#       }
#     });
#     if(data_eouv_text.length > 0){
#       data_eouv_text = 'Opções marcadas:\n'+data_eouv_text
#     }
#     if($('textarea[name=eouv-text]').val().length > 0){
#       data_eouv_text += "\nDescrição da manifestação:\n"+$('textarea[name=eouv-text]').val();
#     }
#
#     $('input[name^=eouv-name]')
#     $('input[name^=eouv-email]')
#     $('input[name^=eouv-receber-email]')
#
#     var data_eouv = {
#       package_id: $('#package_id').html(),
#       package_name: $('#package_name').html(),
#       siorg: $('#package_siorg').html(),
#       text: data_eouv_text,
#       name: $('input[name^=eouv-name]').val(),
#       email: $('input[name^=eouv-email]').val(),
#       receber_email: +$('input[name^=eouv-receber-email]').is(":checked")
#     }
#
#     // Função que converte xml em JSON para tratar o resultado da manifestação
#     xmlToJson = function(xml) {
#       var obj = {};
#       if (xml.nodeType == 1) {
#           if (xml.attributes.length > 0) {
#               obj["@attributes"] = {};
#               for (var j = 0; j < xml.attributes.length; j++) {
#                   var attribute = xml.attributes.item(j);
#                   obj["@attributes"][attribute.nodeName] = attribute.nodeValue;
#               }
#           }
#       } else if (xml.nodeType == 3) {
#           obj = xml.nodeValue;
#       }
#       if (xml.hasChildNodes()) {
#           for (var i = 0; i < xml.childNodes.length; i++) {
#               var item = xml.childNodes.item(i);
#               var nodeName = item.nodeName;
#               if (typeof (obj[nodeName]) == "undefined") {
#                   obj[nodeName] = xmlToJson(item);
#               } else {
#                   if (typeof (obj[nodeName].push) == "undefined") {
#                       var old = obj[nodeName];
#                       obj[nodeName] = [];
#                       obj[nodeName].push(old);
#                   }
#                   obj[nodeName].push(xmlToJson(item));
#               }
#           }
#       }
#       return obj;
#     }
#
#     // DEBUG
#     console.log(data_eouv);
#
#     // Envia requisição
#     $.ajax({ url      : "/eouv/new_negative",
#              type     : 'POST',
#              data     : data_eouv,
#              dataType : 'text'
#           })
#
#       // Sucesso na requisição
#       .done(function( data ) {
#         console.log(data);
#         var xmlDoc = $.parseXML(data);
#
#         dataJson = JSON.stringify(xmlToJson(xmlDoc));
#
#         var objJSON = JSON.parse(dataJson);
#
#         Protocolo = objJSON["s:Envelope"]["s:Body"].RegistrarManifestacaoTerceiroResponse.RegistrarManifestacaoTerceiroResult["a:Protocolo"]["#text"];
#
#         CodigoErro = objJSON["s:Envelope"]["s:Body"].RegistrarManifestacaoTerceiroResponse.RegistrarManifestacaoTerceiroResult["a:CodigoErro"]["#text"]
#
#         // Exibe botão de submit de novo
#         eouv.find('.enviar').show();
#         eouv.find('.carregando').hide();
#
#         // Servidor retornou com sucesso
#         if (CodigoErro == 0) {
#           msg_sucesso();
#           eouv.find(".protocolo").html(Protocolo)
#         }
#
#         // Servidor retornou com erro
#         else {
#           msg_erro();
#         }
#       })
#
#       // Erro na requisição
#       .fail(function( data ) {
#         // Exibe botão de submit de novo
#         eouv.find('.enviar').show();
#         eouv.find('.carregando').hide();
#
#         msg_erro();
#       });
#
#   });
#
#
#
#   // ==============================================
#   // Semantic UI - FIX checkbox
#   // ==============================================
#   $('.ui.checkbox').click(function() {
#     var checkbox_field = $(this).find('input');
#     var checked = !checkbox_field.is(":checked");
#     checkbox_field.prop('checked', checked);
#   });
#   $('.ui.checkbox').bind('keypress', function(e) {
#     if (e.which == 32){ // Spacebar press
#       var checkbox_field = $(this).find('input');
#       var checked = !checkbox_field.is(":checked");
#       checkbox_field.prop('checked', checked);
#     }
#   });
# });
# </script>
# <hr/>
# <section class="resources" id="dataset-resources">
# <h3>Dados e recursos</h3>
# <ul class="resource-list">
# <li class="resource-item" data-id="069f7f06-0e8e-4018-8da1-010a9899bdec">
# <a class="heading" href="/dataset/dados-de-beneficiarios-por-regiao-geografica/resource/069f7f06-0e8e-4018-8da1-010a9899bdec" title="Dados _ Beneficiários por região geográfica">
#     Dados _ Beneficiários por região geográfica<span class="format-label" data-format="zip+csv" property="dc:format">zip+csv</span>
# </a>
# <p class="description">
# </p>
# <div class="dropdown btn-group">
# <a class="btn btn-primary dropdown-toggle" data-toggle="dropdown" href="#">
# <i class="icon-share-alt"></i>
#       Explorar
#       <span class="caret"></span>
# </a>
# <ul class="dropdown-menu">
# <li>
# <a href="/dataset/dados-de-beneficiarios-por-regiao-geografica/resource/069f7f06-0e8e-4018-8da1-010a9899bdec">
# <i class="icon-info-sign"></i>
#             Mais informações
#
#         </a>
# </li>
# <li>
# <a class="resource-url-analytics" href="http://ftp.dadosabertos.ans.gov.br/FTP/PDA/dados_de_beneficiarios_por_regiao_geografica/benef_regiao_geog.zip" target="_blank">
# <i class="icon-external-link"></i>
#             Ir para recurso
#
#         </a>
# </li>
# </ul>
# </div>
# </li>
# <li class="resource-item" data-id="8cabcd0d-3191-44e7-a113-2c890beada61">
# <a class="heading" href="/dataset/dados-de-beneficiarios-por-regiao-geografica/resource/8cabcd0d-3191-44e7-a113-2c890beada61" title="Dicionário de dados_ Beneficiários por região geográfica">
#     Dicionário de dados_ Beneficiários por região ...<span class="format-label" data-format="pdf" property="dc:format">PDF</span>
# </a>
# <p class="description">
# </p>
# <div class="dropdown btn-group">
# <a class="btn btn-primary dropdown-toggle" data-toggle="dropdown" href="#">
# <i class="icon-share-alt"></i>
#       Explorar
#       <span class="caret"></span>
# </a>
# <ul class="dropdown-menu">
# <li>
# <a href="/dataset/dados-de-beneficiarios-por-regiao-geografica/resource/8cabcd0d-3191-44e7-a113-2c890beada61">
# <i class="icon-info-sign"></i>
#             Mais informações
#
#         </a>
# </li>
# <li>
# <a class="resource-url-analytics" href="http://ftp.dadosabertos.ans.gov.br/FTP/PDA/dados_de_beneficiarios_por_regiao_geografica/dicionario_de_dados_beneficiarios_por_regiao_geografica.pdf" target="_blank">
# <i class="icon-external-link"></i>
#             Ir para recurso
#
#         </a>
# </li>
# </ul>
# </div>
# </li>
# </ul>
# </section>
# <hr/>
# <section class="additional-info">
# <h3>Informações Adicionais</h3>
# <table class="table table-striped table-bordered table-condensed">
# <thead>
# <tr>
# <th scope="col">Campo</th>
# <th scope="col">Valor</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th class="dataset-label" scope="row">Fonte</th>
# <td class="dataset-details" property="foaf:homepage">Sistema de Informações de Beneficiários de Plano de Saúde</td>
# </tr>
# <tr>
# <th class="dataset-label" scope="row">Autor</th>
# <td class="dataset-details" property="dc:creator"><a href="mailto:dadosabertos@ans.gov.br">Diretoria de Desenvolvimento Setorial (DIDES)</a></td>
# </tr>
# <tr>
# <th class="dataset-label" scope="row">Mantenedor</th>
# <td class="dataset-details" property="dc:contributor"><a href="mailto:dadosabertos@ans.gov.br">Diretoria de Desenvolvimento Setorial (DIDES)</a></td>
# </tr>
# <tr>
# <th class="dataset-label" scope="row">Última Atualização</th>
# <td class="dataset-details">
# <span class="automatic-local-datetime" data-datetime="2020-03-20T18:04:30-0300">
#     20 de Março de 2020, 18:04 (BRT)
# </span>
# </td>
# </tr>
# <tr>
# <th class="dataset-label" scope="row">Criado</th>
# <td class="dataset-details">
# <span class="automatic-local-datetime" data-datetime="2017-11-09T16:39:30-0200">
#     9 de Novembro de 2017, 16:39 (BRST)
# </span>
# </td>
# </tr>
# <tr rel="dc:relation" resource="_:extra">
# <th class="dataset-label" property="rdfs:label" scope="row">Contato</th>
# <td class="dataset-details" property="rdf:value"> dadosabertos@ans.gov.br</td>
# </tr>
# <tr rel="dc:relation" resource="_:extra">
# <th class="dataset-label" property="rdfs:label" scope="row">Escopo Geopolítico</th>
# <td class="dataset-details" property="rdf:value">Nacional</td>
# </tr>
# <tr rel="dc:relation" resource="_:extra">
# <th class="dataset-label" property="rdfs:label" scope="row">Idioma </th>
# <td class="dataset-details" property="rdf:value">Português</td>
# </tr>
# <tr rel="dc:relation" resource="_:extra">
# <th class="dataset-label" property="rdfs:label" scope="row">Periodicidade de Atualização</th>
# <td class="dataset-details" property="rdf:value">Trimestral</td>
# </tr>
# <tr rel="dc:relation" resource="_:extra">
# <th class="dataset-label" property="rdfs:label" scope="row">Sistema de referência</th>
# <td class="dataset-details" property="rdf:value">Sistema de Informação de Beneficiários (SIB)</td>
# </tr>
# <tr rel="dc:relation" resource="_:extra">
# <th class="dataset-label" property="rdfs:label" scope="row">dados atualizados até</th>
# <td class="dataset-details" property="rdf:value">últimos 12 meses</td>
# </tr>
# </tbody>
# </table>
# </section>
# </div>
# </article>
# </div>
# <aside class="secondary span3">
# <section class="module module-narrow">
# <div class="module context-info">
# <div class="module-content">
# <h1 class="heading">Dados de Beneficiários por Região Geográfica</h1>
# <div class="nums">
# <dl>
# <dt>Seguidores</dt>
# <dd><span>0</span></dd>
# </dl>
# </div>
# <div class="follow_button">
# </div>
# </div>
# </div>
# </section>
# <div class="module module-narrow module-shallow context-info">
# <h2 class="module-heading"><i class="fa fa-building-o"></i> Organização</h2>
# <section class="module-content">
# <div class="image">
# <a href="/organization/agencia-nacional-de-saude-suplementar-ans">
# <img alt="agencia-nacional-de-saude-suplementar-ans" src="http://dados.gov.br/wp/wp-content/uploads/2016/03/logo_ANS.png" width="200"/>
# </a>
# </div>
# <h1 class="heading">Agência Nacional de Saúde Suplementar - ANS
#
#           </h1>
# <p>
#               A Agência Nacional de Saúde Suplementar (ANS) é a agência reguladora vinculada ao Ministério da Saúde responsável pelo setor de planos de saúde no Brasil.
#               <a href="/organization/about/agencia-nacional-de-saude-suplementar-ans">Leia mais</a>
# </p>
# </section>
# </div>
# <section class="module module-narrow social">
# <h2 class="module-heading"><i class="icon-medium icon-share"></i> Social</h2>
# <ul class="nav nav-simple">
# <li class="nav-item"><a href="https://plus.google.com/share?url=http://dados.gov.br/dataset/dados-de-beneficiarios-por-regiao-geografica" target="_blank"><i class="icon-google-plus-sign"></i> Google+</a></li>
# <li class="nav-item"><a href="https://twitter.com/share?url=http://dados.gov.br/dataset/dados-de-beneficiarios-por-regiao-geografica" target="_blank"><i class="icon-twitter-sign"></i> Twitter</a></li>
# <li class="nav-item"><a href="https://www.facebook.com/sharer.php?u=http://dados.gov.br/dataset/dados-de-beneficiarios-por-regiao-geografica" target="_blank"><i class="icon-facebook-sign"></i> Facebook</a></li>
# </ul>
# </section>
# <section class="module module-narrow module-shallow license">
# <h2 class="module-heading"><i class="icon-medium icon-lock"></i> Licença</h2>
# <p class="module-content">
# <a href="http://www.opendefinition.org/licenses/cc-by" rel="dc:rights">Creative Commons Attribution</a>
# <a href="http://opendefinition.org/okd/" title="Este conjunto de dados satisfaz a Definição de Aberto - Open Definition.">
# <img alt="[Open Data]" class="open-data" src="/base/images/od_80x15_blue.png"/>
# </a>
# </p>
# </section>
# </aside>
# </div>
# </div>
# </div>
# <div class="container">
# <div class="footer outer">
# <div class="footer inner bs3">
# <footer>
# <!-- Navegação do Rodapé -->
# <div class="row">
# <div class="col-sm-6 col-md-3" id="portal">
# <h3> O Portal </h3>
# <ul>
# <li>
# <a href="/dataset/"> Catálogo </a>
# </li>
# <li>
# <a href="/organization/"> Organizações </a>
# </li>
# <li>
# <a href="/pagina/cadastrar-organizacao/"> Catalogue seus dados </a>
# </li>
# <li>
# <a href="/pagina/mapa-do-site/"> Mapa do site </a>
# </li>
# <li>
# <a href="/pagina/sobre/"> Sobre o portal </a>
# </li>
# <li>
# <a href="/pagina/faq/"> Perguntas frequentes </a>
# </li>
# <li>
# <a href="/pagina/dev/"> Desenvolvimento do portal </a>
# </li>
# <li>
# <a href="/pagina/agradecimentos/"> Agradecimentos </a>
# </li>
# </ul>
# </div>
# <div class="col-sm-6 col-md-3" id="comunidade">
# <h3> Comunidade </h3>
# <ul>
# <li>
# <a href="/pagina/comunidade"> Comunidades </a>
# </li>
# <li>
# <a href="http://twitter.com/dadosgovbr" target="_blank"> Twitter </a>
# </li>
# <li>
# <a href="http://identi.ca/dadosgovbr" target="_blank"> Identi.ca </a>
# </li>
# <li>
# <a href="https://groups.google.com/forum/#!forum/inda-br" target="_blank"> Lista de discussão </a>
# </li>
# <li>
# <a href="/pagina/ferramentas-colaboracao/"> Ferramentas de colaboração </a>
# </li>
# <li>
# <a href="/revision/list"> Últimas alterações </a>
# </li>
# <li>
# <a href="/pagina/sugira-dados/"> Sugira dados </a>
# </li>
# <li>
# <a href="/pagina/agenda/"> Agenda </a>
# </li>
# <li>
# <a href="/pagina/contato/"> Sugestões </a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 visible-sm" style="text-align: center">
# <hr class="divisor"/>
# </div>
# <div class="col-sm-6 col-md-3" id="manuais">
# <h3> Manuais </h3>
# <ul>
# <li>
# <a href="/pagina/cartilha-publicacao-dados-abertos/"> Cartilha de publicação de dados </a>
# </li>
# <li>
# <a href="http://wiki.gtinda.ibge.gov.br/GetFile.aspx?File=%2fGT3-Tecnologia%2fArquitetura%20Tecnica%20Referencial%20de%20Abertura%20de%20Dados%20v1%20edicao_duke.odt" target="_blank"> Arquitetura Técnica Referencial </a>
# </li>
# <li>
# <a href="http://wiki.dados.gov.br/Capacitacao-para-Catalogacao-de-Dados.ashx" target="_blank">Manual de Catalogação</a>
# </li>
# <li>
# <a href="http://www.w3c.br/pub/Materiais/PublicacoesW3C/Manual_Dados_Abertos_WEB.pdf" target="_blank"> Manual de Dados Abertos <abbr title="World Wide Web Consortium">W3C</abbr></a>
# </li>
# <li>
# <a href="http://www.w3c.br/pub/Materiais/PublicacoesW3C/manual_dados_abertos_desenvolvedores_web.pdf" target="_blank"> Manual do desenvolvedor <abbr title="World Wide Web Consortium">W3C</abbr></a>
# </li>
# <li>
# <a href="http://www.w3c.br/pub/Materiais/PublicacoesW3C/encarte_manual_desenvolvedores_web.pdf" target="_blank"> Cartilha do desenvolvedor <abbr title="World Wide Web Consortium">W3C</abbr> </a>
# </li>
# <li>
# <a href="http://opendatahandbook.org/guide/pt_BR/" target="_blank"> Guia de Dados Abertos <abbr title="Open Knowledge International">OKI</abbr> </a>
# </li>
# <li>
# <a href="http://www.planejamento.gov.br/secretarias/upload/arquivo/governo-aberto/copy_of_manual_elaboracao_plano_dados_abertos.pdf/@@download/file/manual_elaboracao_plano_dados_abertos.pdf" target="_blank"> Manual para Elaboração de Planos de Dados Abertos </a>
# </li>
# </ul>
# </div>
# <div class="col-sm-6 col-md-3" id="about">
# <h3> Saiba mais </h3>
# <ul>
# <li>
# <a href="/pagina/dados-abertos/"> O que são dados abertos? </a>
# </li>
# <li>
# <a href="http://www.acessoainformacao.gov.br/" target="_blank"> Lei de acesso a informação </a>
# </li>
# <li>
# <a href="http://wiki.gtinda.ibge.gov.br/" target="_blank"> Wiki da <abbr title="Infraestrutura Nacional de Dados Abertos">INDA</abbr> </a>
# </li>
# <li>
# <a href="/pagina/instrucao-normativa-da-inda/"> Instrução Normativa da <abbr title="Infraestrutura Nacional de Dados Abertos">INDA</abbr> </a>
# </li>
# <li>
# <a href="http://www.opengovpartnership.org/" target="_blank"> Parceria para Governo Aberto </a>
# </li>
# <li>
# <a href="/pagina/outras-iniciativas/"> Outras iniciativas </a>
# </li>
# <li>
# <a href="http://i3gov.planejamento.gov.br/" target="_blank"> Indicadores de governo </a>
# </li>
# <li>
# <a href="http://paineis.cgu.gov.br/dadosabertos/index.htm" target="_blank"> Painel de Monitoramento </a>
# </li>
# </ul>
# </div>
# </div>
# <!-- FIM Navegação do Rodapé -->
# <div id="colophon">
#           Desenvolvido pela <a href="http://www.planejamento.gov.br/acesso-a-informacao/institucional/unidades/sti" target="_blank">Secretaria de Tecnologia da Informação</a>, <a href="http://www.planejamento.gov.br/" target="_blank">Ministério do Planejamento, Desenvolvimento e Gestão</a>.
#           <a href="http://creativecommons.org/licenses/by-sa/3.0/deed.pt_BR" rel="license" target="_blank">
# <br/>
# <img alt="Licença Creative Commons" src="https://i.creativecommons.org/l/by-sa/3.0/80x15.png"/></a>
#             Todo conteúdo licenciado sob uma  Licença <a href="http://creativecommons.org/licenses/by-sa/3.0/deed.pt_BR" rel="license" target="_blank">
#               Creative Commons Attribution-ShareAlike 3.0 Unported</a>.
#               <br/>
#               Logotipo Licenciado sob <a href="http://www.softwarepublico.gov.br/lpm" target="_blank">Licença Pública de Marca</a>.
#         </div>
# <!-- Logos "Acesso a informação", "CKAN" e "Governo Brasileiro" -->
# <div class="row" id="footer-logos">
# <div class="col-xs-6">
# <div class="acesso-brasil-rodape">
# <a class="logo-acesso" href="http://www.acessoainformacao.gov.br/">
# <img alt="Acesso a Informação" src="/img/acesso-a-informacao2.png"/>
# </a>
# </div>
# <div class="attribution">
# <p><strong>Impulsionado por</strong> <a class="hide-text ckan-footer-logo" href="http://ckan.org">CKAN</a></p>
# </div>
# </div><!-- /.col-xs-6 -->
# <div class="col-xs-6">
# </div><!-- /.col-xs-6 -->
# </div><!-- /.row -->
# </footer>
# </div>
# </div>
# </div>
# <script src="https://barra.brasil.gov.br/barra.js" type="text/javascript"></script>
# <!-- GA -->
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#   ga('create', 'UA-27511850-1', 'auto');
#   ga('send', 'pageview');
#   </script>
# <!-- End GA -->
# <script>document.getElementsByTagName('html')[0].className += ' js';</script>
# <script src="/fanstatic/vendor/:version:2018-07-05T22:13:16/jquery.min.js" type="text/javascript"></script>
# <script src="/fanstatic/vendor/:version:2018-07-05T22:13:16/:bundle:bootstrap/js/bootstrap.min.js;jed.min.js;moment-with-locales.js;select2/select2.min.js" type="text/javascript"></script>
# <script src="/fanstatic/base/:version:2018-07-05T22:13:16/:bundle:plugins/jquery.inherit.min.js;plugins/jquery.proxy-all.min.js;plugins/jquery.url-helpers.min.js;plugins/jquery.date-helpers.min.js;plugins/jquery.slug.min.js;plugins/jquery.slug-preview.min.js;plugins/jquery.truncator.min.js;plugins/jquery.masonry.min.js;plugins/jquery.form-warning.min.js;sandbox.min.js;module.min.js;pubsub.min.js;client.min.js;notify.min.js;i18n.min.js;main.min.js;modules/select-switch.min.js;modules/slug-preview.min.js;modules/basic-form.min.js;modules/confirm-action.min.js;modules/api-info.min.js;modules/autocomplete.min.js;modules/custom-fields.min.js;modules/data-viewer.min.js;modules/table-selectable-rows.min.js;modules/resource-form.min.js;modules/resource-upload-field.min.js;modules/resource-reorder.min.js;modules/resource-view-reorder.min.js;modules/follow.min.js;modules/activity-stream.min.js;modules/dashboard.min.js;modules/resource-view-embed.min.js;view-filters.min.js;modules/resource-view-filters-form.min.js;modules/resource-view-filters.min.js;modules/table-toggle-more.min.js;modules/dataset-visibility.min.js;modules/media-grid.min.js;modules/image-upload.min.js" type="text/javascript"></script></body>
# </html>

# %%
soup.find_all('a', attrs={'class':'heading'})
# Out:
# [<a class="heading" href="/dataset/dados-de-beneficiarios-por-regiao-geografica/resource/069f7f06-0e8e-4018-8da1-010a9899bdec" title="Dados _ Beneficiários por região geográfica">
#      Dados _ Beneficiários por região geográfica<span class="format-label" data-format="zip+csv" property="dc:format">zip+csv</span>
#  </a>,
#  <a class="heading" href="/dataset/dados-de-beneficiarios-por-regiao-geografica/resource/8cabcd0d-3191-44e7-a113-2c890beada61" title="Dicionário de dados_ Beneficiários por região geográfica">
#      Dicionário de dados_ Beneficiários por região ...<span class="format-label" data-format="pdf" property="dc:format">PDF</span>
#  </a>]

# %%
soup.find_all('a', attrs={'class':'heading'})[0].text.strip()
# Out:
# 'Dados _ Beneficiários por região geográficazip+csv'

# %%
'http://www.dados.gov.br' + soup.find_all('a', attrs={'class':'heading'})[0]['href']
# Out:
# '/dataset/dados-de-beneficiarios-por-regiao-geografica/resource/069f7f06-0e8e-4018-8da1-010a9899bdec'

# %%
lista=[]
string = soup.find_all('a', attrs={'class':'heading'})[0].text.strip()
if string.endswith('csv') or string.endswith('zip'):
    lista.append('http://www.dados.gov.br' + soup.find_all('a', attrs={'class':'heading'})[0]['href'])

# %%
new_link = 'http://www.dados.gov.br' + soup.find_all('a', attrs={'class':'heading'})[0]['href']
new_link
# Out:
# 'http://www.dados.gov.br/dataset/dados-de-beneficiarios-por-regiao-geografica/resource/069f7f06-0e8e-4018-8da1-010a9899bdec'

# %%
# acessando última página para pegar o arquivo
new_soup = BeautifulSoup(requests.get(new_link).content)
new_soup
# Out:
# <!DOCTYPE html>
# <!--[if IE 7]> <html lang="pt_BR" class="ie ie7"> <![endif]--><!--[if IE 8]> <html lang="pt_BR" class="ie ie8"> <![endif]--><!--[if IE 9]> <html lang="pt_BR" class="ie9"> <![endif]--><!--[if gt IE 8]><!--><html lang="pt_BR"> <!--<![endif]-->
# <head>
# <!--[if lte ie 8]><script type="text/javascript" src="/fanstatic/vendor/:version:2018-07-05T22:13:16/html5.min.js"></script><![endif]-->
# <link href="/fanstatic/vendor/:version:2018-07-05T22:13:16/select2/select2.css" rel="stylesheet" type="text/css"/>
# <link href="/fanstatic/css/:version:2018-07-05T22:13:16/main.min.css" rel="stylesheet" type="text/css"/>
# <link href="/fanstatic/vendor/:version:2018-07-05T22:13:16/font-awesome/css/font-awesome.min.css" rel="stylesheet" type="text/css"/>
# <!--[if ie 7]><link rel="stylesheet" type="text/css" href="/fanstatic/vendor/:version:2018-07-05T22:13:16/font-awesome/css/font-awesome-ie7.min.css" /><![endif]-->
# <link href="/fanstatic/ckanext-harvest/:version:2018-07-05T22:15:46/styles/harvest.css" rel="stylesheet" type="text/css"/>
# <meta charset="utf-8"/>
# <meta content="ckan 2.6.3" name="generator"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta name="description" value="O Portal Brasileiro de Dados Abertos (dados.gov.br) é o sítio eletrônico de referência para a busca e o acesso aos dados públicos, seus metadados, informações, aplicativos e serviços relacionados."/>
# <title>Dados de Beneficiários por Região Geográfica - Dados _ Beneficiários por região geográfica - Portal Brasileiro de Dados Abertos</title>
# <link href="/images/icons/ckan.ico" rel="shortcut icon"/>
# <!-- CSS Basic UI - Governo Brasileiro -->
# <link href="/css/application.css" rel="stylesheet"/>
# <!-- CSS Bootstrap 3 - Grid and Responsive -->
# <link href="/css/bootstrap3-grid.min.css" rel="stylesheet"/>
# <link href="/css/bootstrap3-responsive.min.css" rel="stylesheet"/>
# <!-- JS jQuery 3 -->
# <script src="https://code.jquery.com/jquery-3.2.1.min.js"></script>
# <!-- Semantic UI -->
# <link href="https://cdnjs.cloudflare.com/ajax/libs/semantic-ui/2.2.10/semantic.min.css" rel="stylesheet"/>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/semantic-ui/2.2.10/semantic.min.js"></script>
# <!-- CSS Main CSS - dados.gov.br -->
# <link href="/css/extra.min.css" rel="stylesheet"/>
# <!-- CSS Font Awesome -->
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" integrity="sha384-wvfXpqpZZVQGK6TAh5PVlGOfQNHSoD2xbE+QkPxCAFlNEevoEH3Sl0sibVcOQVnN" rel="stylesheet"/>
# <!-- Favicon -->
# <link href="/img/favicon/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/img/favicon/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/img/favicon/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/img/favicon/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/img/favicon/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/img/favicon/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/img/favicon/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/img/favicon/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/img/favicon/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/img/favicon/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/img/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/img/favicon/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/img/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/img/favicon/manifest.json" rel="manifest"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="/ms-icon-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="Dados de Beneficiários por Região Geográfica - Dados _ Beneficiários por região geográfica - Portal Brasileiro de Dados Abertos" property="og:title"/>
# <meta content="Quantidade de beneficiários por UF, Região Metropolitana e capital." property="og:description"/>
# </head>
# <body data-locale-root="http://dados.gov.br/" data-site-root="http://dados.gov.br/">
# <div class="hide"><a href="#content">Pular para o conteúdo</a></div>
# <div id="barra-brasil">
# <a href="http://brasil.gov.br" style="background:#7F7F7F; height: 20px; padding:4px 0 4px 10px; display: block; font-family:sans,sans-serif; text-decoration:none; color:white; ">Portal do Governo Brasileiro</a>
# </div>
# <header class="masthead">
# <div class="container">
# <ul id="accessibility">
# <li>
# <a accesskey="1" href="#content" id="link-conteudo">
#           Ir para o conteúdo
#           <span>1</span>
# </a>
# </li>
# <li>
# <a accesskey="2" href="#menu-horizontal" id="link-navegacao">
#           Ir para o menu
#           <span>2</span>
# </a>
# </li>
# <li>
# <a accesskey="3" href="#search" id="link-buscar">
#           Ir para a busca
#           <span>3</span>
# </a>
# </li>
# <li>
# <a accesskey="4" href="#footer" id="link-rodape" onclick="window.scrollTo(0,document.body.scrollHeight)">
#           Ir para o rodapé
#           <span>4</span>
# </a>
# </li>
# </ul>
# <hgroup class="header-text-logo-tagline" id="site_logo">
# <h1>
# <a href="/" title="Portal Brasileiro de Dados Abertos"><span id="portal-title">dados.gov.br</span></a>
# </h1>
# <h2><span id="portal-description">Portal Brasileiro de Dados Abertos</span></h2>
# </hgroup>
# <form action="/dataset" class="search-form" data-module="select-switch" method="get">
# <div class="search-input control-group">
# <input autocomplete="off" class="search" name="q" placeholder="Pesquisar conjuntos de dados..." type="text" value=""/>
# <button type="submit" value="search">
# <i class="icon-search"></i>
# <span>Enviar</span>
# </button>
# </div>
# </form>
# <ul id="news">
# <li id="feed"><a href="/feed/" rel="feed" title="Inscrever-se no feed de notícias">feed</a></li>
# <li id="twitter"><a href="http://twitter.com/dadosgovbr" title="Microblog no Twitter">twitter</a></li>
# <li id="github"><a href="https://github.com/dadosgovbr" title="Códigos fonte de projetos do dados.gov.br no Github">Códigos fonte de projetos do dados.gov.br no Github</a></li>
# </ul>
# <div class="content hidden">
# <form action="/dataset" class="section site-search simple-input" method="get">
# <div class="field">
# <label for="field-sitewide-search">Buscar conjunto de dados</label>
# <input id="field-sitewide-search" name="q" placeholder="Pesquisar conjuntos de dados..." type="text"/>
# <button class="btn-search" type="submit"><i class="icon-search"></i></button>
# </div>
# </form>
# </div>
# </div>
# <div id="barra-menu">
# </div>
# <nav class="section navigation" id="menu-horizontal">
# <ul class="barra-apoio">
# <li class="first link-dados"><a href="/dataset/">Dados</a></li>
# <li class="link-organizacoes"><a href="/organization/">Organizações</a></li>
# <!--<li class="link-aplicativos"><a href="/pagina/aplicativos/">Aplicativos</a></li>-->
# <li class="link-aplicativos"><a href="/aplicativos/">Aplicativos</a></li>
# <li class="link-inventarios"><a href="/inventarios/">Inventários</a></li>
# <li class="link-concursos"><a href="/concursos/">Concursos</a></li>
# <li class="link-wiki"><a href="http://wiki.dados.gov.br/"><abbr style="border: none;" title="Infraestrutura Nacional de Dados Abertos">INDA</abbr></a></li>
# <li class="link-perguntas-frequentes"><a href="/pagina/faq/">Perguntas frequentes</a></li>
# <li class="link-contato"><a href="/pagina/contato/">Contato</a></li>
# <li class="link-sobre"><a href="/pagina/sobre/">Sobre o portal</a></li>
# </ul>
# </nav>
# </header>
# <div role="main">
# <div class="container" id="content">
# <div class="flash-messages">
# </div>
# <div class="toolbar">
# <ol class="breadcrumb">
# <li class="home"><a href="/"><i class="icon-home"></i><span> Início</span></a></li>
# <li><a href="/organization">Organizações</a></li>
# <li><a href="/organization/agencia-nacional-de-saude-suplementar-ans">Agência Nacional de Saúde ...</a></li>
# <li><a href="/dataset/dados-de-beneficiarios-por-regiao-geografica">Dados de Beneficiários por ...</a></li>
# <li class="active"><a href="">Dados _ Beneficiários por ...</a></li>
# </ol>
# </div>
# <div class="row wrapper">
# <section class="module module-resource">
# <div class="module-content">
# <div class="actions">
# <ul>
# <li>
# <a class="btn btn-primary resource-url-analytics resource-type-None" href="http://ftp.dadosabertos.ans.gov.br/FTP/PDA/dados_de_beneficiarios_por_regiao_geografica/benef_regiao_geog.zip">
# <i class="fa fa-external-link"></i> Ir para recurso
#
#         </a>
# </li>
# </ul>
# </div>
# <h1 class="page-heading">Dados _ Beneficiários por região geográfica</h1>
# <p class="muted ellipsis">URL: <a href="http://ftp.dadosabertos.ans.gov.br/FTP/PDA/dados_de_beneficiarios_por_regiao_geografica/benef_regiao_geog.zip" title="http://ftp.dadosabertos.ans.gov.br/FTP/PDA/dados_de_beneficiarios_por_regiao_geografica/benef_regiao_geog.zip">http://ftp.dadosabertos.ans.gov.br/FTP/PDA/dados_de_beneficiarios_por_regiao_geografica/benef_regiao_geog.zip</a></p>
# <div class="prose notes" property="rdfs:label">
# <h3>Do resumo do conjunto de dados</h3>
# <blockquote>Quantidade de beneficiários por UF, Região Metropolitana e capital.</blockquote>
# <p>Fonte: <a href="/dataset/dados-de-beneficiarios-por-regiao-geografica">Dados de Beneficiários por Região Geográfica</a>
# </p></div>
# </div>
# <div class="module-content">
# <div class="resource-view">
# <div class="module-content data-viewer-info">
# <p>Não há visões criadas para este recurso ainda.</p>
# </div>
# </div>
# </div>
# </section>
# <div class="primary span9">
# <section class="module">
# <div class="module-content">
# <h2>Informações Adicionais</h2>
# <table class="table table-striped table-bordered table-condensed" data-module="table-toggle-more">
# <thead>
# <tr>
# <th scope="col">Campo</th>
# <th scope="col">Valor</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th scope="row">Ultima atualização</th>
# <td>9/Novembro/2017</td>
# </tr>
# <tr>
# <th scope="row">Criado</th>
# <td>9/Novembro/2017</td>
# </tr>
# <tr>
# <th scope="row">Formato</th>
# <td>zip+csv</td>
# </tr>
# <tr>
# <th scope="row">Licença</th>
# <td>
# <a href="http://www.opendefinition.org/licenses/cc-by" rel="dc:rights">Creative Commons Attribution</a>
# </td>
# </tr>
# <tr class="toggle-more"><th scope="row">created</th><td>há mais de 2 anos</td></tr>
# <tr class="toggle-more"><th scope="row">format</th><td>zip+csv</td></tr>
# <tr class="toggle-more"><th scope="row">id</th><td>069f7f06-0e8e-4018-8da1-010a9899bdec</td></tr>
# <tr class="toggle-more"><th scope="row">package id</th><td>fbea8c97-bef5-4bda-b73a-9d4ffe441e92</td></tr>
# <tr class="toggle-more"><th scope="row">revision id</th><td>713e0508-0cfe-4327-a853-234f33b899b3</td></tr>
# <tr class="toggle-more"><th scope="row">state</th><td>active</td></tr>
# </tbody>
# </table>
# </div>
# </section>
# </div>
# <aside class="secondary span3">
# <section class="module module-narrow resources">
# <h2 class="module-heading"><i class="icon-copy"></i> Recursos</h2>
# <ul class="unstyled nav nav-simple">
# <li class="nav-item active">
# <a class="active" href="/dataset/dados-de-beneficiarios-por-regiao-geografica/resource/069f7f06-0e8e-4018-8da1-010a9899bdec?inner_span=True"><span>Dados _ Beneficiários ...</span></a>
# </li>
# <li class="nav-item">
# <a class="active" href="/dataset/dados-de-beneficiarios-por-regiao-geografica/resource/8cabcd0d-3191-44e7-a113-2c890beada61?inner_span=True"><span>Dicionário de dados_ ...</span></a>
# </li>
# </ul>
# </section>
# <section class="module module-narrow social">
# <h2 class="module-heading"><i class="icon-medium icon-share"></i> Social</h2>
# <ul class="nav nav-simple">
# <li class="nav-item"><a href="https://plus.google.com/share?url=http://dados.gov.br/dataset/dados-de-beneficiarios-por-regiao-geografica/resource/069f7f06-0e8e-4018-8da1-010a9899bdec" target="_blank"><i class="icon-google-plus-sign"></i> Google+</a></li>
# <li class="nav-item"><a href="https://twitter.com/share?url=http://dados.gov.br/dataset/dados-de-beneficiarios-por-regiao-geografica/resource/069f7f06-0e8e-4018-8da1-010a9899bdec" target="_blank"><i class="icon-twitter-sign"></i> Twitter</a></li>
# <li class="nav-item"><a href="https://www.facebook.com/sharer.php?u=http://dados.gov.br/dataset/dados-de-beneficiarios-por-regiao-geografica/resource/069f7f06-0e8e-4018-8da1-010a9899bdec" target="_blank"><i class="icon-facebook-sign"></i> Facebook</a></li>
# </ul>
# </section>
# </aside>
# </div>
# </div>
# </div>
# <div class="container">
# <div class="footer outer">
# <div class="footer inner bs3">
# <footer>
# <!-- Navegação do Rodapé -->
# <div class="row">
# <div class="col-sm-6 col-md-3" id="portal">
# <h3> O Portal </h3>
# <ul>
# <li>
# <a href="/dataset/"> Catálogo </a>
# </li>
# <li>
# <a href="/organization/"> Organizações </a>
# </li>
# <li>
# <a href="/pagina/cadastrar-organizacao/"> Catalogue seus dados </a>
# </li>
# <li>
# <a href="/pagina/mapa-do-site/"> Mapa do site </a>
# </li>
# <li>
# <a href="/pagina/sobre/"> Sobre o portal </a>
# </li>
# <li>
# <a href="/pagina/faq/"> Perguntas frequentes </a>
# </li>
# <li>
# <a href="/pagina/dev/"> Desenvolvimento do portal </a>
# </li>
# <li>
# <a href="/pagina/agradecimentos/"> Agradecimentos </a>
# </li>
# </ul>
# </div>
# <div class="col-sm-6 col-md-3" id="comunidade">
# <h3> Comunidade </h3>
# <ul>
# <li>
# <a href="/pagina/comunidade"> Comunidades </a>
# </li>
# <li>
# <a href="http://twitter.com/dadosgovbr" target="_blank"> Twitter </a>
# </li>
# <li>
# <a href="http://identi.ca/dadosgovbr" target="_blank"> Identi.ca </a>
# </li>
# <li>
# <a href="https://groups.google.com/forum/#!forum/inda-br" target="_blank"> Lista de discussão </a>
# </li>
# <li>
# <a href="/pagina/ferramentas-colaboracao/"> Ferramentas de colaboração </a>
# </li>
# <li>
# <a href="/revision/list"> Últimas alterações </a>
# </li>
# <li>
# <a href="/pagina/sugira-dados/"> Sugira dados </a>
# </li>
# <li>
# <a href="/pagina/agenda/"> Agenda </a>
# </li>
# <li>
# <a href="/pagina/contato/"> Sugestões </a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 visible-sm" style="text-align: center">
# <hr class="divisor"/>
# </div>
# <div class="col-sm-6 col-md-3" id="manuais">
# <h3> Manuais </h3>
# <ul>
# <li>
# <a href="/pagina/cartilha-publicacao-dados-abertos/"> Cartilha de publicação de dados </a>
# </li>
# <li>
# <a href="http://wiki.gtinda.ibge.gov.br/GetFile.aspx?File=%2fGT3-Tecnologia%2fArquitetura%20Tecnica%20Referencial%20de%20Abertura%20de%20Dados%20v1%20edicao_duke.odt" target="_blank"> Arquitetura Técnica Referencial </a>
# </li>
# <li>
# <a href="http://wiki.dados.gov.br/Capacitacao-para-Catalogacao-de-Dados.ashx" target="_blank">Manual de Catalogação</a>
# </li>
# <li>
# <a href="http://www.w3c.br/pub/Materiais/PublicacoesW3C/Manual_Dados_Abertos_WEB.pdf" target="_blank"> Manual de Dados Abertos <abbr title="World Wide Web Consortium">W3C</abbr></a>
# </li>
# <li>
# <a href="http://www.w3c.br/pub/Materiais/PublicacoesW3C/manual_dados_abertos_desenvolvedores_web.pdf" target="_blank"> Manual do desenvolvedor <abbr title="World Wide Web Consortium">W3C</abbr></a>
# </li>
# <li>
# <a href="http://www.w3c.br/pub/Materiais/PublicacoesW3C/encarte_manual_desenvolvedores_web.pdf" target="_blank"> Cartilha do desenvolvedor <abbr title="World Wide Web Consortium">W3C</abbr> </a>
# </li>
# <li>
# <a href="http://opendatahandbook.org/guide/pt_BR/" target="_blank"> Guia de Dados Abertos <abbr title="Open Knowledge International">OKI</abbr> </a>
# </li>
# <li>
# <a href="http://www.planejamento.gov.br/secretarias/upload/arquivo/governo-aberto/copy_of_manual_elaboracao_plano_dados_abertos.pdf/@@download/file/manual_elaboracao_plano_dados_abertos.pdf" target="_blank"> Manual para Elaboração de Planos de Dados Abertos </a>
# </li>
# </ul>
# </div>
# <div class="col-sm-6 col-md-3" id="about">
# <h3> Saiba mais </h3>
# <ul>
# <li>
# <a href="/pagina/dados-abertos/"> O que são dados abertos? </a>
# </li>
# <li>
# <a href="http://www.acessoainformacao.gov.br/" target="_blank"> Lei de acesso a informação </a>
# </li>
# <li>
# <a href="http://wiki.gtinda.ibge.gov.br/" target="_blank"> Wiki da <abbr title="Infraestrutura Nacional de Dados Abertos">INDA</abbr> </a>
# </li>
# <li>
# <a href="/pagina/instrucao-normativa-da-inda/"> Instrução Normativa da <abbr title="Infraestrutura Nacional de Dados Abertos">INDA</abbr> </a>
# </li>
# <li>
# <a href="http://www.opengovpartnership.org/" target="_blank"> Parceria para Governo Aberto </a>
# </li>
# <li>
# <a href="/pagina/outras-iniciativas/"> Outras iniciativas </a>
# </li>
# <li>
# <a href="http://i3gov.planejamento.gov.br/" target="_blank"> Indicadores de governo </a>
# </li>
# <li>
# <a href="http://paineis.cgu.gov.br/dadosabertos/index.htm" target="_blank"> Painel de Monitoramento </a>
# </li>
# </ul>
# </div>
# </div>
# <!-- FIM Navegação do Rodapé -->
# <div id="colophon">
#           Desenvolvido pela <a href="http://www.planejamento.gov.br/acesso-a-informacao/institucional/unidades/sti" target="_blank">Secretaria de Tecnologia da Informação</a>, <a href="http://www.planejamento.gov.br/" target="_blank">Ministério do Planejamento, Desenvolvimento e Gestão</a>.
#           <a href="http://creativecommons.org/licenses/by-sa/3.0/deed.pt_BR" rel="license" target="_blank">
# <br/>
# <img alt="Licença Creative Commons" src="https://i.creativecommons.org/l/by-sa/3.0/80x15.png"/></a>
#             Todo conteúdo licenciado sob uma  Licença <a href="http://creativecommons.org/licenses/by-sa/3.0/deed.pt_BR" rel="license" target="_blank">
#               Creative Commons Attribution-ShareAlike 3.0 Unported</a>.
#               <br/>
#               Logotipo Licenciado sob <a href="http://www.softwarepublico.gov.br/lpm" target="_blank">Licença Pública de Marca</a>.
#         </div>
# <!-- Logos "Acesso a informação", "CKAN" e "Governo Brasileiro" -->
# <div class="row" id="footer-logos">
# <div class="col-xs-6">
# <div class="acesso-brasil-rodape">
# <a class="logo-acesso" href="http://www.acessoainformacao.gov.br/">
# <img alt="Acesso a Informação" src="/img/acesso-a-informacao2.png"/>
# </a>
# </div>
# <div class="attribution">
# <p><strong>Impulsionado por</strong> <a class="hide-text ckan-footer-logo" href="http://ckan.org">CKAN</a></p>
# </div>
# </div><!-- /.col-xs-6 -->
# <div class="col-xs-6">
# </div><!-- /.col-xs-6 -->
# </div><!-- /.row -->
# </footer>
# </div>
# </div>
# </div>
# <script src="https://barra.brasil.gov.br/barra.js" type="text/javascript"></script>
# <!-- GA -->
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#   ga('create', 'UA-27511850-1', 'auto');
#   ga('send', 'pageview');
#   </script>
# <!-- End GA -->
# <script>document.getElementsByTagName('html')[0].className += ' js';</script>
# <script src="/fanstatic/vendor/:version:2018-07-05T22:13:16/jquery.min.js" type="text/javascript"></script>
# <script src="/fanstatic/vendor/:version:2018-07-05T22:13:16/:bundle:bootstrap/js/bootstrap.min.js;jed.min.js;moment-with-locales.js;select2/select2.min.js" type="text/javascript"></script>
# <script src="/fanstatic/base/:version:2018-07-05T22:13:16/:bundle:plugins/jquery.inherit.min.js;plugins/jquery.proxy-all.min.js;plugins/jquery.url-helpers.min.js;plugins/jquery.date-helpers.min.js;plugins/jquery.slug.min.js;plugins/jquery.slug-preview.min.js;plugins/jquery.truncator.min.js;plugins/jquery.masonry.min.js;plugins/jquery.form-warning.min.js;sandbox.min.js;module.min.js;pubsub.min.js;client.min.js;notify.min.js;i18n.min.js;main.min.js;modules/select-switch.min.js;modules/slug-preview.min.js;modules/basic-form.min.js;modules/confirm-action.min.js;modules/api-info.min.js;modules/autocomplete.min.js;modules/custom-fields.min.js;modules/data-viewer.min.js;modules/table-selectable-rows.min.js;modules/resource-form.min.js;modules/resource-upload-field.min.js;modules/resource-reorder.min.js;modules/resource-view-reorder.min.js;modules/follow.min.js;modules/activity-stream.min.js;modules/dashboard.min.js;modules/resource-view-embed.min.js;view-filters.min.js;modules/resource-view-filters-form.min.js;modules/resource-view-filters.min.js;modules/table-toggle-more.min.js;modules/dataset-visibility.min.js;modules/media-grid.min.js;modules/image-upload.min.js" type="text/javascript"></script></body>
# </html>

# %%
new_soup.find_all('p', attrs={'class':'muted ellipsis'})[0].find_all('a')[0]['href']
# Out:
# 'http://ftp.dadosabertos.ans.gov.br/FTP/PDA/dados_de_beneficiarios_por_regiao_geografica/benef_regiao_geog.zip'

# %%
if new_soup.p.a['href'].endswith('zip') or 'csv':
    requests.get(file)
    filename = file.split('/')[-1]

folder_name = './'
urllib.request.urlretrieve(file, f'{folder_name}{filename}')
# Out:
# 'http://ftp.dadosabertos.ans.gov.br/FTP/PDA/dados_de_beneficiarios_por_regiao_geografica/benef_regiao_geog.zip'

# %%
url = 'http://ftp.dadosabertos.ans.gov.br/FTP/PDA/'

response = requests.get(url)
soup = BeautifulSoup(response.content)
# teria que mudar aqui, pra cada url
# for new_url in [url + tag['href'] for tag in soup.find_all('a') if tag['href'].endswith('/')]:
# ...
new_url = [url + tag['href'] for tag in soup.find_all('a') if tag['href'].endswith('/')][4]
soup = BeautifulSoup(requests.get(new_url).content)

# talvez mudar para zip
file = [new_url + tag['href'] for tag in soup.find_all('a') if tag['href'].endswith('zip')][0]
requests.get(file)

filename = file.split('/')[-1]

folder_name = './'
urllib.request.urlretrieve(file, f'{folder_name}{filename}')






# via selenium

from selenium import webdriver
driver = webdriver.Chrome('C:/Users/andreaguiar/Desktop/selenium/chromedriver.exe')
url = 'http://www.dados.gov.br/dataset/abrangencia-geografica-dos-planos-de-saude'
driver.get(url)
elem = driver.find_element_by_xpath('/html/body/div[3]/div/div[3]/div/article/div/section[2]/ul/li[1]/div/a')
elem.click()                        
elem = driver.find_element_by_xpath('/html/body/div[3]/div/div[3]/div/article/div/section[2]/ul/li[1]/div/ul/li[2]/a')

elem.click()
import os
os.rename('C:/Users/andreaguiar/Downloads/abrangencia_geografica.zip', f'{folder_name}/teste.zip')



# Extract zip file
from zipfile import ZipFile
with ZipFile(f'{folder_name}/teste.zip', 'r') as zipObj:
   # Extract all the contents of zip file in current directory
   zipObj.extractall(path=f'{folder_name}/')

# %%
# saving files using selenium:
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# open the chrome browser
driver = webdriver.Chrome(executable_path='/Users/serachung/Desktop/usr/dev/chromedriver')


# navigate to webpage 
    driver.get(file)
    elem = driver.find_element_by_id('usr')
    elem.click

# %%
driver = webdriver.Chrome(executable_path='/Users/serachung/Desktop/usr/dev/chromedriver')
driver.get('http://www.dados.gov.br/dataset/dados-de-beneficiarios-por-regiao-geografica')
elem = driver.findElement(By.cssSelector('data-toggle.dropdown')).click()

# %%
'http://ftp.dadosabertos.ans.gov.br/FTP/PDA/hc_ressarcimento_sus/'

# %% [markdown]
# ## EPIDEMIAS / PANDEMIAS

# %%
# Pandemia 2003 -2004 – Gripe Aviária

# %%
# Pandemia de 2009 – Gripe A (H1N1)  pdm 09 – Gripe Suína.

# %% [markdown]
# # VIA API WRAPPER

# %% [markdown]
# ## SOCIAL

# %%
# IBGE (Pesquisa de Orçamentos Familiares/ Censo Demográfico)
'http://www.dados.gov.br/dataset?tags=Consumo&organization=instituto-brasileiro-de-geografia-e-estatistica-ibge&_tags_limit=0'
# Out:
# 'http://www.dados.gov.br/dataset?tags=Consumo&organization=instituto-brasileiro-de-geografia-e-estatistica-ibge&_tags_limit=0'

# %%
# MINISTÉRIO DA SAÚDE (Cadastro Nacional de Estabelecimentos de Saúde - CNES)
'http://www.dados.gov.br/organization/5b283f30-ced3-4ccc-b44a-406e8a92e1ad?groups=dados-em-destaque'
# Out:
# 'http://www.dados.gov.br/organization/5b283f30-ced3-4ccc-b44a-406e8a92e1ad?groups=dados-em-destaque'

# %% [markdown]
# # FONTES

# %%
'https://animalbusiness.com.br/medicina-veterinaria/ciencia-e-saude/revisao-das-principais-pandemias-de-gripe-dos-ultimos-seculos/'
# Out:
# 'https://animalbusiness.com.br/medicina-veterinaria/ciencia-e-saude/revisao-das-principais-pandemias-de-gripe-dos-ultimos-seculos/'

# %%
# !curl https://api.discogs.com/releases/249504 --user-agent "FooBarApp/3.0"
# Out:
# {"status": "Accepted", "videos": [{"duration": 213, "embed": true, "title": "Rick Astley - Never Gonna Give You Up (Video)", "description": "Rick Astley's official music video for \u201cNever Gonna Give You Up\u201d \nListen to Rick Astley: https://RickAstley.lnk.to/_listenYD\n\nSubscribe to the official Rick Astley YouTube channel: https://RickAstley.lnk.to/subscribeYD\n\nFollow Rick Astley:\nFacebook: h", "uri": "https://www.youtube.com/watch?v=dQw4w9WgXcQ"}], "series": [], "labels": [{"name": "RCA", "entity_type": "1", "catno": "PB 41447", "resource_url": "https://api.discogs.com/labels/895", "id": 895, "entity_type_name": "Label"}], "year": 1987, "community": {"status": "Accepted", "rating": {"count": 129, "average": 3.66}, "want": 261, "contributors": [{"username": "memory", "resource_url": "https://api.discogs.com/users/memory"}, {"username": "vargind", "resource_url": "https://api.discogs.com/users/vargind"}, {"username": "alistairk", "resource_url": "https://api.discogs.com/users/alistairk"}, {"username": "hog", "resource_url": "https://api.discogs.com/users/hog"}, {"username": "rwrackham", "resource_url": "https://api.discogs.com/users/rwrackham"}, {"username": "jan_marian", "resource_url": "https://api.discogs.com/users/jan_marian"}, {"username": "_80_", "resource_url": "https://api.discogs.com/users/_80_"}, {"username": "chillyboy64", "resource_url": "https://api.discogs.com/users/chillyboy64"}, {"username": "strummin", "resource_url": "https://api.discogs.com/users/strummin"}, {"username": "djcarbines", "resource_url": "https://api.discogs.com/users/djcarbines"}, {"username": "Skinheadmate", "resource_url": "https://api.discogs.com/users/Skinheadmate"}, {"username": "Stathisan", "resource_url": "https://api.discogs.com/users/Stathisan"}], "have": 1637, "submitter": {"username": "memory", "resource_url": "https://api.discogs.com/users/memory"}, "data_quality": "Needs Vote"}, "artists": [{"join": "", "name": "Rick Astley", "anv": "", "tracks": "", "role": "", "resource_url": "https://api.discogs.com/artists/72872", "id": 72872}], "images": [{"uri": "", "height": 600, "width": 600, "resource_url": "", "type": "primary", "uri150": ""}, {"uri": "", "height": 600, "width": 600, "resource_url": "", "type": "secondary", "uri150": ""}, {"uri": "", "height": 600, "width": 600, "resource_url": "", "type": "secondary", "uri150": ""}, {"uri": "", "height": 600, "width": 600, "resource_url": "", "type": "secondary", "uri150": ""}], "format_quantity": 1, "id": 249504, "artists_sort": "Rick Astley", "genres": ["Electronic", "Pop"], "thumb": "", "num_for_sale": 70, "title": "Never Gonna Give You Up", "date_changed": "2019-08-21T23:30:18-07:00", "master_id": 96559, "lowest_price": 1.18, "styles": ["Euro-Disco"], "released_formatted": "Jul 1987", "formats": [{"qty": "1", "descriptions": ["7\"", "45 RPM", "Single"], "name": "Vinyl"}], "estimated_weight": 60, "master_url": "https://api.discogs.com/masters/96559", "released": "1987-07-00", "date_added": "2004-04-30T08:10:05-07:00", "extraartists": [{"join": "", "name": "Me Company", "anv": "Me Co", "tracks": "", "role": "Design", "resource_url": "https://api.discogs.com/artists/547352", "id": 547352}, {"join": "", "name": "Mark McGuire", "anv": "", "tracks": "", "role": "Engineer", "resource_url": "https://api.discogs.com/artists/78275", "id": 78275}, {"join": "", "name": "Mike Duffy", "anv": "", "tracks": "", "role": "Engineer", "resource_url": "https://api.discogs.com/artists/95941", "id": 95941}, {"join": "", "name": "Miles Showell", "anv": "MS", "tracks": "", "role": "Lacquer Cut By", "resource_url": "https://api.discogs.com/artists/383408", "id": 383408}, {"join": "", "name": "Pete Hammond", "anv": "Mixmaster Pete Hammond", "tracks": "", "role": "Mixed By", "resource_url": "https://api.discogs.com/artists/34067", "id": 34067}, {"join": "", "name": "Stock, Aitken & Waterman", "anv": "Stock / Aitken / Waterman", "tracks": "", "role": "Producer, Written-By", "resource_url": "https://a ...

# %%
sss
