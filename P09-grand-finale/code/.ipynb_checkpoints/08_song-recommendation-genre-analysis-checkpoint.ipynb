# %%
from getpass import getpass
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Recommender System Model

# %% [markdown]
# > `database`:
# - import
# - preprocess
#
# > `input`:
# - música
# - gênero
#
# > `processamento`:
# - buscar na base de dados de música atual, encontrar artista, separar
# - filtrar DB por target (recomendável)
# - filtrar por cluster POR FEATURES
# - análise word2vec gêneros
# - análise word2vec para a música do input
# - calcular dist cosine
#
# - standardizar dados
# - incluir no sistema de recomendação
# - filtrar os 10 mais semelhantes
#
# > `output`:
# - retornar página com top 5 músicas e artistas
# - links para ouvir a música

# %% [markdown]
# # Genre analysis

# %% [markdown]
# ## Categorizing by genre name

# %%
songs = pd.read_csv('../data/final/songs.csv')

# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
# getting sub-genres clusterings from musicmap.info
url = 'https://www.musicmap.info/#'
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html)

# %%
# LOOKING FOR ALL AVAILABLE MAIN GENRES
pattern='[\n\t]+'
text = soup.find_all('g', attrs={'id' : 'static-genres'})[0].text
n_text = re.sub(pattern, '\n', text).split('\n')

# filtering main genres
main = list(set([x.split(':')[0] for x in list(genres_dict.keys())]))
other_main = ['UTILITY MUSIC','FOLK MUSIC','CLASSICAL MUSIC','WORLD']
main_genres = main + other_main
main_genres
# Out:
# ['RAP / HIP-HOP MUSIC',
#  'DOWNTEMPO / AMBIENT',
#  'ROCK',
#  'POP (MUSIC)',
#  '(HEAVY) METAL',
#  'INDUSTRIAL & GOTHIC',
#  'BLUE NOTE',
#  'EDM / DANCE',
#  'COUNTRY',
#  "RHYTHM 'N' BLUES (R&B)",
#  'JAMAICAN (MUSIC) / REGGAE',
#  'UTILITY MUSIC',
#  'FOLK MUSIC',
#  'CLASSICAL MUSIC',
#  'WORLD']

# %%
# main-genres and sub-genres:
genres_dict = {}
genres = soup.find_all('a', attrs={'class' : 'genre-link'})

for i in range(len(genres)):
    code = genres[i]['data-code']
    genre = genres[i].text
    genres_dict[code] = genre
genres_dict
# Out:
# {'inl': 'INDUSTRIAL & GOTHIC',
#  'met': '(HEAVY) METAL',
#  'rnr': "ROCK: ROCK 'N' ROLL (R'N'R)",
#  'gld': 'ROCK: GOLDEN AGE',
#  'pwv': 'ROCK: PUNK (ROCK) / (NEW) WAVE',
#  'hcp': 'ROCK: HARDCORE (PUNK)',
#  'alt': 'ROCK: ALTERNATIVE / INDIE (ROCK)',
#  'con': 'ROCK: CONTEMPORARY (ROCK)',
#  'pop': 'POP (MUSIC)',
#  'cou': 'COUNTRY',
#  'rnb': "RHYTHM 'N' BLUES (R&B)",
#  'gos': 'BLUE NOTE: GOSPEL & PIONEERS',
#  'blu': 'BLUE NOTE: BLUES',
#  'jaz': 'BLUE NOTE: JAZZ',
#  'jam': 'JAMAICAN (MUSIC) / REGGAE',
#  'rap': 'RAP / HIP-HOP MUSIC',
#  'brb': 'EDM / DANCE: BREAKBEAT',
#  'dnb': "EDM / DANCE: DRUM 'N' BASS / JUNGLE",
#  'hct': 'EDM / DANCE: HARDCORE (TECHNO)',
#  'tec': 'EDM / DANCE: TECHNO',
#  'hou': 'EDM / DANCE: HOUSE',
#  'tra': 'EDM / DANCE: TRANCE',
#  'dtp': 'DOWNTEMPO / AMBIENT'}

# %%
# all micro-genres
micro_genres_dict = {}
micro_genres = soup.find_all('option')

for i in range(len(micro_genres)):
    code = micro_genres[i]['data-code']
    micro_genre = micro_genres[i].text
    micro_genres_dict[code] = micro_genre
    
sub_micro_genres_dict = {}
for i in list(genres_dict.keys()):
    pattern = f'({i}[0-9]+)'
    string = str(micro_genres_dict.keys())
    sub_micro_genres_dict[i] = re.findall(pattern, string)

all_genres_dict = {}
for i in list(genres_dict.keys()):
    micro_genres_list=[]
    for j in sub_micro_genres_dict.get(i):
        micro_genres_list.append(micro_genres_dict.get(j))
    all_genres_dict[genres_dict.get(i)] = micro_genres_list

# %%
#Classifying micro genres into subgenres:

pattern='[\n\t]+'
text = soup.find_all('g', attrs={'id' : 'otherworld-genres'})[0].text
n_text = re.sub(pattern, '\n', text).split('\n')
all_micro_genres = list(set(list(micro_genres_dict.values())+n_text))

CUBAN = ['CONTRADANZA','PUNTO & GUAJIRA','TROVA & FEELING','HABANERA','SON','DANZÓN','BOLERO',
         'RUMBA','MAMBO & CHACHACHA','CUBOP','CANCION','NUEVA TROVA','SALSA','TIMBA']
LATIN = ['BAILE-FUNK','BOMBA, PLENA & MERENGUE','BOOGALOO','BOSSA NOVA','CALYPSO','CHACÓN',
         'CUMBIA','HUAYNO & CHICA','MILONGA','SAMBA','SOCA & PUNTA','TANGO','TROPICALIA','ZOUK',]
CLASSICAL = ['MEDIEVAL','RENAISSANCE','BAROQUE','CLASSICAL','ROMANTIC','MODERN','CONTEMPORARY']
FOLK = ['CELTIC','NORDIC','AFRICAN','ASIAN','EUROPEAN','NORTH-AMERICAN','LATIN',
             'APPALACHIAN','SYMPHONY','CHAMBER','OPERA','SOLO','VOCAL',]
UTILITY = ['HYMNS', 'PSALMS', 'CHANTS','MILITARY MUSIC','MARCH MUSIC','CABARET',
           'VAUDEVILLE','MUSICAL','SOUNDTRACKS','FILM', 'TV', 'GAME', 'PLAY MUSIC']

all_genres_dict['WORLD: CUBAN'] = CUBAN
all_genres_dict['WORLD: LATIN'] = LATIN
all_genres_dict['CLASSICAL'] = CLASSICAL
all_genres_dict['FOLK'] = FOLK
all_genres_dict['UTILITY'] = UTILITY

# %%
list(all_genres_dict.items())[0]
# Out:
# ('INDUSTRIAL & GOTHIC',
#  ['DARK AMBIENT / DARK INDUSTRIAL',
#   'DARKWAVE & COLDWAVE',
#   'GOTHIC ROCK & DEATHROCK',
#   '(AVANT-GARDE) INDUSTRIAL',
#   'INDUSTRIAL ROCK / INDUSTRIAL METAL',
#   'KRAUTROCK',
#   'MINIMAL WAVE / SYNTH & MINIMAL INDUSTRIAL (REVIVAL)'])

# %%
# FINAL micro-genres classified in sub-genres and in main-genres
list_of_lists = []
for i in list(all_genres_dict.items()):
    temp_list = i[1]
    temp_list.append(i[0])
    list_of_lists.append(temp_list)
list_of_lists
# Out:
# [['DARK AMBIENT / DARK INDUSTRIAL',
#   'DARKWAVE & COLDWAVE',
#   'GOTHIC ROCK & DEATHROCK',
#   '(AVANT-GARDE) INDUSTRIAL',
#   'INDUSTRIAL ROCK / INDUSTRIAL METAL',
#   'KRAUTROCK',
#   'MINIMAL WAVE / SYNTH & MINIMAL INDUSTRIAL (REVIVAL)',
#   'INDUSTRIAL & GOTHIC'],
#  ['BLACK METAL',
#   'CLASSIC METAL',
#   'DEATH METAL',
#   'DOOM METAL',
#   'EXTREME METAL (BLACK I & SPEED)',
#   'GLAM METAL / HAIR METAL / POP METAL',
#   'NU METAL & RAP METAL',
#   'NWOBHM (NEW WAVE OF BRITISH HEAVY METAL)',
#   'POWER METAL',
#   'PROGRESSIVE METAL',
#   'STONER METAL / ROCK & SLUDGE METAL / ROCK',
#   'SYMPHONIC METAL & GOTHIC METAL',
#   'THRASH METAL',
#   '(HEAVY) METAL'],
#  ['AMERICAN & BRITISH FOLK REVIVAL',
#   'GARAGE ROCK',
#   "ROCK 'N ROLL & ROCKABILLY",
#   'SKIFFLE (REVIVAL)',
#   'SURF ROCK / INSTRUMENTAL',
#   "ROCK: ROCK 'N' ROLL (R'N'R)"],
#  ['(MERSEY)BEAT / BRITISH INVASION',
#   'FOLK ROCK',
#   'GLAM ROCK / GLITTER ROCK / SHOCK ROCK',
#   'HARD ROCK',
#   'HEARTLAND ROCK & A.O.R. (ADULT ORIENTED ROCK)',
#   'PROGRESSIVE ROCK, ART ROCK & SYMPHONIC ROCK',
#   'PSYCHEDELIC / ACID ROCK & PSYCHEDELIA',
#   'SOUTHERN ROCK',
#   'ROCK: GOLDEN AGE'],
#  ['ANARCHO-PUNK, CRUST PUNK & D-BEAT / DISCORE',
#   'HORROR PUNK & PSYCHOBILLY',
#   'NEW WAVE',
#   'NO WAVE',
#   'POST-PUNK',
#   'PUB ROCK & PROTO PUNK',
#   'PUNK ROCK',
#   'SYNTHPOP & NEW ROMANTICS',
#   'ROCK: PUNK (ROCK) / (NEW) WAVE'],
#  ['CROSSOVER THRASH',
#   'GRINDCORE',
#   'MATH ROCK & MATHCORE',
#   'METALCORE / NEW WAVE OF AMERICAN HEAVY METAL',
#   'ORIGINAL HARDCORE (PUNK)',
#   'POST-HARDCORE, EMO(CORE) & SCREAMO',
#   'SYNTHCORE & CRUNKCORE',
#   'ROCK: HARDCORE (PUNK)'],
#  ['ALTERNATIVE ROCK / INDIE II',
#   'DREAM POP & SHOEGAZE',
#   'GRUNGE',
#   'JANGLE POP / INDIE ROCK (& PAISLEY UNDERGROUND)',
#   'NOISE ROCK',
#   'POST-GRUNGE',
#   'POST-ROCK',
#   'RAP ROCK, RAPCORE & FUNK METAL',
#   'SKATE PUNK & POP PUNK',
#   'ROCK: ALTERNATIVE / INDIE (ROCK)'],
#  ['DANCE-PUNK & NU RAVE',
#   'EMO-ROCK',
#   'GARAGE & POST-PUNK REVIVALS / NU-RAWK',
#   'INDIE FOLK & FREAKFOLK / NEW WEIRD AMERICA',
#   'INDIETRONICA & CHILLWAVE',
#   'NEW PROG / NU PROG / POST PROG (ROCK)',
#   'POST-BRITPOP',
#   'ROCK: CONTEMPORARY (ROCK)'],
#  ['ASIAN POP',
#   'BRILL BUILDING POP',
#   'BRITPOP',
#   'BUBBLEGUM & TEENYBOP',
#   'DANCE POP',
#   'DISCOPOP / POST-DISCO',
#   'ELECTRO POP',
#   'ELECTROCLASH',
#   'HI-NRG / EURODISCO',
#   'INDIE POP (TWEE)',
#   '(EARLY) POP ROCK &POWER POP',
#   'SCHLAGER',
#   'SINGER/SONGWRITER',
#   'SOFT ROCK / ADULT CONTEMPORARY (A.C.)',
#   'POP (MUSIC)'],
#  ['AMERICANA / ALTERNATIVE COUNTRY',
#   'BAKERSFIELD',
#   'BLUEGRASS',
#   'CLASSIC COUNTRY / HILLBILLY',
#   'CONTEMPORARY COUNTRY / NEOTRADITIONALISTS',
#   'COUNTRY POP & COUNTRY ROCK',
#   'HONKY TONK / HARDCORE COUNTRY',
#   'NASHVILLE / COUNTRYPOLITAN',
#   'PROGRESSIVE COUNTRY & OUTLAW COUNTRY',
#   'URBAN COUNTRY',
#   'WESTERN SWING',
#   'COUNTRY'],
#  ['BOOGIE / ELECTROFUNK',
#   'CHICAGO SOUL & DETROIT SOUL (MOTOWN)',
#   'DEEP FUNK / RARE GROOVE & NU FUNK',
#   'DISCO',
#   'DOO WOP',
#   'EARLY FUNK & P-FUNK',
#   'GO-GO',
#   'MEMPHIS SOUL / DEEP SOUL / SOUTHERN SOUL',
#   'NEO SOUL / NU SOUL',
#   'NEW JACK SWING / SWINGBEAT',
#   'NU-DISCO & FUNKTRONICA',
#   'PHILLY SOUL',
#   "(EARLY) RHYTHM 'N' BLUES",
#   'URBAN SOUL / POP (NU R&B I)',
#   "RHYTHM 'N' BLUES (R&B)"],
#  ['MODERN GOSPEL',
#   'RAGTIME & STRIDE',
#   'RELIPOP & -ROCK / CONTEMPORARY CHRISTIAN MUSIC',
#   '(NEGRO) SPIRITUALS & WORKSONGS',
#   'TRADITIONAL GOSPEL',
#   'BLUE NOTE: GOSPEL & PIONEERS'],
#  ['BOOGIE WOOGIE / PIANO BLUES',
#   'BRITISH BLUES & BLUES ROCK',
#   'CHICAGO BLUES / CITY BLUES / URBAN BLUES',
#   'COUNTRY BLUES / FOLK BLUES',
#   'HILL COUNTRY BLUES & TRANCE BLUES',
#   'JUMP BLUES',
#   'LOUISIANA BLUES / SWAMP BLUES',
#   'SOUL BLUES (SOUTHERN SOUL II)',
#   '(ELECTRIC) TEXAS BLUES',
#   'TEXAS BLUESROCK & MODERN ELECTRIC BLUES',
#   'VAUDEVILLE / CLASSIC BLUES',
#   'WEST COAST BLUES',
#   'BLUE NOTE: BLUES'],
#  ['ACID JAZZ / JAZZDANCE',
#   'BEBOP',
#   'CHICAGO JAZZ',
#   'COOL JAZZ & WEST COAST JAZZ',
#   'ELECTRO SWING',
#   'FREE JAZZ / AVANT-GARDE (JAZZ)',
#   'FUSION / JAZZ ROCK',
#   'HARD BOP',
#   'NEW ORLEANS & DIXIELAND JAZZ REVIVALS',
#   'NEW ORLEANS JAZZ & DIXIELAND JAZZ',
#   'NORDIC JAZZ',
#   'NU JAZZ / ELECTRO JAZZ',
#   'SMOOTH JAZZ',
#   'SOUL JAZZ / JAZZ FUNK',
#   'SWING / BIG BAND',
#   'THIRD STREAM / PROGRESSIVE JAZZ & MODAL JAZZ',
#   'BLUE NOTE: JAZZ'],
#  ['DANCEHALL',
#   'DUB',
#   "LOVER'S ROCK & UK REGGAE",
#   'MENTO',
#   'RAGGA',
#   '(ROOTS) REGGAE',
#   'REGGAE FUSION & BHANGRAMUFFIN',
#   'REGGAETÓN & LATIN RAP',
#   'ROCKSTEADY',
#   'SKA',
#   'SKA REVIVAL (2-TONE), SKA PUNK & SKACORE',
#   'JAMAICAN (MUSIC) / REGGAE'],
#  ['EAST COAST GANGSTA RAP',
#   '(WEST COAST) GANGSTA RAP',
#   'GLITCH HOP & WONKY',
#   'GOLDEN AGE RAP (& HARDCORE RAP)',
#   'JAZZ RAP / NATIVE TONGUE',
#   'MIAMI BASS & BOUNCE',
#   'OLD SKOOL RAP PIONEERS',
#   'PROGRESSIVE RAP / NU SKOOL RAP',
#   '(DIRTY) SOUTH RAP, CRUNK & SNAP',
#   'TRAP & DRILL',
#   'URBAN BREAKS (NU R&B II)',
#   'RAP / HIP-HOP MUSIC'],
#  ['BASSLINE & UK FUNKY',
#   'BREAKBEAT GARAGE & GRIME',
#   'BROKEN BEATS',
#   'CHEMICAL BREAKS & BIG BEAT',
#   'EDM TRAP / TRAPSTEP',
#   'ELECTRO',
#   'FLORIDA BREAKS (& FUNKY BREAKS)',
#   'FREESTYLE & BREAKDANCE',
#   'NU SKOOL BREAKS',
#   'TRIP HOP',
#   'UK GARAGE (2-STEP & SPEED GARAGE)',
#   'EDM / DANCE: BREAKBEAT'],
#  ['DARKCORE & DARKSTEP',
#   'DUBSTEP',
#   'FUTURE BASS / FUTURE GARAGE',
#   'HARDSTEP & TECHSTEP',
#   "INTELLIGENT / AMBIENT DRUM 'N' BASS & JAZZSTEP",
#   'JUMP UP',
#   'LIQUID FUNK',
#   'NEUROFUNK',
#   "OLD SKOOL JUNGLE & OLD SKOOL DRUM 'N' BASS",
#   'POST-DUBSTEP',
#   "EDM / DANCE: DRUM 'N' BASS / JUNGLE"],
#  ['BREAKBEAT HARDCORE (RAVE II)',
#   'DIGITAL HARDCORE & BREAKCORE',
#   '(EARLY) GABBER',
#   'HAPPY HARDCORE & BOUNCY TECHNO',
#   'HARDCORE TECHNO / RAVE',
#   'HARDSTYLE (& JUMPSTYLE)',
#   'NEW BEAT',
#   'NU STYLE (GABBER) / MAINSTREAM HARDCORE',
#   'SPEEDCORE, FRENCHCORE & TERRORCORE',
#   'UK HARDCORE & FREEFORM / TRANCECORE & ACIDCORE',
#   'EDM / DANCE: HARDCORE (TECHNO)'],
#  ['AMBIENT TECHNO & IDM (INTELLIGENT DANCE MUSIC)',
#   'DETROIT TECHNO',
#   'HARDTECHNO (SCHRANZ II)',
#   'INDUSTRIAL TECHNO & SCHRANZ',
#   'MINIMAL TECHNO',
#   'TECH HOUSE',
#   'TECH TRANCE',
#   '(FREE)TEK(K)NO',
#   'EDM / DANCE: TECHNO'],
#  ['ACID HOUSE',
#   'CHICAGO HOUSE & GARAGE HOUSE',
#   'DEEP HOUSE',
#   'ELECTRO HOUSE & DUTCH HOUSE',
#   'FIDGET HOUSE & COMPLEXTRO',
#   'FRENCH HOUSE & FUNKY HOUSE',
#   'GHETTO HOUSE, GHETTOTECH &JUKE',
#   'HIP HOUSE & EURODANCE',
#   'MICROHOUSE / MINIMAL HOUSE',
#   'MOOMBAHTON',
#   'NRG, HARD NRG & (UK) HARD HOUSE',
#   'PROGRESSIVE HOUSE',
#   'EDM / DANCE: HOUSE'],
#  ['CLASSIC TRANCE & ACID TRANCE',
#   'EUROTRANCE & VOCAL TRANCE',
#   'GOA TRANCE & PSYTRANCE',
#   'HARDTRANCE',
#   'IBIZA HOUSE / TRANCE & DREAM HOUSE / TRANCE',
#   'NEO-TRANCE',
#   'PROGRESSIVE TRANCE',
#   'UPLIFTING TRANCE / EPIC TRANCE',
#   'EDM / DANCE: TRANCE'],
#  ['AMBIENT',
#   'AMBIENT BREAKS & ILLBIENT',
#   'AMBIENT HOUSE / CHILL-OUT',
#   'BIT MUSIC / VGM (CHIPTUNE & 8-BIT)',
#   'DIGITAL MINIMALISM / LOWERCASE',
#   "GLITCH / CLICKS 'N' CUTS",
#   'LOUNGE / EXOTICA / SPACE AGE POP',
#   'MINIMALISM',
#   'MUSIQUE CONCRETE',
#   'MUZAK / ELEVATOR MUSIC',
#   'NEW AGE',
#   'SYNTH / ELECTRONICA',
#   'SYNTHWAVE & VAPORWAVE',
#   'DOWNTEMPO / AMBIENT'],
#  ['CONTRADANZA',
#   'PUNTO & GUAJIRA',
#   'TROVA & FEELING',
#   'HABANERA',
#   'SON',
#   'DANZÓN',
#   'BOLERO',
#   'RUMBA',
#   'MAMBO & CHACHACHA',
#   'CUBOP',
#   'CANCION',
#   'NUEVA TROVA',
#   'SALSA',
#   'TIMBA',
#   'WORLD: CUBAN'],
#  ['BAILE-FUNK',
#   'BOMBA, PLENA & MERENGUE',
#   'BOOGALOO',
#   'BOSSA NOVA',
#   'CALYPSO',
#   'CHACÓN',
#   'CUMBIA',
#   'HUAYNO & CHICA',
#   'MILONGA',
#   'SAMBA',
#   'SOCA & PUNTA',
#   'TANGO',
#   'TROPICALIA',
#   'ZOUK',
#   'WORLD: LATIN'],
#  ['MEDIEVAL',
#   'RENAISSANCE',
#   'BAROQUE',
#   'CLASSICAL',
#   'ROMANTIC',
#   'MODERN',
#   'CONTEMPORARY',
#   'CLASSICAL'],
#  ['CELTIC',
#   'NORDIC',
#   'AFRICAN',
#   'ASIAN',
#   'EUROPEAN',
#   'NORTH-AMERICAN',
#   'LATIN',
#   'APPALACHIAN',
#   'SYMPHONY',
#   'CHAMBER',
#   'OPERA',
#   'SOLO',
#   'VOCAL',
#   'FOLK'],
#  ['HYMNS',
#   'PSALMS',
#   'CHANTS',
#   'MILITARY MUSIC',
#   'MARCH MUSIC',
#   'CABARET',
#   'VAUDEVILLE',
#   'MUSICAL',
#   'SOUNDTRACKS',
#   'FILM',
#   'TV',
#   'GAME',
#   'PLAY MUSIC',
#   'UTILITY']]

# %% [markdown]
# ## word2vec

# %% [markdown]
# ### preprocessing

# %%
import nltk
import pandas as pd
import gensim
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
cv = CountVectorizer(ngram_range=(1,4), min_df=10)

# %%
np.nan
# Out:
# nan

# %%
[i for i in songs.query('art_genres != "[]"').art_genres]
# Out:
# ["['chanson', 'french rock']",
#  "['cha-cha-cha', 'cuban rumba', 'latin', 'latin jazz', 'mambo', 'salsa', 'tropical']",
#  "['deep indian pop', 'filmi', 'tamil worship']",
#  "['classic soundtrack', 'italian soundtrack', 'soundtrack', 'vintage italian soundtrack']",
#  "['adult standards', 'bossa nova', 'brazilian jazz', 'latin classical', 'mpb', 'violao']",
#  "['motown', 'rhythm and blues']",
#  "['bossa nova', 'mpb', 'samba de roda']",
#  "['baroque pop', 'brill building pop', 'classic rock', 'folk rock', 'psychedelic rock', 'rock', 'sunshine pop']",
#  "['classic soundtrack', 'scorecore', 'soundtrack', 'theme']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'classic rock', 'folk rock', 'mellow gold', 'rock', 'rock-and-roll', 'rockabilly', 'soft rock']",
#  "['accordion', 'baiao', 'forro', 'forro tradicional', 'mpb', 'samba', 'velha guarda']",
#  "['nashville sound']",
#  "['brill building pop', 'classic soul', 'funk', 'motown', 'soul']",
#  "['brega', 'jovem guarda']",
#  "['adult standards', 'brill building pop', 'chicago soul', 'classic soul', 'motown', 'quiet storm', 'rhythm and blues', 'rock-and-roll', 'rockabilly', 'soul']",
#  "['bossa nova', 'mpb', 'samba de roda']",
#  "['orchestra']",
#  nan,
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'folk rock', 'mellow gold', 'rock-and-roll', 'rockabilly', 'sunshine pop']",
#  "['adult standards', 'funk', 'motown', 'quiet storm', 'soul']",
#  "['sleep']",
#  "['art pop', 'art rock', 'baroque pop', 'chamber pop', 'experimental', 'experimental rock', 'melancholia', 'post-punk', 'singer-songwriter', 'slow core']",
#  "['classical', 'italian opera', 'post-romantic era']",
#  "['louisiana blues', 'new orleans blues', 'new orleans funk', 'rhythm and blues']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'doo-wop', 'folk rock', 'merseybeat', 'rock-and-roll', 'rockabilly']",
#  "['beatlesque', 'british invasion', 'classic rock', 'merseybeat', 'psychedelic rock', 'rock']",
#  "['album rock', 'art rock', 'classic rock', 'experimental', 'experimental rock', 'hard rock', 'instrumental rock', 'jazz fusion', 'jazz rock', 'progressive rock', 'protopunk', 'psychedelic rock', 'rock', 'symphonic rock', 'zolo']",
#  "['deep indian pop', 'filmi', 'tamil worship']",
#  "['adult standards', 'brill building pop', 'chicago soul', 'classic soul', 'motown', 'quiet storm', 'rhythm and blues', 'rock-and-roll', 'rockabilly', 'soul']",
#  "['bolero', 'latin pop', 'mexican rock-and-roll', 'ranchera']",
#  "['adult standards', 'classic soul', 'jazz blues', 'piano blues', 'soul', 'soul blues', 'vocal jazz']",
#  "['classical', 'post-romantic era', 'violin']",
#  "['brega', 'jovem guarda']",
#  "['adult standards', 'bossa nova', 'brazilian jazz', 'latin classical', 'mpb', 'violao']",
#  "['banda', 'grupera', 'mariachi', 'norteno', 'ranchera', 'regional mexican']",
#  nan,
#  "['cantautor', 'nova canco', 'nueva cancion', 'spanish pop', 'trova']",
#  "['brill building pop', 'bubblegum pop', 'merseybeat']",
#  "['adult standards', 'brill building pop', 'classic girl group', 'disco', 'folk rock', 'funk', 'motown', 'quiet storm', 'soul']",
#  "['bolero', 'charanga', 'latin jazz', 'mambo', 'salsa', 'salsa international', 'salsa puertorriquena']",
#  nan,
#  "['classic soul', 'funk', 'motown', 'northern soul', 'quiet storm', 'soul']",
#  "['adult standards', 'easy listening', 'lounge', 'vocal jazz']",
#  "['poetry']",
#  "['bolero', 'cumbia', 'latin jazz', 'mambo', 'salsa', 'tropical']",
#  "['avant-garde', 'avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz funk', 'jazz saxophone', 'soul jazz']",
#  "['deep indian pop', 'filmi', 'tamil worship']",
#  "['brill building pop', 'chicago soul', 'classic soul', 'funk', 'memphis soul', 'motown', 'quiet storm', 'soul', 'southern soul']",
#  "['big band', 'jazz orchestra', 'jazz trumpet']",
#  "['bolero', 'mexican classic rock', 'mexican rock-and-roll', 'ranchera', 'rockabilly en espanol']",
#  "['accordion', 'baiao', 'forro', 'forro tradicional', 'mpb', 'samba', 'velha guarda']",
#  nan,
#  "['bossa nova', 'brega', 'forro', 'mpb', 'samba', 'velha guarda']",
#  "['adult standards', 'nashville sound']",
#  "['beatlesque', 'british invasion', 'classic rock', 'merseybeat', 'psychedelic rock', 'rock']",
#  "['bossa nova', 'brazilian composition', 'choro', 'velha guarda', 'violao']",
#  "['chanson']",
#  "['andean', 'cantautor', 'nueva cancion', 'trova']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'folk rock', 'lounge', 'mellow gold', 'merseybeat', 'rockabilly', 'soft rock']",
#  "['library music', 'spytrack']",
#  "['sleep']",
#  "['brill building pop', 'deep adult standards', 'rhythm and blues', 'rock-and-roll', 'rockabilly']",
#  "['classic soul', 'funk', 'motown', 'philly soul', 'quiet storm', 'southern soul']",
#  "['bolero', 'latin jazz', 'mambo', 'space age pop']",
#  "['adult standards', 'brill building pop', 'motown', 'rock-and-roll', 'soul', 'southern soul']",
#  nan,
#  "['brill building pop', 'chicago soul', 'classic soul', 'motown', 'rhythm and blues', 'soul', 'southern soul']",
#  "['bubblegum pop', 'classic garage rock', 'cosmic american', 'country rock', 'pub rock']",
#  "['jazz vibraphone', 'soul jazz']",
#  "['brill building pop', 'bubblegum pop', 'classic canadian rock', 'folk rock']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'easy listening', 'folk', 'folk rock', 'lounge', 'mellow gold', 'merseybeat', 'rock-and-roll', 'soft rock']",
#  "['brill building pop', 'classic girl group', 'motown', 'northern soul']",
#  "['surf music']",
#  "['brill building pop', 'bubblegum pop', 'classic rock', 'folk rock', 'merseybeat']",
#  "['ranchera']",
#  "['adult standards', 'brill building pop', 'british invasion', 'bubblegum pop', 'classic rock', 'folk', 'folk rock', 'mellow gold', 'merseybeat', 'rock-and-roll']",
#  "['american modern classical', 'poetry']",
#  "['acid rock', 'album rock', 'classic rock', 'psychedelic rock', 'rock']",
#  "['classic garage rock']",
#  "['easy listening', 'exotica', 'library music', 'lounge', 'moog', 'spytrack']",
#  "['chanson', 'ye ye']",
#  "['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'electric bass', 'free jazz', 'hard bop', 'jazz', 'jazz double bass', 'jazz fusion']",
#  "['bossa nova', 'forro', 'mpb', 'samba', 'violao']",
#  nan,
#  "['french soundtrack', 'oriental classical']",
#  "['early reggae', 'rock steady']",
#  "['british modern classical', 'classical', 'neoclassicism']",
#  "['adult standards', 'brill building pop', 'british invasion', 'bubblegum pop', 'classic uk pop', 'folk rock', 'merseybeat', 'rock-and-roll', 'rockabilly']",
#  nan,
#  "['art pop', 'art rock', 'baroque pop', 'chamber pop', 'experimental', 'experimental rock', 'melancholia', 'post-punk', 'singer-songwriter', 'slow core']",
#  "['classical', 'italian opera', 'post-romantic era']",
#  "['brill building pop', 'classic girl group']",
#  "['acoustic pop', 'canadian folk', 'canadian indie', 'canadian singer-songwriter', 'deep new americana', 'indie anthem-folk', 'indie folk', 'indiecoustica', 'neo mellow', 'new americana', 'stomp and holler']",
#  "['classic soundtrack', 'italian soundtrack', 'soundtrack', 'vintage italian soundtrack']",
#  "['dub', 'early reggae', 'reggae', 'rock steady', 'roots reggae', 'ska', 'ska jazz']",
#  "['adult standards', 'classic soul', 'jazz blues', 'memphis soul', 'soul', 'southern soul']",
#  "['funk', 'instrumental soul', 'jazz funk', 'jazz fusion', 'jazz piano', 'smooth jazz', 'soul jazz']",
#  "['sleep']",
#  "['alternative rock', 'blues rock', 'classic rock', 'dance rock', 'garage rock', 'new wave', 'permanent wave', 'post-punk', 'protopunk', 'psychedelic rock', 'punk', 'punk blues', 'rock']",
#  "['vintage italian soundtrack']",
#  "['american folk revival', 'appalachian folk', 'bluegrass', 'country rock', 'folk', 'jam band', 'new americana', 'old-time', 'progressive bluegrass', 'traditional folk']",
#  "['sleep']",
#  "['classic soundtrack', 'scorecore', 'soundtrack', 'theme']",
#  "['classic soundtrack', 'italian soundtrack', 'soundtrack', 'vintage italian soundtrack']",
#  "['bakersfield sound', 'traditional country', 'traditional folk', 'western swing']",
#  "['adult standards', 'bossa nova', 'brazilian jazz', 'latin classical', 'mpb', 'violao']",
#  "['classical', 'classical era']",
#  "['mambo']",
#  "['chicago soul', 'doo-wop']",
#  "['classic soul', 'soul', 'southern soul']",
#  "['latin jazz', 'mambo', 'salsa']",
#  "['nashville sound']",
#  "['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free improvisation', 'free jazz', 'hard bop', 'indie jazz', 'jazz', 'jazz funk', 'jazz saxophone', 'spiritual jazz']",
#  "['honky tonk', 'western swing']",
#  "['adult standards', 'brill building pop', 'calypso', 'lounge']",
#  "['british invasion', 'bubblegum pop', 'merseybeat']",
#  "['deep indian pop', 'filmi', 'tamil worship']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'doo-wop', 'folk rock', 'merseybeat', 'rock-and-roll', 'rockabilly']",
#  "['brill building pop', 'classic girl group', 'classic soul', 'motown', 'rhythm and blues', 'soul', 'southern soul']",
#  "['classic garage rock', 'freakbeat']",
#  "['chanson', 'french rock']",
#  "['classical', 'classical performance', 'orchestra']",
#  "['avant-garde jazz', 'bebop', 'big band', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz saxophone', 'soul jazz']",
#  "['adult standards', 'brill building pop', 'classic girl group', 'disco', 'folk rock', 'funk', 'motown', 'quiet storm', 'soul']",
#  "['rhythm and blues', 'rock-and-roll', 'rockabilly', 'surf music']",
#  "['pop edm']",
#  "['classical performance']",
#  "['arkansas country', 'country', 'country rock']",
#  "['beatlesque', 'british invasion', 'classic rock', 'merseybeat', 'psychedelic rock', 'rock']",
#  "['classic soundtrack', 'soundtrack', 'theme']",
#  "['adult standards', 'funk', 'motown', 'quiet storm', 'soul']",
#  "['halloween']",
#  "['forro', 'forro tradicional']",
#  "['adult standards', 'brill building pop', 'easy listening', 'lounge']",
#  "['adult standards', 'brill building pop', 'motown', 'rock-and-roll', 'soul', 'southern soul']",
#  "['classic soundtrack', 'lounge', 'vintage italian soundtrack']",
#  "['classic soundtrack', 'french soundtrack', 'soundtrack']",
#  "['krautrock']",
#  "['bolero', 'grupera', 'mariachi', 'ranchera']",
#  "['motown', 'northern soul', 'soul']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'doo-wop', 'merseybeat', 'nashville sound', 'rock-and-roll', 'rockabilly']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'classic uk pop', 'merseybeat', 'rock-and-roll']",
#  "['chanson']",
#  "['classic soundtrack', 'lounge', 'vintage italian soundtrack']",
#  "['doo-wop', 'rhythm and blues']",
#  "['bossa nova', 'mangue bit', 'mpb', 'pagode', 'samba', 'samba-rock']",
#  "['charanga', 'mambo']",
#  "['album rock', 'art rock', 'british invasion', 'classic rock', 'dance rock', 'folk rock', 'glam rock', 'mellow gold', 'protopunk', 'psychedelic rock', 'rock', 'roots rock']",
#  "['adult standards', 'brill building pop', 'easy listening', 'lounge']",
#  "['classic soundtrack', 'scorecore', 'soundtrack', 'theme']",
#  "['chanson', 'classic soundtrack', 'french jazz', 'french soundtrack']",
#  "['library music', 'spytrack']",
#  "['sleep']",
#  "['brill building pop', 'bubblegum pop', 'classic rock', 'country rock', 'folk', 'folk rock', 'mellow gold', 'merseybeat', 'psychedelic rock', 'rock', 'rock-and-roll', 'roots rock', 'soft rock', 'traditional folk']",
#  "['album rock', 'art rock', 'classic rock', 'experimental', 'experimental rock', 'hard rock', 'instrumental rock', 'jazz fusion', 'jazz rock', 'progressive rock', 'protopunk', 'psychedelic rock', 'rock', 'symphonic rock', 'zolo']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'doo-wop', 'merseybeat', 'nashville sound', 'rock-and-roll', 'rockabilly']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'folk rock', 'merseybeat', 'rock-and-roll']",
#  "['jazz orchestra']",
#  "['classic soundtrack', 'scorecore', 'soundtrack', 'theme']",
#  "['adult standards', 'nashville sound']",
#  "['american folk revival']",
#  "['grupera', 'mariachi', 'ranchera']",
#  "['chanson', 'french pop', 'french rock', 'ye ye']",
#  "['adult standards', 'brill building pop', 'classic rock', 'classic soul', 'folk rock', 'funk', 'memphis soul', 'motown', 'rock-and-roll', 'soul', 'southern soul']",
#  "['classic soundtrack', 'scorecore', 'soundtrack', 'theme']",
#  "['surf music']",
#  nan,
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'doo-wop', 'rock-and-roll', 'rockabilly']",
#  "['acid rock', 'blues rock', 'classic garage rock', 'hard rock', 'protopunk', 'psychedelic blues-rock', 'psychedelic rock']",
#  "['baiao', 'forro', 'forro tradicional']",
#  "['art rock', 'blues rock', 'british blues', 'british invasion', 'classic garage rock', 'classic rock', 'country rock', 'experimental', 'experimental rock', 'folk rock', 'freakbeat', 'garage rock', 'merseybeat', 'protopunk', 'psychedelic rock', 'pub rock']",
#  "['album rock', 'art rock', 'blues rock', 'british blues', 'classic rock', 'country rock', 'electric blues', 'folk', 'folk rock', 'hard rock', 'jam band', 'mellow gold', 'progressive rock', 'psychedelic rock', 'rock', 'roots rock', 'soft rock', 'symphonic rock']",
#  "['classic soundtrack', 'french soundtrack']",
#  "['grupera', 'mariachi', 'ranchera']",
#  "['sleep']",
#  "['adult standards', 'brill building pop', 'easy listening', 'lounge', 'rockabilly']",
#  "['adult standards', 'brill building pop', 'folk', 'folk rock', 'mellow gold', 'singer-songwriter', 'soft rock', 'yacht rock']",
#  "['andean', 'cantautor', 'nueva cancion', 'trova']",
#  "['bolero', 'grupera', 'mariachi', 'ranchera']",
#  "['cantautor', 'nova canco', 'nueva cancion', 'spanish pop', 'trova']",
#  "['brill building pop', 'bubblegum pop', 'folk rock', 'merseybeat']",
#  "['afrobeat', 'afropop', 'ethio-jazz', 'funk', 'world']",
#  "['classical', 'classical era']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'easy listening', 'lounge', 'rock-and-roll']",
#  "['rock-and-roll', 'rockabilly', 'surf music']",
#  "['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz piano', 'soul jazz', 'stride', 'vocal jazz']",
#  "['brill building pop', 'doo-wop', 'motown', 'rhythm and blues', 'rock-and-roll', 'rockabilly', 'soul']",
#  nan,
#  "['pop', 'post-teen pop', 'uk pop']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'doo-wop', 'merseybeat', 'nashville sound', 'rock-and-roll', 'rockabilly']",
#  "['brill building pop', 'deep adult standards', 'rhythm and blues', 'rock-and-roll', 'rockabilly']",
#  "['classic soundtrack', 'scorecore', 'soundtrack', 'theme']",
#  "['american primitive', 'drone folk', 'experimental', 'fingerstyle', 'folk', 'folk rock', 'freak folk', 'traditional blues', 'traditional folk']",
#  "['adult standards', 'disco', 'mellow gold', 'soft rock']",
#  "['avant-garde jazz', 'bebop', 'big band', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz funk', 'jazz trumpet', 'soul jazz']",
#  "['classic soundtrack', 'soundtrack', 'theme']",
#  "['bolero', 'charanga', 'latin jazz', 'mambo', 'salsa', 'salsa international', 'salsa puertorriquena']",
#  "['blues rock', 'classic rock', 'rock', 'rock-and-roll', 'rockabilly', 'roots rock', 'soul']",
#  "['bubblegum pop', 'classic garage rock', 'freakbeat', 'protopunk', 'psychedelic rock']",
#  nan,
#  "['classic uk pop']",
#  "['classic soundtrack', 'scorecore', 'soundtrack', 'theme']",
#  "['orchestra']",
#  "['classic soul', 'funk', 'motown', 'northern soul', 'quiet storm', 'soul']",
#  "['classic soul', 'funk', 'motown', 'northern soul', 'quiet storm', 'soul']",
#  "['adult standards', 'british soundtrack', 'classic soundtrack', 'scorecore', 'soundtrack']",
#  "['classic soundtrack', 'lounge', 'vintage italian soundtrack']",
#  "['deep adult standards']",
#  "['brill building pop', 'chicago soul', 'classic soul', 'funk', 'motown', 'quiet storm', 'rhythm and blues', 'soul']",
#  "['rhythm and blues', 'southern soul']",
#  "['classic soundtrack', 'lounge', 'vintage italian soundtrack']",
#  "['bossa nova', 'brazilian jazz', 'samba']",
#  "['adult standards', 'brill building pop', 'easy listening', 'lounge']",
#  "['early romantic era', 'italian opera']",
#  "['poetry']",
#  "['album rock', 'art rock', 'classic rock', 'experimental', 'experimental rock', 'hard rock', 'instrumental rock', 'jazz fusion', 'jazz rock', 'progressive rock', 'protopunk', 'psychedelic rock', 'rock', 'symphonic rock', 'zolo']",
#  "['poetry']",
#  "['adult standards', 'brill building pop', 'easy listening', 'lounge']",
#  "['art pop', 'art rock', 'baroque pop', 'chamber pop', 'experimental', 'experimental rock', 'melancholia', 'post-punk', 'singer-songwriter', 'slow core']",
#  "['surf music']",
#  "['comic', 'zolo']",
#  "['classic soundtrack', 'italian soundtrack', 'soundtrack', 'vintage italian soundtrack']",
#  "['adult standards', 'easy listening', 'lounge']",
#  "['adult standards', 'brill building pop', 'folk', 'folk rock', 'mellow gold', 'singer-songwriter', 'soft rock', 'yacht rock']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'easy listening', 'folk', 'folk rock', 'lounge', 'mellow gold', 'merseybeat', 'rock-and-roll', 'soft rock']",
#  "['funk', 'motown', 'soul']",
#  "['adult standards', 'british invasion', 'mellow gold']",
#  "['avant-garde', 'avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz funk', 'jazz saxophone', 'soul jazz']",
#  "['italian library music', 'spytrack']",
#  "['library music']",
#  "['classic garage rock', 'experimental rock', 'folk rock', 'freakbeat', 'neo-psychedelic', 'psychedelic rock']",
#  "['brega', 'jovem guarda']",
#  "['motown', 'northern soul']",
#  "['bossa nova', 'brazilian composition', 'brazilian jazz', 'jazz guitar', 'violao']",
#  "['adult standards', 'brill building pop', 'calypso', 'lounge']",
#  "['american modern classical', 'classical', 'classical performance', 'orchestral performance']",
#  "['classic soul', 'funk', 'motown', 'northern soul', 'quiet storm', 'soul']",
#  "['latin jazz', 'mambo', 'salsa']",
#  "['bolero', 'mariachi', 'ranchera']",
#  "['brill building pop', 'bubblegum pop', 'classic rock', 'country rock', 'folk rock', 'mellow gold', 'merseybeat', 'motown', 'psychedelic rock', 'rock-and-roll']",
#  "['chanson', 'french rock']",
#  "['bolero', 'charanga', 'latin jazz', 'mambo', 'salsa', 'salsa international', 'salsa puertorriquena']",
#  "['surf music']",
#  "['classic soundtrack']",
#  "['album rock', 'art rock', 'british invasion', 'classic rock', 'country rock', 'folk', 'folk rock', 'hard rock', 'mellow gold', 'progressive rock', 'psychedelic rock', 'rock', 'roots rock', 'soft rock', 'symphonic rock']",
#  "['art rock', 'beatlesque', 'blues rock', 'brill building pop', 'classic rock', 'cosmic american', 'country rock', 'folk', 'folk rock', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'soft rock', 'traditional folk']",
#  nan,
#  "['adult standards', 'easy listening', 'lounge']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'deep adult standards', 'doo-wop', 'merseybeat', 'rock-and-roll', 'rockabilly']",
#  nan,
#  "['bolero', 'mariachi', 'ranchera']",
#  "['brill building pop', 'classic girl group', 'classic soul', 'doo-wop', 'rhythm and blues']",
#  "['bolero', 'latin pop', 'mexican rock-and-roll', 'ranchera']",
#  "['french soundtrack', 'oriental classical']",
#  nan,
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'folk rock', 'lounge', 'motown', 'rock-and-roll', 'rockabilly', 'soul']",
#  "['library music', 'light music']",
#  "['bossa nova', 'bossa nova jazz', 'violao']",
#  "['adult standards', 'jazz blues', 'swing', 'vocal jazz']",
#  "['big band']",
#  "['classic soundtrack', 'scorecore', 'soundtrack', 'theme']",
#  "['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz quartet', 'jazz saxophone']",
#  "['classical', 'italian opera', 'post-romantic era']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'easy listening', 'lounge', 'vocal harmony group']",
#  "['classic soul', 'memphis soul', 'motown', 'soul', 'southern soul']",
#  nan,
#  "['classical', 'italian opera', 'late romantic era']",
#  "['deep indian pop', 'filmi', 'tamil worship']",
#  "['brill building pop', 'classic soul', 'funk', 'motown', 'soul', 'soul blues', 'southern soul', 'vocal jazz']",
#  "['bossa nova', 'fado', 'mpb', 'samba']",
#  "['early romantic era', 'italian opera']",
#  "['adult standards', 'brill building pop', 'classic girl group', 'doo-wop', 'motown', 'rhythm and blues', 'rock-and-roll', 'rockabilly', 'soul']",
#  "['adult standards', 'brill building pop', 'folk', 'folk rock', 'mellow gold', 'singer-songwriter', 'soft rock', 'yacht rock']",
#  "['beatlesque', 'brill building pop', 'bubblegum pop', 'classic rock', 'country rock', 'folk rock', 'mellow gold', 'psychedelic rock', 'rock', 'rock-and-roll', 'soft rock', 'sunshine pop']",
#  nan,
#  "['classic soundtrack', 'scorecore', 'soundtrack', 'theme']",
#  "['motown']",
#  "['classic soul', 'funk', 'instrumental soul', 'memphis soul', 'motown', 'rhythm and blues', 'soul']",
#  "['adult standards', 'brill building pop', 'chicago soul', 'classic soul', 'motown', 'quiet storm', 'rhythm and blues', 'rock-and-roll', 'rockabilly', 'soul']",
#  nan,
#  "['classic soul', 'funk', 'memphis soul', 'soul', 'soul blues', 'southern soul']",
#  "['baroque', 'classical', 'early music', 'english baroque', 'german baroque']",
#  nan,
#  "['andean', 'cantautor', 'nueva cancion', 'trova']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'classic girl group', 'folk rock', 'rock-and-roll']",
#  "['classic girl group']",
#  "['album rock', 'art rock', 'blues rock', 'british blues', 'british invasion', 'classic rock', 'country rock', 'electric blues', 'folk rock', 'hard rock', 'psychedelic rock', 'rock', 'roots rock', 'symphonic rock']",
#  "['american folk revival', 'folk', 'folk rock', 'traditional folk']",
#  "['halloween']",
#  "['deep indian pop', 'filmi', 'tamil worship']",
#  "['brill building pop', 'british invasion', 'bubblegum pop', 'classic garage rock', 'classic rock', 'folk rock', 'merseybeat', 'rock-and-roll']",
#  "['sleep']",
#  "['adult standards', 'brill building pop', 'calypso', 'lounge']",
#  "['bubblegum pop', 'motown']",
#  "['orchestra']",
#  "['cha-cha-cha', 'cuban rumba', 'latin', 'latin jazz', 'mambo', 'salsa', 'tropical']",
#  "['french soundtrack', 'oriental classical']",
#  "['beatlesque', 'british invasion', 'classic rock', 'merseybeat', 'psychedelic rock', 'rock']",
#  "['adult standards', 'arkansas country', 'brill building pop', 'bubblegum pop', 'classic country pop', 'folk', 'folk rock', 'lounge', 'mellow gold', 'nashville sound', 'soft rock', 'traditional folk']",
#  "['brill building pop', 'deep adult standards', 'doo-wop', 'rhythm and blues', 'rock-and-roll', 'rockabilly']",
#  "['classic soundtrack', 'french soundtrack', 'soundtrack']",
#  "['album rock', 'art rock', 'classic rock', 'experimental', 'experimental rock', 'hard rock', 'instrumental rock', 'jazz fusion', 'jazz rock', 'progressive rock', 'protopunk', 'psychedelic rock', 'rock', 'symphonic rock', 'zolo']",
#  "['poetry']",
#  "['classical', 'italian opera', 'late romantic era']",
#  "['adult standards', 'ballroom', 'easy listening', 'lounge']",
#  "['classical', 'italian opera', 'post-romantic era']",
#  "['poetry']",
#  "['funk', 'memphis soul', 'motown', 'quiet storm', 'soul', 'soul blues', 'southern soul']",
#  nan,
#  "['rock-and-roll', 'rockabilly', 'surf music']",
#  "['classic soul', 'motown', 'northern soul']",
#  "['country rock', 'folk', 'folk rock', 'traditional folk', 'yacht rock']",
#  "['adult standards', 'easy listening', 'lounge', 'vocal jazz']",
#  "['adult standards', 'brill building pop', 'british invasion', 'bubblegum pop', 'classic rock', 'folk', 'folk rock', 'mellow gold', 'merseybeat', 'rock-and-roll']",
#  "['adult standards', 'brill building pop', 'british invasion', 'bubblegum pop', 'classic rock', 'folk', 'folk rock', 'mellow gold', 'merseybeat', 'rock-and-roll']",
#  "['radio symphony']",
#  "['krautrock']",
#  nan,
#  "['comic', 'zolo']",
#  "['jazz rock', 'krautrock']",
#  "['classic girl group']",
#  nan,
#  "['grupera', 'mariachi', 'ranchera']",
#  "['vintage italian soundtrack']",
#  "['early romantic era', 'italian opera']",
#  "['classic soundtrack', 'scorecore', 'soundtrack', 'theme']",
#  "['baroque pop', 'country rock', 'experimental', 'folk rock', 'oklahoma country', 'psychedelic rock', 'singer-songwriter', 'traditional folk']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'folk rock', 'merseybeat', 'rock-and-roll']",
#  "['adult standards', 'vocal jazz']",
#  nan,
#  "['adult standards', 'easy listening', 'lounge', 'vocal jazz']",
#  "['classic soundtrack', 'scorecore', 'soundtrack', 'theme']",
#  nan,
#  "['grupera', 'mariachi', 'ranchera']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'doo-wop', 'rock-and-roll', 'rockabilly']",
#  "['brill building pop', 'classic girl group', 'classic soul', 'doo-wop', 'rhythm and blues']",
#  "['rock-and-roll']",
#  "['cowboy western', 'nashville sound']",
#  "['adult standards', 'brill building pop', 'calypso', 'lounge']",
#  "['adult standards', 'brill building pop', 'doo-wop', 'louisiana blues', 'memphis blues', 'new orleans blues', 'rhythm and blues', 'rock-and-roll', 'rockabilly']",
#  "['classic soul', 'disco', 'funk', 'motown', 'philly soul', 'quiet storm', 'soul', 'southern soul']",
#  "['adult standards', 'classic soul', 'jazz blues', 'memphis soul', 'soul', 'southern soul']",
#  "['brill building pop', 'chicago soul', 'doo-wop', 'rhythm and blues', 'rock-and-roll']",
#  "['adult standards', 'brill building pop', 'calypso', 'lounge']",
#  "['avant-garde jazz', 'experimental', 'free improvisation', 'free jazz', 'jazz saxophone']",
#  "['adult standards', 'brill building pop', 'easy listening', 'lounge']",
#  "['classic soundtrack', 'italian soundtrack', 'soundtrack', 'vintage italian soundtrack']",
#  "['classic soundtrack', 'vintage italian soundtrack']",
#  "['spiritual jazz']",
#  nan,
#  "['art rock', 'experimental', 'experimental rock', 'industrial', 'no wave', 'post-punk', 'psychedelic rock', 'zolo']",
#  "['blues', 'chicago blues', 'electric blues', 'harmonica blues', 'rock-and-roll', 'traditional blues']",
#  "['acid rock', 'art rock', 'classic rock', 'folk rock', 'psychedelic rock', 'rock', 'roots rock']",
#  "['art rock', 'experimental', 'experimental rock', 'industrial', 'no wave', 'post-punk', 'psychedelic rock', 'zolo']",
#  "['american modern classical', 'classical', 'early modern classical']",
#  "['traditional rockabilly']",
#  "['early reggae', 'rock steady']",
#  "['adult standards', 'brill building pop', 'canadian pop', 'easy listening', 'lounge', 'rock-and-roll']",
#  "['adult standards', 'british soundtrack', 'classic soundtrack', 'scorecore', 'soundtrack']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'easy listening', 'lounge', 'rock-and-roll']",
#  "['classic girl group', 'disco', 'motown', 'philly soul', 'quiet storm']",
#  nan,
#  "['adult standards', 'brill building pop', 'disco', 'lounge', 'mellow gold', 'motown', 'quiet storm', 'soft rock', 'soul']",
#  "['bolero', 'cumbia', 'latin jazz', 'mambo', 'salsa', 'tropical']",
#  "['latin jazz', 'mambo', 'salsa']",
#  "['classical', 'italian opera', 'late romantic era']",
#  "['classic soundtrack', 'soundtrack', 'theme']",
#  "['bossa nova', 'mangue bit', 'mpb', 'pagode', 'samba', 'samba-rock']",
#  "['action rock', 'alternative roots rock', 'psychobilly']",
#  "['jazz orchestra']",
#  "['classical', 'italian opera', 'post-romantic era']",
#  "['poetry']",
#  "['adult standards', 'brill building pop', 'calypso', 'lounge']",
#  "['jovem guarda', 'mpb']",
#  "['cowboy western', 'nashville sound']",
#  "['album rock', 'art rock', 'british blues', 'classic rock', 'hard rock', 'progressive rock', 'symphonic rock']",
#  "['cantautor']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'folk rock', 'lounge', 'motown', 'rock-and-roll', 'rockabilly', 'soul']",
#  "['adult standards', 'brill building pop', 'classic soul', 'disco', 'folk rock', 'funk', 'mellow gold', 'motown', 'quiet storm', 'soul']",
#  "['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz drums', 'jazz funk', 'soul jazz']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'folk rock', 'merseybeat', 'rock-and-roll']",
#  nan,
#  "['latin jazz', 'mambo', 'salsa']",
#  "['adult standards', 'easy listening']",
#  "['memphis soul', 'southern soul']",
#  "['brega', 'jovem guarda']",
#  "['bossa nova', 'brazilian indie', 'brazilian psychedelic', 'brazilian rock', 'mpb', 'psychedelic rock', 'rock gaucho']",
#  "['avant-garde jazz', 'bebop', 'big band', 'contemporary jazz', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz funk', 'jazz fusion', 'jazz trumpet', 'soul jazz', 'vocal jazz']",
#  "['bossa nova', 'bossa nova jazz', 'violao']",
#  "['choro', 'samba', 'velha guarda']",
#  "['adult standards', 'american folk revival', 'lounge']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'merseybeat', 'rock-and-roll']",
#  "['latin jazz', 'mambo', 'salsa']",
#  "['brill building pop', 'bubblegum pop', 'classic garage rock', 'folk rock', 'merseybeat']",
#  "['early reggae', 'rock steady']",
#  "['classic soundtrack', 'soundtrack', 'theme']",
#  "['album rock', 'art rock', 'classic rock', 'experimental', 'experimental rock', 'hard rock', 'instrumental rock', 'jazz fusion', 'jazz rock', 'progressive rock', 'protopunk', 'psychedelic rock', 'rock', 'symphonic rock', 'zolo']",
#  "['cantautor', 'nova canco', 'nueva cancion', 'spanish pop', 'trova']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'folk rock', 'lounge', 'motown', 'rock-and-roll', 'rockabilly', 'soul']",
#  "['comic', 'zolo']",
#  "['radio symphony']",
#  "['adult standards', 'rock-and-roll', 'rockabilly']",
#  "['comic', 'zolo']",
#  "['classic soul', 'motown', 'rhythm and blues', 'soul', 'southern soul']",
#  "['album rock', 'art rock', 'classic rock', 'experimental', 'experimental rock', 'hard rock', 'instrumental rock', 'jazz fusion', 'jazz rock', 'progressive rock', 'protopunk', 'psychedelic rock', 'rock', 'symphonic rock', 'zolo']",
#  nan,
#  "['bandinhas', 'musica nativista', 'sertanejo', 'sertanejo tradicional', 'sertanejo universitario']",
#  "['vintage hollywood']",
#  "['acoustic blues', 'blues', 'blues rock', 'classic rock', 'country blues', 'country rock', 'folk rock', 'funk', 'harmonica blues', 'jam band', 'jazz blues', 'modern blues', 'roots rock', 'soul', 'traditional blues']",
#  "['jovem guarda']",
#  "['classic soundtrack', 'scorecore', 'soundtrack', 'theme']",
#  "['classic soundtrack']",
#  "['classic soundtrack', 'soundtrack', 'theme']",
#  "['soul', 'southern soul']",
#  "['cantautor', 'nova canco', 'nueva cancion', 'spanish pop', 'trova']",
#  "['adult standards', 'classic soul', 'disco', 'lounge', 'motown', 'philly soul', 'quiet storm', 'soul', 'soul blues', 'vocal jazz']",
#  nan,
#  "['brill building pop', 'classic soul', 'funk', 'motown', 'soul', 'soul blues', 'southern soul', 'vocal jazz']",
#  "['classic soundtrack', 'italian soundtrack', 'soundtrack', 'vintage italian soundtrack']",
#  "['brill building pop', 'classic girl group']",
#  "['spytrack']",
#  "['classic soul', 'motown']",
#  "['album rock', 'blues rock', 'british invasion', 'classic rock', 'folk rock', 'protopunk', 'psychedelic rock', 'rock', 'rock-and-roll']",
#  "['adult standards', 'brill building pop', 'calypso', 'lounge']",
#  "['dance pop', 'hollywood', 'new wave pop', 'pop']",
#  nan,
#  "['early romantic era', 'italian opera']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'doo-wop', 'folk rock', 'merseybeat', 'rock-and-roll', 'rockabilly']",
#  "['album rock', 'art rock', 'classic rock', 'experimental', 'experimental rock', 'hard rock', 'instrumental rock', 'jazz fusion', 'jazz rock', 'progressive rock', 'protopunk', 'psychedelic rock', 'rock', 'symphonic rock', 'zolo']",
#  nan,
#  "['acoustic pop', 'canadian folk', 'canadian indie', 'canadian singer-songwriter', 'deep new americana', 'indie anthem-folk', 'indie folk', 'indiecoustica', 'neo mellow', 'new americana', 'stomp and holler']",
#  "['adult standards', 'brill building pop', 'british invasion', 'bubblegum pop', 'classic rock', 'folk', 'folk rock', 'mellow gold', 'merseybeat', 'rock-and-roll']",
#  "['british folk', 'country rock', 'folk', 'folk rock', 'traditional folk']",
#  "['bossa nova', 'mangue bit', 'mpb', 'pagode', 'samba', 'samba-rock']",
#  "['british comedy', 'music hall']",
#  "['adult standards', 'brill building pop', 'easy listening', 'lounge', 'vocal jazz']",
#  "['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz drums', 'jazz funk', 'soul jazz']",
#  "['album rock', 'art rock', 'blues rock', 'british blues', 'british invasion', 'classic rock', 'country rock', 'electric blues', 'folk rock', 'hard rock', 'psychedelic rock', 'rock', 'roots rock', 'symphonic rock']",
#  "['classic soul', 'motown', 'soul']",
#  "['rock-and-roll', 'space age pop', 'surf music']",
#  "['adult standards', 'bossa nova', 'brazilian jazz', 'latin classical', 'mpb', 'violao']",
#  "['classical', 'italian opera', 'late romantic era']",
#  "['latin jazz', 'mambo', 'salsa']",
#  "['classic soul', 'northern soul', 'philly soul']",
#  "['grupera', 'mariachi', 'ranchera']",
#  "['classic soul', 'funk', 'memphis soul', 'soul', 'soul blues', 'southern soul']",
#  "['beach music', 'classic soul', 'motown', 'northern soul', 'rhythm and blues', 'southern soul']",
#  "['vintage italian soundtrack']",
#  nan,
#  "['beatlesque', 'british invasion', 'classic rock', 'merseybeat', 'psychedelic rock', 'rock']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'classic girl group', 'doo-wop', 'folk rock', 'merseybeat', 'motown', 'rhythm and blues', 'rock-and-roll']",
#  "['latin jazz', 'mambo', 'salsa']",
#  "['chanson', 'ye ye']",
#  "['sleep']",
#  "['bolero', 'grupera', 'mariachi', 'ranchera']",
#  "['jazz orchestra']",
#  nan,
#  "['classic soundtrack', 'italian soundtrack', 'soundtrack', 'vintage italian soundtrack']",
#  "['adult standards', 'brill building pop', 'easy listening', 'lounge', 'mellow gold']",
#  "['adult standards', 'brill building pop', 'easy listening', 'lounge', 'vocal jazz']",
#  "['deep indian pop', 'filmi', 'tamil worship']",
#  "['orchestra']",
#  "['classic soundtrack', 'scorecore', 'soundtrack', 'theme']",
#  "['bolero', 'cumbia', 'latin jazz', 'mambo', 'salsa', 'tropical']",
#  "['comic']",
#  "['classic garage rock', 'experimental rock', 'folk rock', 'freakbeat', 'neo-psychedelic', 'psychedelic rock']",
#  nan,
#  "['classic soundtrack', 'french soundtrack', 'soundtrack']",
#  "['classical', 'classical era']",
#  "['brill building pop', 'bubblegum pop', 'folk rock', 'merseybeat', 'rock-and-roll']",
#  "['classic soundtrack', 'italian soundtrack', 'soundtrack', 'vintage italian soundtrack']",
#  "['motown']",
#  nan,
#  "['album rock', 'classic rock', 'country rock', 'folk', 'folk rock', 'mellow gold', 'rock', 'roots rock', 'singer-songwriter']",
#  "['sleep']",
#  "['vintage italian soundtrack']",
#  "['beatlesque', 'british invasion', 'classic rock', 'merseybeat', 'psychedelic rock', 'rock']",
#  "['cowboy western', 'nashville sound']",
#  "['classic soundtrack', 'soundtrack', 'theme']",
#  "['radio symphony']",
#  "['art pop', 'art rock', 'baroque pop', 'chamber pop', 'experimental', 'experimental rock', 'melancholia', 'post-punk', 'singer-songwriter', 'slow core']",
#  "['art rock', 'experimental', 'experimental rock', 'industrial', 'no wave', 'post-punk', 'psychedelic rock', 'zolo']",
#  "['exotica', 'library music', 'lounge', 'moog', 'spytrack']",
#  nan,
#  "['classic soundtrack', 'lounge', 'vintage italian soundtrack']",
#  "['deep indian pop', 'filmi', 'tamil worship']",
#  "['avant-garde jazz', 'bebop', 'big band', 'contemporary jazz', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz funk', 'jazz fusion', 'jazz trumpet', 'soul jazz', 'vocal jazz']",
#  "['classic soundtrack', 'soundtrack', 'theme']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'merseybeat', 'rock-and-roll']",
#  "['bolero', 'mariachi', 'ranchera']",
#  "['art rock', 'canterbury scene', 'experimental', 'experimental rock', 'krautrock', 'progressive rock', 'psychedelic rock', 'space rock', 'symphonic rock']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'doo-wop', 'folk rock', 'merseybeat', 'rock-and-roll', 'rockabilly']",
#  "['adult standards', 'brill building pop', 'classic girl group', 'doo-wop', 'motown', 'rhythm and blues', 'rock-and-roll', 'rockabilly', 'soul']",
#  nan,
#  "['classic soundtrack', 'french soundtrack', 'soundtrack']",
#  "['beatlesque', 'brill building pop', 'bubblegum pop', 'classic rock', 'country rock', 'folk rock', 'mellow gold', 'psychedelic rock', 'rock', 'rock-and-roll', 'soft rock', 'sunshine pop']",
#  "['cantautor', 'nueva cancion', 'trova']",
#  "['french soundtrack', 'oriental classical']",
#  "['american folk revival']",
#  "['orchestra']",
#  "['american modern classical', 'classical', 'early modern classical']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'folk rock', 'mellow gold', 'rock-and-roll', 'rockabilly', 'sunshine pop']",
#  "['classical', 'italian opera', 'late romantic era']",
#  "['adult standards', 'brill building pop', 'chicago soul', 'classic soul', 'motown', 'quiet storm', 'rhythm and blues', 'rock-and-roll', 'rockabilly', 'soul']",
#  "['adult standards', 'brill building pop', 'classic girl group', 'doo-wop', 'motown', 'rhythm and blues', 'rock-and-roll', 'rockabilly', 'soul']",
#  "['blues', 'blues rock', 'chicago blues', 'classic rock', 'country blues', 'electric blues', 'modern blues', 'soul blues', 'traditional blues']",
#  "['bossa nova', 'forro', 'mpb', 'samba', 'violao']",
#  "['adult standards', 'brill building pop', 'easy listening', 'lounge', 'motown', 'rock-and-roll', 'rockabilly', 'soul', 'vocal jazz']",
#  "['acid rock', 'art rock', 'classic rock', 'folk rock', 'psychedelic rock', 'rock', 'roots rock']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'classic girl group', 'motown', 'rock-and-roll', 'rockabilly', 'soul']",
#  "['brill building pop']",
#  "['adult standards', 'nashville sound']",
#  "['classical', 'late romantic era']",
#  nan,
#  "['american modern classical', 'classical', 'early modern classical']",
#  "['afrofuturism', 'afropop', 'art rock', 'avant-garde jazz', 'contemporary post-bop', 'experimental', 'fourth world', 'free jazz', 'indie jazz', 'jazz', 'jazz harp', 'spiritual jazz']",
#  "['adult standards', 'deep adult standards']",
#  "['beach music', 'classic soul', 'motown', 'northern soul', 'rhythm and blues', 'southern soul']",
#  "['space age pop']",
#  "['cantautor', 'nova canco', 'nueva cancion', 'spanish pop', 'trova']",
#  "['adult standards']",
#  "['adult standards', 'bolero']",
#  "['album rock', 'classic rock', 'country rock', 'folk', 'folk rock', 'mellow gold', 'rock', 'roots rock', 'singer-songwriter']",
#  "['album rock', 'art rock', 'british invasion', 'classic rock', 'country rock', 'folk', 'folk rock', 'hard rock', 'mellow gold', 'progressive rock', 'psychedelic rock', 'rock', 'roots rock', 'soft rock', 'symphonic rock']",
#  "['american folk revival', 'appalachian folk', 'banjo', 'folk', 'folk rock', 'old-time', 'traditional folk']",
#  "['avant-garde jazz', 'bebop', 'contemporary jazz', 'contemporary post-bop', 'cool jazz', 'experimental', 'experimental rock', 'free improvisation', 'free jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz saxophone']",
#  "['classic soundtrack', 'soundtrack', 'theme']",
#  "['brega', 'jovem guarda']",
#  "['adult standards', 'album rock', 'brill building pop', 'british invasion', 'bubblegum pop', 'classic rock', 'country rock', 'folk', 'folk rock', 'mellow gold', 'merseybeat', 'psychedelic rock', 'rock', 'rock-and-roll', 'roots rock', 'soft rock']",
#  "['sleep']",
#  "['tamil worship']",
#  "['bebop', 'big band', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz blues', 'jazz funk', 'jazz fusion', 'soul jazz', 'vocal jazz']",
#  "['jovem guarda', 'mpb']",
#  "['country', 'country dawn', 'nashville sound']",
#  "['surf music']",
#  "['sleep']",
#  "['brill building pop', 'classic soul', 'motown', 'rhythm and blues', 'soul']",
#  "['baroque pop', 'brill building pop', 'bubblegum pop', 'classic garage rock', 'folk rock', 'freakbeat', 'jangle pop', 'power pop', 'psychedelic rock']",
#  "['album rock', 'art rock', 'blues rock', 'classic rock', 'folk rock', 'hard rock', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'supergroup']",
#  "['dance pop', 'pop rap']",
#  "['disco']",
#  "['classical', 'italian opera', 'post-romantic era']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'deep adult standards', 'doo-wop', 'merseybeat', 'rock-and-roll', 'rockabilly']",
#  "['beach music', 'motown', 'northern soul']",
#  "['calypso']",
#  "['romantico']",
#  "['album rock', 'classic rock', 'country rock', 'folk', 'folk rock', 'mellow gold', 'rock', 'roots rock', 'singer-songwriter']",
#  "['adult standards', 'brill building pop', 'calypso', 'lounge']",
#  "['brill building pop', 'bubblegum pop', 'folk rock', 'mellow gold', 'rock-and-roll']",
#  "['deep adult standards']",
#  "['adult standards', 'brill building pop']",
#  "['classic soul', 'funk', 'jazz funk', 'soul', 'southern soul']",
#  "['british indie rock']",
#  "['adult standards', 'bolero']",
#  "['grupera', 'mariachi', 'ranchera']",
#  "['beach music']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'folk rock', 'mellow gold', 'rock-and-roll', 'rockabilly', 'sunshine pop']",
#  "['classic soundtrack', 'french soundtrack', 'soundtrack']",
#  "['chicago soul', 'classic soul', 'southern soul']",
#  "['andean', 'cantautor', 'nueva cancion', 'trova']",
#  "['philly soul']",
#  "['brega', 'jovem guarda']",
#  "['classic soundtrack', 'soundtrack', 'theme']",
#  "['acoustic pop', 'canadian folk', 'canadian indie', 'canadian singer-songwriter', 'deep new americana', 'indie anthem-folk', 'indie folk', 'indiecoustica', 'neo mellow', 'new americana', 'stomp and holler']",
#  "['adult standards', 'easy listening', 'lounge', 'vocal jazz']",
#  "['canadian pop', 'dance pop']",
#  "['chanson', 'french soundtrack', 'vintage french electronic']",
#  "['early romantic era', 'italian opera']",
#  "['andean', 'cantautor', 'nueva cancion', 'trova']",
#  "['art pop', 'art rock', 'baroque pop', 'chamber pop', 'experimental', 'experimental rock', 'melancholia', 'post-punk', 'singer-songwriter', 'slow core']",
#  "['chicago soul', 'classic soul', 'southern soul']",
#  "['country', 'country rock', 'folk', 'nashville sound', 'oklahoma country', 'traditional folk']",
#  "['acid rock', 'album rock', 'classic rock', 'psychedelic rock', 'rock']",
#  "['norteno', 'ranchera', 'tejano']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'classic rock', 'folk rock', 'mellow gold', 'rock', 'rock-and-roll', 'rockabilly', 'soft rock']",
#  "['afrobeat', 'electronica', 'funk', 'indie soul', 'nu jazz', 'soul']",
#  "['tamil worship']",
#  "['brill building pop', 'bubblegum pop', 'folk rock', 'merseybeat', 'rock-and-roll']",
#  "['deep adult standards']",
#  "['brill building pop', 'bubblegum pop', 'classic rock', 'country rock', 'folk rock', 'mellow gold', 'merseybeat', 'soft rock', 'sunshine pop']",
#  "['adult standards', 'brill building pop', 'doo-wop', 'rhythm and blues', 'rock-and-roll', 'rockabilly']",
#  "['bubblegum pop', 'classic garage rock', 'freakbeat', 'psychedelic rock']",
#  "['soul', 'southern soul']",
#  "['art pop', 'art rock', 'baroque pop', 'chamber pop', 'experimental', 'experimental rock', 'melancholia', 'post-punk', 'singer-songwriter', 'slow core']",
#  "['french soundtrack', 'oriental classical']",
#  "['avant-garde', 'avant-garde jazz', 'contemporary post-bop', 'cool jazz', 'free improvisation', 'free jazz', 'jazz', 'jazz piano']",
#  "['chanson', 'french rock', 'ye ye']",
#  "['motown', 'rhythm and blues']",
#  "['bossa nova', 'brazilian jazz', 'mpb', 'piano mpb', 'samba']",
#  "['adult standards', 'brill building pop', 'louisiana blues', 'lounge', 'new orleans blues', 'piano blues', 'rhythm and blues', 'rock-and-roll', 'rockabilly', 'soul']",
#  "['latin jazz', 'mambo', 'salsa']",
#  "['vintage italian soundtrack']",
#  "['bossa nova', 'forro', 'mpb', 'samba', 'violao']",
#  "['classical', 'classical era', 'early romantic era']",
#  "['grupera', 'mariachi', 'ranchera']",
#  "['baiao', 'forro', 'forro tradicional']",
#  "['classic soundtrack', 'french soundtrack', 'spytrack', 'vintage french electronic']",
#  "['art rock', 'canterbury scene', 'experimental', 'experimental rock', 'jazz fusion', 'jazz rock', 'progressive rock', 'psychedelic rock', 'space rock', 'symphonic rock', 'zolo']",
#  "['bolero', 'mexican classic rock', 'mexican rock-and-roll', 'ranchera', 'rockabilly en espanol']",
#  "['calypso', 'soca']",
#  "['classic soundtrack', 'soundtrack', 'theme']",
#  "['brill building pop', 'bubblegum pop', 'merseybeat', 'nashville sound', 'rock-and-roll']",
#  "['adult standards', 'nashville sound']",
#  "['latin jazz', 'mambo', 'salsa']",
#  "['baroque pop', 'brill building pop', 'british invasion', 'bubblegum pop', 'classic rock', 'folk rock', 'psychedelic rock', 'rock', 'roots rock']",
#  "['bolero', 'charanga', 'latin jazz', 'mambo', 'salsa', 'salsa international', 'salsa puertorriquena']",
#  "['tamil worship']",
#  "['classic soundtrack', 'theme']",
#  "['chanson', 'classic soundtrack', 'french jazz', 'french soundtrack']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'easy listening', 'folk', 'folk rock', 'lounge', 'mellow gold', 'merseybeat', 'rock-and-roll', 'soft rock']",
#  "['brill building pop', 'deep adult standards', 'rhythm and blues', 'rock-and-roll', 'rockabilly']",
#  "['beach music', 'brill building pop', 'chicago soul', 'classic soul', 'motown', 'northern soul', 'rhythm and blues', 'soul']",
#  "['classic soundtrack', 'scorecore', 'soundtrack', 'theme']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'classic uk pop', 'merseybeat', 'rock-and-roll']",
#  "['monastic']",
#  "['bubblegum dance', 'eurodance', 'europop', 'happy hardcore', 'hip house']",
#  "['bebop', 'hard bop', 'instrumental soul', 'jazz', 'jazz funk', 'soul jazz']",
#  "['baiao', 'forro', 'forro tradicional']",
#  "['novelty', 'outsider']",
#  "['country', 'country rock', 'folk', 'nashville sound', 'oklahoma country', 'traditional folk']",
#  "['adult standards', 'rock-and-roll', 'rockabilly']",
#  "['acid rock']",
#  "['brill building pop', 'british invasion', 'bubblegum pop', 'classic garage rock', 'classic rock', 'folk rock', 'merseybeat', 'rock-and-roll']",
#  "['chanson', 'french soundtrack', 'vintage french electronic']",
#  nan,
#  "['american primitive', 'drone folk', 'experimental', 'fingerstyle', 'folk', 'folk rock', 'freak folk', 'traditional blues', 'traditional folk']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'easy listening', 'lounge', 'rock-and-roll']",
#  "['sleep']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'folk rock', 'merseybeat', 'rock-and-roll']",
#  "['american modern classical', 'classical', 'classical performance', 'orchestral performance']",
#  "['classic soundtrack', 'italian soundtrack', 'soundtrack', 'vintage italian soundtrack']",
#  "['cantautor', 'nova canco', 'nueva cancion', 'spanish pop', 'trova']",
#  "['alternative rock', 'blues rock', 'classic rock', 'dance rock', 'garage rock', 'new wave', 'permanent wave', 'post-punk', 'protopunk', 'psychedelic rock', 'punk', 'punk blues', 'rock']",
#  "['brill building pop', 'bubblegum pop', 'classic garage rock', 'folk rock', 'merseybeat']",
#  "['adult standards', 'brill building pop', 'classic rock', 'classic soul', 'folk rock', 'funk', 'memphis soul', 'motown', 'rock-and-roll', 'soul', 'southern soul']",
#  "['adult standards', 'brill building pop', 'classic girl group', 'disco', 'folk rock', 'funk', 'motown', 'quiet storm', 'soul']",
#  "['ambient folk', 'chamber pop', 'indie folk', 'lancaster pa indie', 'slow core']",
#  "['classic soundtrack', 'french soundtrack', 'spytrack', 'vintage french electronic']",
#  nan,
#  "['blues', 'blues rock', 'chicago blues', 'country rock', 'electric blues', 'harmonica blues', 'psychedelic rock', 'traditional blues']",
# ...
#  "['vintage italian soundtrack']",
#  "['classic soundtrack', 'soundtrack', 'theme']",
#  "['brill building pop', 'doo-wop', 'sunshine pop']",
#  "['album rock', 'art rock', 'british invasion', 'classic rock', 'dance rock', 'folk rock', 'glam rock', 'mellow gold', 'protopunk', 'psychedelic rock', 'rock', 'roots rock']",
#  "['latin jazz', 'mambo', 'salsa']",
#  "['classical', 'finnish classical', 'impressionism', 'post-romantic era']",
#  "['adult standards', 'brill building pop', 'calypso', 'lounge']",
#  "['comic', 'zolo']",
#  "['deep indian pop', 'filmi', 'tamil worship']",
#  "['bossa nova', 'fado', 'mpb', 'samba']",
#  "['adult standards', 'brill building pop', 'classic girl group', 'disco', 'folk rock', 'funk', 'motown', 'quiet storm', 'soul']",
#  "['adult standards', 'brill building pop', 'classic girl group', 'doo-wop', 'motown', 'rhythm and blues', 'rock-and-roll', 'rockabilly', 'soul']",
#  "['christelijk']",
#  "['art rock', 'beatlesque', 'blues rock', 'brill building pop', 'classic rock', 'cosmic american', 'country rock', 'folk', 'folk rock', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'soft rock', 'traditional folk']",
#  "['brill building pop', 'bubblegum pop', 'folk rock', 'merseybeat']",
#  "['album rock', 'art rock', 'classic rock', 'experimental', 'experimental rock', 'hard rock', 'instrumental rock', 'jazz fusion', 'jazz rock', 'progressive rock', 'protopunk', 'psychedelic rock', 'rock', 'symphonic rock', 'zolo']",
#  nan,
#  "['classic polish pop', 'poezja spiewana', 'sung poetry']",
#  "['album rock', 'canadian country', 'canadian folk', 'canadian singer-songwriter', 'classic rock', 'country rock', 'folk', 'folk rock', 'mellow gold', 'rock', 'roots rock', 'singer-songwriter', 'soft rock', 'traditional folk']",
#  "['rhythm and blues']",
#  "['latin jazz', 'mambo', 'salsa']",
#  "['adult standards', 'brill building pop', 'british invasion', 'bubblegum pop', 'classic uk pop', 'merseybeat', 'rock-and-roll']",
#  "['adult standards', 'brill building pop', 'doo-wop', 'rhythm and blues', 'rock-and-roll', 'rockabilly']",
#  "['early romantic era', 'italian opera']",
#  "['adult standards']",
#  "['novelty']",
#  nan,
#  "['funk', 'memphis soul', 'motown', 'quiet storm', 'soul', 'soul blues', 'southern soul']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'easy listening', 'lounge', 'vocal harmony group']",
#  "['classical', 'classical era']",
#  "['brill building pop', 'bubblegum pop', 'folk rock', 'mellow gold', 'rock-and-roll']",
#  "['deep indian pop', 'filmi', 'tamil worship']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'classic rock', 'folk rock', 'mellow gold', 'rock', 'rock-and-roll', 'rockabilly', 'soft rock']",
#  "['adult standards', 'brill building pop', 'british invasion', 'bubblegum pop', 'classic uk pop', 'merseybeat', 'rock-and-roll']",
#  "['brill building pop', 'doo-wop', 'rhythm and blues', 'rock-and-roll']",
#  "['adult standards', 'brill building pop', 'deep adult standards', 'doo-wop', 'rhythm and blues', 'rock-and-roll', 'swamp pop']",
#  "['brill building pop', 'chicago soul', 'classic soul', 'doo-wop', 'motown', 'northern soul', 'rhythm and blues', 'soul', 'southern soul']",
#  "['classic soundtrack', 'scorecore', 'soundtrack', 'theme']",
#  "['space age pop']",
#  "['bolero', 'cumbia', 'latin jazz', 'mambo', 'salsa', 'tropical']",
#  "['ambient', 'berlin school', 'krautrock', 'space rock']",
#  "['adult standards', 'brill building pop', 'motown', 'rock-and-roll', 'soul', 'southern soul']",
#  "['memphis soul', 'southern soul']",
#  "['grupera', 'mariachi', 'ranchera']",
#  "['classical', 'late romantic era', 'russian romanticism']",
#  "['adult standards', 'easy listening', 'lounge']",
#  "['bolero', 'charanga', 'latin jazz', 'mambo', 'salsa', 'salsa international', 'salsa puertorriquena']",
#  "['adult standards', 'brill building pop', 'canadian pop', 'easy listening', 'lounge', 'rock-and-roll']",
#  "['adult standards', 'brill building pop', 'motown', 'rhythm and blues', 'rock-and-roll', 'soul', 'southern soul']",
#  "['chicago soul', 'southern soul']",
#  "['classical', 'italian opera', 'late romantic era']",
#  "['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz drums', 'jazz funk', 'soul jazz']",
#  "['classic soul', 'funk', 'memphis soul', 'soul', 'soul blues', 'southern soul']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'easy listening', 'lounge', 'rock-and-roll']",
#  "['chicago soul', 'classic soul', 'disco', 'funk', 'motown', 'quiet storm', 'soul', 'southern soul']",
#  "['latin jazz', 'mambo', 'salsa']",
#  "['bolero', 'grupera', 'mariachi', 'ranchera']",
#  "['brill building pop', 'bubblegum pop', 'classic garage rock', 'folk rock', 'merseybeat']",
#  "['adult standards', 'disco', 'mellow gold', 'soft rock']",
#  "['adult standards', 'brill building pop', 'easy listening', 'lounge']",
#  "['art pop', 'art rock', 'baroque pop', 'chamber pop', 'experimental', 'experimental rock', 'melancholia', 'post-punk', 'singer-songwriter', 'slow core']",
#  "['bossa nova', 'brega', 'forro', 'mpb', 'samba', 'velha guarda']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'doo-wop', 'folk rock', 'lounge', 'rock-and-roll', 'rockabilly']",
#  "['adult standards', 'brill building pop', 'easy listening', 'lounge', 'rock-and-roll', 'rockabilly']",
#  "['bossa nova', 'forro', 'mpb', 'samba', 'violao']",
#  "['classic soul', 'northern soul', 'philly soul']",
#  "['adult standards', 'disco', 'mellow gold', 'soft rock']",
#  "['brill building pop', 'bubblegum pop', 'folk rock', 'merseybeat', 'rock-and-roll', 'sunshine pop']",
#  "['bolero', 'grupera', 'mariachi', 'ranchera']",
#  "['adult standards', 'classic soul', 'jazz blues', 'memphis soul', 'soul', 'southern soul']",
#  "['adult standards', 'brill building pop', 'louisiana blues', 'lounge', 'new orleans blues', 'piano blues', 'rhythm and blues', 'rock-and-roll', 'rockabilly', 'soul']",
#  "['adult standards', 'brill building pop', 'louisiana blues', 'lounge', 'new orleans blues', 'piano blues', 'rhythm and blues', 'rock-and-roll', 'rockabilly', 'soul']",
#  "['art rock', 'blues rock', 'british blues', 'british invasion', 'classic garage rock', 'classic rock', 'country rock', 'experimental', 'experimental rock', 'folk rock', 'freakbeat', 'garage rock', 'merseybeat', 'protopunk', 'psychedelic rock', 'pub rock']",
#  "['adult standards', 'british invasion', 'mellow gold']",
#  "['adult standards', 'nashville sound']",
#  "['blues rock', 'classic rock', 'folk rock', 'mellow gold', 'rock', 'soft rock']",
#  nan,
#  "['adult standards', 'brill building pop', 'chicago soul', 'classic soul', 'motown', 'quiet storm', 'rhythm and blues', 'rock-and-roll', 'rockabilly', 'soul']",
#  "['classical', 'italian opera', 'post-romantic era']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'deep adult standards', 'doo-wop', 'merseybeat', 'rock-and-roll', 'rockabilly']",
#  "['classical', 'italian opera', 'post-romantic era']",
#  "['brill building pop', 'bubblegum pop', 'classic rock', 'country rock', 'folk', 'folk rock', 'mellow gold', 'merseybeat', 'psychedelic rock', 'rock', 'rock-and-roll', 'roots rock', 'soft rock', 'traditional folk']",
#  "['brill building pop', 'bubblegum pop', 'classic rock', 'country rock', 'folk', 'folk rock', 'mellow gold', 'merseybeat', 'psychedelic rock', 'rock', 'rock-and-roll', 'roots rock', 'soft rock', 'traditional folk']",
#  nan,
#  "['adult standards', 'brill building pop', 'easy listening', 'lounge', 'motown', 'rock-and-roll', 'rockabilly', 'soul', 'vocal jazz']",
#  "['bossa nova', 'brazilian jazz', 'samba']",
#  "['art rock', 'experimental', 'experimental rock', 'industrial', 'no wave', 'post-punk', 'psychedelic rock', 'zolo']",
#  "['adult standards', 'brill building pop', 'easy listening', 'lounge', 'vocal jazz']",
#  "['brazilian hip hop', 'trap brasileiro']",
#  "['adult standards', 'brill building pop', 'calypso', 'lounge']",
#  "['adult standards', 'brill building pop', 'disco', 'lounge', 'mellow gold', 'motown', 'quiet storm', 'soft rock', 'soul']",
#  "['classic soundtrack', 'french soundtrack', 'soundtrack']",
#  "['scorecore']",
#  "['brill building pop', 'classic soul', 'funk', 'louisiana blues', 'new orleans blues', 'rhythm and blues', 'soul', 'southern soul']",
#  "['bolero', 'puerto rican pop']",
#  "['adult standards', 'brill building pop', 'doo-wop']",
#  "['deep indian pop', 'filmi', 'tamil worship']",
#  "['classical', 'late romantic era', 'norwegian classical']",
#  "['calypso', 'soca']",
#  "['blues rock', 'classic rock', 'rock', 'rock-and-roll', 'rockabilly', 'roots rock', 'soul']",
#  "['french soundtrack', 'oriental classical']",
#  "['doo-wop', 'rhythm and blues']",
#  "['adult standards', 'jazz blues', 'lounge', 'soul', 'swing', 'vocal jazz']",
#  "['avant-garde jazz', 'bebop', 'big band', 'contemporary jazz', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz funk', 'jazz fusion', 'jazz trumpet', 'soul jazz', 'vocal jazz']",
#  "['bossa nova', 'brazilian jazz', 'mpb', 'samba', 'velha guarda']",
#  "['classical', 'italian opera', 'late romantic era']",
#  "['classical', 'italian opera', 'post-romantic era']",
#  "['adult standards', 'brill building pop', 'easy listening', 'lounge']",
#  "['cantautor', 'nova canco', 'nueva cancion', 'spanish pop', 'trova']",
#  "['baiao', 'forro', 'forro tradicional']",
#  "['grupera', 'mariachi', 'ranchera']",
#  "['poetry']",
#  "['baroque pop', 'brill building pop', 'classic rock', 'folk rock', 'psychedelic rock', 'rock', 'sunshine pop']",
#  "['classic country pop']",
#  "['chanson', 'french rock']",
#  "['chanson', 'french rock']",
#  "['adult standards']",
#  "['brill building pop', 'classic girl group', 'classic soul', 'motown', 'rhythm and blues', 'soul', 'southern soul']",
#  nan,
#  "['baroque pop', 'brill building pop', 'classic rock', 'folk rock', 'psychedelic rock', 'rock', 'sunshine pop']",
#  "['baroque pop', 'brill building pop', 'classic rock', 'folk rock', 'psychedelic rock', 'rock', 'sunshine pop']",
#  "['adult standards', 'bolero']",
#  nan,
#  "['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz quartet', 'jazz saxophone']",
#  "['forro', 'forro tradicional']",
#  "['art rock', 'experimental', 'experimental rock', 'industrial', 'no wave', 'post-punk', 'psychedelic rock', 'zolo']",
#  "['classic soul', 'motown', 'quiet storm', 'soul']",
#  "['beach music']",
#  nan,
#  "['deep adult standards']",
#  "['library music', 'spytrack']",
#  "['radio symphony']",
#  "['bossa nova', 'brazilian rock', 'brega', 'forro', 'jovem guarda', 'mpb', 'samba', 'velha guarda']",
#  "['chanson']",
#  "['hammond organ', 'spiritual jazz']",
#  "['bossa nova', 'brega', 'forro', 'mpb', 'samba', 'velha guarda']",
#  "['vintage italian soundtrack']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'classic rock', 'folk rock', 'mellow gold', 'rock', 'rock-and-roll', 'rockabilly', 'soft rock']",
#  "['bolero', 'cumbia', 'grupera', 'latin pop', 'ranchera', 'rock en espanol']",
#  "['adult standards', 'brill building pop', 'calypso', 'lounge']",
#  "['album rock', 'classic rock', 'country rock', 'folk', 'folk rock', 'mellow gold', 'rock', 'roots rock', 'singer-songwriter']",
#  "['brill building pop', 'chicago soul', 'classic soul', 'funk', 'motown', 'quiet storm', 'rhythm and blues', 'soul']",
#  "['cantautor', 'nova canco', 'nueva cancion', 'spanish pop', 'trova']",
#  "['chanson', 'classic soundtrack', 'french jazz', 'french soundtrack']",
#  "['acoustic blues', 'blues', 'country blues', 'delta blues', 'traditional blues', 'traditional folk']",
#  nan,
#  "['early reggae', 'rock steady', 'ska revival']",
#  "['bubblegum pop']",
#  "['classical', 'italian opera', 'post-romantic era']",
#  "['motown', 'northern soul', 'soul']",
#  "['art pop', 'art rock', 'baroque pop', 'chamber pop', 'experimental', 'experimental rock', 'melancholia', 'post-punk', 'singer-songwriter', 'slow core']",
#  nan,
#  "['art rock', 'canterbury scene', 'experimental', 'experimental rock', 'jazz fusion', 'jazz rock', 'progressive rock', 'psychedelic rock', 'space rock', 'symphonic rock', 'zolo']",
#  "['brill building pop', 'classic girl group', 'doo-wop', 'motown', 'philly soul', 'rhythm and blues']",
#  "['chanson', 'french rock']",
#  "['cantautor', 'nova canco', 'nueva cancion', 'spanish pop', 'trova']",
#  "['brill building pop', 'classic girl group', 'classic soul', 'motown', 'rhythm and blues', 'soul', 'southern soul']",
#  "['classic soundtrack', 'french soundtrack', 'spytrack', 'vintage french electronic']",
#  "['chanson', 'classic soundtrack', 'french jazz', 'french soundtrack']",
#  "['bolero', 'latin pop', 'mexican rock-and-roll', 'ranchera']",
#  "['bolero', 'grupera', 'mariachi', 'ranchera']",
#  "['arkansas country', 'outlaw country']",
#  "['grupera', 'mariachi', 'ranchera']",
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'deep adult standards', 'doo-wop', 'merseybeat', 'rock-and-roll', 'rockabilly']",
#  "['sleep']",
#  "['classic soundtrack', 'lounge', 'vintage italian soundtrack']",
#  "['british modern classical', 'classical', 'neoclassicism']",
#  "['beatlesque', 'british invasion', 'classic rock', 'merseybeat', 'psychedelic rock', 'rock']",
#  "['chanson', 'classic french pop']",
#  "['album rock', 'classic rock', 'country rock', 'folk', 'folk rock', 'mellow gold', 'rock', 'roots rock', 'singer-songwriter']",
#  "['chanson', 'french soundtrack', 'vintage french electronic']",
#  "['brill building pop', 'classic soul', 'motown', 'rhythm and blues', 'southern soul']",
#  "['early romantic era', 'italian opera']",
#  "['christelijk']",
#  "['chanson', 'classic soundtrack', 'french jazz', 'french soundtrack']",
#  "['afrobeat', 'afropop', 'ethio-jazz', 'funk', 'world']",
#  "['chanson', 'classic soundtrack', 'french jazz', 'french soundtrack']",
#  "['classic garage rock', 'experimental rock', 'protopunk', 'psychedelic rock']",
#  "['brill building pop', 'bubblegum pop', 'folk rock', 'merseybeat', 'rock-and-roll', 'sunshine pop']",
#  "['album rock', 'art rock', 'classic rock', 'experimental', 'experimental rock', 'hard rock', 'instrumental rock', 'jazz fusion', 'jazz rock', 'progressive rock', 'protopunk', 'psychedelic rock', 'rock', 'symphonic rock', 'zolo']",
#  "['bolero', 'cumbia', 'latin jazz', 'mambo', 'salsa', 'tropical']",
#  "['library music', 'spytrack']",
#  "['cha-cha-cha', 'cuban rumba', 'latin', 'latin jazz', 'mambo', 'salsa', 'tropical']",
#  "['adult standards', 'easy listening', 'lounge']",
#  "['cantautor', 'nova canco', 'nueva cancion', 'spanish pop', 'trova']",
#  "['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz quartet', 'jazz saxophone']",
#  "['brill building pop', 'doo-wop', 'rhythm and blues']",
#  "['poetry']",
#  "['classic soundtrack', 'scorecore', 'soundtrack', 'theme']",
#  "['chanson', 'ye ye']",
#  "['arkansas country', 'outlaw country']",
#  "['blues', 'blues rock', 'chicago blues', 'country rock', 'electric blues', 'harmonica blues', 'psychedelic rock', 'traditional blues']",
#  "['chanson', 'french rock']",
#  "['forro', 'forro tradicional']",
#  "['adult standards', 'british invasion', 'mellow gold']",
#  "['brill building pop', 'classic girl group', 'classic soul', 'motown', 'rhythm and blues', 'soul', 'southern soul']",
#  "['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'electric bass', 'free jazz', 'hard bop', 'jazz', 'jazz double bass', 'jazz fusion']",
#  "['bossa nova', 'brazilian jazz', 'forro', 'mpb', 'samba']",
#  "['deep adult standards']",
#  "['adult standards', 'brill building pop', 'classic soul', 'funk', 'motown', 'quiet storm', 'soul', 'southern soul']",
#  "['brill building pop', 'chicago soul', 'classic soul', 'funk', 'motown', 'quiet storm', 'rhythm and blues', 'soul']",
#  "['classic soundtrack', 'scorecore', 'soundtrack', 'theme']",
#  nan,
#  "['adult standards', 'brill building pop', 'bubblegum pop', 'folk rock', 'lounge', 'mellow gold', 'merseybeat', 'rockabilly', 'soft rock']",
#  "['sleep']",
#  "['classic soul', 'memphis soul', 'motown', 'rhythm and blues', 'soul', 'southern soul']",
#  ...]

# %%
cv.fit_transform(all_micro_genres)
# Out:
# <292x12 sparse matrix of type '<class 'numpy.int64'>'
# 	with 168 stored elements in Compressed Sparse Row format>

# %%
cv.vocabulary_
# Out:
# {'punk': 9,
#  'blues': 0,
#  'metal': 4,
#  'rap': 10,
#  'rock': 11,
#  'music': 5,
#  'pop': 8,
#  'new': 6,
#  'house': 2,
#  'nu': 7,
#  'hardcore': 1,
#  'jazz': 3}

# %%
# skip-gram is using a word to predict a target context

# %%
# Gensim Python Library for natural language processing

# %%
from gensim.models import Word2Vec

# %%
# skip gram (1)
model = Word2Vec(cv, min_count=1,size= 50,workers=3, window =3, sg = 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-340-87f40089a8f7> in <module>
#       1 # skip gram (1)
# ----> 2 model = Word2Vec(cv, min_count=1,size= 50,workers=3, window =3, sg = 1)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/gensim/models/word2vec.py in __init__(self, sentences, corpus_file, size, alpha, window, min_count, max_vocab_size, sample, seed, workers, min_alpha, sg, hs, negative, ns_exponent, cbow_mean, hashfxn, iter, null_word, trim_rule, sorted_vocab, batch_words, compute_loss, callbacks, max_final_vocab)
#     595         self.trainables = Word2VecTrainables(seed=seed, vector_size=size, hashfxn=hashfxn)
#     596
# --> 597         super(Word2Vec, self).__init__(
#     598             sentences=sentences, corpus_file=corpus_file, workers=workers, vector_size=size, epochs=iter,
#     599             callbacks=callbacks, batch_words=batch_words, trim_rule=trim_rule, sg=sg, alpha=alpha, window=window,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/gensim/models/base_any2vec.py in __init__(self, sentences, corpus_file, workers, vector_size, epochs, callbacks, batch_words, trim_rule, sg, alpha, window, seed, hs, negative, ns_exponent, cbow_mean, min_alpha, compute_loss, **kwargs)
#     743                 raise TypeError("You can't pass a generator as the sentences argument. Try a sequence.")
#     744
# --> 745             self.build_vocab(sentences=sentences, corpus_file=corpus_file, trim_rule=trim_rule)
#     746             self.train(
#     747                 sentences=sentences, corpus_file=corpus_file, total_examples=self.corpus_count,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/gensim/models/base_any2vec.py in build_vocab(self, sentences, corpus_file, update, progress_per, keep_raw_vocab, trim_rule, **kwargs)
#     919
#     920         """
# --> 921         total_words, corpus_count = self.vocabulary.scan_vocab(
#     922             sentences=sentences, corpus_file=corpus_file, progress_per=progress_per, trim_rule=trim_rule)
#     923         self.corpus_count = corpus_count
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/gensim/models/word2vec.py in scan_vocab(self, sentences, corpus_file, progress_per, workers, trim_rule)
#    1401             sentences = LineSentence(corpus_file)
#    1402
# -> 1403         total_words, corpus_count = self._scan_vocab(sentences, progress_per, trim_rule)
#    1404
#    1405         logger.info(
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/gensim/models/word2vec.py in _scan_vocab(self, sentences, progress_per, trim_rule)
#    1370         vocab = defaultdict(int)
#    1371         checked_string_types = 0
# -> 1372         for sentence_no, sentence in enumerate(sentences):
#    1373             if not checked_string_types:
#    1374                 if isinstance(sentence, string_types):
#
# TypeError: 'CountVectorizer' object is not iterable

# %%
model.similarity('HARDSTEP & TECHSTEP', 'DARKCORE & DARKSTEP')
# Out:
# <ipython-input-324-919dd21ef358>:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   model.similarity('HARDSTEP & TECHSTEP', 'DARKCORE & DARKSTEP')
# 0.030814392

# %%
model.most_similar('HIP HOUSE & EURODANCE')[:5]
# Out:
# <ipython-input-325-bbe5177e87cf>:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   model.most_similar('HIP HOUSE & EURODANCE')[:5]
# [('VAUDEVILLE', 0.3551366329193115),
#  ('PROGRESSIVE HOUSE', 0.34077903628349304),
#  ('BREAKBEAT GARAGE & GRIME', 0.31904497742652893),
#  ('ACID JAZZ / JAZZDANCE', 0.3116008937358856),
#  ('MOOMBAHTON', 0.28387388586997986)]

# %%
def cosine_distance (model, word, target_list , num) :
    cosine_dict ={}
    word_list = []
    a = model[word]
    for item in target_list :
        if item != word :
            b = model [item]
            cos_sim = dot(a, b)/(norm(a)*norm(b))
            cosine_dict[item] = cos_sim
    dist_sort=sorted(cosine_dict.items(), key=lambda dist: dist[1],reverse = True) ## in Descedning order 
    for item in dist_sort:
        word_list.append((item[0], item[1]))
    return word_list[0:num]

# %%
all_micro_genres
# Out:
# ['',
#  'FUTUREPOP',
#  'PROGRESSIVE TRANCE',
#  'MIAMI BASS & BOUNCE',
#  'INDIAN RAGA',
#  'POST-PUNK',
#  'SKIFFLE (REVIVAL)',
#  'JUMP BLUES',
#  'POWER METAL',
#  'THRASH METAL',
#  'DISCO',
#  'BOOGIE WOOGIE / PIANO BLUES',
#  'TECNOBREGA & -RUMBA',
#  'SYMPHONY // CHAMBER // OPERA // SOLO // VOCAL',
#  '(DIRTY) SOUTH RAP, CRUNK & SNAP',
#  'CELTIC // NORDIC // AFRICAN // ASIAN // EUROPEAN',
#  'ROCKSTEADY',
#  'MENTO',
#  'SINGER/SONGWRITER',
#  'GRUNGE',
#  'GOTHIC ROCK & DEATHROCK',
#  'BOMBA, PLENA & MERENGUE',
#  'ANARCHO-PUNK, CRUST PUNK & D-BEAT / DISCORE',
#  'SOFT ROCK / ADULT CONTEMPORARY (A.C.)',
#  'DARKWAVE & COLDWAVE',
#  'BIT MUSIC / VGM (CHIPTUNE & 8-BIT)',
#  "LOVER'S ROCK & UK REGGAE",
#  "(EARLY) RHYTHM 'N' BLUES",
#  'NO WAVE',
#  'HARDTECHNO (SCHRANZ II)',
#  'COUNTRY POP & COUNTRY ROCK',
#  'NUEVA TROVA',
#  'RELIPOP & -ROCK / CONTEMPORARY CHRISTIAN MUSIC',
#  'GLAM METAL / HAIR METAL / POP METAL',
#  'LOUNGE / EXOTICA / SPACE AGE POP',
#  'GLITCH HOP & WONKY',
#  'DISCOPOP / POST-DISCO',
#  'DANZÓN',
#  'HARDSTYLE (& JUMPSTYLE)',
#  'CUMBIA',
#  'HIGHLIFE',
#  'AMBIENT',
#  'CHICAGO BLUES / CITY BLUES / URBAN BLUES',
#  'NEW AGE',
#  'SOCA & PUNTA',
#  'PROGRESSIVE HOUSE',
#  'INDIETRONICA & CHILLWAVE',
#  'ARABIAN POP',
#  'BASSLINE & UK FUNKY',
#  'DEEP FUNK / RARE GROOVE & NU FUNK',
#  'URBAN BREAKS (NU R&B II)',
#  'SCHLAGER',
#  'TECH HOUSE',
#  'BOOGALOO',
#  'BALKAN BEAT / POP',
#  'RELIGOUS MUSIC:',
#  'INDUSTRIAL TECHNO & SCHRANZ',
#  'TEXAS BLUESROCK & MODERN ELECTRIC BLUES',
#  'HONKY TONK / HARDCORE COUNTRY',
#  'MUSIQUE CONCRETE',
#  '(ROOTS) REGGAE',
#  'FRENCH HOUSE & FUNKY HOUSE',
#  'GO-GO',
#  'POST-GRUNGE',
#  'NOISE MUSIC',
#  'HIP HOUSE & EURODANCE',
#  'FUTURE BASS / FUTURE GARAGE',
#  'POST-BRITPOP',
#  'HI-NRG / EURODISCO',
#  'SOUL JAZZ / JAZZ FUNK',
#  'NU JAZZ / ELECTRO JAZZ',
#  'DARKCORE & DARKSTEP',
#  'INDIE FOLK & FREAKFOLK / NEW WEIRD AMERICA',
#  'NEW ORLEANS JAZZ & DIXIELAND JAZZ',
#  'AMERICAN & BRITISH FOLK REVIVAL',
#  "ROCK 'N ROLL & ROCKABILLY",
#  'OLD SKOOL RAP PIONEERS',
#  'EUROTRANCE & VOCAL TRANCE',
#  'EXTREME METAL (BLACK I & SPEED)',
#  'SON',
#  'NEW WAVE',
#  'ZOUK',
#  'ACID HOUSE',
#  'NEO SOUL / NU SOUL',
#  'NWOBHM (NEW WAVE OF BRITISH HEAVY METAL)',
#  'UK GARAGE (2-STEP & SPEED GARAGE)',
#  'DANCEHALL',
#  'CANCION',
#  'CHEMICAL BREAKS & BIG BEAT',
#  'CHICAGO SOUL & DETROIT SOUL (MOTOWN)',
#  'NORTEC',
#  'CHALGA',
#  'SPEEDCORE, FRENCHCORE & TERRORCORE',
#  'MEMPHIS SOUL / DEEP SOUL / SOUTHERN SOUL',
#  'NEUROFUNK',
#  'HUAYNO & CHICA',
#  'CHICANO ROCK',
#  'INDUSTRIAL ROCK / INDUSTRIAL METAL',
#  'SKA',
#  'BAKERSFIELD',
#  'HEARTLAND ROCK & A.O.R. (ADULT ORIENTED ROCK)',
#  'SWING / BIG BAND',
#  'ELECTROCLASH',
#  'FUSION / JAZZ ROCK',
#  'MINIMAL WAVE / SYNTH & MINIMAL INDUSTRIAL (REVIVAL)',
#  'SYMPHONIC METAL & GOTHIC METAL',
#  'CLASSIC METAL',
#  'BLACK METAL',
#  'MUZAK / ELEVATOR MUSIC',
#  '(EARLY) POP ROCK &POWER POP',
#  'GOA TRANCE & PSYTRANCE',
#  'TECH TRANCE',
#  'HYMNS, PSALMS, CHANTS',
#  'GARAGE & POST-PUNK REVIVALS / NU-RAWK',
#  'MODERN GOSPEL',
#  'ELECTRO-INDUSTRIAL / AGGREPPO',
#  'RAP ROCK, RAPCORE & FUNK METAL',
#  'SALSA',
#  'NASHVILLE / COUNTRYPOLITAN',
#  'TANGO',
#  'DIGITAL HARDCORE & BREAKCORE',
#  'BRILL BUILDING POP',
#  'NEW JACK SWING / SWINGBEAT',
#  'CONTEMPORARY COUNTRY / NEOTRADITIONALISTS',
#  'ELECTRO HOUSE & DUTCH HOUSE',
#  'DEEP HOUSE',
#  'FILM, TV, GAME, & PLAY MUSIC',
#  'ACID JAZZ / JAZZDANCE',
#  'SYNTHPOP & NEW ROMANTICS',
#  'WESTERN SWING',
#  "OLD SKOOL JUNGLE & OLD SKOOL DRUM 'N' BASS",
#  'INDIE POP (TWEE)',
#  'COOL JAZZ & WEST COAST JAZZ',
#  'ASIAN POP',
#  'BRITISH BLUES & BLUES ROCK',
#  'SKA REVIVAL (2-TONE), SKA PUNK & SKACORE',
#  'RUMBA',
#  'NU-DISCO & FUNKTRONICA',
#  'PROGRESSIVE ROCK, ART ROCK & SYMPHONIC ROCK',
#  'NU SKOOL BREAKS',
#  'NEW ORLEANS & DIXIELAND JAZZ REVIVALS',
#  'CALYPSO',
#  'DOO WOP',
#  'MATH ROCK & MATHCORE',
#  'HARDSTEP & TECHSTEP',
#  '(ELECTRIC) TEXAS BLUES',
#  'GRINDCORE',
#  'POST-ROCK',
#  'RAGGA',
#  'THIRD STREAM / PROGRESSIVE JAZZ & MODAL JAZZ',
#  'BLUEGRASS',
#  'MAMBO & CHACHACHA',
#  'CLASSIC COUNTRY / HILLBILLY',
#  'NU STYLE (GABBER) / MAINSTREAM HARDCORE',
#  'GARAGE ROCK',
#  'AMBIENT BREAKS & ILLBIENT',
#  'TIMBA',
#  'HARD BOP',
#  'HARDCORE TECHNO / RAVE',
#  'EAST COAST GANGSTA RAP',
#  'URBAN COUNTRY',
#  'GLAM ROCK / GLITTER ROCK / SHOCK ROCK',
#  'PROGRESSIVE COUNTRY & OUTLAW COUNTRY',
#  'SYNTHCORE & CRUNKCORE',
#  'UK HARDCORE & FREEFORM / TRANCECORE & ACIDCORE',
#  'CONTRADANZA',
#  "GLITCH / CLICKS 'N' CUTS",
#  'BHANGRA',
#  '(NEGRO) SPIRITUALS & WORKSONGS',
#  'RAGTIME & STRIDE',
#  'AND MARCH MUSIC',
#  'DUBSTEP',
#  'CHICAGO HOUSE & GARAGE HOUSE',
#  'CROSSOVER THRASH',
#  'KRAUTROCK',
#  'POP RAÏ',
#  'SYNTHWAVE & VAPORWAVE',
#  'FREE JAZZ / AVANT-GARDE (JAZZ)',
#  'ELECTRO POP',
#  'HAPPY HARDCORE & BOUNCY TECHNO',
#  'NEW PROG / NU PROG / POST PROG (ROCK)',
#  'PROGRESSIVE METAL',
#  'PROGRESSIVE RAP / NU SKOOL RAP',
#  'TROVA & FEELING',
#  'TROPICALIA',
#  'SYNTH / ELECTRONICA',
#  'DARK AMBIENT / DARK INDUSTRIAL',
#  '(AVANT-GARDE) INDUSTRIAL',
#  'HABANERA',
#  'CUBOP',
#  'AMERICANA / ALTERNATIVE COUNTRY',
#  'MINIMALISM',
#  'SOUTHERN ROCK',
#  'NORTH-AMERICAN // LATIN // APPALACHIAN // ...',
#  'REGGAE FUSION & BHANGRAMUFFIN',
#  'NORDIC JAZZ',
#  'BAILE-FUNK',
#  'SKATE PUNK & POP PUNK',
#  'ELECTRO',
#  'SURF ROCK / INSTRUMENTAL',
#  'VAUDEVILLE / CLASSIC BLUES',
#  'DUB',
#  'NOISE ROCK',
#  'FREESTYLE & BREAKDANCE',
#  'NRG, HARD NRG & (UK) HARD HOUSE',
#  'GHETTO HOUSE, GHETTOTECH &JUKE',
#  'HARDTRANCE',
#  'PUB ROCK & PROTO PUNK',
#  'REGGAETÓN & LATIN RAP',
#  'BOSSA NOVA',
#  'SMOOTH JAZZ',
#  'CAJUN',
#  'LOUISIANA BLUES / SWAMP BLUES',
#  'UPLIFTING TRANCE / EPIC TRANCE',
#  'AMBIENT HOUSE / CHILL-OUT',
#  'BROKEN BEATS',
#  'ELECTRO SWING',
#  'NU METAL & RAP METAL',
#  'ROMANTIC // MODERN // CONTEMPORARY',
#  'NEO-TRANCE',
#  'NEW BEAT',
#  'DEATH METAL',
#  'MOOMBAHTON',
#  'BEBOP',
#  'ALTERNATIVE ROCK / INDIE II',
#  'FOLK ROCK',
#  'HORROR PUNK & PSYCHOBILLY',
#  'PHILLY SOUL',
#  'POST-HARDCORE, EMO(CORE) & SCREAMO',
#  ' ',
#  'BRITPOP',
#  'MICROHOUSE / MINIMAL HOUSE',
#  'STONER METAL / ROCK & SLUDGE METAL / ROCK',
#  'TRAP & DRILL',
#  'JUMP UP',
#  'PSYCHEDELIC / ACID ROCK & PSYCHEDELIA',
#  'BREAKBEAT GARAGE & GRIME',
#  'EARLY FUNK & P-FUNK',
#  'JANGLE POP / INDIE ROCK (& PAISLEY UNDERGROUND)',
#  'ELECTRONIC BODY MUSIC',
#  'METALCORE / NEW WAVE OF AMERICAN HEAVY METAL',
#  'LIQUID FUNK',
#  'ORIGINAL HARDCORE (PUNK)',
#  'SAMBA',
#  'DOOM METAL',
#  'SOUNDTRACKS:',
#  'PUNTO & GUAJIRA',
#  'WEST COAST BLUES',
#  'PUNK ROCK',
#  'CLASSIC TRANCE & ACID TRANCE',
#  '(FREE)TEK(K)NO',
#  'GOLDEN AGE RAP (& HARDCORE RAP)',
#  'JAZZ RAP / NATIVE TONGUE',
#  'DANCE POP',
#  'URBAN SOUL / POP (NU R&B I)',
#  'DANCE-PUNK & NU RAVE',
#  'HILL COUNTRY BLUES & TRANCE BLUES',
#  'MILITARY MUSIC',
#  'DIGITAL MINIMALISM / LOWERCASE',
#  'DREAM POP & SHOEGAZE',
#  'ENTERTAINMENT MUSIC:',
#  'CHICAGO JAZZ',
#  'TRIP HOP',
#  'MINIMAL TECHNO',
#  'BOOGIE / ELECTROFUNK',
#  'HARD ROCK',
#  'COUNTRY BLUES / FOLK BLUES',
#  'EDM TRAP / TRAPSTEP',
#  'EMO-ROCK',
#  "INTELLIGENT / AMBIENT DRUM 'N' BASS & JAZZSTEP",
#  'AFROBEAT',
#  'MEDIEVAL // RENAISSANCE // BAROQUE // CLASSICAL',
#  'POST-DUBSTEP',
#  'BOLERO',
#  'TRADITIONAL GOSPEL',
#  '. . .',
#  '(EARLY) GABBER',
#  'IBIZA HOUSE / TRANCE & DREAM HOUSE / TRANCE',
#  'MILONGA',
#  'CABARET / VAUDEVILLE / MUSICAL',
#  'WORLDBEAT',
#  'BREAKBEAT HARDCORE (RAVE II)',
#  '(WEST COAST) GANGSTA RAP',
#  'TEXMEX & CONJUNTO',
#  '(MERSEY)BEAT / BRITISH INVASION',
#  'SOUL BLUES (SOUTHERN SOUL II)',
#  'BUBBLEGUM & TEENYBOP',
#  'DETROIT TECHNO',
#  'FIDGET HOUSE & COMPLEXTRO',
#  'AMBIENT TECHNO & IDM (INTELLIGENT DANCE MUSIC)',
#  'CHACÓN',
#  'FLORIDA BREAKS (& FUNKY BREAKS)']

# %%
# only get the unique Maker_Model
# all_micro_genres = list(set(list(micro_genres_dict.values())+n_text))
all_micro_genres

# Show the most similar Mercedes-Benz SLK-Class by cosine distance 
cosine_distance (model,'AMBIENT', all_micro_genres, 5)
# Out:
# <ipython-input-326-a61b6768792c>:4: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   a = model[word]
# <ipython-input-326-a61b6768792c>:7: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   b = model [item]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-331-d349f4049057> in <module>
#       4
#       5 # Show the most similar Mercedes-Benz SLK-Class by cosine distance
# ----> 6 cosine_distance (model,'AMBIENT',all_micro_genres, 5)
#
# <ipython-input-326-a61b6768792c> in cosine_distance(model, word, target_list, num)
#       5     for item in target_list :
#       6         if item != word :
# ----> 7             b = model [item]
#       8             cos_sim = dot(a, b)/(norm(a)*norm(b))
#       9             cosine_dict[item] = cos_sim
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/gensim/utils.py in new_func1(*args, **kwargs)
#    1459                     stacklevel=2
#    1460                 )
# -> 1461                 return func(*args, **kwargs)
#    1462
#    1463             return new_func1
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/gensim/models/word2vec.py in __getitem__(self, words)
#     930
#     931         """
# --> 932         return self.wv.__getitem__(words)
#     933
#     934     @deprecated("Method will be removed in 4.0.0, use self.wv.__contains__() instead")
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/gensim/models/keyedvectors.py in __getitem__(self, entities)
#     351         if isinstance(entities, string_types):
#     352             # allow calls like trained_model['office'], as a shorthand for trained_model[['office']]
# --> 353             return self.get_vector(entities)
#     354
#     355         return vstack([self.get_vector(entity) for entity in entities])
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/gensim/models/keyedvectors.py in get_vector(self, word)
#     469
#     470     def get_vector(self, word):
# --> 471         return self.word_vec(word)
#     472
#     473     def words_closer_than(self, w1, w2):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     466             return result
#     467         else:
# --> 468             raise KeyError("word '%s' not in vocabulary" % word)
#     469
#     470     def get_vector(self, word):
#
# KeyError: "word '' not in vocabulary"

# %% [markdown]
# livenes.apply(lambda x: "live" if x > 0.8 else "not live")
#
# energy: (float) Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic fast, loud, and noisy

# %%
genres = pd.read_csv('../data/analysis/everynoise_genres.csv')

# %%
songs.art_genres
# Out:
# 0                                                       []
# 1                               ['chanson', 'french rock']
# 2                                                       []
# 3        ['cha-cha-cha', 'cuban rumba', 'latin', 'latin...
# 4            ['deep indian pop', 'filmi', 'tamil worship']
#                                ...
# 43006    ['compositional ambient', 'focus', 'neo-classi...
# 43007                                                   []
# 43008                                                   []
# 43009    ['edm', 'electropop', 'jamtronica', 'jazztroni...
# 43010    ['downtempo', 'jazz boom bap', 'jazztronica', ...
# Name: art_genres, Length: 43011, dtype: object

# %% [markdown]
# # Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer, KNNImputer
from scipy.spatial import distance
from sklearn.cluster import KMeans

# %%
# feat_selection = ['danceability','energy','key','loudness','mode','speechiness','acousticness',
#          'instrumentalness','liveness','valence','tempo','time_signature']

# feat_selection = ['danceability','energy','loudness','speechiness','acousticness',
#                  'instrumentalness','liveness','valence']

feat_selection = ['danceability','energy','speechiness','acousticness',
         'instrumentalness','valence']

# %%
pipeline = Pipeline(steps=[('features_selection', AudioFeatures()),
                           ('missing', KNNImputer(n_neighbors=30)),
                           ('preprocessing', StandardScaler()),
                           ('feature_clusterization', KMeans(30))])

# %%
songs = pd.read_csv('../data/final/songs.csv')
pipeline.fit(songs)
X = pipeline.named_steps['features_selection'].transform(songs)
pipeline.named_steps['preprocessing'].transform(X)
songs['cluster'] = pipeline.predict(X)
songs.to_csv('../data/final/songs.csv', index=False)

# %% [markdown]
# **Features**
# - `duration_ms`: (int) duration of the track in milliseconds.
# - `key`:	(int) estimated overall key of the track. Integers map to pitches using standard Pitch Class notation . E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on. If no key was detected, the value is -1.
# - `mode`:	(int)	modality (major or minor) of a track, the type of scale from which its melodic content is derived. Major is represented by 1 and minor is 0.
# - `liveness:`	(float)	Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
# - `acousticness:`	(float)	A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
# - `danceability:`	(float)	Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
# - `energy:`	(float)	Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
# - `instrumentalness:`	(float)	Predicts whether a track contains no vocals. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content.
# - `loudness:` (float)	loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typical range between -60 and 0 db.
# - `speechiness:` (float)	Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
# - `valence:`	(float)	A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
# - `tempo:`	(float)	The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
# - `time_signature`:	(int)	An estimated overall time signature of a track. The time signature (meter) is a notational convention to specify how many beats are in each bar (or measure).

# %% [markdown]
# # Input & Validation

# %% [markdown]
# ## Speech recognition

# %%
user_input=check_input(song_input=get_audio('title'), artist_input=get_audio('artist'))
# Out:
# Tell us the title of a song you like :)
# Listening... (you've got 4 seconds)
# Processing...
# Tell us the artist who sings that song
# Listening... (you've got 4 seconds)
# Processing...
# You chose "good news" by Mac Miller, right? (y/n)y

# %% [markdown]
# ## Written song

# %%
user_input=check_input(song_input=get_text('title'), artist_input=get_text('artist'))
# Out:
# Tell us the title of a song you like :)photograph
# Tell us the artist who sings that songnickelback
# You chose "Photograph" by Nickelback, right? (y/n)y

# %% [markdown]
# # Processing

# %%
# processing the input and saving to dabase new information
process = target_process(user_input)
target_song = process[0]
target_cluster = process[1]
# Out:
# found in the database

# %%
target_song
# Out:
#             track      artist                            tracks_uri  decade  \
# 29490  Photograph  Nickelback  spotify:track:3hb2ScEVkGchcAQqrPLP0R  2000.0
#
#        billboard                                         art_genres  \
# 29490        1.0  ['alternative metal', 'canadian rock', 'nu met...
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 29490         0.513   0.877  8.0    -3.756   1.0       0.0292      0.000932
#
#        instrumentalness  liveness  valence    tempo  time_signature  cluster
# 29490          0.000163     0.136    0.389  145.919             4.0       11

# %%
target_cluster
# Out:
# 11

# %%
# now it's time to filter by the 10 nearest songs and artists
cluster_songs = get_recomm_songs(target_cluster)
recomm_songs = cluster_songs.copy().reset_index(drop=True)

# defining X and y 
X = pipeline.named_steps['features_selection'].transform(recomm_songs)
y = pipeline.named_steps['features_selection'].transform(target_song)

#Standardizing
X_std = pd.DataFrame(pipeline.named_steps['preprocessing'].transform(X), columns=X.columns)
y_std = pd.DataFrame(pipeline.named_steps['preprocessing'].transform(y), columns=y.columns)
# Out:
# <ipython-input-116-e920a43962ff>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cluster_songs['is_recommended'] = cluster_songs.artist.apply(lambda x: 1 if x in list(recomm_artists.artist) else 0)

# %% [markdown]
# # Ball Tree

# %%
#Calculate distance based on cluster center

# %%
from sklearn.neighbors import BallTree

#Calculating the distance between the target song to all the rest of the same cluster
tree = BallTree(X_std, metric= 'euclidean')    
dist, ind = tree.query(y, k=10)

# %% [markdown]
# # Recommendation

# %%
# Think of a way to speed up this process:

# %%
# retrieving artist's popularity info 
final_recomm = get_pop_link(recomm_songs)
final_target = get_pop_link(target_song)

# %%
# data to be shown
final_feat = ['track', 'artist','art_genres','link','cluster']

# Tuning by some other parameters and showing the final results
recommendation = final_recomm.loc[list(ind[0]),:].sort_values(by=['liveness','popularity'], ascending=False)

# showing final results
recom = pd.concat([final_target[final_feat],recommendation[final_feat]]).reset_index(drop=True)
recom
# Out:
#                                        track             artist  \
# 0                                 Photograph         Nickelback
# 1               Damn I Wish I Was Your Lover  Sophie B. Hawkins
# 2                             Aao Milo Chalo              Shaan
# 3                             Little Darlin'             Sheila
# 4                  When I Think About Angels       Jamie O'Neal
# 5                Slow Dance In A Parking Lot       Jordan Davis
# 6                             Rock This Town    Daniel Johnston
# 7                                  Barlights               fun.
# 8                                       Rani               Faun
# 9                           California Girls     David Lee Roth
# 10  Song Of Mor'du - From "Brave"/Soundtrack      Patrick Doyle
#
#                                            art_genres  \
# 0   ['alternative metal', 'canadian rock', 'nu met...
# 1              ['lilith', 'new wave pop', 'pop rock']
# 2   ['desi pop', 'filmi', 'modern bollywood', 'sufi']
# 3                                ['background music']
# 4   ['contemporary country', 'country', 'country d...
# 5                            ['contemporary country']
# 6   ['alternative rock', 'anti-folk', 'freak folk'...
# 7   ['axe', 'pagode', 'partido alto', 'samba', 'sa...
# 8   ['hurdy-gurdy', 'medieval folk', 'medieval roc...
# 9   ['album rock', 'classic rock', 'glam metal', '...
# 10  ['british soundtrack', 'hollywood', 'scorecore...
#
#                                                  link  cluster
# 0   https://open.spotify.com/track/3hb2ScEVkGchcAQ...       11
# 1   https://open.spotify.com/track/0RmEn2jcbyrLV4e...       11
# 2   https://open.spotify.com/track/6ocOeSjnWPcSTaS...       11
# 3   https://open.spotify.com/track/3t7iwbVkBY3vT8z...       11
# 4   https://open.spotify.com/track/6X1MOfJSjBT54Vc...       11
# 5   https://open.spotify.com/track/6MBUUSIWCzaXW4q...       11
# 6   https://open.spotify.com/track/3PaSRhmdsbY3GTQ...       11
# 7   https://open.spotify.com/track/4HBeHxm71PBKrc6...       11
# 8   https://open.spotify.com/track/4f5hVnrSBAPuVfE...       11
# 9   https://open.spotify.com/track/4H3vuLX59XPqdtT...       11
# 10  https://open.spotify.com/track/3AVQq5hpwkuJxAz...       11

# %% [markdown]
# # Classes & Functions

# %% [markdown]
# ## Pipeline

# %%
class AudioFeatures():
    
    def __init__(self):     
        pass
    
    def fit(self, X, y=None):
        '''
        `.fit()` method needs to return the object itself
        '''
        return self
    
    def transform(self, X):
        '''
        `.transform()` method needs to return a transformed data like X
        '''
        # feat_selection = ['danceability','energy','key','loudness','mode','speechiness','acousticness',
        #          'instrumentalness','liveness','valence','tempo','time_signature']
        
        # feat_selection = ['danceability','energy','loudness','speechiness','acousticness',
        #          'instrumentalness','liveness','valence']
        
        feat_selection = ['danceability','energy','speechiness','acousticness',
         'instrumentalness','valence']
        
        X = X[feat_selection ]
        
        return X

# %%
songs.columns
# Out:
# Index(['track', 'artist', 'tracks_uri', 'decade', 'billboard', 'art_genres',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature', 'cluster'],
#       dtype='object')

# %% [markdown]
# ## Clean Artist's names

# %%
def clean_name(df:pd.DataFrame, column_name:str)-> pd.DataFrame:
    '''
    This function cleans the artist's name column of a dataframe and 
    returns the df with the respective column containing only the main name
    '''
    
    import re
    
    df = df.reset_index(drop=True)

    for i in range(df.shape[0]):
        string = df.loc[i,'artist']
        pattern ='(?:Feat(?:\. |uring )|, |\/|\+|&| [Xx] | \(|\)| [Ww]ith | And | y )'
        artists = re.split(pattern, string)
        df.loc[i, 'artist'] = artists[0]
    return df

# %% [markdown]
# ## Spotify API functions

# %%
def access_spotify():
    '''
    this function initializes spotify access 
    '''
    import spotipy
    import spotipy.util as util
    from spotipy.oauth2 import SpotifyClientCredentials
    
    # Credentials
    client_id= '1337a27731b840f98acd0c79f0d011f3'
    client_secret = '98f2df2fdde44f40ad768a8142b20074'
    response_type = 'code'
    redirect_uri = 'https://aceworld.com.br/'
    state= 'https%3A%2F%2Faceworld.com.br%2F'
    scope = 'playlist-read-private scope'
    username = 'dnekdiptrsu4rr1heu145y07j'
    playlist = 'spotify:playlist:2QDyvRV0Ct7bGg3AREkL6P'

    #Accessing with token
    scope = 'user-library-read playlist-read-private'
    try:
        token = util.prompt_for_user_token(username, scope,client_id=client_id, 
                                           client_secret=client_secret, 
                                           redirect_uri=redirect_uri)
        sp=spotipy.Spotify(auth= token)
    except:
        print('Token is not accesible for ' + username)

    return sp

# %%
def get_artist_stats(df=False, artist_name: str = 'None', billboard_col: bool = False)-> pd.DataFrame:
    
    '''
    This function receives a dataframe containing a column with artists' names ('artist')
    or a single artist name and the spotify authenticated access to make the requests, 
    and returns a new dataframe, containing the spotify attributes for that artist:
        - artist spotify id (uri)
        - number of followers
        - genres
        - popularity
    
    <parameters>
    df: a DataFrame or 'False' if the request will be for a single artist
    billboard_col: True if the input df already contains a target 
                    column named 'billboard'.
    spotify_access: function that accesses spotify authorization token, 
                    by default: access_spotify()
    '''
    import time
    
    sp = access_spotify()
    artists=[]
    uris = []
    followers = []
    genres =[]
    popularities = []
    error_artists = []
    billboard_targets = []
    
    if df == False and artist_name != 'None':
        artist = artist_name
        q = f'artist:{artist}'
        try:
            results = sp.search(q=q, limit=1, type='artist')['artists']['items'][0]
        except:
            try:
                sp=access_spotify()
                results = sp.search(q=q, limit=1, type='artist')['artists']['items'][0]
            except:
                pass
            
        df_final = pd.DataFrame({'artist': artist,
                     'uri': results['uri'],
                     'followers': results['followers']['total'],
                     'genres': [results['genres']],
                     'popularity': results['popularity'],
                     'billboard': ''})
        
    else: 
        for i in range(df.index[0], df.shape[0]):
            artist = df.loc[i, 'artist']
            q = f'artist:{artist}'

            try:
                results = sp.search(q=q, limit=1, type='artist')['artists']['items'][0]
                print (artist)
            except:
                try:
                    print ('refreshing token')
                    sp=access_spotify()
                    results = sp.search(q=q, limit=1, type='artist')['artists']['items'][0]
                except:
                    print ('error:', artist)
                    pass

            artists.append(artist)
            uris.append(results['uri'])
            followers.append(results['followers']['total'])
            genres.append(results['genres'])
            popularities.append(results['popularity'])
            # if input df contains 'billboard' column
            if billboard_col == True:
                billboard_targets.append(df.loc[i, 'billboard'])
            else:
                pass

            df_2 = pd.DataFrame({'artist': artists,
                                 'uri': uris,
                                 'followers': followers,
                                 'genres': genres,
                                 'popularity': popularities,
                                 'billboard': billboard_targets})
            # saving a version to .csv
            df_2.to_csv('data/processed/artists_stats_process.csv', index=False)

    # saving final version to .csv    
        df_final = df_2
        df_final.to_csv('../data/processed/artists_stats_final.csv', index=False)

    return df_final

# %%
def get_audio_features(df=False, track_title:str='None', artist_name:str='None')-> pd.DataFrame:
    '''
    This function receives a dataframe containing tracks' Spotify uris 
    or a single track title and
    and returns a dataframe with the track's audio features.
    
    <parameters>
    df: a DataFrame or 'False' if the request will be made for a single track
    spotify_access: function that accesses spotify authorization token, 
                    by default: access_spotify()
    '''

    feat_df = pd.DataFrame()
    pop=[]
    art_genres=[]
    cluster=[]
    sp = access_spotify()
    
    if df == False :
        q= f'track:{track_title} artist:{artist_name}'    
        results = sp.search(q=q, limit=1, type='track')
        
        try:
            track_title =results['tracks']['items'][0]['name']
        except: 
            print('Couldn\'t find this track in spotify. Did you type everything correctly?')
        tracks_uri = results['tracks']['items'][0]['uri']
        artist_name = results['tracks']['items'][0]['artists'][0]['name']
        artist_uri = results['tracks']['items'][0]['artists'][0]['uri'] 
        
        audio_feat = sp.audio_features(tracks_uri)
        art_genres = sp.artist(artist_uri)['genres']
        cluster= ''
        
        new_df = pd.concat([pd.DataFrame([[
            track_title, artist_name,tracks_uri, artist_uri, art_genres,cluster]], 
            columns=['track','artist','tracks_uri','artist_uri','art_genres', 'cluster']), 
                            pd.DataFrame(audio_feat)], axis=1)
    else:
        saved_uris = list(df.tracks_uri)

        for uri in saved_uris:
            feat_df = feat_df.append(pd.DataFrame(sp.audio_features(uri)))
            track_req=sp.track(uri)
            pop.append(track_req['popularity'])
            art_genres.append(sp.artist(track_req['artists'][0]['uri'])['genres'])
            cluster.append('')

        new_df = pd.concat([df, feat_df.reset_index(drop=True), 
                            pd.DataFrame(pop, columns=['popularity']),
                            pd.DataFrame(art_genres, columns=['art_genres']),
                            pd.DataFrame(cluster, columns=['cluster'])], axis=1)
    
    
    new_df = new_df [['track', 'artist', 'tracks_uri', 'art_genres',
       'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
       'time_signature', 'cluster']]
    
    return new_df

# %%
def get_pop_link (df):
    
    sp = access_spotify()
    index_list = list(df.index)
    popularity = []
    url =[]
    
    df = df.reset_index(drop=True)
    for artist in df.artist:
        try:
            result= sp.search(q=f"artist:{artist}", limit=1, type='artist')
            url.append(result['artists']['items'][0]['external_urls']['spotify'])
            popularity.append(result['artists']['items'][0]['popularity'])
        except: 
            url.append("")
            popularity.append("")
            
    df_req = pd.DataFrame({'popularity': popularity,
                           'link':url})

    df_final = pd.concat([df, df_req], axis=1)
    df_final.index=index_list
    
    return df_final

# %%
def get_pop_link (df):
    
    sp = access_spotify()
    index_list = list(df.index)
    popularity = []
    url = 'https://open.spotify.com/'
    
    df = df.reset_index(drop=True)
    for artist in df.artist:
        try:
            result= sp.search(q=f"artist:{artist}", limit=1, type='artist')
            popularity.append(result['artists']['items'][0]['popularity'])
        except: 
            popularity.append("")
            
    df_req = pd.DataFrame({'popularity': popularity})
    df_req['link'] = df.tracks_uri.apply(lambda x: 'track/'.join ([url, x.split(':')[-1]]))

    df_final = pd.concat([df, df_req], axis=1)
    df_final.index=index_list
    
    return df_final

# %%
def artist_popularity_link(df):
    # Adding new target based on number of followers:
    
    artists=pd.read_csv('../data/final/artists.csv')
    artist_popularities = []
    url = 'https://open.spotify.com/'

    for artist in list(df_temp.artist):
        try:
            art_index = artists.query(f'artist=="{artist}"').index[0]        
            artist_popularities.append(artists.loc[art_index,'popularity'])
        except:
            artist_popularities.append("")
    df['popularity'] = artist_pop
    df['link'] = df.tracks_uri.apply(lambda x: 'track/'.join ([url, x.split(':')[-1]]))
    
    return df

# %% [markdown]
# ## Billboard API functions

# %%
def get_billboard_charts_data(chart_types: list) -> pd.DataFrame:
    '''
    This function retrieves data from the given list of chart types:
        - song title
        - artist name
        - chart name
    > for more information about chart_types: access 'billboard.charts()'
    '''
    
    df=pd.DataFrame()
    title_list=[]
    artist_list=[]
    chart_name=[]

    for chart_type in chart_types:
        chart = billboard.ChartData(chart_type)
        for song in chart:
            title_list.append(song.title)
            artist_list.append(song.artist)
            chart_name.append(chart.name)

        df = pd.DataFrame({'title':title_list, 
                       'artist':artist_list, 
                       'chart':chart_name})
        df.to_csv('../data/raw/billboard_artists_process.csv', index=False)
    
    df=df.drop_duplicates()
    df.to_csv('../data/raw/billboard_artists.csv', index=False)
    
    return df

# %% [markdown]
# ## Recommendation System Flow

# %%
def artist_recommended(df):
    # Adding new target based on number of followers:
    df['is_recommended'] = df.followers.apply(lambda x: 0 if x > 400000 else 1)
    return df

# %%
def get_audio(audio_type:str)-> str:
    '''
    this function receives a speaked audio and transforms it into written text
    you must specify the type between: 'artist' or 'title'
    '''
    import speech_recognition as sr
    import time
    
    r = sr.Recognizer()
    sec = 4
    
    if audio_type == 'title':
        print(f'Tell us the title of a song you like :)')
    elif audio_type == 'artist':
        print(f'Tell us the artist who sings that song')
    else:
        raise ValueError ('audio_type must be "artist" or "title"')
    
    with sr.Microphone() as source:
        # read the audio data from the default microphone
        print(f"Listening... (you've got {sec} seconds)")
        try:
            audio_data = r.record(source, duration=sec)
        except:
            print(f"I didn't hear you, would you repeat please?")
            print(f"Listening... (you've got {sec} seconds)")
        # convert speech to text
        print("Processing...")
        user_input = r.recognize_google(audio_data)
        
        return user_input

# %%
def get_text(text_type:str)-> str:
    '''
    this function receives a written text
    you must specify the type between: 'artist' or 'title'
    '''
    if text_type == 'title':
        user_input = str(input(f'Tell us the title of a song you like :)'))
    elif text_type == 'artist':
        user_input = str(input(f'Tell us the artist who sings that song'))
    else:
        raise ValueError ('audio_type must be "artist" or "title"')    

    return user_input

# %%
def check_input(song_input: str, artist_input: str)-> list:
    '''
    this function receives an input and confirms if the title was well captured.
    returns a list containing:
        - in position [0]: string (the song title)
        - in position [1]: string (the artist name)
        - in position [2]: bool (0 if not found in database, 1 if found in database)
    '''
    import textdistance
    import time
    n=4

    # assuring if it got the song correctly:     
    try:
        song_lev_dists = songs.track.apply(lambda x:textdistance.levenshtein.normalized_similarity(
                           song_input, x)).sort_values(ascending=False).head(n)
        song_recomm_index = list(song_lev_dists.index)
        song_recomm = songs.loc[song_recomm_index,['track', 'artist']]
        song_recomm['song_dist']=song_lev_dists
        song_recomm['art_dist']= song_recomm.artist.apply(lambda x:textdistance.levenshtein.normalized_similarity(
                           artist_input, x))
        final_recomm = song_recomm.sort_values(by=['song_dist', 'art_dist'], ascending=False)
        final_recomm = final_recomm.query('art_dist > 0.5 and song_dist > 0.5').head(1)
        final_recomm_song = songs.loc[final_recomm.index[0],'track']
        final_recomm_artist = songs.loc[final_recomm.index[0],'artist']    

        # assuring the artist is the same
        if song_lev_dists[final_recomm.index[0]] >= 0.6:
            validate = str(input(f'You chose "{final_recomm_song}" by {final_recomm_artist}, right? (y/n)'))

        elif song_lev_dists[final_recomm.index[0]] < 0.6 and song_lev_dists[final_recomm.index[0]] >= 0.4:
            validate = str(input(f'Did you mean: "{final_recomm_song}" by {final_recomm_artist}? (y/n)'))

        if validate in ['y', 'yes', 'Y', 'Yes', 'YES','sim','Sim','S', 's','SIM']:
            return [final_recomm_song, final_recomm_artist, 1]
        else:
            ## Look for 
            return [song_input, artist_input, 0]
    except:
        validate = str(input(f'You chose "{song_input}" by {artist_input}, right? (y/n)'))
        if validate in ['y', 'yes', 'Y', 'Yes', 'YES','sim','Sim','S', 's','SIM']:
            return [song_input, artist_input, 0]
        else:
            print("We're sorry, we couldn't find this song :(")

# %%
def target_process(user_input: list)-> list:
    '''
    This function processes the target song, and clusterizes it given its features
    returns a list containing:
        - target_song
        - target_cluster
    It also saves to the database new songs/artists.
    '''
    
    songs = pd.read_csv('../data/final/songs.csv')
    artists = pd.read_csv('../data/final/artists.csv')

    # look for the song in the songs database
    if user_input[2] == 1:
        target_song = songs.query(f'track == "{user_input[0]}" & artist == "{user_input[1]}"')
        target_index = target_song.index[0]
        target_cluster =  songs.loc[target_index, 'cluster']
        target_artist = songs.loc[target_index, 'artist']
        print('found in the database')
        
    else:
        print('not found in the database, retrieving infos from spotify')

        # look for song in spotify
        target_song = get_audio_features(track_title=user_input[0], artist_name=user_input[1])
        target_index = target_song.index[0]
        pipeline.transform(target_song)
        target_song['cluster'] = pipeline.predict(target_song)
        target_cluster =  target_song.loc[target_index, 'cluster']
        
        # adding new song to songs database
        if target_song.track[0] not in list(songs.track):
            songs = pd.concat([songs, target_song], axis=0).reset_index(drop=True)
            songs.to_csv('../data/final/songs.csv', index=False)

        #ADDING new artist to artist database_
        target_artist = target_song.artist[0]
        new_art = artist_recommended(get_artist_stats(artist_name=target_artist))
        if new_art.artist[0] not in list(artists.artist):
            artists = pd.concat([artists, new_art]).reset_index(drop=True)
            artists.to_csv('../data/final/artists.csv', index=False)        
        print("we're all set")
    
    return [target_song, target_cluster]

# %%
def get_recomm_songs (target_cluster: int) -> pd.DataFrame:
    '''
    this function receives the target cluster label 
    and returns the songs dataframe filtered by:
        - cluster 
        - target artists (non famous artists)
    '''
    artists = pd.read_csv('../data/final/artists.csv')
    songs = pd.read_csv('../data/final/songs.csv')
    
    # filter song dataset by target artists
    recomm_artists = artists.query('is_recommended == 1').loc[:,['artist', 'followers', 'popularity']]

    # filter songs dataset by cluster
    cluster_songs = songs.query(f'cluster == {target_cluster}')

    # filter songs by artist (is_recommended or not)
    cluster_songs['is_recommended'] = cluster_songs.artist.apply(lambda x: 1 if x in list(recomm_artists.artist) else 0)
    cluster_songs = cluster_songs.query("is_recommended == 1 & decade >= 1980 & art_genres!='[]'")
    
    return cluster_songs

# %%
def artist_popularity_link(df):
    # Adding new target based on number of followers:
    
    artists=pd.read_csv('../data/final/artists.csv')
    artist_popularities = []
    url = 'https://open.spotify.com/'
    
    df_temp = df.copy()
    df_temp['artist'] = df.artist.apply(lambda x: x.replace('"',"'"))

    for artist in list(df_temp.artist):
        art_index = artists.query(f'artist=="{artist}"').index[0]
        
        artist_popularities.append(artists.loc[art_index,'popularity'])
    df['popularity'] = artist_pop
    df['link'] = df.tracks_uri.apply(lambda x: 'track/'.join ([url, x.split(':')[-1]]))
    
    return df

# %% [markdown]
# ## Other

# %%
def remove_outlier(df_in:pd.DataFrame, col_name:str):
    '''
    this function accepts a dataframe, removes outliers, 
    returns a list, containing:
        - [0] new dataframe filtering outliers
        - [1] tuple, containing low, high fences of outliers
    '''
    q1 = df_in[col_name].quantile(0.25)
    q3 = df_in[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    return [df_out, (fence_low, fence_high)]

# %% [markdown]
# # Sources

# %% [markdown]
# https://www.musicmap.info/#
