# %% [markdown]
# # EDA - Exploratory Data Analysis
#
# HINT:
# - Faça uma pergunta para o DATA SET
# - Limpe ao menos 3 colunas

# %%
import pandas as pd
import numpy as np

# %%
shark = pd.read_csv('GSAF5.csv',encoding='latin-1')
shark['Type']
# Out:
# 0       Unprovoked
# 1       Unprovoked
# 2       Unprovoked
# 3       Unprovoked
# 4       Unprovoked
#            ...
# 5987    Unprovoked
# 5988    Unprovoked
# 5989    Unprovoked
# 5990    Unprovoked
# 5991    Unprovoked
# Name: Type, Length: 5992, dtype: object

# %% [markdown]
# # Verificar colunas
# - dropar colunas repetidas: Case number / href (links
# - deletar coluna pdf

# %%
(~(shark['Case Number.1'] == shark['Case Number.2'])).sum()
(~(shark['Case Number.1'] == shark['Case Number'])).sum()
(~(shark['Case Number.2'] == shark['Case Number'])).sum()
# Out:
# 2

# %%
# qual deletar?
mask1 = (~(shark['Case Number.1'] == shark['Case Number.2']))
mask2 = (~(shark['Case Number.1'] == shark['Case Number']))
mask3 = (~(shark['Case Number.2'] == shark['Case Number']))

div_cases = shark[['Case Number','Year','Case Number.1','Case Number.2','pdf','Investigator or Source']].loc[(mask1|mask2|mask3),:]
div_cases
# Out:
#        Case Number  Year Case Number.1 Case Number.2  \
# 4       2016.09.15  2016    2016.09.16    2016.09.15
# 33    2016.07.14.4  2016  2016.07.14.R  2016.07.14.4
# 97    2016.01.24.b  2016  2015.01.24.b  2016.01.24.b
# 116     2015.12.23  2015    2015.11.07    2015.12.23
# 121   2015.10.28.a  2015    2015.10.28  2015.10.28.a
# 169     2015.07-10  2015    2015.07.10    2015.07.10
# 3296    1967.07.05  1967    1967/07.05    1967.07.05
# 3569  1962,08.30.b  1962  1962.08.30.b  1962,08.30.b
# 3654  1961.09.02.R  1961  1961.09,06.R  1961.09.02.R
# 4177    1952.08.05  1952    1952.08.04    1952.08.05
# 4719  1934.01.08.R  1934  1934.02.08.R  1934.02.08.R
# 5043  1900.00.00.R  1919  1919.00.00.R  1900.00.00.R
# 5150  1911.07.31.R  1911  1911.07.31.T  1911.07.31.R
#
#                               pdf       Investigator or Source
# 4       2016.09.16-BellsBeach.pdf           The Age, 9/16/2016
# 33    2016.07.14.R-TigerBeach.pdf           GrindTV, 7/14/2016
# ...

# %%
shark.index
# Out:
# RangeIndex(start=0, stop=5992, step=1)

# %%
for index in shark.index:
    if shark.loc[index,'href'] == shark.loc[index,'href formula'] :
        True
    else: 
        False

# %%
type(shark.loc[0,'href formula'])
# Out:
# str

# %%
shark.loc[:,'href'].apply(lambda x: True if len(x) == )
# Out:
#   File "<ipython-input-56-6337cf40df9a>", line 1
#     shark.loc[:,'href'].apply(lambda x: True if len(x) == )
#                                                           ^
# SyntaxError: invalid syntax

# %%
shark.loc[:,'href formula']
# Out:
# 0       http://sharkattackfile.net/spreadsheets/pdf_di...
# 1       http://sharkattackfile.net/spreadsheets/pdf_di...
# 2       http://sharkattackfile.net/spreadsheets/pdf_di...
# 3       http://sharkattackfile.net/spreadsheets/pdf_di...
# 4       http://sharkattackfile.net/spreadsheets/pdf_di...
#                               ...
# 5987    http://sharkattackfile.net/spreadsheets/pdf_di...
# 5988    http://sharkattackfile.net/spreadsheets/pdf_di...
# 5989    http://sharkattackfile.net/spreadsheets/pdf_di...
# 5990    http://sharkattackfile.net/spreadsheets/pdf_di...
# 5991    http://sharkattackfile.net/spreadsheets/pdf_di...
# Name: href formula, Length: 5992, dtype: object

# %%
(~ (shark['href formula'] == shark['href'])).sum()
# Out:
# 54

# %%
# qual deletar?
mask_link = (~(shark['href'] == shark['href formula']))

div_cases = shark[['Case Number','Year','pdf','href formula','href']].loc[(mask1|mask2|mask3),:]
div_cases.head(50)
# Out:
#        Case Number  Year                          pdf  \
# 4       2016.09.15  2016    2016.09.16-BellsBeach.pdf
# 33    2016.07.14.4  2016  2016.07.14.R-TigerBeach.pdf
# 97    2016.01.24.b  2016        2016.01.24.b-Love.pdf
# 116     2015.12.23  2015     2015.11.07-Underwood.pdf
# 121   2015.10.28.a  2015       2015.10.28-Senensi.pdf
# 169     2015.07-10  2015        2015.07.10-Miskin.pdf
# 3296    1967.07.05  1967         1967.07.05-Guven.pdf
# 3569  1962,08.30.b  1962             1962.08.30.b-pdf
# 3654  1961.09.02.R  1961    1961.09.06.R-Chioggia.pdf
# 4177    1952.08.05  1952         1952.08.05-Speca.pdf
# 4719  1934.01.08.R  1934      1924.02.08.R-Turkey.pdf
# 5043  1900.00.00.R  1919      1919.00.00.R-Savona.pdf
# 5150  1911.07.31.R  1911       1911.07.31.R-Ceuta.pdf
#
#                                            href formula  \
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# 33    http://sharkattackfile.net/spreadsheets/pdf_di...
# ...

# %%
shark[['Case Number','Year', 'Date','pdf','href formula','href']].tail(20)
# Out:
#      Case Number  Year                                               Date  \
# 5972     ND.0020     0                                         1920 -1923
# 5973     ND.0019     0                                        Before 1921
# 5974     ND.0018     0                                        Before 1911
# 5975     ND.0017     0                                        Before 1921
# 5976     ND.0016     0                                        Before 1921
# 5977     ND.0015     0                                        Before 1917
# 5978     ND.0014     0                        Before          17-Jul-1916
# 5979     ND.0013     0  No date (3 days after preceding incident) & pr...
# 5980     ND.0012     0                        Before          19-Jul-1913
# 5981     ND.0011     0                                        Before 1911
# 5982     ND.0010     0                                         Circa 1862
# 5983     ND.0009     0                                        Before 1906
# ...

# %%
shark.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
col_list = [i.lower().strip().replace(' ', '_') for i in shark.columns]

# %%
col_list
# Out:
# ['case_number',
#  'date',
#  'year',
#  'type',
#  'country',
#  'area',
#  'location',
#  'activity',
#  'name',
#  'sex',
#  'age',
#  'injury',
#  'fatal_(y/n)',
#  'time',
#  'species',
#  'investigator_or_source',
#  'pdf',
#  'href_formula',
#  'href',
#  'case_number.1',
#  'case_number.2',
#  'original_order',
#  'unnamed:_22',
#  'unnamed:_23']

# %%
shark[['Type','Fatal (Y/N)','Injury']].loc[shark['Type']== 'Provoked',:].head(50)
# Out:
#          Type Fatal (Y/N)                                             Injury
# 23   Provoked           N       Laceration to left forearm PROVOKED INCIDENT
# 28   Provoked           N  Laceration to left calf from hooked shark PROV...
# 36   Provoked           N  Fin of hooked shark injured fisherman's forear...
# 39   Provoked           N  Right thigh injured by hooked pregnant female ...
# 47   Provoked           N  No injury but shark punctured his wetsuit afte...
# 63   Provoked           N                      Arm grabbed PROVOKED INCIDENT
# 65   Provoked           N      Foot bitten by landed shark PROVOKED INCIDENT
# 70   Provoked           N  Severe lacerations to right forearm, hand and ...
# 80   Provoked           N            Minor injury to chest PROVOKED INCIDENT
# 147  Provoked           N  Laceration to dorsum of foot by hooked shark  ...
# 160  Provoked           N               Right hand bitten  PROVOKED INCIDENT
# ...

# %%
shark.Type.unique()
# Out:
# array(['Unprovoked', 'Boat', 'Provoked', 'Invalid', 'Sea Disaster',
#        'Boating'], dtype=object)

# %% [markdown]
# # Limpar 3 colunas

# %% [markdown]
# ## Limpar a coluna 'Type'
#
# - Tirar amostra
# - Criar uma nova coluna Type_2 com novas clasificações

# %% [markdown]
# ## Limpar coluna "Injury"
#
# - Mantém

# %% [markdown]
# ## Limpar a coluna 'Fatal (Y/N)'

# %% [markdown]
# ## Limpar a coluna Year
# criar nova agrupando por décadas

# %% [markdown]
# # Probabilidade de sobrevivência num ataque de tubarão

# %% [markdown]
# ## Criar coluna de número de sobreviventes em um ataque

# %% [markdown]
# ## Coluna com flags de: injuries / not
