# %% [markdown]
# # EDA - Exploratory Data Analysis
#
# HINT:
# - Faça uma pergunta para o DATA SET
# - Limpe ao menos 3 colunas

# %%
import pandas as pd
import numpy as np

# %%
shark = pd.read_csv('GSAF5.csv',encoding='latin-1')
shark.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   ...  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M  ...
# 2  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  ...
# 4                       Bells Beach  Surfing             male    M  ...
#
#     Species        Investigator or Source                        pdf  \
# ...

# %% [markdown]
# # Verificar colunas
# - dropar colunas repetidas: Case number / href (links
# - deletar coluna pdf

# %%
(~(shark['Case Number.1'] == shark['Case Number.2'])).sum()
(~(shark['Case Number.1'] == shark['Case Number'])).sum()
(~(shark['Case Number.2'] == shark['Case Number'])).sum()
# Out:
# 2

# %%
# qual deletar?
mask1 = (~(shark['Case Number.1'] == shark['Case Number.2']))
mask2 = (~(shark['Case Number.1'] == shark['Case Number']))
mask3 = (~(shark['Case Number.2'] == shark['Case Number']))

div_cases = shark[['Case Number','Case Number.1','Case Number.2','pdf','Investigator or Source']].loc[(mask1|mask2|mask3),:]
div_cases
# Out:
#        Case Number Case Number.1 Case Number.2                          pdf  \
# 4       2016.09.15    2016.09.16    2016.09.15    2016.09.16-BellsBeach.pdf
# 33    2016.07.14.4  2016.07.14.R  2016.07.14.4  2016.07.14.R-TigerBeach.pdf
# 97    2016.01.24.b  2015.01.24.b  2016.01.24.b        2016.01.24.b-Love.pdf
# 116     2015.12.23    2015.11.07    2015.12.23     2015.11.07-Underwood.pdf
# 121   2015.10.28.a    2015.10.28  2015.10.28.a       2015.10.28-Senensi.pdf
# 169     2015.07-10    2015.07.10    2015.07.10        2015.07.10-Miskin.pdf
# 3296    1967.07.05    1967/07.05    1967.07.05         1967.07.05-Guven.pdf
# 3569  1962,08.30.b  1962.08.30.b  1962,08.30.b             1962.08.30.b-pdf
# 3654  1961.09.02.R  1961.09,06.R  1961.09.02.R    1961.09.06.R-Chioggia.pdf
# 4177    1952.08.05    1952.08.04    1952.08.05         1952.08.05-Speca.pdf
# 4719  1934.01.08.R  1934.02.08.R  1934.02.08.R      1924.02.08.R-Turkey.pdf
# ...

# %%
# substituir na coluna 'Case Number' pela info retirada de 'pdf' e dropar colunas: Case Number.1 e Case Number.2

shark.loc[(mask1|mask2|mask3),:]['Case Number'] = shark.loc[(mask1|mask2|mask3),:]['pdf'].apply(lambda x: x.split('-')[0])
# Out:
# /Users/serachung/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
shark
# Out:
#        Case Number         Date  Year        Type             Country  \
# 0     2016.09.18.c    18-Sep-16  2016  Unprovoked                 USA
# 1     2016.09.18.b    18-Sep-16  2016  Unprovoked                 USA
# 2     2016.09.18.a    18-Sep-16  2016  Unprovoked                 USA
# 3       2016.09.17    17-Sep-16  2016  Unprovoked           AUSTRALIA
# 4       2016.09.15    16-Sep-16  2016  Unprovoked           AUSTRALIA
# ...            ...          ...   ...         ...                 ...
# 5987       ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 5988       ND.0004  Before 1903     0  Unprovoked           AUSTRALIA
# 5989       ND.0003    1900-1905     0  Unprovoked                 USA
# 5990       ND.0002    1883-1889     0  Unprovoked              PANAMA
# 5991       ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %% [markdown]
# # Limpar 3 colunas

# %% [markdown]
# ## Limpar a coluna 'Name'
#  - se male == unknown

# %% [markdown]
# ## Limpar a coluna 'Type'

# %% [markdown]
# ## Limpar a coluna Year
# criar nova agrupando por décadas

# %% [markdown]
# # Probabilidade de sobrevivência num ataque de tubarão

# %% [markdown]
# ## Criar coluna de número de sobreviventes em um ataque

# %% [markdown]
# ## Coluna com flags de: injuries / not
