# %%
from getpass import getpass
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Database

# %% [markdown]
# ## Base dataset
# - Kaggle Hits per Decade dataset

# %%
df_1960 = pd.read_csv('data/processed/dataset-of-60s.csv')
df_1970 = pd.read_csv('data/processed/dataset-of-70s.csv')
df_1980 = pd.read_csv('data/processed/dataset-of-80s.csv')
df_1990 = pd.read_csv('data/processed/dataset-of-90s.csv')
df_2000 = pd.read_csv('data/processed/dataset-of-00s.csv')
df_2010 = pd.read_csv('data/processed/dataset-of-10s.csv')

# %%
# Adding the decade information as a column
df_1960['decade'] = 1960
df_1970['decade'] = 1970
df_1980['decade'] = 1980
df_1990['decade'] = 1990
df_2000['decade'] = 2000
df_2010['decade'] = 2010

# %%
# Concatenating all dataframes into one
df = pd.concat([df_1960, df_1970, df_1980, df_1990, df_2000, df_2010], axis=0)

# %%
print(df.shape)
df.head()
# Out:
# (41106, 20)
#                    track            artist  \
# 0  Jealous Kind Of Fella     Garland Green
# 1          Initials B.B.  Serge Gainsbourg
# 2           Melody Twist       Lord Melody
# 3          Mi Bomba Sonó        Celia Cruz
# 4            Uravu Solla       P. Susheela
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:1dtKN6wwlolkM8XZy2y9C1         0.417   0.620    3    -7.727
# 1  spotify:track:5hjsmSnUefdUqzsDogisiX         0.498   0.505    3   -12.475
# 2  spotify:track:6uk8tI6pwxxdVTNlNOJeJh         0.657   0.649    5   -13.392
# 3  spotify:track:7aNjMJ05FvUXACPWZ7yJmv         0.590   0.545    7   -12.058
# 4  spotify:track:1rQ0clvgkzWr001POOPJWx         0.515   0.765   11    -3.515
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0403         0.490          0.000000    0.0779    0.845
# 1     1       0.0337         0.018          0.107000    0.1760    0.797
# 2     1       0.0380         0.846          0.000004    0.1190    0.908
# 3     0       0.1040         0.706          0.024600    0.0610    0.967
# 4     0       0.1240         0.857          0.000872    0.2130    0.906
#
#      tempo  duration_ms  time_signature  chorus_hit  sections  target  decade
# 0  185.655       173533               3    32.94975         9       1    1960
# 1  101.801       213613               4    48.82510        10       0    1960
# 2  115.940       223960               4    37.22663        12       0    1960
# 3  105.592       157907               4    24.75484         8       0    1960
# 4  114.617       245600               4    21.79874        14       0    1960

# %%
# Checking for NaN values: No Missing numbers 
df.isna().sum().sum()
# Out:
# 0

# %%
# Droping duplicated filtered by both: tracks & artists
df = df.drop_duplicates(subset=['artist','uri'])

# %%
# Checking columns
df.columns
# Out:
# Index(['track', 'artist', 'uri', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature', 'chorus_hit',
#        'sections', 'target', 'decade'],
#       dtype='object')

# %%
# inversing columns order: categorical first, and then features

df = df[['track', 'artist', 'uri', 'decade', 'danceability', 'energy', 'key', 'loudness',
       'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo', 'duration_ms', 'time_signature', 'chorus_hit',
       'sections', 'target']]

# %%
# renaming columns to be more 'understandable' 
## -> the target column if the song was in a billboard chart or not)

df.columns = ['track', 'artist', 'uri', 'decade', 'danceability', 'energy', 'key', 'loudness',
       'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo', 'duration_ms', 'time_signature', 'chorus_hit',
       'sections', 'billboard']

# %%
df.head()
# Out:
#                    track            artist  \
# 0  Jealous Kind Of Fella     Garland Green
# 1          Initials B.B.  Serge Gainsbourg
# 2           Melody Twist       Lord Melody
# 3          Mi Bomba Sonó        Celia Cruz
# 4            Uravu Solla       P. Susheela
#
#                                     uri  decade  danceability  energy  key  \
# 0  spotify:track:1dtKN6wwlolkM8XZy2y9C1    1960         0.417   0.620    3
# 1  spotify:track:5hjsmSnUefdUqzsDogisiX    1960         0.498   0.505    3
# 2  spotify:track:6uk8tI6pwxxdVTNlNOJeJh    1960         0.657   0.649    5
# 3  spotify:track:7aNjMJ05FvUXACPWZ7yJmv    1960         0.590   0.545    7
# 4  spotify:track:1rQ0clvgkzWr001POOPJWx    1960         0.515   0.765   11
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -7.727     1       0.0403         0.490          0.000000    0.0779
# 1   -12.475     1       0.0337         0.018          0.107000    0.1760
# 2   -13.392     1       0.0380         0.846          0.000004    0.1190
# 3   -12.058     0       0.1040         0.706          0.024600    0.0610
# 4    -3.515     0       0.1240         0.857          0.000872    0.2130
#
#    valence    tempo  duration_ms  time_signature  chorus_hit  sections  \
# 0    0.845  185.655       173533               3    32.94975         9
# 1    0.797  101.801       213613               4    48.82510        10
# 2    0.908  115.940       223960               4    37.22663        12
# 3    0.967  105.592       157907               4    24.75484         8
# 4    0.906  114.617       245600               4    21.79874        14
#
#    billboard
# 0          1
# 1          0
# 2          0
# 3          0
# 4          0

# %%
# The dataset seems balanced enough
sns.countplot(df.decade);

# %%
# saving this dataset to the 'analysis' directory
df.to_csv('data/analysis/songs_decades.csv', index=False)

# %% [markdown]
# ## API data collect

# %% [markdown]
# Collecting more data to complement the dataset of artists and songs

# %% [markdown]
# ### Artist dataset

# %% [markdown]
# #### Spotify API - additional infos
# - `genres`
# - `artist_uri`
# - `followers`

# %%
# Initializing access to spotify's API
access_spotify()

# %%
df = pd.read_csv('data/analysis/songs_decades.csv')
df.shape
# Out:
# (40617, 20)

# %%
# for each unique value of artist, retrieve stats from spotify (reduced to half):
df_artists = df.drop_duplicates(subset='artist').reset_index(drop=True)
df_artists.shape
# Out:
# (11904, 20)

# %%
df_artists_clean_name = clean_name(df_artists, 'artist')

# %%
# running spotify api get request for dataset
get_artist_stats(df_artists_clean_name, billboard_col= True)
# Out:
# Garland Green
# Serge Gainsbourg
# Lord Melody
# Celia Cruz
# P. Susheela
# Ennio Morricone
# Antônio Carlos Jobim
# Marv Johnson
# Caetano Veloso
# The Beach Boys
# Jerry Goldsmith
# Roy Orbison
# Luiz Gonzaga
# Jimmy Dean
# Mary Wells
# Leño
# Jackie Wilson
# Staatskapelle Berlin
# Shirley
# The Everly Brothers
# Stevie Wonder
# Traditional
# Scott Walker
# Giacomo Puccini
# Ernie K-Doe
# Bobby Vee
# The Beatles
# Frank Zappa
# Enrique Guzman
# Ray Charles
# Fritz Kreisler
# Jerry Adriani
# Gerardo Reyes
# Ike
# Joan Manuel Serrat
# The Happenings
# The Supremes
# Tito Rodriguez
# Jr. Walker
# Marvin Gaye
# Tony Bennett
# Mark Van Doren
# La Sonora Matancera
# Yusef Lateef
# The Staple Singers
# Maynard Ferguson
# Los Teen Tops
# Don Hinson
# Nelson Gonçalves
# Jim Reeves
# Paulinho Nogueira
# Charles Aznavour
# Victor Jara
# Neil Sedaka
# David Lindup
# Jerry Landis
# Johnny Preston
# Barbara Mason
# Pérez Prado
# Ben E. King
# Diana Ross
# Betty Everett
# Sir Douglas Quintet
# Johnny Lytle
# The Archies
# Bobby Goldsboro
# The Exciters
# The Marketts
# The Box Tops
# Guty Cárdenas
# Herman's Hermits
# Langston Hughes
# The Doors
# The Hombres
# Syd Dale
# Françoise Hardy
# Charles Mingus
# Gilberto Gil
# André Hossein
# The Hippy Boys
# Benjamin Britten
# The Detergents
# The Searchers
# Bobby Moore
# The Shangri-Las
# Donovan
# Tommy McCook
# Aretha Franklin
# Ramsey Lewis
# The Stooges
# Carlo Savina
# Doc Watson
# Bob Wills
# Wolfgang Amadeus Mozart
# Ernesto Lecuona
# The Marvelows
# Percy Sledge
# Tito Puente
# David Houston
# Pharoah Sanders
# Cowboy Copas
# Harry Belafonte
# The Ivy League
# The Marvelettes
# The Strangeloves
# Staatskapelle Dresden
# Sonny Rollins
# Johnny Burnette
# Steam
# Vienna State Opera Orchestra
# Bobby Hendricks
# Conway Twitty
# Elmer Bernstein
# John Zacherle
# Marinês E Sua Gente
# Al Martino
# Piero Piccioni
# Maurice Jarre
# Krokodil
# Javier Solís
# The Contours
# Johnny Tillotson
# Cilla Black
# The Olympics
# Jorge Ben Jor
# Julio Gutierrez
# The Kinks
# Jack Scott
# Michel Legrand
# Raimon
# The Lovin' Spoonful
# Gene Pitney
# Gerald Wilson Orchestra
# Patsy Cline
# Pozo Seco Singers
# Vicente Fernández
# Michel Polnareff
# Wilson Pickett
# Captain Beefheart
# Chubby Checker
# Blue Cheer
# Carmelia Alves
# The Pretty Things
# Traffic
# Jean Prodromidès
# The Little Dippers
# Brenda Lee
# Neil Diamond
# The Clique
# Jackie DeShannon
# Mulatu Astatke
# Bobby Vinton
# The Ventures
# Bud Powell
# The Coasters
# Peter Thomas
# Archie Bell
# Smith
# John Fahey
# Bee Gees
# Kenny Dorham
# Chuck Berry
# The Shadows Of Knight
# Don Fardon
# Royal Philharmonic Orchestra
# John Barry
# Ronnie Dove
# The Impressions
# Bobby Marchan
# Armando Trovajoli
# Sérgio Mendes
# Gaetano Donizetti
# Laurie Lee
# Theodore Roethke
# Engelbert Humperdinck
# The Showmen
# The Bonzo Dog Band
# Frank Sinatra
# Petula Clark
# James Brown
# Tom Jones
# Mel Carter
# I Marc 4
# Jiří Malásek
# Ultimate Spinach
# Leno e Lilian
# J.J. Barnes
# Luiz Bonfá
# Leonard Bernstein
# Amalia Mendoza
# The Rascals
# The Rip Chords
# Clint Eastwood
# The Moody Blues
# The Byrds
# The Mamas
# Adam Wade
# Wayne Newton
# Bobby Rydell
# Peter
# The Chantels
# Chris Crosby
# Herb Alpert
# The Drifters
# Laurie Johnson
# Sérgio Ricardo
# Ella Fitzgerald
# Francy Boland
# John Coltrane Quartet
# The Lettermen
# Eddie Floyd
# Flatt
# Giuseppe Verdi
# Solomon Burke
# Chico Buarque
# The Shirelles
# The Monkees
# Tammi Terrell
# Willie Mitchell
# Sonny
# Otis Redding
# George Frideric Handel
# Lesley Gore
# The Sherrys
# The Yardbirds
# The Kingston Trio
# Joe Dowell
# The Dave Clark Five
# Joe Tex
# The Wildweeds
# Johnny Nash
# Glen Campbell
# Buddy Knox
# Roger Williams
# Louise Bogan
# Johnnie Taylor
# Brenda Holloway
# John Sebastian
# Bill Black's Combo
# Leipzig Radio Symphony Orchestra
# James
# Xhol Caravan
# The Pixies Three
# Angelo Francesco Lavagnino
# Lee Hazlewood
# Tommy Roe
# Etta Jones
# Bruce Channel
# Marty Robbins
# Lloyd Price
# The Delfonics
# Dee Clark
# Albert Ayler
# Gianni Ferrio
# Gábor Szabó
# Silver Apples
# Jimmy Reed
# Jefferson Airplane
# Aaron Copland
# Dorsey Burnette
# Autry Inman
# Paul Anka
# The Three Degrees
# Dionne Warwick
# La Lupe
# The Hangmen
# The Dolphins
# Denise Levertov
# Roberto Carlos
# Manfred Mann
# Chicho Sánchez Ferlosio
# Four Tops
# Elvin Jones
# Country Joe
# Ed Ames
# The Astors
# Os Mutantes
# Freddie Hubbard
# Orlando Silva
# Burl Ives
# Helen Shapiro
# The Buckinghams
# The Angels
# Elvis Presley
# Arthur Conley
# Eric Burdon
# Garoto
# Ann-Margret
# Taj Mahal
# Trio Melodia
# Mark Valentino
# Betty Harris
# Lou Rawls
# Sly
# Eddie Hodges
# The Paris Sisters
# Giampiero Boneschi
# The Friends Of Distinction
# The Animals
# Cher
# Jan
# Brian Hyland
# The Mojo Men
# Ruby
# Bert Jansch
# Charlie Drake
# Jack Jones
# Brenton Wood
# Sandy Nelson
# Bunny Sigler
# Chuck Jackson
# The Jamies
# Benedetto Ghiglia
# The Chiffons
# Andy Williams
# National Philharmonic Orchestra
# Allan Sherman
# Vito
# Lou Christie
# The Capitols
# James Gilreath
# Bob Dylan
# Giovanni Fusco
# Alan Hawkshaw
# Martha Reeves
# Chris Montez
# Amon Düül
# Del Shannon
# Georges Delerue
# Patxi Andion
# Buddy Guy
# Bobby Darin
# The Crystals
# Robin Ward
# Camille Saint-Saëns
# Chad
# Alice Coltrane
# Vic Dana
# Billy Strange
# James Darren
# Eydie Gormé
# Pete Seeger
# Ornette Coleman
# The Hollies
# Jolly Abraham
# Cannonball Adderley
# Tammy Wynette
# The Frogmen
# Barbara Lewis
# The Left Banke
# Cream
# Anthony Newley
# Nico
# Junior Parker
# The Tams
# King Fighter
# Johnny Pearson
# Johnny Rivers
# Timi Yuro
# Marlena Shaw
# The Metros
# O.C. Smith
# Laura Lee
# Len Barry
# Dion
# Vladimir Cosma
# Walter Jackson
# Roger Miller
# Los Relampagos Del Norte
# The Dynamics
# Sister Sarah Navaroji
# Anita Bryant
# The Grass Roots
# The Belmonts
# The Music Machine
# Jimmy Hughes
# Cecil Taylor
# Jacques Dutronc
# João Donato
# Fats Domino
# Ludwig van Beethoven
# François de Roubaix
# Soft Machine
# Mighty Sparrow
# Sandy Posey
# Marty Paich
# The Zombies
# Alexander Courage
# Major Lance
# The Monks
# The Brothers Four
# Eddie Harris
# Tiny Tim
# The Bubble Puppy
# Sam
# The McCoys
# The Innocence
# The Paul Butterfield Blues Band
# The Mindbenders
# Bobby "Boris" Pickett
# The Peanut Butter Conspiracy
# Jewel Akens
# Gal Costa
# Robert Schumann
# The Rolling Stones
# Jane Birkin
# Charmian Carr
# Franz von Suppé
# George Hamilton IV
# The Fortunes
# Blood
# Eddy Arnold
# LaVern Baker
# The Kingsmen
# Jack Nitzsche
# The Cyrkle
# The Vogues
# Ary Lobo
# Frankie Avalon
# Peaches
# Erasmo Carlos
# Karen Dalton
# The Johnny Mann Singers
# The Four Pennies
# Sheb Wooley
# Eddie Holland
# Jay
# Max Bruch
# Los Bravos
# Freddy Cannon
# Laura Nyro
# Johann Sebastian Bach
# Nancy Sinatra
# Miklós Rózsa
# Count Lasher
# Richard Wagner
# Elizabeth Jennings
# Tommy Edwards
# The 5th Dimension
# Ramsey Lewis Trio
# Connie Stevens
# Sonny James
# Syndicate Of Sound
# Frankie Valli
# Robert Goulet
# The Tennors
# Frankie Ford
# Brook Benton
# Mark Lindsay
# Lord Invader
# Miguelito Valdes
# Santo
# Nancy Wilson
# The Intruders
# MPB4
# Stelvio Cipriani
# The Tokens
# Jean Sibelius
# Rikkert Zuiderveld
# Wanda Warska
# Gordon Lightfoot
# Gary U.S. Bonds
# Sandie Shaw
# The Marcels
# Bobby Helms
# Larry Verne
# Little Eva
# Jimmy Clanton
# Gene Chandler
# Earl Grant
# Klaus Schulze
# Mable John
# Pyotr Ilyich Tchaikovsky
# Mitty Collier
# Max Roach
# The Chi-lites
# Irma Serrano
# Ricky Nelson
# Connie Francis
# The Piltdown Men
# Joe Cocker
# Simon
# Sunny
# Derek
# Deane Hawley
# The Stereos
# Irma Thomas
# Chucho Avellanet
# The Cascades
# Deon Jackson
# Edvard Grieg
# The Flamingos
# Dinah Washington
# Nara Leão
# Perry Como
# The Simon Sisters
# Jeannie C. Riley
# David Ruffin
# Shep
# Johnny Hawksworth
# Georges Arvanitas
# La Sonora Santanera
# Bukka White
# Danny
# The Royal Guardsmen
# John Wesley Ryles
# Dee Dee Sharp
# James Ray
# Johnny Cash
# Mort Shuman
# Maxine Brown
# Elly Nieman
# The Fugs
# The Duprees
# Lesley Frost
# Elis Regina
# Toni Fisher
# The Miracles
# Tommy Tucker
# White Noise
# Carla Thomas
# Richard Harris
# The Association
# Garnet Mimms
# The Rivieras
# Bobbie Gentry
# William Walton
# Young-Holt Unlimited
# Paul Revere
# Heitor Villa-Lobos
# The String-A-Longs
# Maria Dolores Pradera
# Isaac Hayes
# Fred Bongusto
# The Rooftop Singers
# Adriana
# Jimmy Jones
# Oscar Toney
# Stanley Kunitz
# Alvin Cash
# The Sandpipers
# Pucho
# Maurice Ravel
# The Dells
# Marva Whitney
# The Toys
# Red Simpson
# Pete La Roca
# Gilbert Bécaud
# The Blossoms
# American Symphony Orchestra
# The Seekers
# The Surfaris
# Bill Medley
# Nicole Croisille
# Lou Donaldson
# Wiener Philharmoniker
# Toquinho
# Barry
# Johnny Mathis
# Lee Dorsey
# Little Willie John
# Nick Drake
# Beny Moré
# Johnny Hallyday
# The Lemon Pipers
# Mason Williams
# Gioachino Rossini
# The Statler Brothers
# Nina Simone
# Tom Zé
# CAN
# Kris Jensen
# Sergio Mendes
# Creedence Clearwater Revival
# Rod Lauren
# The Lloyd McNeill Quartet
# Sonny Boy Williamson II
# Della Reese
# The Winstons
# Bob Lind
# Quarteto Em Cy
# The Tymes
# Dave Dudley
# Barbra Streisand
# Lawrence Welk
# Bobby Curtola
# Sam Cooke
# The Champs
# Johnny Crawford
# The New Christy Minstrels
# Leroy Van Dyke
# Pat Boone
# Dean Martin
# Otis Leavill
# The Turtles
# Ohio Express
# Jimmy Gilmer
# Horst Jankowski
# Lefty Frizzell
# The Troggs
# The Swinging Blue Jeans
# The Artistics
# John Williams
# Keith Colley
# The Vibrations
# Isaac Albéniz
# The O'Kaysions
# Keith Mansfield
# Led Zeppelin
# Buck Owens
# The Gestures
# Mal Waldron
# Tommy James
# John Barry Orchestra
# Deep Purple
# Tommy McLain
# Millie Small
# Gale Garnett
# The Rivingtons
# The Righteous Brothers
# Steve Lawrence
# Joe Dassin
# The Don Ellis Orchestra
# The Majors
# Gino Marinuzzi
# Don Covay
# Oliver Nelson
# Francis Lai
# B.B. King
# The Chambers Brothers
# Liverpool Five
# Terry Riley
# Vikki Carr
# Bobby Womack
# Trevor Rabin
# Ruggero Leoncavallo
# Billy Stewart
# Buddy Holly
# Daniel Santos
# Faron Young
# P.J. Proby
# Etta James
# Spirit
# Marianne Faithfull
# Mercy
# Joe Simon
# Jumpin' Gene Simmons
# The Electric Prunes
# Baby Washington
# Gene McDaniels
# Los Indios Tabajaras
# Dickie Goodman
# Marcie Blane
# Paul Bley Trio
# Canhoto
# Walter Wanderley
# Inez Foxx
# King Crimson
# Palito Ortega
# The Who
# Bobby Wood
# Dave Brubeck
# Lee Konitz
# The Temptations
# Jimmy Elledge
# Yves Montand
# Tyrone Davis
# The Hullaballoos
# Don Gibson
# Marcos Valle
# Ravi Shankar
# Bob Luman
# Jeannie Seely
# Robert Charlebois
# Swedish Radio Symphony Orchestra
# Garnet Mimms
# Claudine Clark
# D. G. S. Dhinakaran
# The Merrymen
# O.V. Wright
# Bobby Powell
# Emilio Pericoli
# Nino Tempo
# Piero Umiliani
# Armando Sciascia Orchestra
# Alain Goraguer
# Kevin Ayers
# Bobby Freeman
# McCoy Tyner
# Barbara Lynn
# Coco Lagos
# Noro Morales
# The Meters
# Johnny Winter
# Kasenetz-Katz Singing Orchestral Circus
# Eddie Lovette
# Jessie Hill
# Patti Drew
# Jerry Butler
# Jonathan King
# Ernie Maresca
# Orquesta Casino De La Playa
# Niño Rivera
# Steve Lacy
# Ronnie Hawkins
# Patti LaBelle
# Dusty Springfield
# Francesco De Masi
# Johnny Cymbal
# Clarence Carter
# Curtis Lee
# Don Shirley Trio
# The Five Americans
# Lonnie Mack
# The Arbors
# The Isley Brothers
# Glenn Yarbrough
# Maureen Gray
# The Velaires
# Jeanne Black
# Bobby Hutcherson
# Lawrence Reynolds
# The Sweet Inspirations
# Hugh Masekela
# Johnny Adams
# The United States Of America
# The Spencer Davis Group
# Nat King Cole
# Sammy Davis Jr.
# Don Cherry
# Robert Lowell
# Elza Soares
# Dorothy Ashby
# Joan Baez
# Gustav Mahler
# Ronny Douglas
# The Routers
# Paul Petersen
# Harpers Bizarre
# Johnny Gibson
# Fontella Bass
# Edwin Starr
# Richard Chamberlain
# The Rugbys
# Jose Fajardo
# Theola Kilgore
# Teresa Brewer
# Alvin Cash
# Donny Hathaway
# Guy Mitchell
# U.S. Bonds
# The Spinners
# Sagittarius
# Os Originais Do Samba
# Boots Randolph
# Ben Colder
# Crispian St. Peters
# Fred Hughes
# Zé Keti
# Willie Tee
# Eric Dolphy
# William Bell
# Peter
# Milton Nascimento
# The Hondells
# The Red Krayola
# Leon Haywood
# Berlin Radio Symphony Orchestra
# James Carr
# The Dovells
# Ral Donner
# The Velvelettes
# The Fleetwoods
# Jimmy McCracklin
# The Swans
# Blind Willie McTell
# The Elgins
# Jimmy Cliff
# Joanie Sommers
# Ivo Robic
# Jimmy Charles
# Claude Bolling
# Johannes Brahms
# Ferrante
# Perrey and Kingsley
# The Fireballs
# Tony Williams
# Steve Allen
# Matt Monro
# The Bachelors
# Jimmy Durante
# Kitty Kallen
# Smokey Robinson
# Barbara George
# Judy Collins
# Paulinho Da Viola
# Mitch Ryder
# The Echoes
# The Iveys
# The Foundations
# Willy Alberti
# The Ronettes
# The Busters
# Bobby Taylor
# MGM Studio Orchestra
# Patty
# Jimmie Rodgers
# Troy Keyes
# The Orlons
# The Vejtables
# Small Faces
# Bo Diddley
# Skeeter Davis
# Scott McKenzie
# Frédéric Chopin
# The Blendells
# Oliver
# Ray Stevens
# Lou Johnson
# Trini Lopez
# Vanilla Fudge
# The Trashmen
# Pietro Mascagni
# The Holidays
# Wanderlea
# Philadelphia Orchestra
# The Cookies
# Dizzy Gillespie
# Adam Faith
# Freddie Scott
# Leapy Lee
# Ramrods
# Billy Abbott
# Armando Manzanero
# Waylon Jennings
# Brigitte Bardot
# The Jelly Beans
# Susan Christie
# The Preludes Five
# Lenny Welch
# Merrilee Rush
# Lord Kitchener
# Dale
# The Percells
# Billy Joe Royal
# Rex Allen
# Eddie Fisher
# Lou Monte
# Ray Peterson
# Esther Phillips
# The Honeycombs
# The Beau Brummels
# Shirley Ellis
# Bill Cosby
# Clyde McPhatter
# Lonnie Russ
# Mort Sahl
# Patty Duke
# Shades Of Blue
# Jimmy Holiday
# The Sunshine Company
# The Cleftones
# Andy Kim
# Bettye Swann
# The Young Rascals
# Napoleon XIV
# The Rose Garden
# Wink Martindale
# Grateful Dead
# The Illusion
# Joni Mitchell
# Duane Eddy
# Evie Sands
# Ketty Lester
# The Matadors
# Wayne Shorter
# Joel Oppenheimer
# Jimmy Smith
# The Flirtations
# The Delacardos
# Kim Weston
# Philip Larkin
# Cliff Richard
# The Castells
# Ralph Vaughan Williams
# Jimmy Castor
# Gabriel Fauré
# Little Junior Parker
# The Mills Brothers
# Donnie Brooks
# The Cowsills
# Antonio Vivaldi
# The Dixie Cups
# Randy Newman
# The Dynamites
# Joey Powers
# Tom Northcott
# Kenny Rogers
# Nana Caymmi
# The Waikikis
# Gary Puckett
# Ted Hughes
# Bobby Bare
# Georgie Fame
# Brooklyn Bridge
# Anna King
# The Incredible String Band
# Al Kooper
# Léo Delibes
# Luis Eduardo Aute
# The Moments
# Nancy Ames
# Gil Evans
# Louis Armstrong
# Janie Grant
# Dion
# The Soul Sisters
# Syl Johnson
# Kyu Sakamoto
# The Reflections
# The Deadly Ones
# Terry Stafford
# The Tremeloes
# Billy Edd Wheeler
# Hank Williams
# The Serendipity Singers
# John Mayall
# Frank Ifield
# Norma Tanega
# Steppenwolf
# Lester Flatt
# B.J. Thomas
# Them
# The First Edition
# Ray Smith
# Los Panchos
# Mitchell Torok
# Luis Bacalov
# Alvin Cash
# Jack Eubanks
# Brian Wilson
# Jack Greene
# Peggy Scott
# Candy
# Debbie Taylor
# Ronnie Carroll
# Antonio Aguilar
# Alexander 'Skip' Spence
# Jerry Wallace
# The Halos
# Derrick Harriott
# Vinícius de Moraes
# The Mar-Keys
# Sam Rivers
# Steve Gray
# The Larks
# Gogi Grant
# Big Joe Williams
# Pierre Barouh
# Marcello Giombini
# Herb Alpert
# The Dave Brubeck Quartet
# Keith
# Four Jacks
# Rita Pavone
# Muriel Rukeyser
# Bernard Estardy
# The Irish Rovers
# Bernadette Carroll
# Love
# Bruce
# Floyd Cramer
# Jimmy Ruffin
# The Seeds
# Shelley Fabares
# Teddy
# Dreamlovers
# Hank Snow
# Larry Hall
# Herbie Mann
# King Curtis
# Little Milton
# Dickey Lee
# B. Bumble
# Johnny Horton
# Bobby Lewis
# Dueto America
# Spiral Starecase
# The Dyna-Sores
# Just Us
# The Platters
# Charlie Rich
# The Newbeats
# The Novas
# Patti Page
# Burt Bacharach
# Rufus Thomas
# Lord Creator
# Jackson Mac Low
# Jody Miller
# Da Brat
# Nico Fidenco
# The Nashville Teens
# Sonny Sharrock
# The Joe Harriott-John Mayer Double Quintet
# The Woolies
# Enrico Macias
# The O'Jays
# Joe South
# Gloria Lynne
# Barrett Strong
# Strawberry Alarm Clock
# The Barbarians
# Lorne Greene
# Van Morrison
# The Ribbons
# Lulu
# Johnny Bond
# Stonewall Jackson
# Laurindo Almeida
# Antonín Dvořák
# Nelson Riddle
# Albert King
# Domenico Scarlatti
# The Blue Diamonds
# Bruno Nicolai
# Jackie Lee
# Moondog
# Long John Baldry
# Mickey Murray
# Mongo Santamaria
# The Radiants
# Novalis
# Kool
# Victor Lundberg
# Brooks O'Dell
# Lolita
# Iron Butterfly
# Henson Cargill
# Harold Dorman
# Barbara Acklin
# Bud Shank
# Barry McGuire
# Al Hirt
# Claude King
# Sue Thompson
# The Outsiders
# Jerry Jaye
# Spyder Turner
# The James Boys
# Travis Wammack
# The Youngbloods
# Richard Anthony
# Teddy Randazzo
# Walter Brennan
# Aaron Neville
# Charles Lloyd
# Fred Neil
# Roy Clark
# Lena Horne
# Mrs. Miller
# The Bermudas
# Jerry Vale
# The Packers
# Denny Reed
# Johnny Maestro
# Doris Troy
# refreshing token
# error: Earl-Jean
# Paul Evans
# The Guess Who
# Igor Stravinsky
# Charles Brown
# Slim Harpo
# The Paradons
# Kay Starr
# Bobby Hebb
# The Gentrys
# Arthur Prysock
# Darrell Banks
# Bobby Gregg and His Friends
# Hedgehoppers Anonymous
# The Jaynetts
# Johnny Thunder
# Sammy Turner
# Red Sovine
# Eddie Holman
# Grand Funk Railroad
# The Limeliters
# George Maharis
# Sun Ra
# Rolf Harris
# Janis Joplin
# Mary Hopkin
# The Ivy Three
# Rene
# Byron Morris and Unity
# John D. Loudermilk
# Louise Brown
# Fred Darian
# The Ides Of March
# The Standells
# The Nightcrawlers
# Tony Joe White
# Robert John
# The Clash
# Al Casey
# Merrilee Rush
# Gabriel
# Ruth Brown
# Marion Brown
# Frankie Calen
# Roy Drusky
# The Wailers
# Wes Montgomery
# Ataulfo Alves
# Sarah Vaughan
# The Crests
# The Original Caste
# Mariah Carey
# Billy Bland
# The Springfields
# Three Dog Night
# Mahalia Jackson
# Vanity Fare
# Dee Dee Warwick
# The Sevilles
# Sonny Terry
# Jimmy Soul
# Prince Buster
# Bobby Parker
# The Challengers
# Lalo Schifrin
# Christoph Willibald Gluck
# Rundfunk Sinfonieorchester Berlin
# The Four Preps
# John Buddy Williams
# Rhinoceros
# Alexander Borodin
# Tommy Hunt
# Bombay Jayashri
# Clarence Reid
# 2 Of Clubs
# Dobie Gray
# The New Yorkers
# The Candymen
# Wanda Jackson
# Tim Buckley
# The Texans
# Andre Williams
# The Capris
# Jerry Lee Lewis
# Ferlin Husky
# The Five Stairsteps
# Motherlode
# Rusty Draper
# Canned Heat
# Mickey
# Martinho Da Vila
# Vincenzo Bellini
# The Blue Notes
# Little Johnny Taylor
# Jimmy Velvet
# Count Alert
# Roy Head
# Nino Rota
# Paul Dukas
# The Merry-Go-Round
# Buchanan Brothers
# The Marathons
# Los Cinco Latinos
# The Knockouts
# The Casinos
# The Esquires
# The Ray Conniff Singers
# The Neon Philharmonic
# Anton Rubinstein
# The Rocky Fellers
# The Equals
# Serge Reggiani
# Tommy Boyce
# Duane Eddy and the Rebelettes
# Crosby
# Michael Hurley
# Bill Deal
# Julie Rogers
# Mickey Lee Lane
# The Sharks
# Baden Powell
# Darlene Love
# Tony Orlando
# Spanky
# Ray Barretto
# Bill Doggett
# The Jewels
# The Chanters
# Shorty Long
# Joey Dee
# The Parliaments
# Louis Prima
# We Five
# Larry Finnegan
# The Classics
# The Gants
# The Fantastic Johnny C
# Shelby Flint
# Maurice Chevalier
# Charley Pride
# Savoy Brown
# Bill Shirley
# Visioneers
# The Critters
# Benny Spellman
# Linda Ronstadt
# Gilbert
# J.J. Jackson
# Galway Kinnell
# The Village Stompers
# Collay
# The Valentinos
# Stefano Torossi
# George Gruntz Concert Jazz Band
# The Excellents
# Peggy Lee
# Damita Jo
# Kenny O'Dell
# James Booker
# Enrique Granados
# The Shells
# Jan Bradley
# Phil McLean
# Marion Worth
# Ace Cannon
# H.B. Barnum
# Danny Williams
# Andrew Hill
# Jefferson
# Betty Wright
# The Devotions
# Neal Hefti
# Maysa
# The Blenders
# System Of A Down
# Miltiño
# Felice Taylor
# The Frantics
# The Demensions
# Fever Tree
# Rufus
# The Yellow Balloon
# Lucienne Delyle
# Hector Berlioz
# Clifford Curry
# Joe Henderson
# Candi Staton
# Count Basie
# Howard Tate
# Sergei Rachmaninoff
# The Murmaids
# Toussaint McCall
# The Skyliners
# Mitch Ryder
# The Viscounts
# The Videls
# Miriam Makeba
# Barry Ryan
# Merle Haggard
# John Gary
# Thom Gunn
# Procol Harum
# Marty Wilde
# The Dreamlovers
# Troy Shondell
# G.L. Crockett
# Ray Anthony
# The Sidekicks
# Bill Anderson
# Mitch Miller
# Orpheus
# Danny Hutton
# Count Five
# Bobby Sherman
# Dodie Stevens
# Frankie Lymon
# Richard Burton
# Ned Miller
# Noel Harrison
# Alfredo Zitarrosa
# Clara Nunes
# The Pastel Six
# Kenny Chandler
# The Electric Indian
# Joe Hinton
# The Five Satins
# Margaret Whiting
# The Third Rail
# Terry Knight and The Pack
# John Denver
# Ian Whitcomb
# Robert Knight
# Nora Orlandi
# MC5
# Don Shirley
# Murry Kellum
# Robert Mitchum
# Ruby Andrews
# The Easybeats
# The Rays
# Linda Jones
# The Fendermen
# Barry Young
# refreshing token
# error: Johnny and The Expressions
# Eternity's Children
# Preston Epps
# The Emotions
# The Innocents
# The Hearts
# The Caravelles
# Gil Scott-Heron
# Giuliano Sorgini
# Maurice Williams
# Ralph McTell
# Buddy Greco
# The Four Sportsmen
# The Amboy Dukes
# The Mad Lads
# The Goodees
# Jerry Jeff Walker
# Debbie Reynolds
# Franz Joseph Haydn
# The Fantastic Four
# Darrow Fletcher
# Alberto Cortez
# Mary Mary
# The Starlets
# The Ad Libs
# The Regents
# Arthur Honegger
# George Jones
# The Rondels
# Wayne Fontana
# Hayley Mills
# The Saints
# Zager
# The Scaffold
# Rahsaan Roland Kirk
# The Shindogs
# Pigmeat Markham
# Al Wilson
# Trade Martin
# Tracey Dey
# The Raindrops
# The Sapphires
# The Edsels
# Nino
# Barbara
# The G-Clefs
# The Crazy World Of Arthur Brown
# Mark Dinning
# Tommy Cash
# Hank Locklin
# The Superbs
# Felix Mendelssohn
# Soul Survivors
# Charlie Byrd
# The Paragons
# Classics IV
# The Five Du-Tones
# Willie Nelson
# Andy Stewart
# Erma Franklin
# Claudine Longet
# The Earls
# Magic Lanterns
# Hollywood Argyles
# The Formations
# Fabian
# Buzz Clifford
# The "5" Royales
# Joni James
# Wind
# Chevelle
# Bull
# The Poets
# Ernie Fields
# Joaquín Rodrigo
# Dimitri Tiomkin
# Johnny Sea
# The Band
# Allen Ginsberg
# Sonny Knight
# Scott English
# The Originals
# The Clovers
# The Girlfriends
# Diane Renay
# Nikolai Rimsky-Korsakov
# Rod McKuen
# Roy Hamilton
# The Caslons
# Juan Pardo
# The Premiers
# The Harden Trio
# Little Peggy March
# Shirley Bassey
# Jerry Murad's Harmonicats
# The Tornadoes
# The Beau-Marks
# Jackie Ross
# The Diamonds
# The Secrets
# Michele Lee
# Joe Jones
# The American Breed
# The Timetones
# Fairport Convention
# Funkadelic
# Crazy Elephant
# Sunny
# Guy Marks
# Robert Parker
# The Toy Dolls
# Billy Preston
# The Rollers
# R.B. Greaves
# James MacArthur
# Rod Bernard
# Ronnie and The Hi-Lites
# The Human Beinz
# Buster Brown
# The Music Explosion
# Jimi Hendrix
# Luther Vandross
# Vince Guaraldi Trio
# Ray Price
# Soupy Sales
# The Jarmels
# The Castaways
# The Pyramids
# Henry Mancini
# Silna Grupa Pod Wezwaniem
# Joe Turner
# Janis Ian
# Ryan Louder
# Steve Alaimo
# Johnnie Morisette
# The Knickerbockers
# The Intrigues
# Miss Toni Fisher
# The Spacemen
# Cathy Carroll
# Keith Barbour
# Titus Turner
# Southwest F.O.B.
# Tim Hardin
# The Spellbinders
# Bill Pursell
# Booker Ervin
# The Bar-Kays
# Bing Crosby
# Sammy Masters
# Nazz
# Ella Washington
# Tex Ritter
# Skip James
# The Blue-Belles
# The McGuire Sisters
# Bertha Tillman
# Jo Ann Campbell
# English Chamber Orchestra
# Louis Untermeyer
# Jane Morgan
# Sounds Orchestral
# Jacques Brel
# Big Maybelle
# Porter Wagoner
# The Browns
# The Parade
# Ernie Freeman
# The Flares
# The Ikettes
# Jack Ross
# The Cherry People
# Archie Shepp
# James Phelps
# John Lee Hooker
# Jimmy McGriff
# Bull Moose Jackson
# Carole King
# John Mayall
# The Peels
# Berto Pisano
# The T-Bones
# Fantastic Four
# Kokomo
# Chris Kenner
# Gilberto Monroig
# The Enchanters
# Dylan Thomas
# The Spokesmen
# The Poppies
# The Smothers Brothers
# Jeff Beck
# Vic Damone
# Don
# Little Richard
# Peppermint Rainbow
# The Uniques
# Peter Sarstedt
# Carlo Rustichelli
# Della Humphrey
# Pete Fountain
# Boz Scaggs
# Gewandhausorchester Leipzig
# Randy
# Mike Douglas
# Ike Turner
# Thunderclap Newman
# Lorraine Ellison
# Chris Bartley
# Ruby Winters
# Francisco Alves
# Santana
# Tony Clarke
# Rosco Gordon
# Barry Mann
# Eddie Rambeau
# Hank Thompson
# The Monitors
# The Cupids
# The Chordettes
# The Fiestas
# The Fifth Estate
# Billie Jo Spears
# refreshing token
# error: Cleveland Crochet and Band
# CROW
# Mike Clifford
# Wade Flemons
# Alberto Beltran
# Billy Joe
# The Flying Machine
# The Rationals
# Reginaldo Rossi
# Maria Teresa Luciani
# Crass
# The Jets
# Mike Seeger
# Daniel Boone
# Kate Bush
# The Damned
# Brian Auger
# Hui Ohana
# The Sylvers
# Eric Clapton
# Dennis Brown
# Marvin Hamlisch
# The Whispers
# Ralph Stanley
# Purple Reign
# Luther Ingram
# Foxy
# Foghat
# Bhaskar Chandavarkar
# Frijid Pink
# Woody Herman
# Donna Summer
# Lindisfarne
# Tequila
# Blue Swede
# The New Seekers
# Five Flights Up
# Gerry Rafferty
# Village People
# England Dan
# Sleepy John Estes
# Ace
# Jimmy James
# Suzi Quatro
# Lead Belly
# The Trammps
# Tony Kinsey
# Neil Young
# South Shore Commission
# Krisma
# Gary Toms Empire
# Styx
# Al Di Meola
# Maggie Bell
# Blondie
# Silvio Rodríguez
# Rita Coolidge
# Norman Blake
# ABBA
# Marie Osmond
# François Bréant
# Mary Macgregor
# Rex Smith
# 10cc
# The Dickies
# Bloodstone
# Roxy Music
# Alan Parker
# Alice Cooper
# Ton Steine Scherben
# Muddy Waters
# Supertramp
# Gino Vannelli
# Paco de Lucía
# Lonnie Brooks
# B.W. Stevenson
# James Taylor
# Joel Grey
# Vangelis
# Melanie
# NEU!
# Olivia Newton-John
# Facundo Cabral
# Patti LuPone
# Oswaldo Montenegro
# refreshing token
# error: The Partridge Family Starring Shirley Jones
# Peter Maffay
# Bloodrock
# Mark-Almond
# David Bowie
# Miles Davis
# Buzzcocks
# Sly Stone
# Keith Nichols
# War
# José Alfredo Jimenez
# R. Stevie Moore
# kalapana
# Camaron De La Isla
# Brian Eno
# Ohio Players
# Dom Salvador
# John Coltrane
# Maxine Nightingale
# Alex de Grassi
# Elton John
# Throbbing Gristle
# Jimmy Buffett
# Pete "El Conde" Rodriguez
# Joe Bataan
# The Dramatics
# Little River Band
# Rupert Holmes
# Todd Rundgren
# Los Gatos
# The Osmonds
# Eric Demarsan
# Sweet
# Arawak
# Loggins
# Joe Walsh
# Sham 69
# Freddy Fender
# Gregory Isaacs
# Kenny Nolan
# Kris Kristofferson
# Nature's Mystic Moods
# Deuter
# Brownsville Station
# Hot Chocolate
# Derek
# The Brothers Cazimero
# Donna Fargo
# Andy Fairweather Low
# Westernhagen
# Ann Peebles
# Kitaro
# 5000 Volts
# Johnny Shines
# The Fall
# Ramon Muntaner
# Brian Bennett
# Compost
# Lee Michaels
# Bette Midler
# Beverly Bremers
# Big Star
# The Main Ingredient
# Elba Ramalho
# Latimore
# Las Grecas
# Doc
# Wailing Souls
# U.K. Subs
# J.B. Lenoir
# Eagles
# The Persuaders
# Stefan Grossman
# Liquid Gold
# Johnny Rodriguez
# Martha Reeves
# John Hartford
# Diana Ross
# Al Green
# Philip Glass
# The Gaylads
# Don Ho
# Gabby Pahinui
# Sonny Boy Nelson
# Earth
# National Health
# The Jazz Crusaders
# Jermaine Jackson
# Black Heat
# Michael Chapman
# David Bromberg
# Lol Coxhill
# Lynyrd Skynyrd
# Bill Evans
# Billy Boy Arnold
# Rose Royce
# The J. Geils Band
# Redbone
# Wolfgang Ambros
# Mike Post
# Neil Young
# The James Gang
# Sister Sledge
# Carly Simon
# Genesis
# Bob Seger
# Pholhas
# Stephen Sondheim
# Electric Light Orchestra
# Bobby Valentin
# Tommy James
# De Wolfe Music
# Glen Campbell
# Komintern
# Bobby Moore
# Rod Stewart
# Ron Carter
# Commodores
# Slave
# Carla Bley
# Les Baxter
# Sunnyland Slim
# Gallery
# Billy Joel
# Dexter Gordon
# refreshing token
# error: The Hues Corporation
# The Vibrators
# Starcastle
# Jean-Luc Ponty
# Gloria Gaynor
# Raydio
# The Pointer Sisters
# The Poppy Family
# Carpenters
# Jim Hall
# First Choice
# Michael Jackson
# Jethro Tull
# Iggy Pop
# Kayak
# Burton Cummings
# Carlos Alexandre
# Carey Bell
# J.D. Crowe
# Steven Halpern
# Maureen McGovern
# Larry Sparks
# Son Seals
# Graham Central Station
# Chiquetete
# Edgar Winter's White Trash
# Maria Muldaur
# Gene Ammons
# Prince Far I
# Crosby
# Rare Earth
# Aerosmith
# Barry White
# Willie Colón
# Millie Jackson
# Cheryl Barnes
# Robert Palmer
# Anne Murray
# Leo Kottke
# Lobo
# Walter Egan
# Barry Manilow
# Big Band Katowice
# Brotherhood Of Man
# Crystal Gayle
# Art Farmer
# Jaume Arnella
# Robert Fripp
# Eloy
# Loleatta Holloway
# David Gates
# Michael Johnson
# Walter Murphy
# Chavela Vargas
# Claude Debussy
# Paul Hindemith
# Leon Redbone
# Don McLean
# Iasos
# Rick Springfield
# Gene Redding
# Nazareth
# Dave Maclean
# Josep Maria Espinàs
# Stealers Wheel
# Billy Bond
# The Babys
# Tonto's Expanding Head Band
# Renato Teixeira
# Leslie Bricusse
# J.D. Short
# Melissa Manchester
# refreshing token
# error: Joe Cocker and The Chris Stainton Band
# Tito Schipa Jr.
# Brigitte Fontaine
# Little Sonny
# Olivier Messiaen
# Meco
# Meat Loaf
# Bread
# Kas Product
# Grover Washington
# Harry Chapin
# Tycoon
# El Chicano
# Ecstasy
# Five Man Electrical Band
# Taeko Onuki
# Andrea True Connection
# Collin Walcott
# Casa Das Máquinas
# Hannes Wader
# Amado Batista
# refreshing token
# error: Jane Birkin Serge Gainsbourg
# Python Lee Jackson
# Stargard
# Tanya Tucker
# R. Dean Taylor
# Toto
# Ginger Baker's Air Force
# Fatback Band
# Hot Rize
# Little Feat
# Plastic Bertrand
# Black Sabbath
# George Harrison
# Ronnie Milsap
# Jan Ptaszyn Wróblewski Quartet
# The Doobie Brothers
# Bill Withers
# Player
# Haruomi Hosono
# Verckys
# Terry Jacks
# Nikhil Banerjee
# refreshing token
# error: Santa Esmeralda Starring Leroy Gomez
# Raul Seixas
# Sam Spence
# The Mob
# Al Tall
# The Manhattans
# Riz Ortolani
# Brick
# Gregg Allman
# Blueridge Mountain Bluegrass Band
# The Stylistics
# Gordon Giltrap
# KISS
# Blue Haze
# Dom Salvador
# Extra Ball
# Chuck Mangione
# Marian McPartland
# Jerry Reed
# Bandit
# John Cameron
# Tavares
# Nigel Olsson
# Andrew Gold
# Ronnie Dyson
# Evelyn "Champagne" King
# Saga
# refreshing token
# error: Hog Heaven
# The Ritchie Family
# The Buggles
# YELLOW MAGIC ORCHESTRA
# Smokey Robinson
# Dorothy Moore
# Laurence Vanay
# Ana Belén
# Chuck Mangione
# Joy Division
# Jimmy Johnson
# Rubinho
# Wire
# David Soul
# Foreigner
# The Alan Parsons Project
# The Floaters
# Wings
# Emerson
# Graham Nash
# Bram Tchaikovsky
# Afrique
# Karat
# Trio Ternura
# Jesse Anderson
# Raspberries
# I-Roy
# Flipper
# Mikey Dread
# Steely Dan
# Chicago
# Paul Davis
# Ednardo
# refreshing token
# error: Little Carl Carlton
# Lynn Anderson
# Stephen Bishop
# Fernando Mendes
# Denise LaSalle
# Tommy Flanagan
# Natalie Cole
# Merle Haggard
# Chic
# Stanley Turrentine
# Paper Lace
# Tom Clay
# Paul Simon
# Silvetti
# Conway Twitty
# Yvonne Elliman
# Eddie Rabbitt
# ZZ Top
# Climax Blues Band
# Gary Wright
# New York City
# Bill Evans Trio
# Dan Hill
# Cheryl Ladd
# Jackson Browne
# Philly Cream
# Los Terricolas
# Blackfoot
# Steve Martin
# Derek Bailey
# Charles Strouse
# Firefall
# Mighty Joe Young
# Al Stewart
# Ashra
# Tim Maia
# Pino Donaggio
# Ebo Taylor
# John Stewart
# U-Roy
# Austin Roberts
# The Salsoul Orchestra
# Sammy Hagar
# Henry Kaiser
# Billy Preston
# Timmy Thomas
# João Bosco
# Eric Weissberg
# Jean-Michel Jarre
# Wednesday
# Jessi Colter
# Barbra Streisand
# Marion
# Jack Owens
# Laboratorium
# Christophe
# Ebony
# The Reggae Boys
# Mighty Diamonds
# Schawkie Roth
# The Temprees
# Donny Osmond
# Kenny Rogers
# Cyndi Grecco
# Telegraph Avenue
# Cornelio Reyna
# Hugh Mundell
# Elvin Bishop
# Journey
# Earl Hooker
# Shalamar
# Wet Willie
# Narada Michael Walden
# Mandy Patinkin
# Adam Makowicz
# Bachman-Turner Overdrive
# Willie Dixon
# Sugarloaf
# Triana
# Swell Maps
# Luther Johnson
# Uriah Heep
# Poco
# Pablo Cruise
# Pinetop Perkins
# Hammie Nixon
# Johnny "Big Moose" Walker
# Udo Lindenberg
# Bobby Byrd
# King Floyd
# Cecilio
# Georges Van Parys
# Stephanie Mills
# Dogs
# Cornelius Brothers
# The Lurkers
# The Rubinoos
# The Caboose
# Albert Hammond
# Les Crane
# Pablo de Sarasate
# Eric Carmen
# Jim Croce
# Fanny
# Anita Ward
# Simeon ten Holt
# Commander Cody
# Pasteur Lappe
# León Gieco
# B.T. Express
# Kansas
# Love
# The Jaggerz
# Gilbert O'Sullivan
# G.Q.
# Penguin Cafe Orchestra
# Fleetwood Mac
# Ernie
# JD Souther
# Linda Clifford
# Frankie Miller
# Bruce Springsteen
# Carles Benavent
# Atlanta Rhythm Section
# Yukihiro Takahashi
# The Cars
# Bobby Womack
# Delaney
# The Web
# The Bells
# Bobby Cruz
# The Buoys
# Lazy Racer
# Amerindios
# Karlheinz Stockhausen
# Johnny Wakelin
# Lô Borges
# Parker McGee
# John Travolta
# The Tubes
# The Sports
# Peter Nero
# Jerry Garcia
# D.J. Rogers
# Pat Benatar
# Carl Carlton
# Argent
# The Raiders
# The Flame
# Chris Spheeris
# Sui Generis
# Fred Wesley
# Alphataurus
# Flash
# Jefferson Starship
# Sugarloaf
# James Clarke
# The Police
# Silver Convention
# Milt Buckner
# Eddie Money
# Bad Company
# Czeslaw Bartkowski
# Buffy Sainte-Marie
# Suzi Quatro
# British Lions
# Quicksilver Messenger Service
# Dean Friedman
# James Gang
# Rufus
# Godspell
# Billy Paul
# Gene Cotton
# Hazel Dickens
# The Goodies
# Harold Budd
# The Walter Murphy Band
# Franco D'Andrea
# El Gran Combo De Puerto Rico
# The Brothers Johnson
# The Jimmy Castor Bunch
# Cooker
# Ram Jam
# The Knack
# Os Incríveis
# Norman Greenbaum
# Frannie Golde
# Steve Miller
# The Allman Brothers Band
# El Coco
# Daniel Viglietti
# Frankie Valli
# Sniff 'n' the Tears
# Captain
# Dave Loggins
# Donnie Elbert
# Dr. Buzzard's Original Savannah Band
# Eric Burdon
# Ramon Ayala Y Sus Bravos Del Norte
# Orleans
# Brenda Russell
# Itzhak Perlman
# Gina
# Chocolate Milk
# Slade
# America
# Sylvester
# Kiko Veneno
# REO Speedwagon
# The McCrarys
# Chase
# Gabelo
# Dan Hartman
# Rubicon
# Loriot
# Ananda Shankar
# Jean Knight
# Looking Glass
# A Taste Of Honey
# Red Garland
# Chi Coltrane
# Steve Hackett
# Secos
# Chris Rea
# Design
# Andy Gibb
# Silvio Rodriguez and Pablo Milanes
# The Crusaders
# The Independents
# Lone Ranger
# Hurricane Smith
# John Jackson
# Bob Seger
# C.C.S.
# Karla Bonoff
# Machine
# Blue
# Heart
# Guillermina Motta
# The Residents
# Billy Swan
# Van Der Graaf Generator
# Jerry Herman
# Manolo Sanlucar
# Golden Earring
# Johnny Bristol
# Helen Reddy
# Bob Welch
# MFSB
# Johnny Paycheck
# John Renbourn
# The Fuzz
# Hot Butter
# Eddie Kendricks
# Gary Numan
# Arne Domnérus
# Bobby Bloom
# Mac Davis
# 999
# Mark O'Connor
# Angelic Upstarts
# Chaka Khan
# Jards Macalé
# Sylvia
# Charlie McCoy
# Alan Moorhouse
# Dawn
# Gwen McCrae
# Dr. John
# Public Image Ltd.
# Leo Sayer
# Van Halen
# Mississippi Fred McDowell
# Roberto Pregadio
# Teixeirinha
# Elizabeth Cotten
# Guilherme Arantes
# Aguaviva
# Badfinger
# David Cassidy
# Gene Rondo
# Boston
# Lebrón Brothers
# Belle Epoque
# Novos Baianos
# Yes
# Esquirols
# Amaury Pérez
# Black Flag
# Elvin Bishop
# Bebeto
# Barbara Mandrell
# Blue Magic
# Love Unlimited
# Jerry Butler
# Christie
# Blue Mink
# C.W. McCall
# T-Connection
# PeeWee Bluesgang
# Das Dritte Ohr
# Catherine Christer Hennix
# Stampeders
# Carmen Linares
# Vanusa
# Heatwave
# Al DeLory
# Guy Lafitte
# Jazz Band Ball Orchestra
# Jerry Butler
# Street People
# Jan Garbarek
# Paul Anka
# Jon Hassell
# Will Ackerman
# Enrico Simonetti
# Dave Mason
# Enrico Pieranunzi
# Mott The Hoople
# Universal Robot Band
# Oscar Peterson
# The Presidents
# Edison Lighthouse
# Lou Reed
# Curtis Mayfield
# Ian Matthews
# Roberta Flack
# Kalyani Roy
# The Lost Generation
# Agepê
# Stan Getz
# Melveen Leed
# Keola Beamer
# Hubert Sumlin
# The Jacksons
# Dr. Hook
# Leon Russell
# Stephen Stills
# Bulldog
# Freda Payne
# Free
# Big John Wrencher
# Debby Boone
# refreshing token
# error: The Shocking Blue
# Wipers
# Johnny Colon
# Drupi
# Paul
# Andy Pratt
# Deodato
# T. Rex
# David Grisman
# Carlos Puebla
# Danny Holien
# Quincy Jones
# Los Del Guadalquivir
# Starz
# Torfrock
# Art Garfunkel
# Mass Production
# Antonio Marcos
# Whirlwind
# Renato Sellani
# Melba Moore
# Michal Urbaniak
# Yabby You
# The Ebonys
# Brenda
# Don Nix
# The Blackbyrds
# Margie Joseph
# The Brecker Brothers
# Lightnin' Hopkins
# Paul Anka
# VELHA GUARDA DA PORTELA
# Eddie Palmieri
# Merry Clayton
# Cluster
# Gunnar 'Silja-Bloo' Nilsson
# Henry Gross
# Melanie
# Triumph
# Peter Frampton
# Cheap Trick
# Shaun Cassidy
# Silver
# Glass Hammer
# Gladys Knight
# Bill LaBounty
# Tom T. Hall
# New Grass Revival
# Earl Scruggs
# Samantha Sang
# Leon
# Brass Construction
# Charo
# Tom Petty
# Don Goodwin
# Jonathan Edwards
# Prince
# Leif Garrett
# Bill Keith
# refreshing token
# error: The Steve Miller Band
# Cashman
# George McCrae
# Achim Reichel
# The New Lost City Ramblers
# Mike Bloomfield
# Krzysztof Sadowski
# Third World
# McGuinn
# Lonnie Johnson
# Paco Cepero
# Los Angeles Negros
# Angel
# Duncan Lamont
# Chilliwack
# Liz Damon's Orient Express
# Marilyn Sellars
# Zbigniew Namysłowski Quintet
# Queen
# The Ruts
# refreshing token
# error: James Brown-Lyn Collins
# Pete Dunaway
# Geraldo Azevedo
# Jerry Orbach
# The Michael Zager Band
# Big Youth
# Bonnie Raitt
# Luther Allison
# Gary Glitter
# Gonzalez
# Roger Whittaker
# Alessandro Alessandroni
# John Miles
# Dolly Parton
# Dolors Laffitte
# Tim Moore
# The New Birth
# Manfred Mann's Earth Band
# Turner Foddrell
# Dr. Hook
# Ambrosia
# Frank Mills
# Donna Summer
# Hot Tuna
# Edu Lobo
# Joy Of Cooking
# Cissy Houston
# Beth Carvalho
# Bobby "Blue" Bland
# The Pop Group
# Patrick Hernandez
# Eduardo Falú
# The Marshall Tucker Band
# U.K.
# Sammi Smith
# Paul Butterfield's Better Days
# Keola
# John Lennon
# Red Eye
# Jose Roberto
# Giorgio Gaslini
# Benny Goodman
# Tony Orlando
# Lana Cantrell
# Michael Parks
# Mac McAnally
# Andrew Lloyd Webber
# Rick Nelson
# Rosa Maria
# Los Muecas
# Q
# Diana Ross
# Roger Daltrey
# Moon Martin
# Kenny Loggins
# Rick James
# Ten Years After
# Eruption
# Brian Protheroe
# Nick Gilder
# Michael Stearns
# Amparo Ochoa
# Carol Douglas
# Johnnie Taylor
# Ashton
# Mieczysław Kosz
# refreshing token
# error: Runt-Todd Rundgren
# Good Rockin' Charles
# Nick Lowe
# Bay City Rollers
# Vince Tempera
# Aksak Maboul
# Ramones
# refreshing token
# error: Dionne Warwicke
# Rick Derringer
# Arthur Verocai
# Soul Train Gang
# Gary Puckett
# Greg Lake
# The Soul Children
# The Rattles
# Champion Jack Dupree
# Zbigniew Namysłowski
# Grace Jones
# Gary Wilson
# Gary's Gang
# Larry Santos
# Hot
# Sandro Brugnolini
# Diego Verdaguer
# Starbuck
# Oak
# Lamont Dozier
# Nitty Gritty Dirt Band
# Dawn
# Klaus der Geiger
# Humble Pie
# Michael Henderson
# Teddy Pendergrass
# Tower Of Power
# Tom Petty
# Ronnie McDowell
# Johnny Williams
# The Hollywood Stars
# Tony Scott
# Maria del Mar Bonet
# Tomasz Stanko Quintet
# Amazing Rhythm Aces
# George Benson
# Sun
# Earnest Jackson
# Ahmad Jamal Trio
# Jarcha
# Joaquín Sabina
# J.J. Cale
# France Joli
# Fabulous Poodles
# The Twinkle Brothers
# Ironhorse
# Cheryl Lynn
# Fancy
# Lighthouse
# Kraftwerk
# Dom Um Romao
# Ringo Starr
# Big Mama Thornton
# Nancy Hennings
# Jay Ferguson
# Jim Stafford
# Dave Edmunds
# Piero
# Noel Pointer
# James Cotton
# Doctor Ross
# Enchantment
# Quincy Jones
# Jigsaw
# Wendy Waldman
# Buster Benton
# Focus
# Peter Skellern
# Dennis Alcapone
# Michael Murphey
# Keith Carradine
# Giorgio Moroder
# The Grateful Dead
# Donny
# Ovidi Montllor
# Night
# Ocean
# Meri Wilson
# Shirley Caesar
# Ryuichi Sakamoto
# Wild Cherry
# Charlie
# Cerrone
# Agent Orange
# Noel Nicola
# Rhythm Heritage
# Electric Callas
# Bimbo Jet
# Ashford
# Carl Douglas
# Loretta Lynn
# Maze
# Jeanne Pruett
# Paul Stanley
# Snooks Eaglin
# Liza Minnelli
# Dwight Twilley Band
# Dan Fogelberg
# Peter Rowan
# Joan Baptista Humet
# The Supremes
# Bobby "Boris" Pickett
# Suicide
# Emmylou Harris
# Amancio Prada
# Santa Esmeralda
# Justin Hayward
# Manzanita
# Dottie West
# Beaver Harris
# Narvel Felts
# Marilyn McCoo
# Carol Channing
# Bill Le Sage
# Shirley Brown
# The Newcomers
# Rod Hart
# Bill Emerson
# The Band Of The Black Watch
# Hamilton
# Thelma Houston
# Candeia
# Kiki Dee
# Mouth
# Dennis Yost
# Andy Irvine
# Lauren Wood
# Lole Y Manuel
# Creative Source
# Dire Straits
# David Dundas
# Bill Conti
# Paul Kelly
# Chelsea
# Popol Vuh
# Switch
# Djavan
# Marshall Hain
# Nektar
# Jacques Ibert
# Johnny Mars
# Hagood Hardy
# Prism
# Head East
# Peter Gabriel
# 84 Flesh
# George Thorogood
# Mr. Big
# The Manhattan Transfer
# Miguel Rios
# La Paquera De Jerez
# Crawler
# Cab Calloway
# Lee Oskar
# Mary Travers
# Sammy Johns
# Gene Simmons
# The Records
# Willie Rosario and His Orchestra
# Daryl Hall John Oates
# George Baker Selection
# Ted Nugent
# Cheech
# Talking Heads
# Major Harris
# João Gilberto
# Gato Barbieri
# Nelson Cavaquinho
# Toti Soler
# Exile
# Dennis Wilson
# Ramsey Lewis
# Girish
# John Fiddy
# The Pipkins
# Assim Assado
# Roberta Flack
# Crown Heights Affair
# High Inergy
# Teresa Rebull
# Jack Blanchard
# Grup De Folk
# The Nite-Liters
# Faces
# The Mike Curb Congregation
# Kenny Drew
# The Charlie Daniels Band
# Fábio Jr.
# The Sweet
# Luiz Melodia
# Instant Funk
# Charlie Daniels
# Jordi Sabatés
# Ted Lucas
# Buddy Miles
# Climax
# Toby Beau
# La Niña de los Peines
# Deliverance
# Barbara Fairchild
# The Chakachas
# Kris Kristofferson
# Samla Mammas Manna
# Tee Mac
# Dan Peek
# Sha Na Na
# John Handy
# Minnie Riperton
# Necros
# Cartola
# The Real Thing
# Justin Hayward
# Les McCann
# Bonnie Pointer
# The Undisputed Truth
# AC
# Space
# King Harvest
# Felipe Arriaga
# Tony Rice
# Astrud Gilberto
# Daddy Dewdrop
# Congreso
# Lyn Collins
# Belchior
# Sérgio Sampaio
# Mel
# Jerry Naylor
# Emílio Santiago
# Los Olimareños
# Allen Shelton
# Alan O'Day
# Kevin Braheny
# Joey Heatherton
# Mickey Newbury
# Flash
# Moraes Moreira
# Sabicas
# Lake
# Mickey Gilley
# The DeFranco Family featuring Tony DeFranco
# Funky Kings
# Bang
# Pilot
# Ry Cooder
# Melba Montgomery
# Bro Smith
# Edgar Winter
# Graham Nash
# Laverne
# L.T.D.
# Rafael Subirachs
# X
# Ahmad Jamal
# Billy Thorpe
# Sutherland Brothers
# Flower Travellin' Band
# New England
# Mashmakhan
# Chuck Brown and the Soul Searchers
# Cozy Powell
# Michael Nesmith
# Junior Byles
# Norman Connors
# Starland Vocal Band
# Spyro Gyra
# Doug Sahm
# Steve Reich
# The Peppers
# Donny Hathaway
# Víctor Manuel
# Mama Cass Elliot
# Chita Rivera
# The Nitty Gritty Dirt Band
# John Williams
# Aretha Franklin
# Jane Olivor
# Danny O'Keefe
# Delaney
# Alicia Bridges
# Audience
# MFSB
# Mungo Jerry
# Rickie Lee Jones
# Jim Weatherly
# Townes Van Zandt
# McFadden
# City Boy
# Doucette
# Crabby Appleton
# The Glitter Band
# Henry Mancini
# Doris Duke
# Zeca Do Trombone
# Roger Voudouris
# Parliament
# Pure Prairie League
# London Symphony Orchestra
# Warren Zevon
# Goblin
# Lindomar Castilho
# Rita Lee
# Tom Johnston
# Gallagher
# Prelude
# Bonnie Tyler
# Tom Scott
# Michael Franks
# Biddu Orchestra
# Mountain
# Five Special
# Charles Ives
# Deniece Williams
# M
# refreshing token
# error: Sharon Paige and Harold Melvin
# Duck Baker
# Pink Floyd
# Easy Street
# Suni Paz
# Amii Stewart
# Fox
# Ola Belle Reed
# Jennifer Warnes
# Pat Travers
# Willie Bobo
# Jim Ed Brown
# Lubomyr Melnyk
# Faith Band
# Willie Hutch
# Billy Ocean
# Engerling
# Susan Jacks
# Wadsworth Mansion
# Weather Report
# Bettina Wegner
# David Laflamme
# Vox Dei
# Homesick James
# Mavis Staples
# John Rowles
# Chris Thompson
# Painter
# The Mixtures
# Big Walter Horton
# People's Choice
# Rory Gallagher
# Labelle
# Blues Image
# Casey Kelly
# Rush
# Witch Queen
# Adolescents
# The Sons Of Champlin
# The People's Choice
# April Wine
# Goose Creek Symphony
# Penny Mclean
# Double Exposure
# (The Preacher
# John Phillips
# Cold Blood
# Vicki Lawrence
# Steve Martin
# Ian Hunter
# The Ramones
# Yvonne Fair
# Thin Lizzy
# Creedence Clearwater Revival
# The Rowans
# Shawn Phillips
# Carole Bayer Sager
# Nicolette Larson
# Graham Parker
# David Essex
# Ace Frehley
# Phoebe Snow
# Franco Micalizzi
# Cross Country
# Louisiana Red
# A Bolha
# The Assembled Multitude
# Chris Hodge
# Valerie Simpson
# Ricardo "Richie" Ray
# T.G. Sheppard
# Xesco Boix
# Charles De Goal
# Gram Parsons
# John Paul Young
# Joe Lee Wilson
# John Fogerty
# Van Mccoy
# Fall Out Boy
# Nolan Porter
# Foster Sylvers
# Maria Bethânia
# Paul McCartney
# Johnny Cash
# Bryan Ferry
# First Class
# The Fantastics
# Circle Jerks
# Odyssey
# Jesse Winchester
# Larry Groce
# The Dillards
# Paul Williams
# Asphalt Jungle
# John Baldry
# Delegation
# Ian Lloyd
# Sammy Burdson
# Bill Quateman
# Marmalade
# Willie Mabon
# Black Oak Arkansas
# Pablo Milanés
# Ariel Kalma
# Mighty Clouds Of Joy
# Dick Feller
# Clint Holmes
# Donald Byrd
# Brainstorm
# Pratt
# GQ
# Joe Jackson
# Average White Band
# Voyage
# The Varukers
# Alive 'N Kickin'
# Sweet Dreams
# Di Melo
# Hank Williams
# Rusty Wier
# Chuck Brown
# William DeVaughn
# The Outlaws
# The Stanley Brothers
# White Plains
# Buckeye
# Peter Brown
# Goody Goody
# Kongas
# David Geddes
# A3 Dans Le WC
# Davy Jones
# Mandrill
# Rare Essence
# Susan Raye
# Tasha Thomas
# The First Class
# Cheech
# Michael Nesmith
# Hermeto Pascoal
# Stories
# Steve Forbert
# John Lennon
# Kathy Dalton
# Odair Jose
# Dan Fogelberg
# C Company
# Angel Face
# Pickettywitch
# Donna McDaniel
# Frank Lucas
# Los Troqueros
# Fotomaker
# Frederick Knight
# Richie Havens
# Smokie
# Ron Banks
# Cal Smith
# Commander Cody and His Lost Planet Airmen
# James Last
# Nacha Guevara
# Wolf Biermann
# Country Joe McDonald
# The Kingstonians
# Charlene
# Malo
# Snail
# The Kiki Dee Band
# Gwen Verdon
# Dollar
# Brooklyn Dreams
# The Inmates
# Koko Taylor
# Juice Newton
# Robin Trower
# Ellen Foley
# Vicki Sue Robinson
# American Flyer
# Isaac Hayes
# Bill Brandon
# Jo Jo Gunne
# Randy VanWarmer
# The Flying Lizards
# Jackie Moore
# Herbie Hancock
# Woody Herman
# Isabel Parra
# Carly Simon
# Danyel Gerard
# Niteflyte
# Edward Bear
# Brighter Side Of Darkness
# Altemar Dutra
# John Kongos
# Alan Tew
# Peter Mccann
# The Marmalade
# Mike Oldfield
# Kim Carnes
# Furry Lewis
# Marvin Foddrell
# Trooper
# Elton John
# Arlo Guthrie
# Carrie Lucas
# Cochise
# Tamiko Jones
# Pleasure
# Lea Roberts
# Ike
# Grin
# Carlos Santana
# The Wackers
# The Kendalls
# Paul Simon
# Shoes
# Matthews' Southern Comfort
# The Gibson Brothers
# Tufano
# Snooky Pryor
# L. Subramaniam
# Mistress
# Sweathog
# Conway Twitty
# Fern Kinney
# The Elton John Band
# Little Sister
# The Birthday Party
# Arthur Alexander
# Jorge Cafrune
# Potliquor
# Guilty Razors
# Philippe Sarde
# Morris Albert
# Carolyne Mas
# Heartsfield
# Ace Spectrum
# Commander Cody
# Hound Dog Taylor
# Patti Smith Group
# David Naughton
# Reunion
# Joe Cuba
# Rolando Alarcon
# Chanson
# High Society
# John Travolta
# Larry Gatlin
# Kevin Lamb
# Sailcat
# Alan Parsons
# Les Hurdle
# Natalino Otto
# Ripple
# Polly Brown
# Hot Sauce
# Bobbi Martin
# Sarah Dash
# Liquid Smoke
# Willie Henderson
# refreshing token
# error: John Lennon Plastic Ono Band
# The New Hope
# Pratt
# Mocedades
# Magog
# The Glass Bottle
# Lena Zavaroni
# Lorenzo De Monteclaro
# Bob Dylan
# McGuinness Flint
# Franz Josef Degenhardt
# Falsterbo 3
# The Jones Girls
# Roedelius
# Attitudes
# Bobby Caldwell
# George Duke
# Celi Bee
# refreshing token
# error: The Brotherhood Of Man
# Andrew Jackman
# Negative Trend
# Sister Janet Mead
# Cindy Bullens
# Ronnie Spector
# Cymande
# Cast
# Pink Lady
# Cherie
# Jean Shepard
# New Riders Of The Purple Sage
# Dennis Coffey
# Livingston Taylor
# Ian Lloyd
# David Blue
# Ian Thomas
# Larry Norman
# Paul Stookey
# Loudon Wainwright III
# Angela Ro Ro
# Emitt Rhodes
# Sherbet
# Rainbow
# Germs
# refreshing token
# error: Dionne Warwicke
# Ian Gomm
# Jake Holmes
# Clifford Brown
# Sea Level
# Gino Soccio
# Clout
# Som Nosso
# Lightnin' Slim
# Nicola Piovani
# Limmie
# Jimmy "Bo" Horne
# Musique
# The Rubettes
# Cherry Vanilla
# Karen Young
# Petra
# Manu Dibango
# The Motels
# Béla Fleck
# The Pogues
# John Schneider
# Fields Of The Nephilim
# Brighton Rock
# The Other Ones
# Yngwie Malmsteen
# The Breakfast Club
# Chris
# Orchestra Baobab
# Martika
# Running Wild
# Carlos Cano
# Eric B.
# Slime
# Phil Seymour
# Enya
# Real Life
# Moebius
# Simply Red
# Big Country
# Barbra Streisand
# Sheena Easton
# Skinny Puppy
# Huey Lewis
# Tenor Fly
# Demented Are Go
# Los Suaves
# Luiz Henrique
# Miami Sound Machine
# Paula Abdul
# George Michael
# Cocteau Twins
# The Fixx
# Jody Watley
# Royal House
# Stars On 45
# Sisters of Mercy
# Arthur Russell
# The Robert Cray Band
# Matthew Young
# Spider
# Sharon Bryant
# refreshing token
# error: Terry Lewis and Wild Flower
# Klymaxx
# The Cover Girls
# "Weird Al" Yankovic
# Lucinda Williams
# 2 LIVE CREW
# Icehouse
# The Suicide Twins
# Ratt
# Cutting Crew
# Gerard Lenorman
# Men At Work
# Pseudo Echo
# El DeBarge
# The Bats
# Ray
# Don Henley
# John Cafferty
# Junkyard Band
# EPMD
# Red Rockers
# Fugazi
# Psychic TV
# Talat Aziz
# Bruce Willis
# Starpoint
# Dmitri Shostakovich
# Pauline Oliveros
# Hal Singer
# Robbie Nevil
# Randy Travis
# John Carpenter
# Otis Spann
# Billy Idol
# Oscar Chavez
# Beat Happening
# Um Toque a Mais
# Yarbrough
# Mr. Fingers
# Marc Lavoine
# Wham!
# bel canto
# Hüsker Dü
# The Bluegrass Album Band
# Phyllis Nelson
# Ricky Skaggs
# Jovelina Perola Negra
# Paul McCartney
# John Parr
# Tony MacAlpine
# Malcolm Arnold
# Rick James
# Eye To Eye
# Aries Vigoth
# Los Bukis
# The Cramps
# Further Seems Forever
# Lio
# Michael Bolton
# 808 State
# Mick Jagger
# Johnny Clegg
# José Guardiola
# Death In June
# The Reddings
# Shooting Star
# Demolition Man
# The Dillman Band
# Andy Clark
# Clan of Xymox
# The Crusaders
# Rocío Dúrcal
# Fist
# Glass Moon
# Luis Enrique
# The Cleaners From Venus
# Violent Femmes
# Stryper
# The Sugarhill Gang
# Pink Anderson
# Duran Duran
# The Clark Sisters
# Anup Jalota
# Strength In Numbers
# Elaine Machado
# Def Leppard
# Heavy D
# Danny Elfman
# Mr. Mister
# Phil Collins
# Keith Jarrett Trio
# Kishore Kumar
# Doctor Ice
# Grandmaster Flash
# Chuckii Booker
# Gyedu-Blay Ambolley
# Belinda Carlisle
# Dinosaur Jr.
# Minutemen
# Flamin' Groovies
# Boytronic
# Zohar Argov
# Regina Belle
# Palabra en Acción
# Lulu Santos
# Los Yonic's
# Dead Can Dance
# Manowar
# Fast Eddie
# Opus
# Helstar
# Pagan Altar
# Laurie Anderson
# Éric Serra
# Last Rites
# Dwarves
# Jeffrey Osborne
# Dutch Swing College Band
# Martin Gore
# Ali Farka Touré
# Madonna
# Robbie Patton
# Eurythmics
# Billy Vera
# Balance
# Ricardo Arjona
# Culture Club
# Steve Winwood
# Sly Fox
# Cloven Hoof
# Los Rebeldes
# Udo Jürgens
# One Way
# Accept
# Abstürzende Brieftauben
# Spandau Ballet
# Amit Kumar
# Whitney Houston
# Laura Branigan
# Survivor
# The Fools
# Dr. Jeckyll
# Redd Kross
# Squeeze
# Sam Bush
# Nataural
# Fine Young Cannibals
# Inner City
# Crimson Glory
# Babatunde Olatunji
# Roky Erickson
# Nobuo Uematsu
# Limahl
# The Prisoners
# Take 6
# Beatriz Adriana
# Bananarama
# My Life
# Roy Ayers
# Zebra
# KMFDM
# Bessie Smith
# Kanchan
# Corey Hart
# Big Black
# UB40
# Doc Severinsen
# The Cult
# Dolly Parton
# Bob Fitts
# Ultramagnetic MC's
# Gerry Mulligan
# Quincy Jones
# The Outfield
# Elisa Fiorillo
# Imperiet
# D.R.I.
# Thompson Twins
# Together?
# Bronski Beat
# Leandro
# Venom
# Stormwitch
# The Cutlass Dance Band
# Nocera
# Larry Gatlin
# Donnie Iris
# Sandra De Sá
# The Real Roxanne
# Minor Threat
# Hans Zimmer
# Bob Mould
# Arcadia
# José José
# Re-flex
# Rufus
# Steve Perry
# Lisa Lisa
# Aretha Franklin
# Evelyn Thomas
# Kylie Minogue
# Super Coper
# Sweet Sensation
# Roger Hodgson
# A Flock Of Seagulls
# Sad Lovers
# Go West
# Dexys Midnight Runners
# Curiosity Killed The Cat
# The Gap Band
# Alison Krauss
# Brooklyn Funk Essentials
# Brad Fiedel
# Ten City
# Aldo Nova
# Models
# Zeca Pagodinho
# Mexicanto
# Frankie Smith
# Lone Justice
# Louise Tucker
# Howard Jones
# The Darling Buds
# Benny Goodman Trio
# Newcity Rockers
# Isabel Pantoja
# Robin Gibb
# Red Hot Chili Peppers
# Ana Gabriel
# Change
# Duncan Dhu
# The Gregg Allman Band
# Tommy Shaw
# Fiona
# Breathless
# Nana Mouskouri
# LL Cool J
# Al B. Sure!
# Ann Wilson
# Helix
# Rev. Gary Davis
# Terence Trent D'Arby
# Harvey Reid
# Jon Butcher Axis
# Clarence Clemons
# The Jesus and Mary Chain
# Glenn Miller Orchestra
# The Gun Club
# The Time
# Pat Travers Band
# Frankie Goes To Hollywood
# The Georgia Satellites
# Missing Persons
# Amy Grant
# Grover Washington
# Jagjit Singh
# Duke Ellington
# Tears For Fears
# Anthony Braxton
# Dave Van Ronk
# Sting
# Jesse Johnson
# Lee Ritenour
# Current 93
# John Mellencamp
# Don Moen
# Roberta Flack
# Saraya
# Metal Church
# Twennynine
# Miguel Cantilo
# Bryan Adams
# Shana
# Robbie Dupree
# Rev. Milton Brunson
# Momus
# Cyndi Lauper
# White Flag
# Picture
# Tina Turner
# BulletBoys
# Mondo Rock
# The Firm
# Helloween
# Valentín Clastrier
# Ofra Haza
# Jorge Aragão
# David Pack
# Leila Pinheiro
# El Fary
# Psyche
# Daniel Johnston
# Bill Monroe
# The Communards
# INXS
# Timex Social Club
# Tom Petty
# Haim Moshe
# Anita Baker
# Anthrax
# Animotion
# Felt
# Jonathan Ulysses
# Gloria Estefan
# Cazuza
# Debbie Gibson
# Édith Piaf
# Michael Morales
# Crowded House
# Gualberto Ibarreto
# The Silencers
# Cameo
# Mai Tai
# Michael Stanley Band
# Tora Tora
# Adrian Oblanca
# Joan Jett
# David Grier
# Bon Jovi
# Don Williams
# The Dream Syndicate
# John Waite
# Franke
# Pierre Favre
# Torment
# Device
# Reba McEntire
# Grim Reaper
# U2
# Starship
# Europe
# Boaz Sharabi
# Guns N' Roses
# Karl-Heinz Schäfer
# Fela Kuti
# Cowboy Junkies
# Charley Patton
# Kim Wilde
# Diamanda Galás
# Eddie Money
# Scandal
# Seduction
# Rich Mullins
# Patrice Rushen
# Ali Thomson
# Red Flag
# Léo Ferré
# Pedrinho Da Flor
# La Unión
# The Human League
# Midnight Star
# Rappers Rapp Group
# Les Rita Mitsouko
# Lionel Richie
# Camilo Sesto
# Richard Marx
# Naked Eyes
# refreshing token
# error: The Payolas
# Pet Shop Boys
# The Escape Club
# Asha Bhosle
# Young MC
# Legião Urbana
# Tesla
# Martha Davis
# Soundgarden
# Tony Carey
# Kurtis Blow
# Ketama
# Morris Day
# Glenn Frey
# Raven
# The Alarm
# Joey Scarbury
# Sortilège
# Mission Of Burma
# Tuxedomoon
# Rosanne Cash
# Trouble Funk
# Rocío Jurado
# Charles Fox
# Cinderella
# Rub A Dub
# Jack Starr's Burning Starr
# Rick Springfield
# Shanice Wilson
# Debarge
# Josie Cotton
# Juliette Gréco
# Quarterflash
# Neneh Cherry
# Nitzer Ebb
# Twisted Sister
# Babyface
# Alabama
# Magnum
# Barbra Streisand
# Galaxie 500
# The Proclaimers
# Christopher Cross
# Sade
# Errobi
# Peter Cetera
# refreshing token
# error: Meli'sa Morgan
# Daryl Runswick
# Hipsway
# Loverboy
# Cock Robin
# Underworld
# Bruce Hornsby
# Rough Trade
# Manos Hadjidakis
# Divine Sounds
# Siouxsie and the Banshees
# Artefact
# Anuradha Paudwal
# Champaign
# Henry Lee Summer
# George Strait
# W.C. Handy
# Patti Austin
# Sheriff
# Ludwig Hirsch
# Rick Astley
# Whitesnake
# Celtas Cortos
# Pebbles
# Yaz
# Nazia Hassan
# ...
# Android Apartment
# Shawn Mendes
# Toehider
# Blackberry Smoke
# refreshing token
# error: K'Naan
# Christina Aguilera
# Cate le Bon
# Hatti Vatti
# Los Huracanes del Norte
# Gold Lounge
# Metal Command
# Timecop1983
# Jay Sean
# Flake Music
# Christina Aguilera
# Justin Bieber
# DJ Khaled
# Métal Urbain
# Prince Royce
# Sunidhi Chauhan
# Raymix
# Protomartyr
# Lupe Fiasco
# PARTYNEXTDOOR
# Dusk
# eli filosov [ p h i l o ]
# Exposé
# Danger Radio
# Ski Mask The Slump God
# Dawin
# Lil Wayne
# Sugluk
# David Torn
# Les Friction
# Patti Smith
# Anne Hathaway
# Wild Front
# Beyond Helvete
# Sandy Rivera
# Lil Dicky
# Kat Frankie
# Martin Garrix
# 2 Chainz
# DJ Khaled
# Austin Mahone
# Remute
# ODESZA
# HNNY
# Trippie Redd
# Brownout
# Lars Graugaard
# Benny Sings
# Technohead
# Offset
# Fabolous
# Guru Randhawa
# Nate Ruess
# Kygo
# Becky G
# Martin Garrix
# Offset
# Oak Pantheon
# My Morning Jacket
# Ozuna
# The House That Gloria Vanderbilt
# Future
# J. Cole
# Das Ding
# Ray Guell
# Enrique Iglesias
# Leon Vynehall
# The Chainsmokers
# Young Greatness
# Skarra Mucci
# The New Roses
# Enrique Iglesias
# Ninja Sex Party
# DJ Taye
# Gonzalo Rubalcaba
# BTS
# Matt McAndrew
# Granger Smith
# FUCK ART
# Lil Baby
# DJ Khaled
# Matt Stell
# Summer Walker
# Roscoe Dash
# Fireboy DML
# Pitbull
# Emerging from the Cocoon
# Hidden Citizens
# Foster The People
# Macklemore
# Summer Walker
# Anuel AA
# A$AP Rocky
# Valesca Popozuda
# Alan Walker
# R. Kelly
# Black Tiger Sex Machine
# K Camp
# DJ Khaled
# Rickyxsan
# Girl Unit
# Kenneth G
# Roddy Ricch
# Sage The Gemini
# Lil Tecca
# Jeremy Camp
# B.o.B
# ScHoolboy Q
# Iggy Azalea
# Yo Gotti
# Gershon Jackson
# Ca$h Out
# Austin Mahone
# ill-esha
# Charlie Puth
# Jonn Hart
# Dollar Signs
# Tyler Farr
# Rae Sremmurd
# G Sidhu
# Jeremih
# Migos
# Om Unit
# Beast In Black
# Tranquil Cove
# James Arthur
# Labrinth
# Oliver Heldens
# Spencer Day
# Vance Joy
# Devin Dawson
# Nicky Jam
# August Alsina
# Rayvanny
# Wizex
# They Dream By Day
# John Henriksson
# Jhene Aiko
# Skrillex
# Dylan Scott
# Andrew Bird
# Calvin Harris
# Travis Scott
# Glitchy
# Rhiannon Bannenberg
# Anamanaguchi
# 11 Acorn Lane
# Felix Da Housecat
# Stefanie Bennett
# YG
# Jamie Foxx
# Ace Hood
# Blood Ages
# John Kane
# Lupe Fiasco
# Jaron
# The New Rob Van Bavel Trio
# Drake
# Jamie xx
# Lantlôs
# Snowy White
# Linkin Park
# Jerrod Niemann
# Helhorse
# Cygnus X
# B.o.B
# Eminem
# The Electric Swing Circus
# AWOLNATION
# Jingo De Lunch
# DJ Khaled
# Disgrace
# Sykelig Englen
# Cajmere
# Black Elk
# VCTRE
# Late
# Khoma
# Snoop Dogg
# Badklaat
# A Great Big World
# Joe Arroyo
# Janet
# Beyonce
# Kanye West
# De-Phazz
# Zero Bedroom Apartment
# Anthony Linell
# Nokae
# Zayde Wølf
# Mordkey
# Cruel Force
# Meek Mill
# Logic
# Benighted
# Alabama Shakes
# Deep Watch
# SEU Worship
# G-Eazy
# Venom Inc.
# The Monotone Droner
# Tapps
# Quartz
# Pitbull
# Lupe Fiasco
# Big Sean
# The Covasettes
# Slaughter to Prevail
# Glee Cast
# Blueface
# Highlands Worship
# 7 H. Target
# Vicci Martinez
# David Guetta
# Keith Urban
# The Souljazz Orchestra
# In Aeternam Vale
# Usher
# Wun Two
# Britney Spears
# Brothers Osborne
# Machine Gun Kelly
# Sharry Mann
# Voyager
# ScHoolboy Q
# Grave Digger
# Bad Wolves
# Big Sean
# AceMo
# Queen Naija
# Kid Ink
# Kanye West
# Abhi The Nomad
# This Century
# J Balvin
# Future
# Donatachi
# Ottawa
# Unknown Mortal Orchestra
# Calvin Harris
# Nohidea
# Sheppard
# Driveways
# Wale
# Diddy - Dirty Money
# Waka Flocka Flame
# Pigeon Hole
# G-Eazy
# La Adictiva Banda San José de Mesillas
# Lord Of Bass
# TeeFLii
# Khiza
# Eddie Meduza
# Of The Trees
# Luke Bryan
# Sofi Tukker
# Myth Syzer
# Go Radio
# Craig Wayne Boyd
# Bondax
# Eminem
# Pitbull
# Nebra
# DJ Khaled
# Chris Brown
# Robert Cray
# Birdman
# Drake
# Clean Bandit
# Endtime Odyssey
# Yo Gotti
# SPIRIT DESCENT
# Brooke Candy
# Shiro Schwarz
# Roscoe Dash
# Blake Shelton
# Drake
# Chance The Rapper
# YBN Nahmir
# Pitbull
# Ben Lukas Boysen
# Regina Mira
# Tab Benoit
# Ludacris
# Selena Gomez
# Rannar Sillard
# Rachel Platten
# Chris Brown
# Machine Gun Kelly
# Seaway
# David Guetta
# Missy Elliott
# DaniLeigh
# Kygo
# SOB
# Oliver Davis
# Juliet Simms
# Snow Patrol
# Gesaffelstein
# Travie McCoy
# Bayside Worship
# Thom Yorke
# Tomppabeats
# Disaster
# Sophia Grace
# Rudimental
# Cameron DeLuca
# Snootie Wild
# Tory Lanez
# Jennifer Lopez
# Mosh36
# Kaleo
# Usher
# Meniscus
# Ripcordz
# Jakob Bro
# PnB Rock
# ScHoolboy Q
# Fir Cone Children
# Matty B
# Panda Bear
# Chris Brown
# Logic
# Empire Cast
# Justin Bieber
# Carpathian Forest
# Wiz Khalifa
# John Summit
# Kenny Chesney
# Nicole Scherzinger
# Ace Hood
# Alesso
# Lil Baby
# Eminem
# Missing Andy
# Lil Wayne
# Sick Puppies
# Wale
# Blake Shelton
# Murs
# Daniel Pemberton
# Steven C
# Calvin Harris
# Timbaland
# Luis Fonsi
# Cassadee Pope
# Migos
# Lana Del Rey
# Pandrezz
# David Arnold
# Solitude Aeturnus
# Nick Jonas
# Lucy In Disguise
# Iggy Azalea
# The Friday Night Boys
# Bobby Brackins
# Self Defense Family
# Young Jeezy
# Gunna
# 2 Chainz
# Gerardo Ortiz
# Dierks Bentley
# Antoine Dodson
# Justin Jay
# Ariana Grande
# Enrique Iglesias
# Move D
# Flume
# Sam Smith
# Taio Cruz
# Ramshackle Glory
# Miracle Of Sound
# Jamie Foxx
# Masala Roo
# AS IT IS
# Future Islands
# Sahlene Williams
# MC G15
# Chance The Rapper
# Urfaust
# Joyner Lucas
# Camila Cabello
# refreshing token
# error: Brad Paisley Duet
# The Duhks
# Eminem
# Sachin-Jigar
# Cynic
# Karma Violens
# will.i.am
# Barcelona Atmosphere
# Walter Trout
# ScHoolboy Q
# The 1975
# Wale
# A Boogie Wit da Hoodie
# King Heavy
# Jon Bellion
# Josh Thompson
# Skeptical
# Pulsedriver
# The JaneDear Girls
# Marian Hill
# G-Eazy
# Sean Paul
# Big Sean
# Ghostface Killah
# Fat Joe
# Crossface
# Mitchell Tenpenny
# Russell Haswell
# Knight Riderz
# ASMR Fan Sounds
# Beyonce
# Bryce Vine
# Le Réparateur
# Post Malone
# Morgan Evans
# Réka Ioescu
# Portugal. The Man
# Subtronics
# Zhou Long
# La Féline
# 6ix9ine
# Vitor Munhoz
# The Polynesians
# Melvin Taylor
# Chris Brown
# Hard Excess
# Runaway June
# Glee Cast
# Down To The Bone
# Hammerhands
# A$AP Rocky
# A$AP Rocky
# Milow
# Lorne Balfe
# Movements
# Gwyneth Paltrow
# Ollie Macfarlane
# Arkaea
# Taio Cruz
# Jhay Cortez
# Cat's Eyes
# Rasmus Gozzi
# Beyonce
# New Boyz
# Arcanjo Ras
# Old 97's
# Ludacris
# Meek Mill
# Drake
# Bad Meets Evil
# Beach Fossils
# Leather Chalice
# Royal Blood
# Nipsey Hussle
# Josh Lee Hamilton
# Chris Lorenzo
# Lil Skies
# Pitbull
# Big Sean
# Los Llayras
# Heavee
# ConsciousThoughts
# French Montana
# Palomo
# Juice WRLD
# MAX
# Hugh Jackman
# Vermillion Lies
# O.T. Genasis
# Big Sean
# Greg Bates
# Cardi B
# Nicki Minaj
# A Thousand Horses
# BTS
# Major Lazer
# New Boyz
# DeJ Loaf
# La Roux
# Demi Lovato
# Rich Homie Quan
# Khalid
# Family Force 5
# Clean Bandit
# Days N Daze
# STRFKR
# Yellow Claw
# Lambert
# B.o.B
# Tegan
# Barefoot Jerry
# The Black Eyed Peas
# Levellers
# Russ
# Romeo Santos
# Tetra Hydro K
# Nature Recordings
# Migos
# Yusuf
# Momentum
# Epicycle
# Freddy Todd
# Evil Activities
# Jackie McLean
# Michel Mondrain
# Plies
# Tété
# Ebb
# Subvert
# Bleed From Within
# Kenny Chesney
# The Shaking Sensations
# Nicki Minaj
# Howard Goodman
# Rob $tone
# Tiesto
# Calvin Harris
# Hailee Steinfeld
# The Young Novelists
# Afrojack
# 24kGoldn
# Lil Xan
# Justin Timberlake
# Lloyd Banks
# Big Sean
# Rövballebandet
# Tones
# Rihanna
# Robin Thicke
# Zac Brown Band
# David Guetta
# Justin Bieber
# Hey Violet
# Aphyxion
# リアムMAZE1981
# Wiz Khalifa
# RL Grime
# Ty Dolla $ign
# Morgan Wallen
# G-Space
# Joyner Lucas
# Dub Silence
# Tristam
# Rico Love
# refreshing token
# error: Pusha T Kanye West
# Bost
# Janelle Monae
# General Larry Platt
# B.o.B
# Game
# fantompower
# Empire Cast
# Jimmie Davis
# Future Breeze
# G-Eazy
# DJ Sakin
# Necrocurse
# Destiny Potato
# The Script
# Future
# Fakkboiz
# Gucci Mane
# Nicky Jam
# Lil Nas
# David Guetta
# Blanco Brown
# Battle Beast
# Tyga
# 10 Years
# MC Kekel
# Foxygen
# Brittany Howard
# Major Lazer
# The Swon Brothers
# The Ocean
# Tha Playah
# Cobra Starship
# Aidan Knight
# Young Thug
# Brand of Sacrifice
# Drake
# Afrojack
# Kanye West
# The Acacia Strain
# Gym Class Heroes
# mommy
# Alec Benjamin
# Dae Dae
# Hoodie Allen
# Spitback
# Meek Mill
# Bastille
# FBG Duck
# Michael Jackson
# Chris Brown
# Robert Armani
# Omac
# Enbilulugugal
# Midland
# Hong Kong Atmosphere
# The Barden Bellas
# Taetre
# Roddy Ricch
# Bad Meets Evil
# Juicy J
# P!nk
# Ariana Grande
# Rod Wave
# Bad Bunny
# Florida Georgia Line
# Polo
# BlocBoy JB
# Ben Frost
# Miguel
# Swedish House Mafia
# Olly Murs
# Lupe Fiasco
# Ty Dolla $ign
# Kaitlyn Aurelia Smith
# Chris Brown
# Wiz Khalifa
# Martin Solveig
# Lloyd
# Deathstars
# DJ Snake
# G-Eazy
# Ty Dolla $ign
# Northlane
# BTS
# Hypocrisy
# David Guetta
# Zedd
# Zayn
# 6ix9ine
# Meditation Music Masters
# Marshmello
# Snail's House
# Empire Of The Sun
# Tiamat
# Bali Bandits
# Rajasinga
#
# Hexer
# Chris Brown
# Caroline Polachek
# Kenny Chesney
# Helene Fischer
# Eat Your Heart Out
# Audiomachine
# FLETCHER
# Seth Gueko
# Ty Dolla $ign
# M-Dot
# Noisestorm
# T-Wayne
# B.o.B
# Lindsey Pavao
# Pitbull
# Kreator
# Smaxone
# Selena Gomez
# Ozuna
# An-Ten-Nae
# Troop 41
# B.o.B
# Ava Max
# Mors Principium Est
# Quavo
# Luciferion
# My Darkest Days
# Creative Calm ASMR
# La Femme
# Dwayne Johnson
# Young Thug
# Papik
# Calvin Harris
# Brad Mehldau Trio
# Jidenna
# Ray J
# Zara Larsson
# Sukhbir
# PIKOTARO
# Sarke
# Ariana Grande
# David Guetta
# Zayn
# Kanye West
# Duck Sauce
# refreshing token
# error: Maejor Ali
# Forward Strategy Group
# Orion's Reign
# Chris Duke and the Royals
# Artists Of Then
# Drake
# Manilla Road
# Weather Factory
# Dennis Lloyd
# Roddy Ricch
# Calvin Harris
# YG
# Post Malone
# Keala Settle
# Of Monsters
# Sidhu Moose Wala
# Wale
# The Dirty Heads
# Fifth Harmony
# Los Alegres de la Sierra
# Yuval Ron
# Mary Lambert
# Nicky Jam
# Reel People
# Rae Sremmurd
# Jodarok
# Royal Republic
# Flipp Dinero
# Nicki Minaj
# Axis
# Danakil
# The Cross Movement
# Nicki Minaj
# Flo Rida
# Rihanna
# Major Lazer
# George Brigman
# George Ezra
# Los Cadetes De Linares
# Bonde do Tigrão
# Bing
# Piotr Miteska
# XXXTENTACION
# Martin Phipps
# Crimson Dawn
# Usher
# Post Malone
# Cloud Rat
# The Swing Bot
# Drake
# Drake
# Slaughterhouse
# M. Geddes Gengras
# Elf Power
# Cash Cash
# Orden Ogan
# Talla 2XLC
# Mustard
# Doja Cat
# Tessanne Chin
# Wiz Khalifa
# Rihanna
# Don Omar
# William Michael Morgan
# David Lee Murphy
# The Soundcarriers
# Lil Baby
# Kevin Gates
# Kirko Bangz
# Sodré
# Good Morning
# Sass Dragons
# Glee Cast
# benny blanco
# Protohype
# Sawyer Fredericks
# Fedel
# Brutality
# Ivo Phi
# Cardi B
# Georgia Anne Muldrow
# Scibex
# Lil Baby
# The Stills
# Alasdair Roberts
# TOBIAS LARSSON BAND
# Ariana Grande
# Katy Perry
# Sledding
# Idina Menzel
# Sam Smith
# Kid Ink
# Selena Gomez
# King Promise
# Drake
# Banda Carnaval
# J. Cole
# Mark Ronson
# Harris Cole
# Iron Heade
# Yo Gotti
# Russ
# Hard-FI
# Jamie Foxx
# Ellie Goulding
# Rivers
# Alice Merton
# Kim Fowley
# refreshing token
# error: Narrow House
# Lingua Nada
# Breakestra
# Nicki Minaj
# Nolwenn Leroy
# Lightning Bolt
# I Prevail
# Street to the Ocean
# Monkey Business
# Edguy
# Pepe Aguilar
# The Knocks
# Megan Thee Stallion
# 21 Savage
# Enrique Iglesias
# STARSET
# French Montana
# Khalid
# 6ix9ine
# Myke Forte
# Black Book Lodge
# Buku
# D.O.A.
# Luke Combs
# Jamie N Commons
# Xavier Cugat
# David Pfeffer
# Big D and the Kids Table
# Yella Beezy
# Tyga
# Pedro Capo
# Juice WRLD
# DJ Khaled
# Popeska
# Mustard
# Jai Paul
# Marshmello
# Kindbergs
# Olamide
# Martin Garrix
# Sleepy Fish
# Vishal Dadlani
# Moneybagg Yo
# YFN Lucci
# Jordy Maxwell
# Kelly Rowland
# refreshing token
# error: Mustard featuring NAV
# benny blanco
# Quavo
# Tyga
# DJ Shog
# William Prince
# Lil Wayne
# The Chainsmokers
# Linkin Park
# Mann
# Bill Frisell
# Habstrakt
# Sam Manning
# Cute Is What We Aim For
# Al Atkins
# Al Gromer Khan
# Pulp
# Martin Dupont
# B.o.B
# Logic
# Martin Garrix
# Tinie Tempah
# A Boogie Wit da Hoodie
# Nicki Minaj
# il:lo
# Adrian Von Ziegler
# Nicki Minaj
# Rick Ross
# Usher
# E.C. Illa
# Jacob Sartorius
# refreshing token
# error: Kanye West Jay Z
# Bazzi
# Young Money
# PARTYNEXTDOOR
# Knowmadic
# The Chainsmokers
# Spite
# The Chainsmokers
# C Bank feat. Diamond Eyes
# Yaeji
# Kleinstadthelden
# Brantley Gilbert
# Janet
# R3HAB
# Danne Stråhed
# John Legend
# The Palace Guards
# DeJ Loaf
# Joji
# Kink
# Phil Woods
# Odunsi
# The House of Love
# Bridgit Mendler
# Waldeck
# TANUKI
# Hozier
# Barns Courtney
# Parov Stelar
# SadDoLLs
# Sage The Gemini
# Reks
# 2 Chainz
# Lil Wayne
# Voia
# Marionette
# Terry McDermott
# Nguyên Lê
# Lil Peep
# Natti Natasha
# Chief Keef
# refreshing token
# error: Royce Da 5'9"
# Andrew McMahon In The Wilderness
# John Powell
# Gucci Mane
# Blake Shelton
# Lee DeWyze
# Y2K
# TM Juke
# Belle Margaux
# Watered
# 2 Chainz
# Chon
# J Balvin
# Marsha Ambrosius
# Gavin Luke
# Labh Janjua
# Beyonce
# Charles Koechlin
# August Alsina
# Passion Pit
# G-Eazy
# Nipsey Hussle
# Los Acosta
# Aaron Smith
# Kurt Elling
# Hawk Nelson
# What So Not
# School Of Seven Bells
# Marc E. Bassy
# Diggy
# Jamie Berry
# Willie Thrasher
# A Boogie Wit da Hoodie
# Iyaz
# Banda Tierra Sagrada
# Gucci Mane
# Corey Voss
# Julie Lamontagne Trio
# Rick Ross
# Kreayshawn
# DJ Snake
# Steve Aoki
# Kumbhaka
# Cherrelle
# Lunay
# Blake Shelton
# Kali Uchis
# Flo Rida
# Jeremy Warmsley
# Plini
# quickly
# Taylor Swift
# Anaal Nathrakh
# Jay Z
# High Valley
# Johnny O.
# Rick Ross
# Bela Nemeth
# Kendrick Lamar
# Jack Wins
# Tyga
# Ad Inferos
# The Music Tapes
# Fat Joe
# Justin Timberlake
# Tropkillaz
# Kesha
# The Chainsmokers
# Flo Rida
# Train
# Edens Edge
# Marshmello
# T.I.
# Bad Bunny
# Skrillex
# DJ Snake
# Mike WiLL Made-It
# John Surman
# New Boyz
# Famous Dex
# Thergothon
# Inigo Montoya
# New Years Day
# The Wanted
# Jason Derulo
# Flo Rida
# Lana Del Rey
# Trampa
# T.I.
# Ranveer Singh
# YNW Melly
# Adam Levine
# KC
# Havana Brown
# Glee Cast
# Swutscher
# POCAH
# Anti-System
# Mason Ramsey
# Birdman
# The Mountain Goats
# A-Trak
# Banda El Recodo
# Layton Greene
# Geoff Zanelli
# Justify Rebellion
# Kid Ink
# Julien Baker
# Zac Efron
# Kanye West
# Eïs
# Christina Perri
# Ariel Camacho
# Arbor Lights
# refreshing token
# error: Jay Z Kanye West
# MKTO
# Wonders of Nature
# K. Michelle
# Cryptic One
# Migos
# Ke$ha
# Hank Jones
# Darcy Baylis
# Mastic Scum
# Fight The Fury
# Meek Mill
# Maroon 5
# Big Sean
# Roberta Gambarini
# GONZO
# Brad Paisley
# Left Boy
# La Sonora Dinamita
# Pegassi
# Kasabian
# Ed Sheeran
# Lil Dicky
# DLOW
# Zomboy
# 6ix9ine
# Wolfgang Lohr
# David Guetta
# Attila
# Trippie Redd
# Tunes of Negation
# Bhad Bhabie
# Jimmie Allen
# Dillon Francis
# Kristen Bell
# DJ Drama
# RŮDE
# Flavien Berger
# Rod Wave
# Giya Kancheli
# Brantley Gilbert
# Dr. Dre
# Delle Alpi
# FX Sleep Creator
# benny blanco
# Red Rocks Worship
# Timbaland
# Tiesto
# Zack Hemsey
# Cæcilie Norby
# Children Of Bodom
# Au5
# Taylor Swift
# H.E.R.
# Drake
# Víkingur Ólafsson
# Endymion
# David Guetta
# SZA
# DJ Khaled
# Spose
# Young The Giant
# Lil Mosey
# Samini
# Neeti Mohan
# Riley Pearce
# Gyptian
# Charlie Puth
# Factory Floor
# Eminem
# AJJ
# The Pirouettes
# Casper Magico
# Prima Nocta
# Mega Drive
# Lando Chill
# Lil Jon
# Masahiro Sugaya
# Mary Lou Lord
# refreshing token
# error: The London Suede
# Flo Rida
# Mělník Philharmonic Orchestra
# Trippie Redd
# Regentum
# Liam Payne
# The Neighbourhood
#                               artist                                    uri  \
# 0                      Garland Green  spotify:artist:3RY9bgHN1mRp5EX2wXF3NS
# 1                   Serge Gainsbourg  spotify:artist:01C9OoXDvCKkGcf735Tcfo
# 2                        Lord Melody  spotify:artist:5gyQ6QvPiTtPYLnifOEYld
# 3                         Celia Cruz  spotify:artist:2weA6hhVqTIN2gSn9PUB9U
# 4                        P. Susheela  spotify:artist:0aFGod7DM6b3O5l1AmvFwK
# ...                              ...                                    ...
# 11899  Mělník Philharmonic Orchestra  spotify:artist:1NXnbWMRTorBroMDX79R9H
# 11900                  Trippie Redd   spotify:artist:6Xgp2XMz1fhVYe7i6yNAax
# 11901                       Regentum  spotify:artist:6gfKfJS89ZAy4mSAlwTXvc
# 11902                    Liam Payne   spotify:artist:5pUo3fmmHT8bhCyHE52hA6
# 11903              The Neighbourhood  spotify:artist:77SW9BnxLY8rJ0RciFqkHh
#
#        followers                                             genres  \
# 0            113                                                 []
# 1         316662                             [chanson, french rock]
# 2              2                                                 []
# 3         336456  [cha-cha-cha, cuban rumba, latin, latin jazz, ...
# 4         100166            [deep indian pop, filmi, tamil worship]
# ...          ...                                                ...
# 11899         75                             [calming instrumental]
# 11900    4655708                           [melodic rap, rap, trap]
# 11901       1188                                 [background music]
# 11902    5451198    [dance pop, pop, post-teen pop, tropical house]
# 11903    3823748  [modern alternative rock, modern rock, pop, rock]
#
#        popularity  billboard
# 0               0          1
# 1              61          0
# 2               0          0
# 3              66          0
# 4              42          0
# ...           ...        ...
# 11899          31          0
# 11900          88          1
# 11901          37          0
# 11902          78          1
# 11903          79          1
#
# [11904 rows x 6 columns]

# %%
df_artists_clean_name.head()
# Out:
#                    track            artist  \
# 0  Jealous Kind Of Fella     Garland Green
# 1          Initials B.B.  Serge Gainsbourg
# 2           Melody Twist       Lord Melody
# 3          Mi Bomba Sonó        Celia Cruz
# 4            Uravu Solla       P. Susheela
#
#                                     uri  decade  danceability  energy  key  \
# 0  spotify:track:1dtKN6wwlolkM8XZy2y9C1    1960         0.417   0.620    3
# 1  spotify:track:5hjsmSnUefdUqzsDogisiX    1960         0.498   0.505    3
# 2  spotify:track:6uk8tI6pwxxdVTNlNOJeJh    1960         0.657   0.649    5
# 3  spotify:track:7aNjMJ05FvUXACPWZ7yJmv    1960         0.590   0.545    7
# 4  spotify:track:1rQ0clvgkzWr001POOPJWx    1960         0.515   0.765   11
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -7.727     1       0.0403         0.490          0.000000    0.0779
# 1   -12.475     1       0.0337         0.018          0.107000    0.1760
# 2   -13.392     1       0.0380         0.846          0.000004    0.1190
# 3   -12.058     0       0.1040         0.706          0.024600    0.0610
# 4    -3.515     0       0.1240         0.857          0.000872    0.2130
#
#    valence    tempo  duration_ms  time_signature  chorus_hit  sections  \
# 0    0.845  185.655       173533               3    32.94975         9
# 1    0.797  101.801       213613               4    48.82510        10
# 2    0.908  115.940       223960               4    37.22663        12
# 3    0.967  105.592       157907               4    24.75484         8
# 4    0.906  114.617       245600               4    21.79874        14
#
#    billboard
# 0          1
# 1          0
# 2          0
# 3          0
# 4          0

# %%
# Reading saved Dataset
df_artist_sp = pd.read_csv('data/processed/artists_stats_final.csv')
df_artist_sp.shape
# Out:
# (11904, 6)

# %%
##DROP DUPLICATES
df_artist_sp_clean = df_artist_sp.drop_duplicates(subset='artist').reset_index(drop=True)
df_artist_sp_clean.shape
# Out:
# (10706, 6)

# %%
# Saving it to analysis
df_artist_sp_clean.to_csv('data/processed/artists_stats_final_clean.csv', index=False)

# %% [markdown]
# #### Billboard API - year 2020 top artists

# %%
import billboard

# %%
## DATA COLLECTION

# retrieving data from year 2020 top trending artists and songs charts
bb_charts=get_billboard_charts_data(billboard.charts())

# saving unique values of artists into a separate df
bb_artist = bb_charts.drop(columns='title').drop_duplicates(subset='artist')

# cleaning artists' names strings and saving into a csv
bb_artist_clean=clean_artist_name(bb_artist, 'chart')
bb_artist_clean.to_csv('data/processed/bb_artists_unique_clean.csv', index=False)

# retrieving spotify stats
bb_artist_complete = get_artist_stats(bb_artist_clean, access_spotify()).artist.apply(lambda x:x.strip())
bb_artist_complete.to_csv('data/analysis/bb_artists_complete.csv', index=False)

# %%
# Concatenating with base dataset retrieved from Billboard API (2020's top charts)
bb_artists = pd.read_csv('data/analysis/bb_artists_complete.csv').drop(columns=['Unnamed: 0','spotify_id','chart'])
bb_artists.head(2)
# Out:
#                 artist                                    uri  followers  \
# 0             Doja Cat  spotify:artist:5cj0lLjcoR7YOSnhnX0Po5    1892264
# 1  Megan Thee Stallion  spotify:artist:181bsRPaVXVlUKXrxwZfHK    1107542
#
#                                             genres  popularity
# 0                              ['la indie', 'pop']          91
# 1  ['houston rap', 'pop', 'pop rap', 'trap queen']          87

# %%
bb_artists['billboard'] = bb_artists['artist'].apply(lambda x: 1)

# %%
bb_artists.shape, df_artist_sp_clean.shape
# Out:
# ((3021, 6), (10706, 6))

# %%
# ADD DECADE AGAIN

# %%
df_bf_sp_clean = df_artists_clean_name.drop_duplicates(subset='artist').reset_index(drop=True)
dec_dict = {}

for i in range(df_bf_sp_clean.shape[0]):
    dec_dict[df_bf_sp_clean.loc[i,'artist']] = df_bf_sp_clean.loc[i,'decade']

# %%
df_artist_sp_clean.head()
# Out:
#              artist                                    uri  followers  \
# 0     Garland Green  spotify:artist:3RY9bgHN1mRp5EX2wXF3NS        113
# 1  Serge Gainsbourg  spotify:artist:01C9OoXDvCKkGcf735Tcfo     316662
# 2       Lord Melody  spotify:artist:5gyQ6QvPiTtPYLnifOEYld          2
# 3        Celia Cruz  spotify:artist:2weA6hhVqTIN2gSn9PUB9U     336456
# 4       P. Susheela  spotify:artist:0aFGod7DM6b3O5l1AmvFwK     100166
#
#                                               genres  popularity  billboard
# 0                                                 []           0          1
# 1                         ['chanson', 'french rock']          61          0
# 2                                                 []           0          0
# 3  ['cha-cha-cha', 'cuban rumba', 'latin', 'latin...          66          0
# 4      ['deep indian pop', 'filmi', 'tamil worship']          42          0

# %%
df_artist_sp_clean['decade'] = df_artist_sp_clean.artist.apply(lambda x: dec_dict.get(x))

# %%
df_artist_sp_clean.to_csv('data/processed/artists_stats_final_clean.csv', index=False)

# %%
bb_artists['decade']=bb_artists.artist.apply(lambda x: 2020)

# %%
bb_artists.head()
# Out:
#                 artist                                    uri  followers  \
# 0             Doja Cat  spotify:artist:5cj0lLjcoR7YOSnhnX0Po5    1892264
# 1  Megan Thee Stallion  spotify:artist:181bsRPaVXVlUKXrxwZfHK    1107542
# 2           The Weeknd  spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ   20303554
# 3                Drake  spotify:artist:3TVXtAsR1Inumwj472S9r4   46377628
# 4          Roddy Ricch  spotify:artist:757aE44tKEUQEqRuT6GnEB    2526217
#
#                                               genres  popularity  billboard  \
# 0                                ['la indie', 'pop']          91          1
# 1    ['houston rap', 'pop', 'pop rap', 'trap queen']          87          1
# 2  ['canadian contemporary r&b', 'canadian pop', ...          97          1
# 3  ['canadian hip hop', 'canadian pop', 'hip hop'...         100          1
# 4                                    ['melodic rap']          93          1
#
#    decade
# 0    2020
# 1    2020
# 2    2020
# 3    2020
# 4    2020

# %%
df_artist_final = pd.concat([df_artist_sp_clean,bb_artists])
df_artist_final.shape
# Out:
# (13727, 7)

# %%
df_artist_final = df_artist_final.drop_duplicates()
df_artist_final.shape
# Out:
# (13413, 7)

# %%
df_artist_final.to_csv('data/analysis/artists_sp_complete.csv')

# %% [markdown]
# ### Song

# %% [markdown]
# #### Billboard API - 2020 songs

# %%
bb_song = pd.read_csv('data/analysis/bb_songs_complete.csv').drop(columns='Unnamed: 0')
bb_song['decade'] = bb_song.artist.apply(lambda x:2020)
bb_song['billboard'] = bb_song.artist.apply(lambda x:1)
bb_song.head()
# Out:
#              track               artist  \
# 0           Say So             Doja Cat
# 1           Savage  Megan Thee Stallion
# 2  Blinding Lights           The Weeknd
# 3     Toosie Slide                Drake
# 4          The Box          Roddy Ricch
#
#                                           art_genres    chart  \
# 0                                ['la indie', 'pop']  hot-100
# 1    ['houston rap', 'pop', 'pop rap', 'trap queen']  hot-100
# 2  ['canadian contemporary r&b', 'canadian pop', ...  hot-100
# 3  ['canadian hip hop', 'canadian pop', 'hip hop'...  hot-100
# 4                                    ['melodic rap']  hot-100
#
#                              tracks_uri                           albums_uris  \
# 0  spotify:track:3Dv1eDb0MEgF93GpLXlucZ  spotify:album:1MmVkhiwTH0BkNOU3nw5d3
# 1  spotify:track:55CHeLEfn5iJ0IIkgaa4si  spotify:album:6Lo6ylJg4qbFfxicPEOzMI
# 2  spotify:track:0VjIjW4GlUZAMYd2vXMi3b  spotify:album:4yP0hdKOZPNshxUOjY0cZj
# 3  spotify:track:127QTOFJsJQp5LbJbu3A1y  spotify:album:3xIwVbGJuAcovYIhzbLO3J
# 4  spotify:track:0nbXyq5TXYPCO7pr3N8S4I  spotify:album:52u4anZbHd6UInnmHRFzba
#
#    popularity  acousticness  danceability  energy  instrumentalness   key  \
# 0          96       0.25600         0.787   0.673          0.000004  11.0
# 1          92       0.02520         0.843   0.741          0.000000  11.0
# 2         100       0.00146         0.514   0.730          0.000095   1.0
# 3          97       0.32100         0.834   0.454          0.000006   1.0
# 4          97       0.10400         0.896   0.586          0.000000  10.0
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0    0.0904    -4.577   0.0       0.1580  110.962             4.0    0.786
# 1    0.0960    -5.609   1.0       0.3340  168.983             4.0    0.680
# 2    0.0897    -5.934   1.0       0.0598  171.005             4.0    0.334
# 3    0.1140    -9.750   0.0       0.2010   81.618             4.0    0.837
# 4    0.7900    -6.687   0.0       0.0559  116.971             4.0    0.642
#
#    decade
# 0    2020
# 1    2020
# 2    2020
# 3    2020
# 4    2020

# %%
bb_song.columns
# Out:
# Index(['track', 'artist', 'art_genres', 'chart', 'tracks_uri', 'albums_uris',
#        'popularity', 'acousticness', 'danceability', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence', 'decade',
#        'billboard'],
#       dtype='object')

# %% [markdown]
# #### Additional info - Spotify API
# - `genres`
# - `popularity`

# %%
# Reading the final and complete ARTISTS' dataset 
print(df_artist_final.shape)
df_artist_final.head()
# Out:
# (13413, 7)
#              artist                                    uri  followers  \
# 0     Garland Green  spotify:artist:3RY9bgHN1mRp5EX2wXF3NS        113
# 1  Serge Gainsbourg  spotify:artist:01C9OoXDvCKkGcf735Tcfo     316662
# 2       Lord Melody  spotify:artist:5gyQ6QvPiTtPYLnifOEYld          2
# 3        Celia Cruz  spotify:artist:2weA6hhVqTIN2gSn9PUB9U     336456
# 4       P. Susheela  spotify:artist:0aFGod7DM6b3O5l1AmvFwK     100166
#
#                                               genres  popularity  billboard  \
# 0                                                 []           0          1
# 1                         ['chanson', 'french rock']          61          0
# 2                                                 []           0          0
# 3  ['cha-cha-cha', 'cuban rumba', 'latin', 'latin...          66          0
# 4      ['deep indian pop', 'filmi', 'tamil worship']          42          0
#
#    decade
# 0  1960.0
# 1  1960.0
# 2  1960.0
# 3  1960.0
# 4  1960.0

# %%
# Inputing artists' genres to each track

# %%
df_songs = df.copy()

# %%
print(df_songs.shape)
df_songs.head()
# Out:
# (40617, 20)
#                    track            artist  \
# 0  Jealous Kind Of Fella     Garland Green
# 1          Initials B.B.  Serge Gainsbourg
# 2           Melody Twist       Lord Melody
# 3          Mi Bomba Sonó        Celia Cruz
# 4            Uravu Solla       P. Susheela
#
#                                     uri  decade  danceability  energy  key  \
# 0  spotify:track:1dtKN6wwlolkM8XZy2y9C1    1960         0.417   0.620    3
# 1  spotify:track:5hjsmSnUefdUqzsDogisiX    1960         0.498   0.505    3
# 2  spotify:track:6uk8tI6pwxxdVTNlNOJeJh    1960         0.657   0.649    5
# 3  spotify:track:7aNjMJ05FvUXACPWZ7yJmv    1960         0.590   0.545    7
# 4  spotify:track:1rQ0clvgkzWr001POOPJWx    1960         0.515   0.765   11
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -7.727     1       0.0403         0.490          0.000000    0.0779
# 1   -12.475     1       0.0337         0.018          0.107000    0.1760
# 2   -13.392     1       0.0380         0.846          0.000004    0.1190
# 3   -12.058     0       0.1040         0.706          0.024600    0.0610
# 4    -3.515     0       0.1240         0.857          0.000872    0.2130
#
#    valence    tempo  duration_ms  time_signature  chorus_hit  sections  \
# 0    0.845  185.655       173533               3    32.94975         9
# 1    0.797  101.801       213613               4    48.82510        10
# 2    0.908  115.940       223960               4    37.22663        12
# 3    0.967  105.592       157907               4    24.75484         8
# 4    0.906  114.617       245600               4    21.79874        14
#
#    billboard
# 0          1
# 1          0
# 2          0
# 3          0
# 4          0

# %%
#Creating dictionary with genres for each artist
df_temp = df_artist_final.drop_duplicates(subset='artist').reset_index(drop=True)
genres_dict = {}

for i in range(df_temp.shape[0]):
    genres_dict[df_temp.loc[i,'artist']] = df_temp.loc[i,'genres']

# %%
df_songs['genres'] = df_songs.artist.apply(lambda x: genres_dict.get(x))
df_songs.head()
# Out:
#                    track            artist  \
# 0  Jealous Kind Of Fella     Garland Green
# 1          Initials B.B.  Serge Gainsbourg
# 2           Melody Twist       Lord Melody
# 3          Mi Bomba Sonó        Celia Cruz
# 4            Uravu Solla       P. Susheela
#
#                                     uri  decade  danceability  energy  key  \
# 0  spotify:track:1dtKN6wwlolkM8XZy2y9C1    1960         0.417   0.620    3
# 1  spotify:track:5hjsmSnUefdUqzsDogisiX    1960         0.498   0.505    3
# 2  spotify:track:6uk8tI6pwxxdVTNlNOJeJh    1960         0.657   0.649    5
# 3  spotify:track:7aNjMJ05FvUXACPWZ7yJmv    1960         0.590   0.545    7
# 4  spotify:track:1rQ0clvgkzWr001POOPJWx    1960         0.515   0.765   11
#
#    loudness  mode  speechiness  ...  instrumentalness  liveness  valence  \
# 0    -7.727     1       0.0403  ...          0.000000    0.0779    0.845
# 1   -12.475     1       0.0337  ...          0.107000    0.1760    0.797
# 2   -13.392     1       0.0380  ...          0.000004    0.1190    0.908
# 3   -12.058     0       0.1040  ...          0.024600    0.0610    0.967
# 4    -3.515     0       0.1240  ...          0.000872    0.2130    0.906
#
#      tempo  duration_ms  time_signature  chorus_hit  sections  billboard  \
# 0  185.655       173533               3    32.94975         9          1
# 1  101.801       213613               4    48.82510        10          0
# 2  115.940       223960               4    37.22663        12          0
# 3  105.592       157907               4    24.75484         8          0
# 4  114.617       245600               4    21.79874        14          0
#
#                                               genres
# 0                                                 []
# 1                         ['chanson', 'french rock']
# 2                                                 []
# 3  ['cha-cha-cha', 'cuban rumba', 'latin', 'latin...
# 4      ['deep indian pop', 'filmi', 'tamil worship']
#
# [5 rows x 21 columns]

# %%
# Matching features to concatenate both

# %%
df_songs.columns
# Out:
# Index(['track', 'artist', 'uri', 'decade', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature',
#        'chorus_hit', 'sections', 'billboard', 'genres'],
#       dtype='object')

# %%
bb_song.columns
# Out:
# Index(['track', 'artist', 'art_genres', 'chart', 'tracks_uri', 'albums_uris',
#        'popularity', 'acousticness', 'danceability', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence', 'decade',
#        'billboard'],
#       dtype='object')

# %%
bb_song=bb_song[['track', 'artist', 'tracks_uri', 'decade','billboard', 'art_genres', 
          'danceability', 'energy','key', 'loudness', 'mode','speechiness',
          'acousticness','instrumentalness', 'liveness', 'valence',  'tempo', 
          'time_signature']]

# %%
df_songs=df_songs[['track', 'artist', 'uri', 'decade', 'billboard', 'genres', 
 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 
 'acousticness', 'instrumentalness','liveness', 'valence', 'tempo', 
 'time_signature']]

# %%
df_songs.columns=bb_song.columns

# %%
# retrieving same features for the whole dataset

# %%
ds_songs_complete = pd.concat([df_songs, bb_song], axis=0).reset_index(drop=True)
ds_songs_complete.shape
# Out:
# (43929, 18)

# %%
#Droping duplicates
ds_songs_complete = ds_songs_complete.drop_duplicates(subset=['tracks_uri', 'artist']).reset_index(drop=True)
ds_songs_complete.shape
# Out:
# (43009, 18)

# %%
# saving to csv
ds_songs_complete.to_csv('data/analysis/songs_sp_complete.csv', index=False)

# %% [markdown]
# # Artist Classification
#
# - How to classify if artist is famous or not

# %% [markdown]
# ## Analyzing the dataset

# %%
#Retrieving data
df_art = pd.read_csv('data/analysis/artists_sp_complete.csv').drop(columns='Unnamed: 0')

# %%
df_art.head()
# Out:
#              artist                                    uri  followers  \
# 0     Garland Green  spotify:artist:3RY9bgHN1mRp5EX2wXF3NS        113
# 1  Serge Gainsbourg  spotify:artist:01C9OoXDvCKkGcf735Tcfo     316662
# 2       Lord Melody  spotify:artist:5gyQ6QvPiTtPYLnifOEYld          2
# 3        Celia Cruz  spotify:artist:2weA6hhVqTIN2gSn9PUB9U     336456
# 4       P. Susheela  spotify:artist:0aFGod7DM6b3O5l1AmvFwK     100166
#
#                                               genres  popularity  billboard  \
# 0                                                 []           0          1
# 1                         ['chanson', 'french rock']          61          0
# 2                                                 []           0          0
# 3  ['cha-cha-cha', 'cuban rumba', 'latin', 'latin...          66          0
# 4      ['deep indian pop', 'filmi', 'tamil worship']          42          0
#
#    decade
# 0  1960.0
# 1  1960.0
# 2  1960.0
# 3  1960.0
# 4  1960.0

# %%
df_art.describe()
# Out:
#           followers    popularity     billboard        decade
# count  1.341300e+04  13413.000000  13413.000000  13412.000000
# mean   8.564824e+05     48.030866      0.607023   1994.127647
# std    3.023777e+06     21.715004      0.488430     20.079800
# min    0.000000e+00      0.000000      0.000000   1960.000000
# 25%    5.646000e+03     34.000000      0.000000   1980.000000
# 50%    5.470100e+04     50.000000      1.000000   2000.000000
# 75%    4.194190e+05     64.000000      1.000000   2010.000000
# max    6.357919e+07    100.000000      1.000000   2020.000000

# %%
# popularity of the artist is between 0 and 100 
# it is calculated from the popularity of all the artist’s tracks
sns.distplot(df_art.popularity);

# %%
sns.distplot(df_art.followers);

# %%
sns.countplot(df_art.billboard)

# %%
sns.boxplot(df_art.followers)

# %%
df_art.shape
# Out:
# (13413, 7)

# %%
(11404/13413)-1
# Out:
# -0.14978006411690148

# %%
13413-11404
# Out:
# 2009

# %%
outliers = remove_outlier(df_art, 'followers')
print('outliers range:' , outliers[1])
sns.boxplot(outliers[0].followers);
# Out:
# outliers range: (-615013.5, 1040078.5)

# %%
outliers[0].shape
# Out:
# (11404, 7)

# %%
sns.distplot(df_art.query('followers>50000 & followers<1000000').followers)

# %%
sns.distplot(df_art.query('followers<5000').followers)

# %% [markdown]
# ## Defining the filters

# %% [markdown]
# There isn't much similarities that separates famous X non famous artists.
# Since there is a great number of outliers, non famous artists will be considered as follows:
#
# > Cut by Number of followers:
# - max: the cut will be made higher fence
#
# > Sort by Popularity
#
# > Sort by year (priority to recent decade)

# %%
df_art=df_art.drop(columns='billboard')

# %%
artist_recommended(df_art)

# %%
df_art.head()
# Out:
#              artist                                    uri  followers  \
# 0     Garland Green  spotify:artist:3RY9bgHN1mRp5EX2wXF3NS        113
# 1  Serge Gainsbourg  spotify:artist:01C9OoXDvCKkGcf735Tcfo     316662
# 2       Lord Melody  spotify:artist:5gyQ6QvPiTtPYLnifOEYld          2
# 3        Celia Cruz  spotify:artist:2weA6hhVqTIN2gSn9PUB9U     336456
# 4       P. Susheela  spotify:artist:0aFGod7DM6b3O5l1AmvFwK     100166
#
#                                               genres  popularity  decade  \
# 0                                                 []           0  1960.0
# 1                         ['chanson', 'french rock']          61  1960.0
# 2                                                 []           0  1960.0
# 3  ['cha-cha-cha', 'cuban rumba', 'latin', 'latin...          66  1960.0
# 4      ['deep indian pop', 'filmi', 'tamil worship']          42  1960.0
#
#    is_recommended
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %%
sns.countplot(df_art.is_recommended)

# %%
# Saving to a .csv
df_art.to_csv('data/final/artists.csv')

# %% [markdown]
# # Song recommendation

# %%
#reading complete dataset
df= pd.read_csv('data/analysis/songs_sp_complete.csv')
df.head()
# Out:
#                    track            artist  \
# 0  Jealous Kind Of Fella     Garland Green
# 1          Initials B.B.  Serge Gainsbourg
# 2           Melody Twist       Lord Melody
# 3          Mi Bomba Sonó        Celia Cruz
# 4            Uravu Solla       P. Susheela
#
#                              tracks_uri  decade  billboard  \
# 0  spotify:track:1dtKN6wwlolkM8XZy2y9C1    1960          1
# 1  spotify:track:5hjsmSnUefdUqzsDogisiX    1960          0
# 2  spotify:track:6uk8tI6pwxxdVTNlNOJeJh    1960          0
# 3  spotify:track:7aNjMJ05FvUXACPWZ7yJmv    1960          0
# 4  spotify:track:1rQ0clvgkzWr001POOPJWx    1960          0
#
#                                           art_genres  danceability  energy  \
# 0                                                 []         0.417   0.620
# 1                         ['chanson', 'french rock']         0.498   0.505
# 2                                                 []         0.657   0.649
# 3  ['cha-cha-cha', 'cuban rumba', 'latin', 'latin...         0.590   0.545
# 4      ['deep indian pop', 'filmi', 'tamil worship']         0.515   0.765
#
#     key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   3.0    -7.727   1.0       0.0403         0.490          0.000000
# 1   3.0   -12.475   1.0       0.0337         0.018          0.107000
# 2   5.0   -13.392   1.0       0.0380         0.846          0.000004
# 3   7.0   -12.058   0.0       0.1040         0.706          0.024600
# 4  11.0    -3.515   0.0       0.1240         0.857          0.000872
#
#    liveness  valence    tempo  time_signature
# 0    0.0779    0.845  185.655             3.0
# 1    0.1760    0.797  101.801             4.0
# 2    0.1190    0.908  115.940             4.0
# 3    0.0610    0.967  105.592             4.0
# 4    0.2130    0.906  114.617             4.0

# %% [markdown]
# ## Checking for NaN

# %%
df.shape
# Out:
# (43009, 18)

# %%
df.isna().sum()
# Out:
# track                  0
# artist                 0
# tracks_uri             0
# decade                 0
# billboard              0
# art_genres          3454
# danceability           2
# energy                 2
# key                    2
# loudness               2
# mode                   2
# speechiness            2
# acousticness           2
# instrumentalness       2
# liveness               2
# valence                2
# tempo                  2
# time_signature         2
# dtype: int64

# %%
df = df.drop(df.query('key == "NaN"').index).reset_index(drop=True)

# %%
df.shape
# Out:
# (43007, 18)

# %%
df=df.fillna('not available')

# %%
df.isna().sum()
# Out:
# track               0
# artist              0
# tracks_uri          0
# decade              0
# billboard           0
# art_genres          0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# dtype: int64

# %% [markdown]
# ## Selecting Features

# %% [markdown]
# **> Features that won't be used to classify the tracks**
# - `duration_ms`: (int) duration of the track in milliseconds.
# - `key`:	(int) estimated overall key of the track. Integers map to pitches using standard Pitch Class notation . E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on. If no key was detected, the value is -1.
# - `mode`:	(int)	modality (major or minor) of a track, the type of scale from which its melodic content is derived. Major is represented by 1 and minor is 0.
# - `liveness:`	(float)	Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
#
#
# **> Features that can be used to classify the tracks**
#
# - `acousticness:`	(float)	A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
# - `danceability:`	(float)	Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
# - `energy:`	(float)	Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
# - `instrumentalness:`	(float)	Predicts whether a track contains no vocals. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content.
# - `loudness:` (float)	loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typical range between -60 and 0 db.
# - `speechiness:` (float)	Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
# - `valence:`	(float)	A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
# - `tempo:`	(float)	The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
# - `time_signature`:	(int)	An estimated overall time signature of a track. The time signature (meter) is a notational convention to specify how many beats are in each bar (or measure).

# %%
df.columns
# Out:
# Index(['track', 'artist', 'tracks_uri', 'decade', 'billboard', 'art_genres',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature'],
#       dtype='object')

# %%
import seaborn as sns

# %%
#First we'll use all numerical features that are related to the Audio Features,
## later on we can drop some features that bring similar info based on the performance 

sns.heatmap(df.corr())

# %%
# Selecting all audio related features For the clusterization analysis: 
selected_feat=['danceability', 'loudness', 'speechiness',
       'acousticness', 'instrumentalness', 'valence', 'tempo']

# %%
X = df[selected_feat]

# %%
X.head()
# Out:
#    danceability  loudness  speechiness  acousticness  instrumentalness  \
# 0         0.417    -7.727       0.0403         0.490          0.000000
# 1         0.498   -12.475       0.0337         0.018          0.107000
# 2         0.657   -13.392       0.0380         0.846          0.000004
# 3         0.590   -12.058       0.1040         0.706          0.024600
# 4         0.515    -3.515       0.1240         0.857          0.000872
#
#    valence    tempo
# 0    0.845  185.655
# 1    0.797  101.801
# 2    0.908  115.940
# 3    0.967  105.592
# 4    0.906  114.617

# %% [markdown]
# ## Standardizing data

# %% [markdown]
# Since the clusterization will be made based on the distances

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(X)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaler.transform(X)
# Out:
# array([[-0.70703105,  0.44502615, -0.3805068 , ..., -0.49984528,
#          1.14131119,  2.27546986],
#        [-0.25130756, -0.45302378, -0.45677918, ..., -0.14328831,
#          0.9610514 , -0.60261199],
#        [ 0.64326076, -0.62646771, -0.40708657, ..., -0.49983055,
#          1.37790216, -0.11732567],
#        ...,
#        [-1.70287126, -2.63384007, -0.27881029, ...,  2.61253048,
#         -1.80255653, -1.7962468 ],
#        [-1.08961373,  0.74633061, -0.48567023, ..., -0.49594648,
#         -0.60495554, -1.71778548],
#        [-1.71412369,  0.37523247, -0.27187643, ..., -0.49984528,
#         -1.86414529, -1.39216759]])

# %%
X_std = pd.DataFrame(scaler.transform(X), columns=X.columns)
X_std
# Out:
#        danceability  loudness  speechiness  acousticness  instrumentalness  \
# 0         -0.707031  0.445026    -0.380507      0.386991         -0.499845
# 1         -0.251308 -0.453024    -0.456779     -1.012228         -0.143288
# 2          0.643261 -0.626468    -0.407087      1.442334         -0.499831
# 3          0.266304 -0.374151     0.355637      1.027312         -0.417871
# 4         -0.155662  1.241696     0.586766      1.474943         -0.496940
# ...             ...       ...          ...           ...               ...
# 43002     -1.595973  0.541678    -0.441756     -0.770922         -0.499845
# 43003      0.986460  0.946255    -0.448690     -1.001259         -0.499797
# 43004     -1.702871 -2.633840    -0.278810      1.774353          2.612530
# 43005     -1.089614  0.746331    -0.485670      1.667632         -0.495946
# 43006     -1.714124  0.375232    -0.271876     -1.037248         -0.499845
#
#         valence     tempo
# 0      1.141311  2.275470
# 1      0.961051 -0.602612
# 2      1.377902 -0.117326
# 3      1.599471 -0.472495
# 4      1.370391 -0.162734
# ...         ...       ...
# 43002 -1.461190 -1.416228
# 43003  0.915986 -0.902213
# 43004 -1.802557 -1.796247
# 43005 -0.604956 -1.717785
# 43006 -1.864145 -1.392168
#
# [43007 rows x 7 columns]

# %% [markdown]
# ## Hierarchical

# %% [markdown]
# ###  Exploring number of Clusters - Dendrogram

# %%
import scipy.cluster.hierarchy as sch
import matplotlib.pyplot as plt

# %%
X_std.shape
# Out:
# (43007, 8)

# %%
##Getting a sample of 500 to run dendrogram
X_std_sample = X_std.sample(500, random_state = 42)
X_std_sample.head()
# Out:
#        danceability  loudness  speechiness  acousticness  instrumentalness  \
# 27290      0.795169  0.456186    -0.491448     -0.084356         -0.498212
# 34156     -1.376551 -0.394390    -0.429044     -0.937820          2.046038
# 41559      1.661606  0.512928    -0.069639     -0.632779         -0.499845
# 28446     -0.082521  0.328892    -0.237207     -1.055449         -0.499818
# 31491      0.221295  0.587829    -0.386285     -0.906101         -0.499845
#
#         valence     tempo
# 27290  1.576939  0.945472
# 34156 -1.880669  0.245326
# 41559  0.315120 -0.768802
# 28446  1.081225  0.973067
# 31491  0.025954  0.960333

# %%
# 17 clusters
dendrogram = sch.dendrogram(sch.linkage(X_std_sample, method='ward'), color_threshold=12)

# %%
# 30 clusters
dendrogram = sch.dendrogram(sch.linkage(X_std_sample, method='ward'), 
                            color_threshold=7,)

# %% [markdown]
# > `Conclusion`: Seems like the dendrogram is capturing well the distances between the songs

# %% [markdown]
# ### Agglomerative Clustering

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
# First of all, since this model has a high cost, only the sample of 500 units will be fit

model = AgglomerativeClustering(n_clusters=30, linkage='ward')
model.fit(X_std_sample)
labels = model.labels_

# %%
# 30 Clusters: Some categories have more data than other, but apparently, the 15 clusters
## model seems to bring 
sns.countplot(labels);

# %% [markdown]
# ### Visualizing - PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(2)
pca.fit(X_std_sample)
pca.transform(X_std_sample)
print('cumsum of explained variance ratio:', pca.explained_variance_ratio_.cumsum())

plt.scatter(pca.transform(X_std_sample)[:,0], 
            pca.transform(X_std_sample)[:,1], 
            c = labels, cmap = 'viridis');
# Out:
# cumsum of explained variance ratio: [0.34526412 0.54108851]

# %%
from yellowbrick.features import PCA
visualizer = PCA(scale=True, proj_features=True)
visualizer.fit_transform(X_std_sample)

visualizer.show();

# %% [markdown]
# ### Sanity check - Comparing to real genres

# %%
sample_lbl = df.loc[list(X_std_sample.index),['track','artist','art_genres','billboard']]
sample_lbl['label'] = labels

# %%
# It got pretty much all right with label 13 for 17 and 30 clusters 
sample_lbl.query('label==4')
# Out:
#                                  track                              artist  \
# 24239                 Mulholland Drive                        Bryan Savage
# 24318                    Soul Sanction              Booker T. & the M.G.'s
# 21476                          Le Parc                     Tangerine Dream
# 7402                         Abba Zaba  Captain Beefheart & His Magic Band
# 33016                Marubari (Javali)                         E. Gayathri
# 11355                        Lucky Man                            Starbuck
# 40883                    Fleetwood Mac                       Fleetwood Mac
# 27661  When They Ring The Golden Bells                        Craig Duncan
# 20857  Always with Me, Always with You                        Joe Satriani
# 24006                  St. Anne's Reel                        Scott Vestal
# 42480                          Twinkle                        Greg Manning
# 39599            Don't Come Home Today                        Good Morning
# 11912                       Banjo Whiz                        Bill Emerson
# 3541                          Oblivion                   Georges Arvanitas
#
#                                               art_genres  billboard  label
# 24239                                    ['smooth jazz']          0      4
# 24318                                                NaN          0      4
# 21476  ['ambient', 'art rock', 'berlin school', 'krau...          0      4
# 7402                                                 NaN          0      4
# 33016  ['carnatic', 'carnatic instrumental', 'indian ...          0      4
# 11355                        ['soft rock', 'yacht rock']          1      4
# 40883  ['album rock', 'classic rock', 'mellow gold', ...          1      4
# 27661  ['instrumental bluegrass', 'irish dance', 'str...          0      4
# 20857  ['album rock', 'hard rock', 'instrumental rock...          0      4
# 24006  ['banjo', 'bluegrass', 'instrumental bluegrass...          0      4
# 42480                ['deep smooth jazz', 'smooth jazz']          1      4
# 39599          ['experimental pop', 'indie garage rock']          0      4
# 11912   ['banjo', 'bluegrass', 'instrumental bluegrass']          0      4
# 3541                 ['hammond organ', 'spiritual jazz']          0      4

# %%
# Label 3 for 17 and 30 clusters seems to be quite right, but still mixes up a little bit. 

sample_lbl.query('label==22')
# Out:
#                                     track                   artist  \
# 34156                       In The Summer              Terry Riley
# 38146                         Rottenatomy                  Gorguts
# 2191                      Midnight Cowboy       Ferrante & Teicher
# 18979                  Hero Without Honor             Vinnie Moore
# 22267                           Altitudes             Jason Becker
# 29573                                Cafo       Animals As Leaders
# 13196  Still Life - 2005 Digital Remaster  Van Der Graaf Generator
# 18879                        Tunnel Chase              Brad Fiedel
# 40148           Devouring Entities Devour               Winterwolf
#
#                                               art_genres  billboard  label
# 34156  ['american contemporary classical', 'avant-gar...          0     22
# 38146  ['brutal death metal', 'canadian metal', 'deat...          0     22
# 2191                                                 NaN          1     22
# 18979  ['instrumental rock', 'neo classical metal', '...          0     22
# 22267  ['instrumental rock', 'neo classical metal', '...          0     22
# 29573  ['djent', 'instrumental rock', 'jazz metal', '...          0     22
# 13196  ['art rock', 'canterbury scene', 'experimental...          0     22
# 18879  ['classic soundtrack', 'scorecore', 'soundtrack']          0     22
# 40148                            ['finnish death metal']          0     22

# %% [markdown]
# > Conclusions:
# - Seems like some features bring almost the same information, such as:
#     - `energy` & `loudness`
#     - `valence` & `danceability`
# - There are important features that aren't receiving the right emphasis to the analysis as they should
# - Following with 30 clusters: 'WARD' Metric brought better results than the complete

# %% [markdown]
# ## KMeans

# %% [markdown]
# ### Exploring num of Clusters

# %%
from sklearn.cluster import KMeans

# %%
# the elbow method

from yellowbrick.cluster import KElbowVisualizer
model = KMeans()
visualizer = KElbowVisualizer(model)

visualizer.fit(X_std)  
visualizer.show();

# %% [markdown]
# ### Clustering

# %%
# testing with 10 clusters
kmeans = KMeans(10)
kmeans.fit(X_std)
kmeans.predict(X_std)
labels = list(kmeans.labels_)

# %%
sns.countplot(labels)

# %%
kmeans = KMeans(30)
kmeans.fit(X_std)
kmeans.predict(X_std)
labels = list(kmeans.labels_)

# %%
sns.countplot(labels)

# %% [markdown]
# ### Visualizing - PCA

# %%
# for 30 clusters
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
pca = PCA(8)
pca.fit(X_std)
pca.transform(X_std)
print('cumsum of explained variance ratio:', pca.explained_variance_ratio_.cumsum())

plt.scatter(pca.transform(X_std)[:,0], 
            pca.transform(X_std)[:,1], 
            c = labels, cmap = 'viridis');
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1207-ae0ef2a0bff5> in <module>
#       3 from sklearn.decomposition import PCA
#       4 pca = PCA(8)
# ----> 5 pca.fit(X_std)
#       6 pca.transform(X_std)
#       7 print('cumsum of explained variance ratio:', pca.explained_variance_ratio_.cumsum())
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/decomposition/_pca.py in fit(self, X, y)
#     342             Returns the instance itself.
#     343         """
# --> 344         self._fit(X)
#     345         return self
#     346
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/decomposition/_pca.py in _fit(self, X)
#     414         # Call different fits for either full or truncated SVD
#     415         if self._fit_svd_solver == 'full':
# --> 416             return self._fit_full(X, n_components)
#     417         elif self._fit_svd_solver in ['arpack', 'randomized']:
#     418             return self._fit_truncated(X, n_components, self._fit_svd_solver)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/decomposition/_pca.py in _fit_full(self, X, n_components)
#     430                                  "if n_samples >= n_features")
#     431         elif not 0 <= n_components <= min(n_samples, n_features):
# --> 432             raise ValueError("n_components=%r must be between 0 and "
#     433                              "min(n_samples, n_features)=%r with "
#     434                              "svd_solver='full'"
#
# ValueError: n_components=8 must be between 0 and min(n_samples, n_features)=7 with svd_solver='full'

# %%
from yellowbrick.features import PCA
visualizer = PCA(scale=True, proj_features=True)
visualizer.fit_transform(X_std)

visualizer.show();

# %% [markdown]
# ### Sanity check

# %%
sample_lbl = df.copy()
sample_lbl['label'] = labels

# %%
sample_lbl.query('label==4')[['track','artist','art_genres','billboard']]
# Out:
#                             track              artist  \
# 17     Alfômega - Remastered 2006      Caetano Veloso
# 38                     Españolito  Joan Manuel Serrat
# 127        Nothing But Heartaches        The Supremes
# 318    How Could I Be Such A Fool         Frank Zappa
# 334                     Mis Blues            Krokodil
# ...                           ...                 ...
# 42920                 Finira Bene          Ermal Meta
# 42923                    16 Marzo       Achille Lauro
# 42929  In Your Eyes (Feat. Alida)        Robin Schulz
# 42976                Yuve Yuve Yu              The Hu
# 42979                      Ridin'           NCT DREAM
#
#                                               art_genres  billboard
# 17                ['bossa nova', 'mpb', 'samba de roda']          0
# 38     ['cantautor', 'nova canco', 'nueva cancion', '...          0
# 127    ['adult standards', 'brill building pop', 'cla...          1
# 318    ['album rock', 'art rock', 'classic rock', 'ex...          0
# 334                                        ['krautrock']          0
# ...                                                  ...        ...
# 42920               ['italian arena pop', 'italian pop']          1
# 42923  ['italian alternative', 'italian hip hop', 'it...          1
# 42929  ['dance pop', 'deep euro house', 'deep house',...          1
# 42976                                    ['trap pesado']          1
# 42979                       ['k-pop', 'k-pop boy group']          1
#
# [2285 rows x 4 columns]

# %%
sample_lbl.query('label==18')[['track','artist','art_genres','billboard']]
# Out:
#                                                 track  \
# 140                     Amore mio aiutami - Version 4
# 212                                      Dirty Dishes
# 213                  Western générique - Version Live
# 267                                Bataille de Zaccar
# 274    All I Have To Do Is Take A Bite Of Your Apple?
# ...                                               ...
# 40896                                    The Graduate
# 41097                                Miami Vice Theme
# 42436                                      Cello Blue
# 42457                     We Are Sent Here By History
# 42954                            Music For Deep Sleep
#
#                              artist  \
# 140                  Piero Piccioni
# 212                 Jerry Goldsmith
# 213    Royal Philharmonic Orchestra
# 267                   André Hossein
# 274                 Jerry Goldsmith
# ...                             ...
# 40896                    Soundtrack
# 41097                    Jan Hammer
# 42436                 David Darling
# 42457                       Shabaka
# 42954               Various Artists
#
#                                               art_genres  billboard
# 140    ['classic soundtrack', 'lounge', 'vintage ital...          0
# 212    ['classic soundtrack', 'scorecore', 'soundtrac...          0
# 213                                        ['orchestra']          0
# 267          ['french soundtrack', 'oriental classical']          0
# 274    ['classic soundtrack', 'scorecore', 'soundtrac...          0
# ...                                                  ...        ...
# 40896                                                 []          1
# 41097                                    ['jazz fusion']          1
# 42436                                        ['bow pop']          1
# 42457                                   ['british jazz']          1
# 42954                                                 []          1
#
# [684 rows x 4 columns]

# %%
sample_lbl.query('billboard ==1 & label==10')[['track','artist','art_genres','billboard']]
# Out:
#                                      track                      artist  \
# 20     I'm Here To Get My Baby Out Of Jail         The Everly Brothers
# 115               You Mean The World To Me               David Houston
# 183                          Heart In Hand                  Brenda Lee
# 223                        Tears And Roses                  Al Martino
# 294                      My Lover's Prayer                Otis Redding
# ...                                    ...                         ...
# 42571                    I Saw Three Ships               Nat King Cole
# 42583                   Christmas Classics                 Bing Crosby
# 42646                       Dehors L'hiver                   Ian Kelly
# 42899                        A Vava Inouva                        Idir
# 42969           Somewhere Over The Rainbow  Israel "IZ" Kamakawiwo'Ole
#
#                                               art_genres  billboard
# 20     ['adult standards', 'brill building pop', 'bub...          1
# 115                                  ['nashville sound']          1
# 183    ['adult standards', 'brill building pop', 'eas...          1
# 223    ['adult standards', 'brill building pop', 'eas...          1
# 294    ['classic soul', 'funk', 'memphis soul', 'soul...          1
# ...                                                  ...        ...
# 42571        ['adult standards', 'lounge', 'vocal jazz']          1
# 42583    ['adult standards', 'easy listening', 'lounge']          1
# 42646               ['indie quebecois', 'pop quebecois']          1
# 42899                                         ['kabyle']          1
# 42969                                       ['hawaiian']          1
#
# [630 rows x 4 columns]

# %% [markdown]
# ## Some Insights

# %% [markdown]
# > Agglomerative Hierarchiqual Clustering:
# - Seems like the dendrogram is capturing well the distances between the songs
# - Seems like some features bring almost the same information, such as:
#     - `energy` & `loudness`
#     - `speechness` & `liveness`
# - There are important features that aren't receiving the right emphasis to the analysis as they should
#
# > KMeans Clustering:
# - Through the sanity check analysis, with these features, seems like even 20 clusters are too few to classify all songs
# - Features selection has to be made more carefully and with different degrees / weights

# %% [markdown]
# ### Chosen Model : AGG

# %%
# Aglomerative 
# .fit em um sample estratificado(?)
# .predict no ds inteiro

# %%
model = AgglomerativeClustering(n_clusters=30, linkage='ward')
model.fit(X_std)
labels = model.labels_

# %%
songs_final = df.copy()
songs_final['cluster'] = labels
songs_final.head()
# Out:
#                    track            artist  \
# 0  Jealous Kind Of Fella     Garland Green
# 1          Initials B.B.  Serge Gainsbourg
# 2           Melody Twist       Lord Melody
# 3          Mi Bomba Sonó        Celia Cruz
# 4            Uravu Solla       P. Susheela
#
#                              tracks_uri  decade  billboard  \
# 0  spotify:track:1dtKN6wwlolkM8XZy2y9C1    1960          1
# 1  spotify:track:5hjsmSnUefdUqzsDogisiX    1960          0
# 2  spotify:track:6uk8tI6pwxxdVTNlNOJeJh    1960          0
# 3  spotify:track:7aNjMJ05FvUXACPWZ7yJmv    1960          0
# 4  spotify:track:1rQ0clvgkzWr001POOPJWx    1960          0
#
#                                           art_genres  danceability  energy  \
# 0                                                 []         0.417   0.620
# 1                         ['chanson', 'french rock']         0.498   0.505
# 2                                                 []         0.657   0.649
# 3  ['cha-cha-cha', 'cuban rumba', 'latin', 'latin...         0.590   0.545
# 4      ['deep indian pop', 'filmi', 'tamil worship']         0.515   0.765
#
#     key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   3.0    -7.727   1.0       0.0403         0.490          0.000000
# 1   3.0   -12.475   1.0       0.0337         0.018          0.107000
# 2   5.0   -13.392   1.0       0.0380         0.846          0.000004
# 3   7.0   -12.058   0.0       0.1040         0.706          0.024600
# 4  11.0    -3.515   0.0       0.1240         0.857          0.000872
#
#    liveness  valence    tempo  time_signature  cluster
# 0    0.0779    0.845  185.655             3.0       12
# 1    0.1760    0.797  101.801             4.0        7
# 2    0.1190    0.908  115.940             4.0        0
# 3    0.0610    0.967  105.592             4.0       22
# 4    0.2130    0.906  114.617             4.0       22

# %%
songs_final.to_csv('data/final/songs_teste.csv', index=False)

# %%
songs_final.to_csv('data/final/songs.csv', index=False)

# %%
# It takes too long, another model would be good

# %% [markdown]
# # Pipeline

# %%
df= pd.read_csv('data/analysis/songs_sp_complete.csv')

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from scipy.spatial import distance
from sklearn.cluster import KMeans

# %%
df.head(3)
# Out:
#                    track            artist  \
# 0  Jealous Kind Of Fella     Garland Green
# 1          Initials B.B.  Serge Gainsbourg
# 2           Melody Twist       Lord Melody
#
#                              tracks_uri  decade  billboard  \
# 0  spotify:track:1dtKN6wwlolkM8XZy2y9C1    1960          1
# 1  spotify:track:5hjsmSnUefdUqzsDogisiX    1960          0
# 2  spotify:track:6uk8tI6pwxxdVTNlNOJeJh    1960          0
#
#                    art_genres  danceability  energy  key  loudness  mode  \
# 0                          []         0.417   0.620  3.0    -7.727   1.0
# 1  ['chanson', 'french rock']         0.498   0.505  3.0   -12.475   1.0
# 2                          []         0.657   0.649  5.0   -13.392   1.0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0403         0.490          0.000000    0.0779    0.845  185.655
# 1       0.0337         0.018          0.107000    0.1760    0.797  101.801
# 2       0.0380         0.846          0.000004    0.1190    0.908  115.940
#
#    time_signature
# 0             3.0
# 1             4.0
# 2             4.0

# %%
df.shape
# Out:
# (43009, 18)

# %%
df.isna().sum()
# Out:
# track                  0
# artist                 0
# tracks_uri             0
# decade                 0
# billboard              0
# art_genres          3454
# danceability           2
# energy                 2
# key                    2
# loudness               2
# mode                   2
# speechiness            2
# acousticness           2
# instrumentalness       2
# liveness               2
# valence                2
# tempo                  2
# time_signature         2
# dtype: int64

# %%
pipeline = Pipeline(steps=[('features_selection', AudioFeatures()),
                           ('missing', SimpleImputer(fill_value='[]')),
                           ('preprocessing', StandardScaler()),
                           ('feature_clusterization', KMeans(30))])

# %%
pipeline.fit(df)
# Out:
# Pipeline(memory=None,
#          steps=[('features_selection',
#                  <__main__.AudioFeatures object at 0x14ca90610>),
#                 ('missing',
#                  SimpleImputer(add_indicator=False, copy=True, fill_value='[]',
#                                missing_values=nan, strategy='mean',
#                                verbose=0)),
#                 ('preprocessing',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('feature_clusterization',
#                  KMeans(algorithm='auto', copy_x=True, init='k-means++',
#                         max_iter=300, n_clusters=30, n_init=10, n_jobs=None,
#                         precompute_distances='auto', random_state=None,
#                         tol=0.0001, verbose=0))],
#          verbose=False)

# %%
pipeline

# %%
pipeline.transform(df)
# Out:
# array([[3.76936336, 5.15042597, 4.24739794, ..., 4.7545603 , 4.93624529,
#         5.49547694],
#        [1.94247804, 3.60210704, 2.00104027, ..., 3.02629928, 3.8233182 ,
#         3.81886075],
#        [1.55603792, 3.6836638 , 3.19077489, ..., 3.73178484, 4.96205333,
#         4.09555122],
#        ...,
#        [6.314581  , 5.42099976, 6.35415403, ..., 6.31396274, 6.08762129,
#         7.63091608],
#        [3.15399723, 3.0401941 , 3.07185032, ..., 4.68510515, 4.59195979,
#         4.7207005 ],
#        [4.24991999, 3.59254054, 2.77703583, ..., 4.67273917, 3.77295373,
#         4.8276547 ]])

# %%
pipeline.predict(df)
# Out:
# array([10,  3,  0, ..., 23, 24,  2], dtype=int32)

# %%
pipeline.named_steps['missing']
pipeline.steps[3]
# Out:
# ('feature_clusterization',
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#         n_clusters=30, n_init=10, n_jobs=None, precompute_distances='auto',
#         random_state=None, tol=0.0001, verbose=0))

# %%
df['cluster'] = pipeline.predict(df)
df.head()
# Out:
#                    track            artist  \
# 0  Jealous Kind Of Fella     Garland Green
# 1          Initials B.B.  Serge Gainsbourg
# 2           Melody Twist       Lord Melody
# 3          Mi Bomba Sonó        Celia Cruz
# 4            Uravu Solla       P. Susheela
#
#                              tracks_uri  decade  billboard  \
# 0  spotify:track:1dtKN6wwlolkM8XZy2y9C1    1960          1
# 1  spotify:track:5hjsmSnUefdUqzsDogisiX    1960          0
# 2  spotify:track:6uk8tI6pwxxdVTNlNOJeJh    1960          0
# 3  spotify:track:7aNjMJ05FvUXACPWZ7yJmv    1960          0
# 4  spotify:track:1rQ0clvgkzWr001POOPJWx    1960          0
#
#                                           art_genres  danceability  energy  \
# 0                                                 []         0.417   0.620
# 1                         ['chanson', 'french rock']         0.498   0.505
# 2                                                 []         0.657   0.649
# 3  ['cha-cha-cha', 'cuban rumba', 'latin', 'latin...         0.590   0.545
# 4      ['deep indian pop', 'filmi', 'tamil worship']         0.515   0.765
#
#     key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   3.0    -7.727   1.0       0.0403         0.490          0.000000
# 1   3.0   -12.475   1.0       0.0337         0.018          0.107000
# 2   5.0   -13.392   1.0       0.0380         0.846          0.000004
# 3   7.0   -12.058   0.0       0.1040         0.706          0.024600
# 4  11.0    -3.515   0.0       0.1240         0.857          0.000872
#
#    liveness  valence    tempo  time_signature  cluster
# 0    0.0779    0.845  185.655             3.0       10
# 1    0.1760    0.797  101.801             4.0        3
# 2    0.1190    0.908  115.940             4.0        0
# 3    0.0610    0.967  105.592             4.0       15
# 4    0.2130    0.906  114.617             4.0       15

# %%
df.isna().sum().sum()
# Out:
# 3478

# %%
df.to_csv('data/final/pipeline.csv')

# %% [markdown]
# # Recommender System Model

# %%
from scipy.spatial.distance import pdist, squareform

# %% [markdown]
# > `database`:
# - import
# - preprocess
#
# > `input`:
# - música
# - gênero
#
# > `processamento`:
# - buscar na base de dados de música atual, encontrar artista, separar
# - filtrar DB por target (recomendável)
# - filtrar por cluster POR FEATURES
# - análise word2vec gêneros
# - análise word2vec para a música do input
# - calcular dist cosine
#
# - standardizar dados
# - incluir no sistema de recomendação
# - filtrar os 10 mais semelhantes
#
# > `output`:
# - retornar página com top 5 músicas e artistas
# - links para ouvir a música

# %% [markdown]
# ## Databases

# %% [markdown]
# ### Import

# %%
# retrieve datasets
songs = pd.read_csv('data/final/songs.csv')
artists = pd.read_csv('data/final/artists.csv')

# %%
songs = pd.read_csv('data/final/pipeline.csv').drop(columns='Unnamed: 0')

# %%
songs.head()
# Out:
#                    track            artist  \
# 0  Jealous Kind Of Fella     Garland Green
# 1          Initials B.B.  Serge Gainsbourg
# 2           Melody Twist       Lord Melody
# 3          Mi Bomba Sonó        Celia Cruz
# 4            Uravu Solla       P. Susheela
#
#                              tracks_uri  decade  billboard  \
# 0  spotify:track:1dtKN6wwlolkM8XZy2y9C1    1960          1
# 1  spotify:track:5hjsmSnUefdUqzsDogisiX    1960          0
# 2  spotify:track:6uk8tI6pwxxdVTNlNOJeJh    1960          0
# 3  spotify:track:7aNjMJ05FvUXACPWZ7yJmv    1960          0
# 4  spotify:track:1rQ0clvgkzWr001POOPJWx    1960          0
#
#                                           art_genres  danceability  energy  \
# 0                                                 []         0.417   0.620
# 1                         ['chanson', 'french rock']         0.498   0.505
# 2                                                 []         0.657   0.649
# 3  ['cha-cha-cha', 'cuban rumba', 'latin', 'latin...         0.590   0.545
# 4      ['deep indian pop', 'filmi', 'tamil worship']         0.515   0.765
#
#     key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   3.0    -7.727   1.0       0.0403         0.490          0.000000
# 1   3.0   -12.475   1.0       0.0337         0.018          0.107000
# 2   5.0   -13.392   1.0       0.0380         0.846          0.000004
# 3   7.0   -12.058   0.0       0.1040         0.706          0.024600
# 4  11.0    -3.515   0.0       0.1240         0.857          0.000872
#
#    liveness  valence    tempo  time_signature  cluster
# 0    0.0779    0.845  185.655             3.0       10
# 1    0.1760    0.797  101.801             4.0        3
# 2    0.1190    0.908  115.940             4.0        0
# 3    0.0610    0.967  105.592             4.0       15
# 4    0.2130    0.906  114.617             4.0       15

# %% [markdown]
# ## Input & Validation

# %% [markdown]
# ### Speech recognition

# %%
user_input=check_input(song_input=get_audio('title'), artist_input=get_audio('artist'))
# Out:
# Tell us the title of a song you like :)
# Listening... (you've got 4 seconds)
# Processing...
# Tell us the artist who sings that song
# Listening... (you've got 4 seconds)
# Processing...
# You chose "be humble" by Kendrick Lamar, right? (y/n)y

# %% [markdown]
# ### Written song

# %%
user_input=check_input(song_input=get_text('title'), artist_input=get_text('artist'))
# Out:
# Tell us the title of a song you like :)humble
# Tell us the artist who sings that songkendrick lamar
# You chose "Humble." by Kendrick Lamar, right? (y/n)y

# %% [markdown]
# ## Processing

# %%
# processing the input and saving to dabase new information
process = target_process(user_input)
target_song = process[0]
target_cluster = process[1]
# Out:
# found in the database

# %%
# now it's time to filter by the 10 nearest songs and artists
cluster_songs = get_recomm_songs(target_cluster)
recomm_songs = cluster_songs.copy().reset_index(drop=True)

# defining X and y 
X = recomm_songs[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
       'time_signature']]
y = target_song[list(X_std.columns)]

#Standardizing
X_std = pd.DataFrame(scaler.transform(X), columns=X.columns)
y_std = pd.DataFrame(scaler.transform(y), columns=y.columns)

# %% [markdown]
# ## Ball Tree

# %%
from sklearn.neighbors import BallTree

# %%
#Calculating the distance between the target song to all the rest of the same cluster
tree = BallTree(X_std, metric= 'euclidean')    
dist, ind = tree.query(y, k=10)

# %%
# Tuning by some other parameters and showing the final results
final_feat = ['track', 'artist']
recommendation = recomm_songs.loc[list(ind[0])].query('billboard ==0').sort_values(by=['valence','speechiness',])
recommendation
# Out:
#                         track                     artist  \
# 131                Le bonheur               L'Entourloop
# 196    The Penniless Optimist  The Electric Swing Circus
# 170                      Fall             Swing Republic
# 58               Metal Reggae                 Adão Negro
# 161  Fever - Pagany Jazzy Mix                 Jazz Juice
# 153     We No Speak Americano            Yolanda Be Cool
#
#                                tracks_uri  decade  billboard  \
# 131  spotify:track:50x8tChpDOmtHIX3mdUqWk  2010.0        0.0
# 196  spotify:track:1VmReZno6HCogQfamIMNzs  2010.0        0.0
# 170  spotify:track:36twTEaOCQ68AYe8DYKU4P  2010.0        0.0
# 58   spotify:track:46wyeXuUsoaQ8jeVRWRLzD  2000.0        0.0
# 161  spotify:track:0tkZSSlga53MxBstm3O9Js  2010.0        0.0
# 153  spotify:track:3SmzFvJKGjsNTnMu7TCvCF  2010.0        0.0
#
#                                             art_genres  danceability  energy  \
# 131                                    ['future funk']         0.748   0.469
# 196                       ['electro swing', 'nu jazz']         0.759   0.701
# 170                       ['electro swing', 'nu jazz']         0.783   0.660
# 58                         ['axe', 'brazilian reggae']         0.831   0.429
# 161                                        ['nu jazz']         0.792   0.682
# 153  ['australian dance', 'australian house', 'bass...         0.860   0.595
#
#      key  loudness  ...  speechiness  acousticness  instrumentalness  \
# 131  4.0    -9.619  ...       0.0586      0.002250           0.08940
# 196  2.0    -8.836  ...       0.0421      0.074100           0.00785
# 170  2.0    -8.625  ...       0.0465      0.148000           0.00000
# 58   0.0    -8.433  ...       0.0465      0.029600           0.00000
# 161  0.0    -8.686  ...       0.0468      0.000972           0.17000
# 153  3.0    -9.273  ...       0.0648      0.046800           0.37200
#
#      liveness  valence    tempo  time_signature  cluster  is_recommended  \
# 131    0.0660    0.191  140.024             4.0       21               1
# 196    0.1180    0.465  122.017             4.0       21               1
# 170    0.0739    0.475  122.979             4.0       21               1
# 58     0.2260    0.485  130.568             4.0       21               1
# 161    0.0757    0.542  125.001             4.0       21               1
# 153    0.0824    0.545  124.987             4.0       21               1
#
#      Topic
# 131      8
# 196      0
# 170      0
# 58       2
# 161      0
# 153      0
#
# [6 rows x 21 columns]

# %%
def get_url (df, sp_ac = access_spotify()):

    url_list=[]
    for artist in df.artist:
        sp = sp_ac
        link = sp.search(q=f"artist:{artist}", limit=1, type='artist')['artists']['items'][0]['external_urls']['spotify']
        url_list.append(link)
    return url_list

# %% [markdown]
# # Deploy: Streamlit

# %%
df = pd.read_csv('data/analysis/everynoise_genres.csv')
df
# Out:
#                         genres
# 0               latin shoegaze
# 1        norwegian psychedelic
# 2      progressive power metal
# 3        indonesian indie rock
# 4                 operatic pop
# ...                        ...
# 4345         experimental rock
# 4346                     drone
# 4347  rock progresivo mexicano
# 4348            ambient techno
# 4349        experimental synth
#
# [4350 rows x 1 columns]

# %%
df.to_csv('data//analysis/everynoise_genres.csv', index=False)

# %% [markdown]
# # Classes & Functions

# %% [markdown]
# ## Pipeline

# %%
class AudioFeatures():
    
    def __init__(self):     
        pass
    
    def fit(self, X, y=None):
        '''
        `.fit()` method needs to return the object itself
        '''
        return self
    
    def transform(self, X):
        '''
        `.transform()` method needs to return a transformed data like X
        '''
        features = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
       'time_signature'] 
        
        X = X[features]
        
        return X

# %% [markdown]
# ## Clean Artist's names

# %%
def clean_name(df:pd.DataFrame, column_name:str)-> pd.DataFrame:
    '''
    This function cleans the artist's name column of a dataframe and 
    returns the df with the respective column containing only the main name
    '''
    
    import re
    
    df = df.reset_index(drop=True)

    for i in range(df.shape[0]):
        string = df.loc[i,'artist']
        pattern ='(?:Feat(?:\. |uring )|, |\/|\+|&| [Xx] | \(|\)| [Ww]ith | And | y )'
        artists = re.split(pattern, string)
        df.loc[i, 'artist'] = artists[0]
    return df

# %% [markdown]
# ## Spotify API functions

# %%
def get_sptf_link(track_uri):
    'external_urls'

# %%
def access_spotify():
    '''
    this function initializes spotify access 
    '''
    import spotipy
    import spotipy.util as util
    from spotipy.oauth2 import SpotifyClientCredentials
    
    # Credentials
    client_id= '1337a27731b840f98acd0c79f0d011f3'
    client_secret = '98f2df2fdde44f40ad768a8142b20074'
    response_type = 'code'
    redirect_uri = 'https://aceworld.com.br/'
    state= 'https%3A%2F%2Faceworld.com.br%2F'
    scope = 'playlist-read-private scope'
    username = 'dnekdiptrsu4rr1heu145y07j'
    playlist = 'spotify:playlist:2QDyvRV0Ct7bGg3AREkL6P'

    #Accessing with token
    scope = 'user-library-read playlist-read-private'
    try:
        token = util.prompt_for_user_token(username, scope,client_id=client_id, 
                                           client_secret=client_secret, 
                                           redirect_uri=redirect_uri)
        sp=spotipy.Spotify(auth= token)
    except:
        print('Token is not accesible for ' + username)

    return sp

# %%
def get_artist_stats(df=False, artist_name: str = 'None', billboard_col: bool = False,
                     spotify_access=access_spotify())-> pd.DataFrame:
    
    '''
    This function receives a dataframe containing a column with artists' names ('artist')
    or a single artist name and the spotify authenticated access to make the requests, 
    and returns a new dataframe, containing the spotify attributes for that artist:
        - artist spotify id (uri)
        - number of followers
        - genres
        - popularity
    
    <parameters>
    df: a DataFrame or 'False' if the request will be for a single artist
    billboard_col: True if the input df already contains a target 
                    column named 'billboard'.
    spotify_access: function that accesses spotify authorization token, 
                    by default: access_spotify()
    '''
    import time
    
    sp = spotify_access
    artists=[]
    uris = []
    followers = []
    genres =[]
    popularities = []
    error_artists = []
    billboard_targets = []
    
    if df == False and artist_name != 'None':
        artist = artist_name
        q = f'artist:{artist}'
        try:
            results = sp.search(q=q, limit=1, type='artist')['artists']['items'][0]
        except:
            try:
                sp=access_spotify()
                results = sp.search(q=q, limit=1, type='artist')['artists']['items'][0]
            except:
                pass
            
        df_final = pd.DataFrame({'artist': artist,
                     'uri': results['uri'],
                     'followers': results['followers']['total'],
                     'genres': [results['genres']],
                     'popularity': results['popularity'],
                     'billboard': ''})
        
    else: 
        for i in range(df.index[0], df.shape[0]):
            artist = df.loc[i, 'artist']
            q = f'artist:{artist}'

            try:
                results = sp.search(q=q, limit=1, type='artist')['artists']['items'][0]
                print (artist)
            except:
                try:
                    print ('refreshing token')
                    sp=access_spotify()
                    results = sp.search(q=q, limit=1, type='artist')['artists']['items'][0]
                except:
                    print ('error:', artist)
                    pass

            artists.append(artist)
            uris.append(results['uri'])
            followers.append(results['followers']['total'])
            genres.append(results['genres'])
            popularities.append(results['popularity'])
            # if input df contains 'billboard' column
            if billboard_col == True:
                billboard_targets.append(df.loc[i, 'billboard'])
            else:
                pass

            df_2 = pd.DataFrame({'artist': artists,
                                 'uri': uris,
                                 'followers': followers,
                                 'genres': genres,
                                 'popularity': popularities,
                                 'billboard': billboard_targets})
            # saving a version to .csv
            df_2.to_csv('data/processed/artists_stats_process.csv', index=False)

    # saving final version to .csv    
        df_final = df_2
        df_final.to_csv('data/processed/artists_stats_final.csv', index=False)

    return df_final

# %%
def get_audio_features(df=False, track_title:str='None', artist_name:str='None',
                      spotify_access=access_spotify())-> pd.DataFrame:
    '''
    This function receives a dataframe containing tracks' Spotify uris 
    or a single track title and
    and returns a dataframe with the track's audio features.
    
    <parameters>
    df: a DataFrame or 'False' if the request will be made for a single track
    spotify_access: function that accesses spotify authorization token, 
                    by default: access_spotify()
    '''
    feat_df = pd.DataFrame()
    pop=[]
    art_genres=[]
    cluster=[]
    
    if df == False :
        q= f'track:{track_title} artist:{artist_name}'
        sp=access_spotify()
        results = sp.search(q=q, limit=1, type='track')
        track_title =results['tracks']['items'][0]['name']
        tracks_uri = results['tracks']['items'][0]['uri']
        artist_name = results['tracks']['items'][0]['artists'][0]['name']
        artist_uri = results['tracks']['items'][0]['artists'][0]['uri'] 
        
        audio_feat = sp.audio_features(track_uri)
        art_genres = sp.artist(artist_uri)['genres']
        cluster= ''
        
        new_df = pd.concat([pd.DataFrame([[
            track_title, artist_name,tracks_uri, artist_uri, art_genres,cluster]], 
            columns=['track','artist','tracks_uri','artist_uri','art_genres', 'cluster']), 
                            pd.DataFrame(audio_feat)], axis=1)
    else:
        saved_uris = list(df.tracks_uri)

        for uri in saved_uris:
            feat_df = feat_df.append(pd.DataFrame(sp.audio_features(uri)))
            track_req=sp.track(uri)
            pop.append(track_req['popularity'])
            art_genres.append(sp.artist(track_req['artists'][0]['uri'])['genres'])
            cluster.append('')

        new_df = pd.concat([df, feat_df.reset_index(drop=True), 
                            pd.DataFrame(pop, columns=['popularity']),
                            pd.DataFrame(art_genres, columns=['art_genres']),
                            pd.DataFrame(cluster, columns=['cluster'])], axis=1)
    
    
    new_df = new_df [['track', 'artist', 'tracks_uri', 'art_genres',
       'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
       'time_signature', 'cluster']]
    
    return new_df

# %% [markdown]
# ## Billboard API functions

# %%
def get_billboard_charts_data(chart_types: list) -> pd.DataFrame:
    '''
    This function retrieves data from the given list of chart types:
        - song title
        - artist name
        - chart name
    > for more information about chart_types: access 'billboard.charts()'
    '''
    
    df=pd.DataFrame()
    title_list=[]
    artist_list=[]
    chart_name=[]

    for chart_type in chart_types:
        chart = billboard.ChartData(chart_type)
        for song in chart:
            title_list.append(song.title)
            artist_list.append(song.artist)
            chart_name.append(chart.name)

        df = pd.DataFrame({'title':title_list, 
                       'artist':artist_list, 
                       'chart':chart_name})
        df.to_csv('data/raw/billboard_artists_process.csv', index=False)
    
    df=df.drop_duplicates()
    df.to_csv('data/raw/billboard_artists.csv', index=False)
    
    return df

# %% [markdown]
# ## Recommendation System Flow

# %%
# Adding new target based on number of followers:
def artist_recommended(df):
    df['is_recommended'] = df.followers.apply(lambda x: 0 if x > 400000 else 1)
    return df

# %%
def get_audio(audio_type:str)-> str:
    '''
    this function receives a speaked audio and transforms it into written text
    you must specify the type between: 'artist' or 'title'
    '''
    import speech_recognition as sr
    import time
    
    r = sr.Recognizer()
    sec = 4
    
    if audio_type == 'title':
        print(f'Tell us the title of a song you like :)')
    elif audio_type == 'artist':
        print(f'Tell us the artist who sings that song')
    else:
        raise ValueError ('audio_type must be "artist" or "title"')
    
    with sr.Microphone() as source:
        # read the audio data from the default microphone
        print(f"Listening... (you've got {sec} seconds)")
        try:
            audio_data = r.record(source, duration=sec)
        except:
            print(f"I didn't hear you, would you repeat please?")
            print(f"Listening... (you've got {sec} seconds)")
        # convert speech to text
        print("Processing...")
        user_input = r.recognize_google(audio_data)
        
        return user_input

# %%
def get_text(text_type:str)-> str:
    '''
    this function receives a written text
    you must specify the type between: 'artist' or 'title'
    '''
    if text_type == 'title':
        user_input = str(input(f'Tell us the title of a song you like :)'))
    elif text_type == 'artist':
        user_input = str(input(f'Tell us the artist who sings that song'))
    else:
        raise ValueError ('audio_type must be "artist" or "title"')    

    return user_input

# %%
def check_input(song_input: str, artist_input: str)-> list:
    '''
    this function receives an input and confirms if the title was well captured.
    returns a list containing:
        - in position [0]: string (the song title)
        - in position [1]: string (the artist name)
        - in position [2]: bool (0 if not found in database, 1 if found in database)
    '''
    import textdistance
    import time
    n=4

    # assuring if it got the song correctly:     
    try:
        song_lev_dists = songs.track.apply(lambda x:textdistance.levenshtein.normalized_similarity(
                           song_input, x)).sort_values(ascending=False).head(n)
        song_recomm_index = list(song_lev_dists.index)
        song_recomm = songs.loc[song_recomm_index,['track', 'artist']]
        song_recomm['song_dist']=song_lev_dists
        song_recomm['art_dist']= song_recomm.artist.apply(lambda x:textdistance.levenshtein.normalized_similarity(
                           artist_input, x))
        final_recomm = song_recomm.sort_values(by=['song_dist', 'art_dist'], ascending=False)
        final_recomm = final_recomm.query('art_dist > 0.5 and song_dist > 0.5').head(1)
        final_recomm_song = songs.loc[final_recomm.index[0],'track']
        final_recomm_artist = songs.loc[final_recomm.index[0],'artist']    

        # assuring the artist is the same
        if song_lev_dists[final_recomm.index[0]] >= 0.6:
            validate = str(input(f'You chose "{final_recomm_song}" by {final_recomm_artist}, right? (y/n)'))

        elif song_lev_dists[final_recomm.index[0]] < 0.6 and song_lev_dists[final_recomm.index[0]] >= 0.4:
            validate = str(input(f'Did you mean: "{final_recomm_song}" by {final_recomm_artist}? (y/n)'))

        if validate in ['y', 'yes', 'Y', 'Yes', 'YES','sim','Sim','S', 's','SIM']:
            return [final_recomm_song, final_recomm_artist, 1]
        else:
            ## Look for 
            return [song_input, artist_input, 0]
    except:
        validate = str(input(f'You chose "{song_input}" by {artist_input}, right? (y/n)'))
        if validate in ['y', 'yes', 'Y', 'Yes', 'YES','sim','Sim','S', 's','SIM']:
            return [song_input, artist_input, 0]
        else:
            print("We're sorry, we couldn't find this song :(")

# %%
# look for the song in the songs database

def target_process(user_input: list)-> list:
    '''
    This function processes the target song, and clusterizes it given its features
    returns a list containing:
        - target_song
        - target_cluster
    It also saves to the database new songs/artists.
    '''
    
    songs = pd.read_csv('data/final/songs.csv')
    artists = pd.read_csv('data/final/artists.csv')

    if user_input[2] == 1:
        target_song = songs.query(f'track == "{user_input[0]}"')
        target_index = target_song.index[0]
        target_cluster =  songs.loc[target_index, 'cluster']
        target_artist = songs.loc[target_index, 'artist']
        print('found in the database')
    else:
        print('not found in the database, retrieving infos from spotify')

        # look for song in spotify
        target_song = get_audio_features(track_title=user_input[0], artist_name=user_input[1])
        pipeline.transform(target_song)
        target_song['cluster'] = pipeline.predict(target_song)

        # adding new song to songs database
        if target_song.track[0] not in list(songs.track):
            songs = pd.concat([songs, target_song], axis=0).reset_index(drop=True)
            songs.to_csv('data/final/songs.csv', index=False)

        #ADDING new artist to artist database_
        target_artist = target_song.artist[0]
        new_art = artist_recommended(get_artist_stats(artist_name=target_artist))
        if new_art.artist[0] not in list(artists.artist):
            artists = pd.concat([artists, new_art]).reset_index(drop=True)
            artists.to_csv('data/final/artists.csv', index=False)        
        print("we're all set")
    
    return [target_song, target_cluster]

# %%
def get_recomm_songs (target_cluster: int) -> pd.DataFrame:
    '''
    this function receives the target cluster label, filters songs dataset by 
    cluster and target artists (non famous artists)
    '''
    
    # filter song dataset by target artists
    recomm_artists = artists.query('is_recommended == 1').loc[:,['artist', 'followers', 'popularity']]


    # filter songs dataset by cluster
    cluster_songs = songs.loc[songs.cluster == target_cluster]

    # filter songs by artist (is_recommended or not)
    cluster_songs['is_recommended'] = cluster_songs.artist.apply(lambda x: 1 if x in list(recomm_artists.artist) else 0)
    cluster_songs = cluster_songs.loc[cluster_songs.is_recommended == 1]
    cluster_songs = cluster_songs.loc[cluster_songs.decade > 1990]

    cluster_songs = cluster_songs.loc[cluster_songs.art_genres != "[]",:]
    
    return cluster_songs

# %% [markdown]
# ## Other

# %%
def remove_outlier(df_in:pd.DataFrame, col_name:str):
    '''
    this function accepts a dataframe, removes outliers, 
    returns a list, containing:
        - [0] new dataframe filtering outliers
        - [1] tuple, containing low, high fences of outliers
    '''
    q1 = df_in[col_name].quantile(0.25)
    q3 = df_in[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    return [df_out, (fence_low, fence_high)]

# %% [markdown]
# # Sources and References

# %% [markdown]
# ## Databases & APIs

# %% [markdown]
# > `Spotify`
# - Official Documentation: https://developer.spotify.com/documentation/web-api/reference/
# - spotipy: Python module for Spotify's API (https://pypi.org/project/spotipy/)
#
# > `Billboard`
# - billboard.py: Python module for Billboard's API (https://pypi.org/project/billboard.py/)
# - github: (https://github.com/guoguo12/billboard-charts)
#
# > `Kaggle`
# - hit predictor: https://www.kaggle.com/theoverman/the-spotify-hit-predictor-dataset
#
# > `Genres`
# - Every noise at once: http://everynoise.com/#otherthings
#
# > `Chartmetric`
# - https://blog.chartmetric.com/genre-specific-music-recommendations/

# %% [markdown]
# ## Requirements

# %%
def get_imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            name = val.__name__.split(".")[0]
        elif isinstance(val, type):
            name = val.__module__.split(".")[0]
        poorly_named_packages = {
            "PIL": "Pillow",
            "sklearn": "scikit-learn"
        }
        if name in poorly_named_packages.keys():
            name = poorly_named_packages[name]
        yield name
        
imports = list(set(get_imports()))
requirements = []
for m in pkg_resources.working_set:
    if m.project_name in imports and m.project_name!="pip":
        requirements.append((m.project_name, m.version))
for r in requirements:
    print("{}=={}".format(*r))
